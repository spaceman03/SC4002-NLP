# %% [markdown]
# # Part 0: Data Preparation

# %%
# !pip install datasets
# !pip install nltk

# %%
from datasets import load_dataset
dataset = load_dataset("rotten_tomatoes")
train_dataset = dataset['train']
validation_dataset = dataset['validation']
test_dataset = dataset['test']

# %% [markdown]
# # Part 1: Preparing Word Embeddings

# %% [markdown]
# As the first step of building your model, you need to prepare the word embeddings to form the input layer of your model. You are required to choose only from **Word2vec** or **Glove** to initialize your word embedding matrix. The word embedding matrix stores the pre-trained word vectors (taken from Word2vec or Glove) where each row corresponds to a vector for a specific word in the vocabulary formed from your task dataset.set.

# %%
import gensim.downloader
import matplotlib.pyplot as plt
import nltk
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from gensim.models import KeyedVectors
import gensim.downloader as api
import re
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\JamesYS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Question 1. Word Embedding

# %% [markdown]
# ### (a) What is the size of the vocabulary formed from your training data?

# %%
# import re
# from nltk.tokenize import word_tokenize
# import nltk

# # Download the necessary tokenizer data
# nltk.download('punkt')

# # Define a function to clean and tokenize text
# def clean_token(text):
#     # Replace specific punctuation with spaces
#     text = text.replace('-', ' ').replace('/', ' ')
#     # Remove all other punctuation, including special characters
#     text = re.sub(r'[^\w\s]', '', text)
#     return text

# # Define a function to tokenize text
# def tokenize(text):
#     # Clean the text first
#     text = clean_token(text.lower())  # Convert to lowercase for consistency
#     # Tokenize the cleaned text
#     tokens = word_tokenize(text)
#     return tokens

# # Example usage


# # Create a set to store unique tokens
# unique_tokens = set()

# # Tokenize each example and update the set of unique tokens
# for example in train_dataset:
#     tokens = tokenize(example['text'])
#     unique_tokens.update(tokens)  # Add tokens from each example to the set

# # Output the number of unique tokens and the tokens themselves
# print(f"Number of unique tokens: {len(unique_tokens)}")
# print("Unique tokens:", unique_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\JamesYS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Number of unique tokens: 16995
# Unique tokens: {'lends', 'creators', 'dunsts', 'shrapnel', 'gimmick', 'greed', 'popcorn', 'peso', 'composer', 'agreed', 'demonstrate', 'servants', 'disobedience', 'war', 'niro', 'survivors', 'smarts', 'beause', 'contained', 'rounded', 'pryce', 'ghandi', 'virtues', 'editor', 'unreligious', 'sociology', 'obtuse', 'assed', 'town', 'fake', 'showmanship', 'noble', 'blank', 'playbook', 'bucks', 'laughed', 'agers', 'improbabilities', 'stuntwork', 'multiplex', 'winsome', 'among', 'error', 'adore', 'destination', 'named', 'communicate', 'cultura', 'notice', 'prequel', 'sweetheart', 'biographical', 'flight', 'chopsocky', 'dysfunctionally', 'nowadays', 'lilias', 'philibert', 'sexually', 'usher', 'grub', 'reviewers', 'cabins', 'manufactured', 'quasi', 'purr', 'neo', 'streamlined', 'older', 'python', 'charles', 'sandbox', 'ramsay', 'roteirista', 'tomorrow', 'hicks', 'summery', 'counterpart', 'assures', 'bmw', 'adoration', 'specialized', 'races', 'doctor', 'spinoffs', 'rental', 'nightclub', 'wit', 'wrap', 'backs', 'letting', 'pissed', 'cintas', 'hardscrabble', 'archival', 'todays', 'sorvinos', 'rowdy', 'bola', 'chilling', 'aged', 'denzel', 'firsthand', 'shots', 'actuada', 'snoozy', 'outrun', 'scripted', 'embellishing', 'monkeys', 'disneys', 'iran', 'cogent', 'atrocious', 'longest', 'destined', 'leonard', 'vacation', 'fourth', 'monte', 'limits', 'niros', 'extravaganzas', 'tolerate', 'resonance', 'apted', 'genesis', 'circle', 'acute', 'bow', 'luther', 'judge', 'pearl', 'wilcos', 'territory', 'life', 'transition', 'throat', 'deriding', 'areas', 'integrated', 'sunburn', 'anachronistic', 'forward', 'candle', 'wollter', 'bw', 'divided', 'doubled', 'spook', 'kieslowskis', 'awry', 'profanity', 'kasem', 'stretches', 'oatmeal', 'crossover', 'create', 'womens', 'emigre', 'smugly', 'plants', 'flailing', 'adultery', 'apollo', 'inspires', 'rousing', 'hidebound', 'drippiness', 'non', 'tribulations', 'comedies', 'interviewees', 'tuck', 'excellent', 'compulsively', 'unromantic', 'girls', 'countless', 'please', 'respites', 'martins', 'seagal', 'recite', 'outweighs', 'runner', 'flaunts', 'helmer', 'framework', 'errs', 'hammering', 'seemingly', 'heist', 'tvs', 'shindlers', 'rebellion', 'europe', 'avary', 'toxic', 'everlyn', 'change', 'noyces', 'convincingly', 'claire', 'destiny', 'igualmente', 'moods', 'nenette', 'baby', 'hedonistic', '12', 'changing', 'confirming', 'repairing', 'recoiling', 'inert', 'woos', 'reginald', 'breezes', 'diggs', 'cavaradossi', 'pulp', 'phoniness', '60', 'invited', 'bvs', 'ladies', 'fires', 'kills', 'leafing', 'china', 'dia', 'such', 'mcculloch', 'graham', 'retains', '15th', 'godard', 'heartening', 'romanticization', 'suicide', 'roberto', 'intrinsically', 'existing', 'unrealistic', 'burnt', 'beseechingly', 'virtuosity', 'flashy', 'followers', 'underwear', 'journalists', 'steak', 'unimaginative', 'employs', 'mejores', 'uninspired', 'pootie', 'outlet', 'amorality', 'curdling', 'superlarge', 'pointed', 'received', 'puccini', 'banging', 'banal', 'heaviest', 'mediocre', 'culkin', 'bearable', 'screwed', 'impersonation', 'miles', 'overtake', 'superb', 'bessons', 'hobby', 'porno', 'ideal', 'bangs', 'exhibit', 'crystals', 'zigzag', 'hos', 'beautifully', 'promenade', '18', 'mentioned', 'crime', 'richly', 'offsets', 'nurses', 'surround', 'ferris', 'album', 'void', 'context', 'shown', 'problems', 'sprinkled', 'intimate', 'disgust', 'deleted', 'instances', 'guitar', '28k', 'melange', 'hayek', 'crackles', 'palestinian', 'programmer', 'bouncy', 'waterboy', 'palatable', 'vivi', 'jumps', 'way', 'beckett', 'farenheit', 'remembers', 'surviving', 'sacred', 'riffs', 'episódio', 'unconcerned', 'abrams', 'pratfalls', 'raptures', 'unemployment', 'amnesiac', 'attempted', 'friggin', 'justify', 'transform', 'requiem', 'unexplored', 'delve', 'fascism', 'spins', 'endeavor', 'visualized', 'civilized', 'interests', 'temptation', 'gauzy', 'detail', 'helene', 'stevens', 'subcontinent', 'descent', 'function', 'rote', 'adventure', 'ouro', 'limit', 'curls', 'bully', 's ...

# %%
tokens = []
tokenized_sentences = [nltk.tokenize.word_tokenize(sentence['text'].lower()) for sentence in train_dataset]

for sentence in train_dataset:
    tokens.extend(nltk.tokenize.word_tokenize(sentence['text'].lower()))

print ('Number of tokens: '+ str(len(tokens)))
# Out:
# Number of tokens: 183968

# %%
# List of all distinct words found in the tokens list
vocab = list(set(tokens))
vocab_size = len(vocab)
print ('Number of token types (Vocabulary Size): '+ str(vocab_size))
# Out:
# Number of token types (Vocabulary Size): 18029

# %% [markdown]
# (a) The size of vocabulary formed from the training data is 18029.

# %% [markdown]
# ### (b) We use OOV (out-of-vocabulary) to refer to those words appeared in the training data but  not in the Word2vec (or Glove) dictionary. How many OOV words exist in your training data?

# %%
# word2vec_model = gensim.downloader.load('word2vec-google-news-300')
# embedding_dim = word2vec_model.vector_size
# print("Embedding dimension:", embedding_dim)

# %%
glove_file = './glove.840B.300d/glove.840B.300d.txt'  # adjust path and file name accordingly

# Convert the GloVe format to Gensim's Word2Vec format
glove_model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

# Print the embedding dimension to verify
embedding_dim = glove_model.vector_size
print("Embedding dimension:", embedding_dim)
# Out:
# Embedding dimension: 300

# %%
# Initialize the embedding matrix
embedding_matrix = np.zeros((vocab_size, embedding_dim))
oov_words = []

# Map vocabulary to embedding matrix
word_to_idx = {word: idx for idx, word in enumerate(vocab)}

for word, idx in word_to_idx.items():
    if word in glove_model:
        embedding_matrix[idx] = glove_model[word]
    else:
        # Count OOV words
        oov_words.append(word)

# OOV words count
oov_count = len(oov_words)
print("Number of OOV words:", oov_count)
# Out:
# Number of OOV words: 1387

# %% [markdown]
# (b) There are **3612** OOV words in the training data.

# %% [markdown]
# ### (c) The existence of the OOV words is one of the well-known limitations of Word2vec (or Glove). Without using any transformer-based language models (e.g., BERT, GPT, T5), what do you think is the best strategy to mitigate such limitation? Implement your solution in your source code. Show the corresponding code snippet.

# %% [markdown]
# #### Method: Cosine Similarity

# %% [markdown]
# Find replacement words for OOV based on cosine similarity. The steps are:
# 1. Converting the OOV word into a vector (by summing the embeddings of its subwords or by using a neighboring word’s embedding).
# 2. Selecting replacement candidates based on similarity in the vector space.
# 3. Calculating cosine similarity between the OOV word and replacement candidates.
# 4. Choosing a candidate with a high cosine similarity score, ideally close to 1, as the replacement.

# %% [markdown]
# (c) We use the **Cosine Similarity** method to handle OOV words. The advantages of using this method is that it is scale-invariant, focusing on the direction of word vectors instead of their magnitude, making it ideal for comparing word embeddings. It is also an efficient method as it replaces the OOV words by finding a close semantic replacement within the existing vocabulary.
#
# The function used to find the replacement word is defined as `find_replacement_word` below.
#
# For each OOV word, our function `find_replacement_word` attempts to find semantically similar words by first checking if subwords or morphemes (like prefixes or suffixes) have embeddings within the pre-trained model. If these subwords exist, their embeddings are averaged to create a composite vector representing the OOV word.
#
# Once the composite OOV vector is generated, we use cosine similarity to find the most similar words within the vocabulary. By comparing directional alignment rather than vector magnitude, cosine similarity efficiently identifies a word that has the closest semantic relation to the OOV term.
#
# If a replacement word is found, we assign the vector of this replacement to the OOV word’s slot in the embedding matrix. If no suitable replacement exists, a vector of random values (drawn from a normal distribution) is assigned. This ensures that the embedding matrix is fully populated, preventing model errors.

# %%
# Define a function to find replacement words based on cosine similarity
def find_replacement_word(oov_word, model, topn=5):
    subword_vectors = [model[word] for word in oov_word if word in model]

    if subword_vectors:  # If there are subwords with embeddings
        # Generate vector for OOV by averaging embeddings of subwords
        oov_vector = np.mean(subword_vectors, axis=0)

        # Find similar words to this estimated vector
        similar_words = model.similar_by_vector(oov_vector, topn=topn)

        # Return the word with highest similarity
        return similar_words[0][0] if similar_words else None

    return None

# %%
# # Populate embedding matrix and handle OOV words
# for word, idx in word_to_idx.items():
#     if word in word2vec_model:
#         embedding_matrix[idx] = word2vec_model[word]
#     else:
#         # Handle OOV words
#         oov_words.append(word)
#         replacement_word = find_replacement_word(word, word2vec_model)

#         if replacement_word:
#             embedding_matrix[idx] = word2vec_model[replacement_word]  # Use replacement word vector
#         else:
#             embedding_matrix[idx] = np.random.normal(size=(embedding_dim,))  # Random initialization if no replacement found

# %% [markdown]
# # Part 2: Model Training & Evaluation - RNN

# %% [markdown]
# Now with the pretrained word embeddings acquired from Part 1 and the dataset acquired from Part 0, you need to train a deep learning model for sentiment classification using the training set, conforming to these requirements:
# - Use the pretrained word embeddings from Part 1 as inputs; do not update them during training (they are “frozen”).
# - Design a simple recurrent neural network (RNN), taking the input word embeddings, and predicting a sentiment label for each sentence. To do that, you need to consider how to aggregate the word representations to represent a sentence.
# - Use the validation set to gauge the performance of the model for each epoch during training. You are required to use **accuracy** as the performance metric during validation and evaluation.
# - Use the mini-batch strategy during training. You may choose any preferred optimizer (e.g., SGD, Adagrad, Adam, RMSprop). Be careful when you choose your initial learning rate and mini-batch size. (You should use the validation set to determine the optimal configuration.) Train the model until the **accuracy** score on the validation set is not increasing for a few epochs.
# - Evaluate your trained model on the test dataset, observing the **accuracy** score.

# %% [markdown]
# ## Question 2: RNN

# %% [markdown]
# ### (a) Report the final configuration of your best model, namely the number of training epochs, learning rate, optimizer, batch size.

# %% [markdown]
# ### (b) Report the **accuracy** score on the test set, as well as the accuracy score on the validation  set for each epoch during training.

# %% [markdown]
# ### (c) RNNs produce a hidden vector for each word, instead of the entire sentence. Which methods have you tried in deriving the final sentence representation to perform sentiment classification? Describe all the strategies you have implemented, together with their accuracy scores on the test set.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
from torch.nn.utils.rnn import pad_sequence

# %%
# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print(f"Using device: {device}")
# device = 'cpu'

# %%
# Initialize an empty dictionary to store test accuracies
test_accuracies = {}

# %%
max_length = max(len(item) for item in tokens)

# %%
def prepare_data(dataset, word_to_idx, max_len):
    sequences = []
    labels = []

    for sentence in dataset:
        tokenized = nltk.tokenize.word_tokenize(sentence['text'].lower())
        indices = [word_to_idx[word] for word in tokenized if word in word_to_idx]
        sequences.append(torch.tensor(indices[:max_len]))  # Trim to max_len
        labels.append(sentence['label'])

    # Pad sequences to ensure all are the same length
    padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=0)

    # Convert labels to tensor
    labels = torch.tensor(labels)

    return padded_sequences, labels

# %% [markdown]
# (c) For deriving sentence representations, we implemented different strategies:
# - **Last Hidden State**: Use the last hidden state of the RNN.
# - **Max Pooling**: Take the maximum hidden state across all words.
# - **Average Pooling**: Average the hidden states across all words.

# %%
class LastHiddenRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(LastHiddenRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Aggregate using the last hidden state
        last_hidden = hidden[-1]
        output = self.fc(last_hidden)
        return output

class MaxPoolingRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(MaxPoolingRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Max pooling over all hidden states
        max_pooled, _ = torch.max(rnn_output, dim=1)
        output = self.fc(max_pooled)
        return output

class AveragePoolingRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(AveragePoolingRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, _ = self.rnn(embedded)

        # Average pooling over the hidden states
        mean_pooled = rnn_output.mean(dim=1)  # Take the mean across the sequence length dimension
        output = self.fc(mean_pooled)  # Pass through the fully connected layer
        return output

# %%
# Training function
def train_one_epoch(model, train_loader, optimizer, criterion):
    model.train()  # Set model to training mode
    train_loss = 0
    train_correct = 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to device
        optimizer.zero_grad()  # Clear gradients
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights

        # Accumulate loss and accuracy
        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    # Calculate average accuracy and loss
    train_acc = train_correct / total_train
    train_loss /= len(train_loader)  # Average loss per batch

    return train_loss, train_acc

# Validation function
def evaluate_model(model, loader):
    model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():  # Disable gradient computation for validation
        for inputs, labels in loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    return correct / total  # Return validation accuracy

# Training loop with validation
def train_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience=3):
    best_val_acc = 0
    epochs_no_improve = 0

    train_losses = []
    train_accuracies = []
    val_accuracies = []

    model = model.to(device)

    for epoch in range(epochs):
        # Training step
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Validation step
        val_acc = evaluate_model(model, validation_loader)
        val_accuracies.append(val_acc)

        # Print training and validation results
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}')

        # Early stopping logic
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            epochs_no_improve = 0
            best_model = model.state_dict()  # Save best model
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print("Early stopping")
            break

    model.load_state_dict(best_model)  # Load the best model weights

    return model, train_losses, train_accuracies, val_accuracies

# %%
# Define hyperparameter search space
learning_rates = [0.001, 0.005, 0.01, 0.1]
batch_sizes = [16, 32, 64]
optimizers = ['SGD', 'Adam', 'RMSprop']

# %%
def train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience):
    # Training the model (uses functions defined earlier for training and evaluation)
    model, train_losses, train_accuracies, val_accuracies = train_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)

    # Get best validation accuracy
    best_val_acc = max(val_accuracies)

    return best_val_acc, train_losses, train_accuracies, val_accuracies

# %%
def run_grid_search(model_class, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                    validation_sequences, validation_labels, criterion, epochs, patience):

    best_val_acc = 0
    best_hyperparams = {}

    # Prepare datasets
    train_data = TensorDataset(train_sequences.to(device), train_labels.to(device))
    validation_data = TensorDataset(validation_sequences.to(device), validation_labels.to(device))

    for lr in learning_rates:
        for batch_size in batch_sizes:
            for opt in optimizers:
                print(f"Training with lr={lr}, batch_size={batch_size}, optimizer={opt}")

                # Set up DataLoader with the current batch size
                train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
                validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)

                # Initialize a new model for each set of hyperparameters
                model = model_class(embedding_matrix=embedding_matrix, hidden_dim=hidden_dim, output_dim=output_dim)  # Reinitialize model
                model = model.to(device)

                # Choose optimizer
                if opt == 'SGD':
                    optimizer = optim.SGD(model.parameters(), lr=lr)
                elif opt == 'Adam':
                    optimizer = optim.Adam(model.parameters(), lr=lr)
                elif opt == 'RMSprop':
                    optimizer = optim.RMSprop(model.parameters(), lr=lr)

                # Train and evaluate the model
                val_acc, _, _, _ = train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)


                # Track the best configuration based on validation accuracy
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_hyperparams = {'lr': lr, 'batch_size': batch_size, 'optimizer': opt}

    print(f"Best Validation Accuracy: {best_val_acc}")
    print(f"Best Hyperparameters: {best_hyperparams}")

    return best_hyperparams

# %%
# Prepare the train, validation, and test datasets
train_sequences, train_labels = prepare_data(train_dataset, word_to_idx, max_length)
validation_sequences, validation_labels = prepare_data(validation_dataset, word_to_idx, max_length)
test_sequences, test_labels = prepare_data(test_dataset, word_to_idx, max_length)

# %%
train_sequences = train_sequences.to(device)
train_labels = train_labels.to(device)
validation_sequences = validation_sequences.to(device)
validation_labels = validation_labels.to(device)
test_sequences = test_sequences.to(device)
test_labels = test_labels.to(device)

# %%
# Plot accuracy scores
def plot_metrics(epochs, train_losses, train_accuracies, val_accuracies):
    # Epochs range
    epoch_range = range(1, epochs + 1)

    # Plot Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epoch_range, train_losses, label='Train Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Epoch vs Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epoch_range, train_accuracies, label='Train Accuracy')
    plt.plot(epoch_range, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Epoch vs Accuracy')
    plt.legend()

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) RNN Last Hidden State

# %%
# Call grid search
best_hyperparams_RNN_last = run_grid_search(LastHiddenRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                            validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6950, Train Acc: 0.5072, Val Acc: 0.5094
# Epoch 2, Train Loss: 0.6959, Train Acc: 0.4951, Val Acc: 0.5066
# Epoch 3, Train Loss: 0.6957, Train Acc: 0.4947, Val Acc: 0.5094
# Epoch 4, Train Loss: 0.6936, Train Acc: 0.5053, Val Acc: 0.5094
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7095, Train Acc: 0.5038, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7081, Train Acc: 0.5046, Val Acc: 0.4822
# Epoch 3, Train Loss: 0.7079, Train Acc: 0.5045, Val Acc: 0.5159
# Epoch 4, Train Loss: 0.7046, Train Acc: 0.5083, Val Acc: 0.5338
# Epoch 5, Train Loss: 0.7029, Train Acc: 0.5127, Val Acc: 0.5009
# Epoch 6, Train Loss: 0.7065, Train Acc: 0.5104, Val Acc: 0.5056
# Epoch 7, Train Loss: 0.7053, Train Acc: 0.5110, Val Acc: 0.4944
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7264, Train Acc: 0.4940, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.7154, Train Acc: 0.4961, Val Acc: 0.4991
# Epoch 3, Train Loss: 0.7117, Train Acc: 0.4919, Val Acc: 0.5066
# Epoch 4, Train Loss: 0.7104, Train Acc: 0.5008, Val Acc: 0.5028
# Epoch 5, Train Loss: 0.7080, Train Acc: 0.5086, Val Acc: 0.5084
# Epoch 6, Train Loss: 0.7098, Train Acc: 0.5075, Val Acc: 0.4991
# Epoch 7, Train Loss: 0.7081, Train Acc: 0.5130, Val Acc: 0.5281
# Epoch 8, Train Loss: 0.7095, Train Acc: 0.5110, Val Acc: 0.5000
# Epoch 9, Train Loss: 0.7109, Train Acc: 0.4943, Val Acc: 0.4897
# Epoch 10, Train Loss: 0.7102, Train Acc: 0.5041, Val Acc: 0.5141
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6950, Train Acc: 0.5025, Val Acc: 0.5038
# Epoch 2, Train Loss: 0.6955, Train Acc: 0.4959, Val Acc: 0.4925
# Epoch 3, Train Loss: 0.6947, Train Acc: 0.4975, Val Acc: 0.5075
# Epoch 4, Train Loss: 0.6949, Train Acc: 0.4973, Val Acc: 0.5047
# Epoch 5, Train Loss: 0.6949, Train Acc: 0.4964, Val Acc: 0.5094
# Epoch 6, Train Loss: 0.6953, Train Acc: 0.5018, Val Acc: 0.4925
# Epoch 7, Train Loss: 0.6941, Train Acc: 0.5030, Val Acc: 0.5056
# Epoch 8, Train Loss: 0.6944, Train Acc: 0.4972, Val Acc: 0.5113
# Epoch 9, Train Loss: 0.6949, Train Acc: 0.4958, Val Acc: 0.4925
# Epoch 10, Train Loss: 0.6940, Train Acc: 0.5027, Val Acc: 0.5094
# Epoch 11, Train Loss: 0.6940, Train Acc: 0.5090, Val Acc: 0.4925
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7026, Train Acc: 0.4993, Val Acc: 0.5113
# Epoch 2, Train Loss: 0.6954, Train Acc: 0.4996, Val Acc: 0.5056
# Epoch 3, Train Loss: 0.7111, Train Acc: 0.5013, Val Acc: 0.5122
# Epoch 4, Train Loss: 0.7057, Train Acc: 0.5142, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.7114, Train Acc: 0.5097, Val Acc: 0.5094
# Epoch 6, Train Loss: 0.7019, Train Acc: 0.5064, Val Acc: 0.5038
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7280, Train Acc: 0.5069, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7074, Train Acc: 0.5027, Val Acc: 0.5056
# Epoch 3, Train Loss: 0.7034, Train Acc: 0.5123, Val Acc: 0.5141
# Epoch 4, Train Loss: 0.7057, Train Acc: 0.5040, Val Acc: 0.5169
# Epoch 5, Train Loss: 0.7042, Train Acc: 0.5049, Val Acc: 0.5188
# Epoch 6, Train Loss: 0.7047, Train Acc: 0.5048, Val Acc: 0.4906
# Epoch 7, Train Loss: 0.7041, Train Acc: 0.5082, Val Acc: 0.5159
# Epoch 8, Train Loss: 0.7036, Train Acc: 0.5093, Val Acc: 0.5225
# Epoch 9, Train Loss: 0.7034, Train Acc: 0.5093, Val Acc: 0.5225
# Epoch 10, Train Loss: 0.7033, Train Acc: 0.5109, Val Acc: 0.5084
# Epoch 11, Train Loss: 0.7022, Train Acc: 0.5008, Val Acc: 0.4981
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6950, Train Acc: 0.5046, Val Acc: 0.5084
# Epoch 2, Train Loss: 0.6956, Train Acc: 0.4958, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.6964, Train Acc: 0.4834, Val Acc: 0.5094
# Epoch 4, Train Loss: 0.6947, Train Acc: 0.5028, Val Acc: 0.5094
# Epoch 5, Train Loss: 0.6946, Train Acc: 0.5063, Val Acc: 0.5094
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7039, Train Acc: 0.5008, Val Acc: 0.4962
# Epoch 2, Train Loss: 0.6963, Train Acc: 0.4971, Val Acc: 0.5047
# Epoch 3, Train Loss: 0.6948, Train Acc: 0.4994, Val Acc: 0.4991
# Epoch 4, Train Loss: 0.6971, Train Acc: 0.5117, Val Acc: 0.4831
# Epoch 5, Train Loss: 0.7096, Train Acc: 0.4975, Val Acc: 0.4906
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7293, Train Acc: 0.5052, Val Acc: 0.5113
# Epoch 2, Train Loss: 0.7023, Train Acc: 0.5125, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7040, Train Acc: 0.5008, Val Acc: 0.5178
# Epoch 4, Train Loss: 0.6998, Train Acc: 0.5101, Val Acc: 0.5103
# Epoch 5, Train Loss: 0.7023, Train Acc: 0.5045, Val Acc: 0.5028
# Epoch 6, Train Loss: 0.6987, Train Acc: 0.5093, Val Acc: 0.4794
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6966, Train Acc: 0.4948, Val Acc: 0.4944
# Epoch 2, Train Loss: 0.6955, Train Acc: 0.4970, Val Acc: 0.4953
# Epoch 3, Train Loss: 0.6947, Train Acc: 0.5016, Val Acc: 0.5056
# Epoch 4, Train Loss: 0.6950, Train Acc: 0.4954, Val Acc: 0.5019
# Epoch 5, Train Loss: 0.6944, Train Acc: 0.5068, Val Acc: 0.4972
# Epoch 6, Train Loss: 0.6942, Train Acc: 0.5013, Val Acc: 0.4953
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7546, Train Acc: 0.4981, Val Acc: 0.4859
# Epoch 2, Train Loss: 0.7504, Train Acc: 0.5082, Val Acc: 0.4831
# Epoch 3, Train Loss: 0.7648, Train Acc: 0.5041, Val Acc: 0.5056
# Epoch 4, Train Loss: 0.7400, Train Acc: 0.4911, Val Acc: 0.4944
# Epoch 5, Train Loss: 0.7521, Train Acc: 0.5013, Val Acc: 0.4944
# Epoch 6, Train Loss: 0.7454, Train Acc: 0.4962, Val Acc: 0.5000
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0069, Train Acc: 0.4985, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.9205, Train Acc: 0.4991, Val Acc: 0.5009
# Epoch 3, Train Loss: 0.9091, Train Acc: 0.4992, Val Acc: 0.5019
# Epoch 4, Train Loss: 0.9020, Train Acc: 0.5013, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.9124, Train Acc: 0.5042, Val Acc: 0.4906
# Epoch 6, Train Loss: 0.9080, Train Acc: 0.4995, Val Acc: 0.4981
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6952, Train Acc: 0.5030, Val Acc: 0.5066
# Epoch 2, Train Loss: 0.6945, Train Acc: 0.5036, Val Acc: 0.5159
# Epoch 3, Train Loss: 0.6953, Train Acc: 0.4932, Val Acc: 0.5159
# Epoch 4, Train Loss: 0.6938, Train Acc: 0.5091, Val Acc: 0.5113
# Epoch 5, Train Loss: 0.6955, Train Acc: 0.4890, Val Acc: 0.5084
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7363, Train Acc: 0.4887, Val Acc: 0.5159
# Epoch 2, Train Loss: 0.7312, Train Acc: 0.5000, Val Acc: 0.4887
# Epoch 3, Train Loss: 0.7322, Train Acc: 0.4928, Val Acc: 0.4944
# Epoch 4, Train Loss: 0.7430, Train Acc: 0.4911, Val Acc: 0.4991
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0533, Train Acc: 0.5059, Val Acc: 0.5131
# Epoch 2, Train Loss: 0.8806, Train Acc: 0.4989, Val Acc: 0.5131
# Epoch 3, Train Loss: 0.9006, Train Acc: 0.4910, Val Acc: 0.4981
# Epoch 4, Train Loss: 0.8659, Train Acc: 0.5011, Val Acc: 0.5000
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6960, Train Acc: 0.4946, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6945, Train Acc: 0.5029, Val Acc: 0.4962
# Epoch 3, Train Loss: 0.6943, Train Acc: 0.5036, Val Acc: 0.4944
# Epoch 4, Train Loss: 0.6954, Train Acc: 0.4948, Val Acc: 0.4981
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7398, Train Acc: 0.4965, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7082, Train Acc: 0.4950, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7146, Train Acc: 0.4973, Val Acc: 0.5019
# Epoch 4, Train Loss: 0.7108, Train Acc: 0.5036, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.7250, Train Acc: 0.5007, Val Acc: 0.4991
# Epoch 6, Train Loss: 0.7177, Train Acc: 0.5006, Val Acc: 0.4991
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1682, Train Acc: 0.4978, Val Acc: 0.4906
# Epoch 2, Train Loss: 0.8768, Train Acc: 0.4959, Val Acc: 0.4953
# Epoch 3, Train Loss: 0.8038, Train Acc: 0.4958, Val Acc: 0.4944
# Epoch 4, Train Loss: 0.7578, Train Acc: 0.5035, Val Acc: 0.5084
# Epoch 5, Train Loss: 0.7952, Train Acc: 0.4971, Val Acc: 0.4981
# Epoch 6, Train Loss: 0.8877, Train Acc: 0.5009, Val Acc: 0.4953
# Epoch 7, Train Loss: 0.8280, Train Acc: 0.5039, Val Acc: 0.4784
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6969, Train Acc: 0.5000, Val Acc: 0.5038
# Epoch 2, Train Loss: 0.6959, Train Acc: 0.4996, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.6952, Train Acc: 0.5027, Val Acc: 0.5084
# Epoch 4, Train Loss: 0.6945, Train Acc: 0.5052, Val Acc: 0.5028
# Epoch 5, Train Loss: 0.6951, Train Acc: 0.5032, Val Acc: 0.5066
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.8526, Train Acc: 0.5176, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.8259, Train Acc: 0.5028, Val Acc: 0.5047
# Epoch 3, Train Loss: 0.8065, Train Acc: 0.5161, Val Acc: 0.4981
# Epoch 4, Train Loss: 0.8233, Train Acc: 0.5118, Val Acc: 0.4916
# Epoch 5, Train Loss: 0.8371, Train Acc: 0.5052, Val Acc: 0.5178
# Epoch 6, Train Loss: 0.8396, Train Acc: 0.5154, Val Acc: 0.4859
# Epoch 7, Train Loss: 0.8172, Train Acc: 0.5069, Val Acc: 0.4991
# Epoch 8, Train Loss: 0.8051, Train Acc: 0.5073, Val Acc: 0.5038
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4282, Train Acc: 0.5041, Val Acc: 0.4944
# Epoch 2, Train Loss: 1.3017, Train Acc: 0.5131, Val Acc: 0.5000
# Epoch 3, Train Loss: 1.3503, Train Acc: 0.4996, Val Acc: 0.5047
# Epoch 4, Train Loss: 1.3456, Train Acc: 0.5005, Val Acc: 0.4981
# Epoch 5, Train Loss: 1.3334, Train Acc: 0.4991, Val Acc: 0.4991
# Epoch 6, Train Loss: 1.3611, Train Acc: 0.4965, Val Acc: 0.4981
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6968, Train Acc: 0.4925, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.6951, Train Acc: 0.5004, Val Acc: 0.5141
# Epoch 3, Train Loss: 0.6946, Train Acc: 0.5066, Val Acc: 0.5131
# Epoch 4, Train Loss: 0.6951, Train Acc: 0.4970, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.6940, Train Acc: 0.5090, Val Acc: 0.4991
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7798, Train Acc: 0.5019, Val Acc: 0.5019
# Epoch 2, Train Loss: 0.7802, Train Acc: 0.4991, Val Acc: 0.5113
# Epoch 3, Train Loss: 0.7911, Train Acc: 0.4991, Val Acc: 0.4916
# Epoch 4, Train Loss: 0.7572, Train Acc: 0.4981, Val Acc: 0.4859
# Epoch 5, Train Loss: 0.7559, Train Acc: 0.5019, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.8525, Train Acc: 0.4986, Val Acc: 0.5000
# Epoch 2, Train Loss: 1.3500, Train Acc: 0.5004, Val Acc: 0.4991
# Epoch 3, Train Loss: 1.2655, Train Acc: 0.4941, Val Acc: 0.5028
# Epoch 4, Train Loss: 1.2488, Train Acc: 0.5008, Val Acc: 0.4925
# Epoch 5, Train Loss: 1.3109, Train Acc: 0.4962, Val Acc: 0.4944
# Epoch 6, Train Loss: 1.2910, Train Acc: 0.5042, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6954, Train Acc: 0.5021, Val Acc: 0.4991
# Epoch 2, Train Loss: 0.6949, Train Acc: 0.5027, Val Acc: 0.5066
# Epoch 3, Train Loss: 0.6945, Train Acc: 0.5027, Val Acc: 0.4991
# Epoch 4, Train Loss: 0.6943, Train Acc: 0.5045, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.6953, Train Acc: 0.4981, Val Acc: 0.5113
# Epoch 6, Train Loss: 0.6955, Train Acc: 0.4960, Val Acc: 0.5122
# Epoch 7, Train Loss: 0.6940, Train Acc: 0.5038, Val Acc: 0.5009
# Epoch 8, Train Loss: 0.6938, Train Acc: 0.5042, Val Acc: 0.5141
# Epoch 9, Train Loss: 0.6944, Train Acc: 0.4945, Val Acc: 0.4991
# Epoch 10, Train Loss: 0.6927, Train Acc: 0.5114, Val Acc: 0.5113
# Epoch 11, Train Loss: 0.6934, Train Acc: 0.5114, Val Acc: 0.4981
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.8290, Train Acc: 0.5049, Val Acc: 0.4906
# Epoch 2, Train Loss: 0.7382, Train Acc: 0.4952, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.7400, Train Acc: 0.4943, Val Acc: 0.5235
# Epoch 4, Train Loss: 0.7651, Train Acc: 0.4907, Val Acc: 0.5038
# Epoch 5, Train Loss: 0.7576, Train Acc: 0.5014, Val Acc: 0.4869
# Epoch 6, Train Loss: 0.7402, Train Acc: 0.4965, Val Acc: 0.5028
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.6813, Train Acc: 0.4994, Val Acc: 0.5319
# Epoch 2, Train Loss: 1.1134, Train Acc: 0.5080, Val Acc: 0.5066
# Epoch 3, Train Loss: 1.2810, Train Acc: 0.4951, Val Acc: 0.4953
# Epoch 4, Train Loss: 1.3388, Train Acc: 0.5063, Val Acc: 0.4972
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.7020, Train Acc: 0.5029, Val Acc: 0.4981
# Epoch 2, Train Loss: 0.7002, Train Acc: 0.4921, Val Acc: 0.4944
# Epoch 3, Train Loss: 0.6999, Train Acc: 0.4918, Val Acc: 0.4944
# Epoch 4, Train Loss: 0.6978, Train Acc: 0.5131, Val Acc: 0.4991
# Epoch 5, Train Loss: 0.6994, Train Acc: 0.4980, Val Acc: 0.5122
# Epoch 6, Train Loss: 0.6980, Train Acc: 0.5152, Val Acc: 0.5019
# Epoch 7, Train Loss: 0.6979, Train Acc: 0.5083, Val Acc: 0.5009
# Epoch 8, Train Loss: 0.6984, Train Acc: 0.5094, Val Acc: 0.5019
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 2.0916, Train Acc: 0.4973, Val Acc: 0.5000
# Epoch 2, Train Loss: 2.9879, Train Acc: 0.5021, Val Acc: 0.5019
# Epoch 3, Train Loss: 2.3828, Train Acc: 0.4941, Val Acc: 0.5000
# Epoch 4, Train Loss: 2.0678, Train Acc: 0.5002, Val Acc: 0.5000
# Epoch 5, Train Loss: 1.7969, Train Acc: 0.4988, Val Acc: 0.4991
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 14.9371, Train Acc: 0.5025, Val Acc: 0.4981
# Epoch 2, Train Loss: 13.1235, Train Acc: 0.4951, Val Acc: 0.5019
# Epoch 3, Train Loss: 12.6342, Train Acc: 0.4966, Val Acc: 0.4972
# Epoch 4, Train Loss: 12.4367, Train Acc: 0.5074, Val Acc: 0.5103
# Epoch 5, Train Loss: 12.9685, Train Acc: 0.4972, Val Acc: 0.5019
# Epoch 6, Train Loss: 13.0405, Train Acc: 0.4943, Val Acc: 0.5028
# Epoch 7, Train Loss: 12.7164, Train Acc: 0.5064, Val Acc: 0.5028
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.7010, Train Acc: 0.5039, Val Acc: 0.4934
# Epoch 2, Train Loss: 0.6977, Train Acc: 0.4906, Val Acc: 0.5028
# Epoch 3, Train Loss: 0.6968, Train Acc: 0.5035, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.6958, Train Acc: 0.5038, Val Acc: 0.5075
# Epoch 5, Train Loss: 0.6968, Train Acc: 0.4981, Val Acc: 0.5019
# Epoch 6, Train Loss: 0.6959, Train Acc: 0.5011, Val Acc: 0.4972
# Epoch 7, Train Loss: 0.6966, Train Acc: 0.4975, Val Acc: 0.5038
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 2.0709, Train Acc: 0.5035, Val Acc: 0.4991
# Epoch 2, Train Loss: 2.4366, Train Acc: 0.4986, Val Acc: 0.4972
# Epoch 3, Train Loss: 2.2056, Train Acc: 0.4952, Val Acc: 0.5019
# Epoch 4, Train Loss: 1.4553, Train Acc: 0.5070, Val Acc: 0.5019
# Epoch 5, Train Loss: 2.7802, Train Acc: 0.5021, Val Acc: 0.4962
# Epoch 6, Train Loss: 1.5014, Train Acc: 0.5047, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 10.6341, Train Acc: 0.4965, Val Acc: 0.5141
# Epoch 2, Train Loss: 7.2715, Train Acc: 0.4994, Val Acc: 0.5159
# Epoch 3, Train Loss: 7.5320, Train Acc: 0.4925, Val Acc: 0.4972
# Epoch 4, Train Loss: 7.3407, Train Acc: 0.5022, Val Acc: 0.4850
# Epoch 5, Train Loss: 7.9113, Train Acc: 0.5048, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6988, Train Acc: 0.5061, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.6967, Train Acc: 0.4936, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.6954, Train Acc: 0.5053, Val Acc: 0.5188
# Epoch 4, Train Loss: 0.6950, Train Acc: 0.5083, Val Acc: 0.4991
# Epoch 5, Train Loss: 0.6949, Train Acc: 0.4968, Val Acc: 0.5150
# Epoch 6, Train Loss: 0.6945, Train Acc: 0.5008, Val Acc: 0.5169
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 3.4561, Train Acc: 0.4972, Val Acc: 0.5000
# Epoch 2, Train Loss: 1.6012, Train Acc: 0.4921, Val Acc: 0.4831
# Epoch 3, Train Loss: 1.4977, Train Acc: 0.4951, Val Acc: 0.4962
# Epoch 4, Train Loss: 1.4899, Train Acc: 0.4987, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 18.5429, Train Acc: 0.5148, Val Acc: 0.4906
# Epoch 2, Train Loss: 12.1066, Train Acc: 0.5077, Val Acc: 0.5000
# Epoch 3, Train Loss: 10.9928, Train Acc: 0.5033, Val Acc: 0.5000
# Epoch 4, Train Loss: 11.8234, Train Acc: 0.4912, Val Acc: 0.4953
# Epoch 5, Train Loss: 11.0686, Train Acc: 0.4938, Val Acc: 0.4991
# Early stopping
# Best Validation Accuracy: 0.5337711069418386
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 16, 'optimizer': 'Adam'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_last['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_last = LastHiddenRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_last['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])
elif best_hyperparams_RNN_last['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])
elif best_hyperparams_RNN_last['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])

best_model_RNN_last, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_last, train_loader, validation_loader,
                                                                                  best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.7067, Train Acc: 0.4998, Val Acc: 0.5028
# Epoch 2, Train Loss: 0.7080, Train Acc: 0.5027, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7072, Train Acc: 0.4996, Val Acc: 0.5019
# Epoch 4, Train Loss: 0.7073, Train Acc: 0.5035, Val Acc: 0.5019
# Early stopping

# %%
epochs_LHS = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_LHS, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_last, test_loader)
test_accuracies['RNN Last Hidden State'] = test_acc
print(f'Test Accuracy (RNN Last Hidden State): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Last Hidden State): 0.5159

# %% [markdown]
# ### 2) RNN Max Pooling

# %%
# Call grid search
best_hyperparams_RNN_max = run_grid_search(MaxPoolingRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                           validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6960, Train Acc: 0.4899, Val Acc: 0.5235
# Epoch 2, Train Loss: 0.6928, Train Acc: 0.5172, Val Acc: 0.5141
# Epoch 3, Train Loss: 0.6902, Train Acc: 0.5368, Val Acc: 0.5582
# Epoch 4, Train Loss: 0.6871, Train Acc: 0.5557, Val Acc: 0.6041
# Epoch 5, Train Loss: 0.6848, Train Acc: 0.5701, Val Acc: 0.6060
# Epoch 6, Train Loss: 0.6817, Train Acc: 0.5801, Val Acc: 0.6529
# Epoch 7, Train Loss: 0.6789, Train Acc: 0.6096, Val Acc: 0.6463
# Epoch 8, Train Loss: 0.6749, Train Acc: 0.6332, Val Acc: 0.6510
# Epoch 9, Train Loss: 0.6705, Train Acc: 0.6462, Val Acc: 0.6726
# Epoch 10, Train Loss: 0.6663, Train Acc: 0.6524, Val Acc: 0.5844
# Epoch 11, Train Loss: 0.6612, Train Acc: 0.6613, Val Acc: 0.6942
# Epoch 12, Train Loss: 0.6542, Train Acc: 0.6760, Val Acc: 0.6970
# Epoch 13, Train Loss: 0.6467, Train Acc: 0.6866, Val Acc: 0.7073
# Epoch 14, Train Loss: 0.6382, Train Acc: 0.7020, Val Acc: 0.7129
# Epoch 15, Train Loss: 0.6279, Train Acc: 0.7023, Val Acc: 0.7148
# Epoch 16, Train Loss: 0.6151, Train Acc: 0.7056, Val Acc: 0.7186
# Epoch 17, Train Loss: 0.5998, Train Acc: 0.7164, Val Acc: 0.7148
# Epoch 18, Train Loss: 0.5812, Train Acc: 0.7190, Val Acc: 0.7205
# Epoch 19, Train Loss: 0.5626, Train Acc: 0.7217, Val Acc: 0.7242
# Epoch 20, Train Loss: 0.5439, Train Acc: 0.7297, Val Acc: 0.7139
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5317, Train Acc: 0.7226, Val Acc: 0.7430
# Epoch 2, Train Loss: 0.4729, Train Acc: 0.7707, Val Acc: 0.7655
# Epoch 3, Train Loss: 0.4521, Train Acc: 0.7832, Val Acc: 0.7805
# Epoch 4, Train Loss: 0.4375, Train Acc: 0.7955, Val Acc: 0.7805
# Epoch 5, Train Loss: 0.4258, Train Acc: 0.8025, Val Acc: 0.7617
# Epoch 6, Train Loss: 0.4151, Train Acc: 0.8033, Val Acc: 0.7871
# Epoch 7, Train Loss: 0.3888, Train Acc: 0.8197, Val Acc: 0.7842
# Epoch 8, Train Loss: 0.3807, Train Acc: 0.8253, Val Acc: 0.7917
# Epoch 9, Train Loss: 0.3681, Train Acc: 0.8309, Val Acc: 0.7674
# Epoch 10, Train Loss: 0.3616, Train Acc: 0.8324, Val Acc: 0.7683
# Epoch 11, Train Loss: 0.3295, Train Acc: 0.8550, Val Acc: 0.7749
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5440, Train Acc: 0.7182, Val Acc: 0.7739
# Epoch 2, Train Loss: 0.4793, Train Acc: 0.7678, Val Acc: 0.7786
# Epoch 3, Train Loss: 0.4480, Train Acc: 0.7859, Val Acc: 0.7251
# Epoch 4, Train Loss: 0.4295, Train Acc: 0.7974, Val Acc: 0.7205
# Epoch 5, Train Loss: 0.4072, Train Acc: 0.8087, Val Acc: 0.6567
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6955, Train Acc: 0.4998, Val Acc: 0.5075
# Epoch 2, Train Loss: 0.6930, Train Acc: 0.5106, Val Acc: 0.5253
# Epoch 3, Train Loss: 0.6919, Train Acc: 0.5208, Val Acc: 0.5366
# Epoch 4, Train Loss: 0.6905, Train Acc: 0.5257, Val Acc: 0.5675
# Epoch 5, Train Loss: 0.6879, Train Acc: 0.5450, Val Acc: 0.5525
# Epoch 6, Train Loss: 0.6867, Train Acc: 0.5617, Val Acc: 0.5835
# Epoch 7, Train Loss: 0.6849, Train Acc: 0.5692, Val Acc: 0.6041
# Epoch 8, Train Loss: 0.6838, Train Acc: 0.5781, Val Acc: 0.6341
# Epoch 9, Train Loss: 0.6810, Train Acc: 0.6020, Val Acc: 0.6379
# Epoch 10, Train Loss: 0.6791, Train Acc: 0.6046, Val Acc: 0.6445
# Epoch 11, Train Loss: 0.6777, Train Acc: 0.6183, Val Acc: 0.6360
# Epoch 12, Train Loss: 0.6766, Train Acc: 0.6171, Val Acc: 0.6642
# Epoch 13, Train Loss: 0.6736, Train Acc: 0.6339, Val Acc: 0.6689
# Epoch 14, Train Loss: 0.6708, Train Acc: 0.6481, Val Acc: 0.6773
# Epoch 15, Train Loss: 0.6693, Train Acc: 0.6510, Val Acc: 0.6895
# Epoch 16, Train Loss: 0.6664, Train Acc: 0.6519, Val Acc: 0.6585
# Epoch 17, Train Loss: 0.6630, Train Acc: 0.6702, Val Acc: 0.6979
# Epoch 18, Train Loss: 0.6610, Train Acc: 0.6716, Val Acc: 0.7064
# Epoch 19, Train Loss: 0.6574, Train Acc: 0.6791, Val Acc: 0.6961
# Epoch 20, Train Loss: 0.6544, Train Acc: 0.6773, Val Acc: 0.6932
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5456, Train Acc: 0.7111, Val Acc: 0.7627
# Epoch 2, Train Loss: 0.4625, Train Acc: 0.7808, Val Acc: 0.7805
# Epoch 3, Train Loss: 0.4381, Train Acc: 0.7943, Val Acc: 0.7242
# Epoch 4, Train Loss: 0.4197, Train Acc: 0.8073, Val Acc: 0.7880
# Epoch 5, Train Loss: 0.4033, Train Acc: 0.8111, Val Acc: 0.7946
# Epoch 6, Train Loss: 0.3777, Train Acc: 0.8273, Val Acc: 0.7842
# Epoch 7, Train Loss: 0.3719, Train Acc: 0.8277, Val Acc: 0.7786
# Epoch 8, Train Loss: 0.3421, Train Acc: 0.8464, Val Acc: 0.7814
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5646, Train Acc: 0.7005, Val Acc: 0.7261
# Epoch 2, Train Loss: 0.4698, Train Acc: 0.7717, Val Acc: 0.7777
# Epoch 3, Train Loss: 0.4389, Train Acc: 0.7911, Val Acc: 0.7814
# Epoch 4, Train Loss: 0.4169, Train Acc: 0.8039, Val Acc: 0.7833
# Epoch 5, Train Loss: 0.3978, Train Acc: 0.8136, Val Acc: 0.7758
# Epoch 6, Train Loss: 0.3759, Train Acc: 0.8294, Val Acc: 0.7824
# Epoch 7, Train Loss: 0.3625, Train Acc: 0.8305, Val Acc: 0.7955
# Epoch 8, Train Loss: 0.3349, Train Acc: 0.8536, Val Acc: 0.7786
# Epoch 9, Train Loss: 0.3171, Train Acc: 0.8587, Val Acc: 0.7523
# Epoch 10, Train Loss: 0.3123, Train Acc: 0.8644, Val Acc: 0.7917
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6942, Train Acc: 0.4971, Val Acc: 0.5281
# Epoch 2, Train Loss: 0.6928, Train Acc: 0.5138, Val Acc: 0.5356
# Epoch 3, Train Loss: 0.6924, Train Acc: 0.5157, Val Acc: 0.5300
# Epoch 4, Train Loss: 0.6917, Train Acc: 0.5232, Val Acc: 0.5525
# Epoch 5, Train Loss: 0.6907, Train Acc: 0.5329, Val Acc: 0.5666
# Epoch 6, Train Loss: 0.6896, Train Acc: 0.5401, Val Acc: 0.5760
# Epoch 7, Train Loss: 0.6887, Train Acc: 0.5472, Val Acc: 0.5741
# Epoch 8, Train Loss: 0.6880, Train Acc: 0.5576, Val Acc: 0.5788
# Epoch 9, Train Loss: 0.6875, Train Acc: 0.5606, Val Acc: 0.5816
# Epoch 10, Train Loss: 0.6867, Train Acc: 0.5597, Val Acc: 0.6041
# Epoch 11, Train Loss: 0.6853, Train Acc: 0.5791, Val Acc: 0.6201
# Epoch 12, Train Loss: 0.6854, Train Acc: 0.5836, Val Acc: 0.5901
# Epoch 13, Train Loss: 0.6838, Train Acc: 0.5887, Val Acc: 0.6313
# Epoch 14, Train Loss: 0.6837, Train Acc: 0.5902, Val Acc: 0.6370
# Epoch 15, Train Loss: 0.6822, Train Acc: 0.6020, Val Acc: 0.6051
# Epoch 16, Train Loss: 0.6815, Train Acc: 0.6073, Val Acc: 0.6435
# Epoch 17, Train Loss: 0.6802, Train Acc: 0.6083, Val Acc: 0.6548
# Epoch 18, Train Loss: 0.6799, Train Acc: 0.6117, Val Acc: 0.6341
# Epoch 19, Train Loss: 0.6787, Train Acc: 0.6142, Val Acc: 0.6501
# Epoch 20, Train Loss: 0.6778, Train Acc: 0.6270, Val Acc: 0.6032
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5385, Train Acc: 0.7170, Val Acc: 0.7683
# Epoch 2, Train Loss: 0.4672, Train Acc: 0.7744, Val Acc: 0.7570
# Epoch 3, Train Loss: 0.4416, Train Acc: 0.7905, Val Acc: 0.7852
# Epoch 4, Train Loss: 0.4250, Train Acc: 0.7984, Val Acc: 0.7842
# Epoch 5, Train Loss: 0.4043, Train Acc: 0.8118, Val Acc: 0.7852
# Epoch 6, Train Loss: 0.3839, Train Acc: 0.8246, Val Acc: 0.7842
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5931, Train Acc: 0.6842, Val Acc: 0.7552
# Epoch 2, Train Loss: 0.4794, Train Acc: 0.7679, Val Acc: 0.7795
# Epoch 3, Train Loss: 0.4504, Train Acc: 0.7877, Val Acc: 0.6642
# Epoch 4, Train Loss: 0.4292, Train Acc: 0.7999, Val Acc: 0.7289
# Epoch 5, Train Loss: 0.4196, Train Acc: 0.8001, Val Acc: 0.7767
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6936, Train Acc: 0.5176, Val Acc: 0.5891
# Epoch 2, Train Loss: 0.6782, Train Acc: 0.5869, Val Acc: 0.5638
# Epoch 3, Train Loss: 0.6478, Train Acc: 0.6584, Val Acc: 0.5919
# Epoch 4, Train Loss: 0.5829, Train Acc: 0.7015, Val Acc: 0.7186
# Epoch 5, Train Loss: 0.5299, Train Acc: 0.7317, Val Acc: 0.7017
# Epoch 6, Train Loss: 0.5142, Train Acc: 0.7476, Val Acc: 0.7467
# Epoch 7, Train Loss: 0.5018, Train Acc: 0.7530, Val Acc: 0.7542
# Epoch 8, Train Loss: 0.4883, Train Acc: 0.7614, Val Acc: 0.7561
# Epoch 9, Train Loss: 0.4818, Train Acc: 0.7646, Val Acc: 0.7608
# Epoch 10, Train Loss: 0.4762, Train Acc: 0.7681, Val Acc: 0.7664
# Epoch 11, Train Loss: 0.4679, Train Acc: 0.7692, Val Acc: 0.7373
# Epoch 12, Train Loss: 0.4592, Train Acc: 0.7834, Val Acc: 0.7758
# Epoch 13, Train Loss: 0.4572, Train Acc: 0.7781, Val Acc: 0.7336
# Epoch 14, Train Loss: 0.4510, Train Acc: 0.7828, Val Acc: 0.7514
# Epoch 15, Train Loss: 0.4456, Train Acc: 0.7860, Val Acc: 0.7767
# Epoch 16, Train Loss: 0.4442, Train Acc: 0.7856, Val Acc: 0.7824
# Epoch 17, Train Loss: 0.4334, Train Acc: 0.7953, Val Acc: 0.7711
# Epoch 18, Train Loss: 0.4279, Train Acc: 0.7950, Val Acc: 0.7580
# Epoch 19, Train Loss: 0.4228, Train Acc: 0.8020, Val Acc: 0.7683
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7488, Train Acc: 0.5184, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7458, Train Acc: 0.4979, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7510, Train Acc: 0.4993, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.7359, Train Acc: 0.4980, Val Acc: 0.5000
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8089, Train Acc: 0.5355, Val Acc: 0.5563
# Epoch 2, Train Loss: 0.7149, Train Acc: 0.6004, Val Acc: 0.5141
# Epoch 3, Train Loss: 0.6868, Train Acc: 0.6410, Val Acc: 0.6360
# Epoch 4, Train Loss: 0.6874, Train Acc: 0.6402, Val Acc: 0.5019
# Epoch 5, Train Loss: 0.6750, Train Acc: 0.6556, Val Acc: 0.5741
# Epoch 6, Train Loss: 0.6601, Train Acc: 0.6689, Val Acc: 0.5075
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6925, Train Acc: 0.5245, Val Acc: 0.5159
# Epoch 2, Train Loss: 0.6845, Train Acc: 0.5627, Val Acc: 0.6238
# Epoch 3, Train Loss: 0.6745, Train Acc: 0.6011, Val Acc: 0.6426
# Epoch 4, Train Loss: 0.6628, Train Acc: 0.6424, Val Acc: 0.6538
# Epoch 5, Train Loss: 0.6421, Train Acc: 0.6726, Val Acc: 0.6998
# Epoch 6, Train Loss: 0.6038, Train Acc: 0.7012, Val Acc: 0.6961
# Epoch 7, Train Loss: 0.5575, Train Acc: 0.7159, Val Acc: 0.7167
# Epoch 8, Train Loss: 0.5404, Train Acc: 0.7267, Val Acc: 0.7186
# Epoch 9, Train Loss: 0.5264, Train Acc: 0.7321, Val Acc: 0.7392
# Epoch 10, Train Loss: 0.5131, Train Acc: 0.7372, Val Acc: 0.7364
# Epoch 11, Train Loss: 0.5028, Train Acc: 0.7476, Val Acc: 0.7383
# Epoch 12, Train Loss: 0.4975, Train Acc: 0.7542, Val Acc: 0.7448
# Epoch 13, Train Loss: 0.4930, Train Acc: 0.7601, Val Acc: 0.7383
# Epoch 14, Train Loss: 0.4875, Train Acc: 0.7547, Val Acc: 0.7448
# Epoch 15, Train Loss: 0.4829, Train Acc: 0.7637, Val Acc: 0.7477
# Epoch 16, Train Loss: 0.4762, Train Acc: 0.7716, Val Acc: 0.7355
# Epoch 17, Train Loss: 0.4761, Train Acc: 0.7672, Val Acc: 0.7664
# Epoch 18, Train Loss: 0.4755, Train Acc: 0.7673, Val Acc: 0.7486
# Epoch 19, Train Loss: 0.4725, Train Acc: 0.7674, Val Acc: 0.7233
# Epoch 20, Train Loss: 0.4651, Train Acc: 0.7734, Val Acc: 0.7439
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6411, Train Acc: 0.6359, Val Acc: 0.6961
# Epoch 2, Train Loss: 0.5896, Train Acc: 0.6873, Val Acc: 0.7101
# Epoch 3, Train Loss: 0.5778, Train Acc: 0.6977, Val Acc: 0.6829
# Epoch 4, Train Loss: 0.5720, Train Acc: 0.7009, Val Acc: 0.6651
# Epoch 5, Train Loss: 0.5467, Train Acc: 0.7234, Val Acc: 0.7176
# Epoch 6, Train Loss: 0.5532, Train Acc: 0.7198, Val Acc: 0.6848
# Epoch 7, Train Loss: 0.5467, Train Acc: 0.7196, Val Acc: 0.7129
# Epoch 8, Train Loss: 0.5310, Train Acc: 0.7314, Val Acc: 0.6867
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8304, Train Acc: 0.5458, Val Acc: 0.5582
# Epoch 2, Train Loss: 0.7209, Train Acc: 0.5868, Val Acc: 0.6098
# Epoch 3, Train Loss: 0.6914, Train Acc: 0.6356, Val Acc: 0.6951
# Epoch 4, Train Loss: 0.6360, Train Acc: 0.6683, Val Acc: 0.6388
# Epoch 5, Train Loss: 0.6132, Train Acc: 0.6870, Val Acc: 0.5263
# Epoch 6, Train Loss: 0.6331, Train Acc: 0.6835, Val Acc: 0.6979
# Epoch 7, Train Loss: 0.6040, Train Acc: 0.6948, Val Acc: 0.6773
# Epoch 8, Train Loss: 0.5954, Train Acc: 0.7046, Val Acc: 0.5178
# Epoch 9, Train Loss: 0.6069, Train Acc: 0.7022, Val Acc: 0.7083
# Epoch 10, Train Loss: 0.5822, Train Acc: 0.7060, Val Acc: 0.6501
# Epoch 11, Train Loss: 0.5874, Train Acc: 0.7127, Val Acc: 0.5976
# Epoch 12, Train Loss: 0.5720, Train Acc: 0.7261, Val Acc: 0.7233
# Epoch 13, Train Loss: 0.5681, Train Acc: 0.7251, Val Acc: 0.6717
# Epoch 14, Train Loss: 0.5756, Train Acc: 0.7249, Val Acc: 0.6745
# Epoch 15, Train Loss: 0.5642, Train Acc: 0.7275, Val Acc: 0.7195
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6936, Train Acc: 0.5103, Val Acc: 0.5319
# Epoch 2, Train Loss: 0.6889, Train Acc: 0.5380, Val Acc: 0.5826
# Epoch 3, Train Loss: 0.6851, Train Acc: 0.5713, Val Acc: 0.6088
# Epoch 4, Train Loss: 0.6819, Train Acc: 0.5918, Val Acc: 0.6313
# Epoch 5, Train Loss: 0.6779, Train Acc: 0.6142, Val Acc: 0.6604
# Epoch 6, Train Loss: 0.6720, Train Acc: 0.6260, Val Acc: 0.6313
# Epoch 7, Train Loss: 0.6661, Train Acc: 0.6408, Val Acc: 0.6914
# Epoch 8, Train Loss: 0.6592, Train Acc: 0.6613, Val Acc: 0.6970
# Epoch 9, Train Loss: 0.6504, Train Acc: 0.6749, Val Acc: 0.6876
# Epoch 10, Train Loss: 0.6392, Train Acc: 0.6841, Val Acc: 0.7092
# Epoch 11, Train Loss: 0.6253, Train Acc: 0.6995, Val Acc: 0.6932
# Epoch 12, Train Loss: 0.6069, Train Acc: 0.7116, Val Acc: 0.7129
# Epoch 13, Train Loss: 0.5846, Train Acc: 0.7215, Val Acc: 0.7158
# Epoch 14, Train Loss: 0.5546, Train Acc: 0.7244, Val Acc: 0.7205
# Epoch 15, Train Loss: 0.5417, Train Acc: 0.7250, Val Acc: 0.7289
# Epoch 16, Train Loss: 0.5351, Train Acc: 0.7311, Val Acc: 0.7308
# Epoch 17, Train Loss: 0.5194, Train Acc: 0.7380, Val Acc: 0.7308
# Epoch 18, Train Loss: 0.5134, Train Acc: 0.7448, Val Acc: 0.7186
# Epoch 19, Train Loss: 0.5064, Train Acc: 0.7498, Val Acc: 0.7355
# Epoch 20, Train Loss: 0.5037, Train Acc: 0.7483, Val Acc: 0.7430
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5757, Train Acc: 0.6899, Val Acc: 0.7477
# Epoch 2, Train Loss: 0.5369, Train Acc: 0.7273, Val Acc: 0.7242
# Epoch 3, Train Loss: 0.5114, Train Acc: 0.7419, Val Acc: 0.7486
# Epoch 4, Train Loss: 0.5194, Train Acc: 0.7404, Val Acc: 0.7373
# Epoch 5, Train Loss: 0.5182, Train Acc: 0.7381, Val Acc: 0.6989
# Epoch 6, Train Loss: 0.5309, Train Acc: 0.7373, Val Acc: 0.7514
# Epoch 7, Train Loss: 0.5103, Train Acc: 0.7508, Val Acc: 0.7392
# Epoch 8, Train Loss: 0.4980, Train Acc: 0.7583, Val Acc: 0.7533
# Epoch 9, Train Loss: 0.5014, Train Acc: 0.7532, Val Acc: 0.7448
# Epoch 10, Train Loss: 0.4746, Train Acc: 0.7658, Val Acc: 0.7636
# Epoch 11, Train Loss: 0.4864, Train Acc: 0.7583, Val Acc: 0.7720
# Epoch 12, Train Loss: 0.4628, Train Acc: 0.7768, Val Acc: 0.7439
# Epoch 13, Train Loss: 0.4642, Train Acc: 0.7726, Val Acc: 0.7289
# Epoch 14, Train Loss: 0.4510, Train Acc: 0.7877, Val Acc: 0.7120
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9050, Train Acc: 0.5444, Val Acc: 0.5816
# Epoch 2, Train Loss: 0.7401, Train Acc: 0.5791, Val Acc: 0.5666
# Epoch 3, Train Loss: 0.9188, Train Acc: 0.5583, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.6881, Train Acc: 0.6382, Val Acc: 0.7017
# Epoch 5, Train Loss: 0.6504, Train Acc: 0.6685, Val Acc: 0.6726
# Epoch 6, Train Loss: 0.6145, Train Acc: 0.6846, Val Acc: 0.6679
# Epoch 7, Train Loss: 0.6092, Train Acc: 0.7008, Val Acc: 0.6623
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6840, Train Acc: 0.5499, Val Acc: 0.5732
# Epoch 2, Train Loss: 0.6075, Train Acc: 0.6802, Val Acc: 0.7420
# Epoch 3, Train Loss: 0.5335, Train Acc: 0.7336, Val Acc: 0.5826
# Epoch 4, Train Loss: 0.5036, Train Acc: 0.7526, Val Acc: 0.6632
# Epoch 5, Train Loss: 0.4858, Train Acc: 0.7592, Val Acc: 0.7036
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7769, Train Acc: 0.5230, Val Acc: 0.5507
# Epoch 2, Train Loss: 0.7857, Train Acc: 0.5333, Val Acc: 0.5141
# Epoch 3, Train Loss: 0.7683, Train Acc: 0.5417, Val Acc: 0.5094
# Epoch 4, Train Loss: 0.7746, Train Acc: 0.5542, Val Acc: 0.5206
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1834, Train Acc: 0.5137, Val Acc: 0.5197
# Epoch 2, Train Loss: 0.9808, Train Acc: 0.5308, Val Acc: 0.4953
# Epoch 3, Train Loss: 1.0013, Train Acc: 0.5382, Val Acc: 0.5094
# Epoch 4, Train Loss: 1.3236, Train Acc: 0.5182, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6924, Train Acc: 0.5204, Val Acc: 0.5113
# Epoch 2, Train Loss: 0.6745, Train Acc: 0.5938, Val Acc: 0.6660
# Epoch 3, Train Loss: 0.6434, Train Acc: 0.6685, Val Acc: 0.6970
# Epoch 4, Train Loss: 0.5774, Train Acc: 0.7076, Val Acc: 0.7026
# Epoch 5, Train Loss: 0.5330, Train Acc: 0.7306, Val Acc: 0.7514
# Epoch 6, Train Loss: 0.5074, Train Acc: 0.7488, Val Acc: 0.7308
# Epoch 7, Train Loss: 0.5002, Train Acc: 0.7535, Val Acc: 0.7514
# Epoch 8, Train Loss: 0.4855, Train Acc: 0.7556, Val Acc: 0.7561
# Epoch 9, Train Loss: 0.4787, Train Acc: 0.7630, Val Acc: 0.7542
# Epoch 10, Train Loss: 0.4700, Train Acc: 0.7674, Val Acc: 0.7664
# Epoch 11, Train Loss: 0.4717, Train Acc: 0.7652, Val Acc: 0.7730
# Epoch 12, Train Loss: 0.4658, Train Acc: 0.7744, Val Acc: 0.7692
# Epoch 13, Train Loss: 0.4568, Train Acc: 0.7801, Val Acc: 0.7767
# Epoch 14, Train Loss: 0.4436, Train Acc: 0.7906, Val Acc: 0.7767
# Epoch 15, Train Loss: 0.4450, Train Acc: 0.7880, Val Acc: 0.7786
# Epoch 16, Train Loss: 0.4380, Train Acc: 0.7941, Val Acc: 0.7852
# Epoch 17, Train Loss: 0.4386, Train Acc: 0.7960, Val Acc: 0.7861
# Epoch 18, Train Loss: 0.4259, Train Acc: 0.7993, Val Acc: 0.7730
# Epoch 19, Train Loss: 0.4239, Train Acc: 0.8006, Val Acc: 0.7880
# Epoch 20, Train Loss: 0.4213, Train Acc: 0.8002, Val Acc: 0.7692
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7780, Train Acc: 0.5032, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7357, Train Acc: 0.4920, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7464, Train Acc: 0.4933, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.7561, Train Acc: 0.4984, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.3344, Train Acc: 0.5198, Val Acc: 0.5291
# Epoch 2, Train Loss: 0.9224, Train Acc: 0.5457, Val Acc: 0.5535
# Epoch 3, Train Loss: 0.8896, Train Acc: 0.5666, Val Acc: 0.5910
# Epoch 4, Train Loss: 0.8901, Train Acc: 0.5751, Val Acc: 0.5844
# Epoch 5, Train Loss: 0.8891, Train Acc: 0.5893, Val Acc: 0.5159
# Epoch 6, Train Loss: 0.8617, Train Acc: 0.5967, Val Acc: 0.5947
# Epoch 7, Train Loss: 0.8682, Train Acc: 0.5978, Val Acc: 0.5169
# Epoch 8, Train Loss: 0.8437, Train Acc: 0.6108, Val Acc: 0.5328
# Epoch 9, Train Loss: 0.8159, Train Acc: 0.6144, Val Acc: 0.6182
# Epoch 10, Train Loss: 0.8507, Train Acc: 0.6240, Val Acc: 0.6107
# Epoch 11, Train Loss: 0.8419, Train Acc: 0.6251, Val Acc: 0.5422
# Epoch 12, Train Loss: 0.8546, Train Acc: 0.6314, Val Acc: 0.6088
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6919, Train Acc: 0.5240, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6854, Train Acc: 0.5542, Val Acc: 0.6041
# Epoch 3, Train Loss: 0.6797, Train Acc: 0.5919, Val Acc: 0.6407
# Epoch 4, Train Loss: 0.6699, Train Acc: 0.6220, Val Acc: 0.6595
# Epoch 5, Train Loss: 0.6569, Train Acc: 0.6581, Val Acc: 0.6032
# Epoch 6, Train Loss: 0.6364, Train Acc: 0.6853, Val Acc: 0.6492
# Epoch 7, Train Loss: 0.5987, Train Acc: 0.7061, Val Acc: 0.7195
# Epoch 8, Train Loss: 0.5560, Train Acc: 0.7223, Val Acc: 0.7326
# Epoch 9, Train Loss: 0.5382, Train Acc: 0.7272, Val Acc: 0.6698
# Epoch 10, Train Loss: 0.5254, Train Acc: 0.7348, Val Acc: 0.7186
# Epoch 11, Train Loss: 0.5133, Train Acc: 0.7449, Val Acc: 0.7486
# Epoch 12, Train Loss: 0.5032, Train Acc: 0.7487, Val Acc: 0.7402
# Epoch 13, Train Loss: 0.4947, Train Acc: 0.7546, Val Acc: 0.7486
# Epoch 14, Train Loss: 0.4880, Train Acc: 0.7559, Val Acc: 0.7552
# Epoch 15, Train Loss: 0.4890, Train Acc: 0.7625, Val Acc: 0.6529
# Epoch 16, Train Loss: 0.4848, Train Acc: 0.7606, Val Acc: 0.7430
# Epoch 17, Train Loss: 0.4799, Train Acc: 0.7689, Val Acc: 0.7411
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7459, Train Acc: 0.5202, Val Acc: 0.5844
# Epoch 2, Train Loss: 0.7243, Train Acc: 0.5064, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7289, Train Acc: 0.5032, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.7361, Train Acc: 0.4960, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.7612, Train Acc: 0.5141, Val Acc: 0.5244
# Epoch 2, Train Loss: 0.8383, Train Acc: 0.5458, Val Acc: 0.5507
# Epoch 3, Train Loss: 0.8365, Train Acc: 0.5671, Val Acc: 0.5750
# Epoch 4, Train Loss: 0.8846, Train Acc: 0.5674, Val Acc: 0.5469
# Epoch 5, Train Loss: 0.8157, Train Acc: 0.5970, Val Acc: 0.5741
# Epoch 6, Train Loss: 0.7856, Train Acc: 0.6137, Val Acc: 0.5366
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6149, Train Acc: 0.6624, Val Acc: 0.5741
# Epoch 2, Train Loss: 0.5026, Train Acc: 0.7517, Val Acc: 0.7655
# Epoch 3, Train Loss: 0.4818, Train Acc: 0.7715, Val Acc: 0.7908
# Epoch 4, Train Loss: 0.4667, Train Acc: 0.7773, Val Acc: 0.7017
# Epoch 5, Train Loss: 0.4425, Train Acc: 0.7950, Val Acc: 0.7908
# Epoch 6, Train Loss: 0.4414, Train Acc: 0.7979, Val Acc: 0.6407
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 2.5259, Train Acc: 0.5206, Val Acc: 0.5469
# Epoch 2, Train Loss: 2.2397, Train Acc: 0.5122, Val Acc: 0.5000
# Epoch 3, Train Loss: 2.1512, Train Acc: 0.5136, Val Acc: 0.5366
# Epoch 4, Train Loss: 2.6108, Train Acc: 0.5244, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 12.4402, Train Acc: 0.5152, Val Acc: 0.5328
# Epoch 2, Train Loss: 9.4823, Train Acc: 0.5231, Val Acc: 0.5000
# Epoch 3, Train Loss: 9.3926, Train Acc: 0.5186, Val Acc: 0.5047
# Epoch 4, Train Loss: 9.2696, Train Acc: 0.5230, Val Acc: 0.4991
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6699, Train Acc: 0.6059, Val Acc: 0.6285
# Epoch 2, Train Loss: 0.5166, Train Acc: 0.7400, Val Acc: 0.7655
# Epoch 3, Train Loss: 0.4766, Train Acc: 0.7680, Val Acc: 0.7739
# Epoch 4, Train Loss: 0.4527, Train Acc: 0.7857, Val Acc: 0.7120
# Epoch 5, Train Loss: 0.4383, Train Acc: 0.7947, Val Acc: 0.7927
# Epoch 6, Train Loss: 0.4177, Train Acc: 0.8097, Val Acc: 0.7936
# Epoch 7, Train Loss: 0.3946, Train Acc: 0.8196, Val Acc: 0.7514
# Epoch 8, Train Loss: 0.4146, Train Acc: 0.8108, Val Acc: 0.7261
# Epoch 9, Train Loss: 0.3823, Train Acc: 0.8277, Val Acc: 0.8002
# Epoch 10, Train Loss: 0.3611, Train Acc: 0.8401, Val Acc: 0.7739
# Epoch 11, Train Loss: 0.3743, Train Acc: 0.8365, Val Acc: 0.7664
# Epoch 12, Train Loss: 0.3725, Train Acc: 0.8372, Val Acc: 0.7908
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 1.9699, Train Acc: 0.5179, Val Acc: 0.5197
# Epoch 2, Train Loss: 1.8085, Train Acc: 0.5195, Val Acc: 0.5563
# Epoch 3, Train Loss: 1.3574, Train Acc: 0.5315, Val Acc: 0.5432
# Epoch 4, Train Loss: 1.3465, Train Acc: 0.5319, Val Acc: 0.4991
# Epoch 5, Train Loss: 1.4603, Train Acc: 0.5191, Val Acc: 0.5047
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 14.4988, Train Acc: 0.5155, Val Acc: 0.5300
# Epoch 2, Train Loss: 9.8925, Train Acc: 0.5244, Val Acc: 0.5019
# Epoch 3, Train Loss: 9.7080, Train Acc: 0.5217, Val Acc: 0.5019
# Epoch 4, Train Loss: 9.2596, Train Acc: 0.5312, Val Acc: 0.5009
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.7218, Train Acc: 0.5721, Val Acc: 0.6679
# Epoch 2, Train Loss: 0.5669, Train Acc: 0.7045, Val Acc: 0.7111
# Epoch 3, Train Loss: 0.4998, Train Acc: 0.7484, Val Acc: 0.7617
# Epoch 4, Train Loss: 0.4869, Train Acc: 0.7576, Val Acc: 0.7842
# Epoch 5, Train Loss: 0.4513, Train Acc: 0.7880, Val Acc: 0.7880
# Epoch 6, Train Loss: 0.4208, Train Acc: 0.8018, Val Acc: 0.6642
# Epoch 7, Train Loss: 0.4302, Train Acc: 0.7959, Val Acc: 0.7936
# Epoch 8, Train Loss: 0.4073, Train Acc: 0.8116, Val Acc: 0.7814
# Epoch 9, Train Loss: 0.4002, Train Acc: 0.8125, Val Acc: 0.7889
# Epoch 10, Train Loss: 0.3708, Train Acc: 0.8341, Val Acc: 0.7383
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 2.4355, Train Acc: 0.5104, Val Acc: 0.5131
# Epoch 2, Train Loss: 1.2977, Train Acc: 0.5338, Val Acc: 0.5019
# Epoch 3, Train Loss: 1.4566, Train Acc: 0.5304, Val Acc: 0.5516
# Epoch 4, Train Loss: 1.3199, Train Acc: 0.5361, Val Acc: 0.5056
# Epoch 5, Train Loss: 1.2868, Train Acc: 0.5320, Val Acc: 0.5403
# Epoch 6, Train Loss: 1.0686, Train Acc: 0.5517, Val Acc: 0.5047
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 18.9387, Train Acc: 0.5103, Val Acc: 0.5600
# Epoch 2, Train Loss: 10.7439, Train Acc: 0.5134, Val Acc: 0.5525
# Epoch 3, Train Loss: 9.9771, Train Acc: 0.5084, Val Acc: 0.5047
# Epoch 4, Train Loss: 9.5124, Train Acc: 0.5245, Val Acc: 0.5741
# Epoch 5, Train Loss: 9.2149, Train Acc: 0.5238, Val Acc: 0.5178
# Epoch 6, Train Loss: 9.6054, Train Acc: 0.5234, Val Acc: 0.5619
# Epoch 7, Train Loss: 9.9132, Train Acc: 0.5152, Val Acc: 0.5647
# Early stopping
# Best Validation Accuracy: 0.800187617260788
# Best Hyperparameters: {'lr': 0.1, 'batch_size': 32, 'optimizer': 'SGD'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_max['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_max = MaxPoolingRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_max['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])
elif best_hyperparams_RNN_max['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])
elif best_hyperparams_RNN_max['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])

best_model_RNN_max, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_max, train_loader, validation_loader,
                                                                                 best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.6402, Train Acc: 0.6402, Val Acc: 0.7289
# Epoch 2, Train Loss: 0.5126, Train Acc: 0.7386, Val Acc: 0.7683
# Epoch 3, Train Loss: 0.4832, Train Acc: 0.7657, Val Acc: 0.7730
# Epoch 4, Train Loss: 0.4653, Train Acc: 0.7754, Val Acc: 0.7664
# Epoch 5, Train Loss: 0.4348, Train Acc: 0.7924, Val Acc: 0.7777
# Epoch 6, Train Loss: 0.4229, Train Acc: 0.8011, Val Acc: 0.7467
# Epoch 7, Train Loss: 0.4119, Train Acc: 0.8106, Val Acc: 0.7964
# Epoch 8, Train Loss: 0.3848, Train Acc: 0.8302, Val Acc: 0.7795
# Epoch 9, Train Loss: 0.3897, Train Acc: 0.8236, Val Acc: 0.7946
# Epoch 10, Train Loss: 0.3666, Train Acc: 0.8314, Val Acc: 0.7636
# Early stopping

# %%
epochs_max = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_max, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_max, test_loader)
test_accuracies['RNN Max Pooling'] = test_acc
print(f'Test Accuracy (RNN Max Pooling): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Max Pooling): 0.7720

# %% [markdown]
# ### 3) RNN Average Pooling

# %%
# Call grid search
best_hyperparams_RNN_avg = run_grid_search(AveragePoolingRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6953, Train Acc: 0.4905, Val Acc: 0.5113
# Epoch 2, Train Loss: 0.6932, Train Acc: 0.5013, Val Acc: 0.5657
# Epoch 3, Train Loss: 0.6916, Train Acc: 0.5336, Val Acc: 0.5779
# Epoch 4, Train Loss: 0.6904, Train Acc: 0.5689, Val Acc: 0.6126
# Epoch 5, Train Loss: 0.6894, Train Acc: 0.5785, Val Acc: 0.5938
# Epoch 6, Train Loss: 0.6881, Train Acc: 0.5869, Val Acc: 0.6248
# Epoch 7, Train Loss: 0.6868, Train Acc: 0.5994, Val Acc: 0.5994
# Epoch 8, Train Loss: 0.6851, Train Acc: 0.6159, Val Acc: 0.6107
# Epoch 9, Train Loss: 0.6834, Train Acc: 0.6091, Val Acc: 0.6388
# Epoch 10, Train Loss: 0.6820, Train Acc: 0.6227, Val Acc: 0.5882
# Epoch 11, Train Loss: 0.6800, Train Acc: 0.6285, Val Acc: 0.6041
# Epoch 12, Train Loss: 0.6778, Train Acc: 0.6387, Val Acc: 0.6567
# Epoch 13, Train Loss: 0.6754, Train Acc: 0.6438, Val Acc: 0.6538
# Epoch 14, Train Loss: 0.6720, Train Acc: 0.6563, Val Acc: 0.6876
# Epoch 15, Train Loss: 0.6682, Train Acc: 0.6625, Val Acc: 0.6548
# Epoch 16, Train Loss: 0.6624, Train Acc: 0.6713, Val Acc: 0.6079
# Epoch 17, Train Loss: 0.6525, Train Acc: 0.6710, Val Acc: 0.6520
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6796, Train Acc: 0.5832, Val Acc: 0.5844
# Epoch 2, Train Loss: 0.6633, Train Acc: 0.5945, Val Acc: 0.6867
# Epoch 3, Train Loss: 0.5746, Train Acc: 0.7012, Val Acc: 0.7214
# Epoch 4, Train Loss: 0.5484, Train Acc: 0.7233, Val Acc: 0.7308
# Epoch 5, Train Loss: 0.5191, Train Acc: 0.7482, Val Acc: 0.7570
# Epoch 6, Train Loss: 0.5034, Train Acc: 0.7589, Val Acc: 0.7655
# Epoch 7, Train Loss: 0.5058, Train Acc: 0.7546, Val Acc: 0.7711
# Epoch 8, Train Loss: 0.5097, Train Acc: 0.7505, Val Acc: 0.6989
# Epoch 9, Train Loss: 0.5042, Train Acc: 0.7555, Val Acc: 0.7617
# Epoch 10, Train Loss: 0.4904, Train Acc: 0.7652, Val Acc: 0.7514
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7007, Train Acc: 0.5298, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.6838, Train Acc: 0.5744, Val Acc: 0.4203
# Epoch 3, Train Loss: 0.6040, Train Acc: 0.6739, Val Acc: 0.5835
# Epoch 4, Train Loss: 0.5422, Train Acc: 0.7339, Val Acc: 0.5854
# Epoch 5, Train Loss: 0.5315, Train Acc: 0.7430, Val Acc: 0.7486
# Epoch 6, Train Loss: 0.5154, Train Acc: 0.7470, Val Acc: 0.7270
# Epoch 7, Train Loss: 0.5101, Train Acc: 0.7504, Val Acc: 0.7326
# Epoch 8, Train Loss: 0.4981, Train Acc: 0.7594, Val Acc: 0.7289
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6930, Train Acc: 0.5101, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6919, Train Acc: 0.5210, Val Acc: 0.5235
# Epoch 3, Train Loss: 0.6912, Train Acc: 0.5287, Val Acc: 0.5235
# Epoch 4, Train Loss: 0.6907, Train Acc: 0.5397, Val Acc: 0.5225
# Epoch 5, Train Loss: 0.6901, Train Acc: 0.5477, Val Acc: 0.5403
# Epoch 6, Train Loss: 0.6897, Train Acc: 0.5491, Val Acc: 0.5422
# Epoch 7, Train Loss: 0.6894, Train Acc: 0.5557, Val Acc: 0.5525
# Epoch 8, Train Loss: 0.6884, Train Acc: 0.5693, Val Acc: 0.5488
# Epoch 9, Train Loss: 0.6881, Train Acc: 0.5679, Val Acc: 0.5619
# Epoch 10, Train Loss: 0.6875, Train Acc: 0.5832, Val Acc: 0.5694
# Epoch 11, Train Loss: 0.6870, Train Acc: 0.5864, Val Acc: 0.5769
# Epoch 12, Train Loss: 0.6863, Train Acc: 0.5859, Val Acc: 0.5835
# Epoch 13, Train Loss: 0.6855, Train Acc: 0.6006, Val Acc: 0.5947
# Epoch 14, Train Loss: 0.6851, Train Acc: 0.5962, Val Acc: 0.6023
# Epoch 15, Train Loss: 0.6842, Train Acc: 0.6174, Val Acc: 0.6154
# Epoch 16, Train Loss: 0.6836, Train Acc: 0.6128, Val Acc: 0.6154
# Epoch 17, Train Loss: 0.6831, Train Acc: 0.6216, Val Acc: 0.6041
# Epoch 18, Train Loss: 0.6819, Train Acc: 0.6189, Val Acc: 0.6295
# Epoch 19, Train Loss: 0.6812, Train Acc: 0.6352, Val Acc: 0.6248
# Epoch 20, Train Loss: 0.6804, Train Acc: 0.6309, Val Acc: 0.6238
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6189, Train Acc: 0.6510, Val Acc: 0.7326
# Epoch 2, Train Loss: 0.5454, Train Acc: 0.7360, Val Acc: 0.7008
# Epoch 3, Train Loss: 0.5173, Train Acc: 0.7510, Val Acc: 0.7580
# Epoch 4, Train Loss: 0.5069, Train Acc: 0.7537, Val Acc: 0.7514
# Epoch 5, Train Loss: 0.5014, Train Acc: 0.7631, Val Acc: 0.7627
# Epoch 6, Train Loss: 0.4906, Train Acc: 0.7660, Val Acc: 0.7645
# Epoch 7, Train Loss: 0.4888, Train Acc: 0.7647, Val Acc: 0.7767
# Epoch 8, Train Loss: 0.4851, Train Acc: 0.7666, Val Acc: 0.7674
# Epoch 9, Train Loss: 0.4709, Train Acc: 0.7742, Val Acc: 0.7674
# Epoch 10, Train Loss: 0.4715, Train Acc: 0.7762, Val Acc: 0.7580
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6672, Train Acc: 0.5848, Val Acc: 0.7092
# Epoch 2, Train Loss: 0.5464, Train Acc: 0.7283, Val Acc: 0.6857
# Epoch 3, Train Loss: 0.5191, Train Acc: 0.7447, Val Acc: 0.7158
# Epoch 4, Train Loss: 0.5059, Train Acc: 0.7563, Val Acc: 0.7289
# Epoch 5, Train Loss: 0.4935, Train Acc: 0.7646, Val Acc: 0.7448
# Epoch 6, Train Loss: 0.4909, Train Acc: 0.7645, Val Acc: 0.7514
# Epoch 7, Train Loss: 0.4865, Train Acc: 0.7660, Val Acc: 0.7739
# Epoch 8, Train Loss: 0.4744, Train Acc: 0.7762, Val Acc: 0.7842
# Epoch 9, Train Loss: 0.4702, Train Acc: 0.7730, Val Acc: 0.7636
# Epoch 10, Train Loss: 0.4764, Train Acc: 0.7710, Val Acc: 0.7430
# Epoch 11, Train Loss: 0.4747, Train Acc: 0.7735, Val Acc: 0.7767
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6947, Train Acc: 0.5013, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6929, Train Acc: 0.5128, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.6927, Train Acc: 0.5192, Val Acc: 0.5432
# Epoch 4, Train Loss: 0.6925, Train Acc: 0.5190, Val Acc: 0.5403
# Epoch 5, Train Loss: 0.6921, Train Acc: 0.5273, Val Acc: 0.5347
# Epoch 6, Train Loss: 0.6919, Train Acc: 0.5314, Val Acc: 0.5300
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.6263, Train Acc: 0.6409, Val Acc: 0.7139
# Epoch 2, Train Loss: 0.5465, Train Acc: 0.7346, Val Acc: 0.7448
# Epoch 3, Train Loss: 0.5211, Train Acc: 0.7488, Val Acc: 0.7448
# Epoch 4, Train Loss: 0.5083, Train Acc: 0.7569, Val Acc: 0.7242
# Epoch 5, Train Loss: 0.4972, Train Acc: 0.7600, Val Acc: 0.7617
# Epoch 6, Train Loss: 0.4810, Train Acc: 0.7652, Val Acc: 0.7655
# Epoch 7, Train Loss: 0.4785, Train Acc: 0.7730, Val Acc: 0.7664
# Epoch 8, Train Loss: 0.4728, Train Acc: 0.7710, Val Acc: 0.7814
# Epoch 9, Train Loss: 0.4600, Train Acc: 0.7866, Val Acc: 0.7767
# Epoch 10, Train Loss: 0.4538, Train Acc: 0.7862, Val Acc: 0.8039
# Epoch 11, Train Loss: 0.4395, Train Acc: 0.7961, Val Acc: 0.7814
# Epoch 12, Train Loss: 0.4417, Train Acc: 0.7938, Val Acc: 0.7814
# Epoch 13, Train Loss: 0.4227, Train Acc: 0.8045, Val Acc: 0.7477
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6818, Train Acc: 0.5721, Val Acc: 0.5788
# Epoch 2, Train Loss: 0.5825, Train Acc: 0.7005, Val Acc: 0.6923
# Epoch 3, Train Loss: 0.5402, Train Acc: 0.7369, Val Acc: 0.7083
# Epoch 4, Train Loss: 0.5192, Train Acc: 0.7492, Val Acc: 0.7326
# Epoch 5, Train Loss: 0.5101, Train Acc: 0.7511, Val Acc: 0.7552
# Epoch 6, Train Loss: 0.4993, Train Acc: 0.7565, Val Acc: 0.7336
# Epoch 7, Train Loss: 0.4977, Train Acc: 0.7555, Val Acc: 0.7617
# Epoch 8, Train Loss: 0.4937, Train Acc: 0.7594, Val Acc: 0.7552
# Epoch 9, Train Loss: 0.4922, Train Acc: 0.7638, Val Acc: 0.7617
# Epoch 10, Train Loss: 0.4894, Train Acc: 0.7662, Val Acc: 0.7683
# Epoch 11, Train Loss: 0.4859, Train Acc: 0.7669, Val Acc: 0.7026
# Epoch 12, Train Loss: 0.4789, Train Acc: 0.7735, Val Acc: 0.7439
# Epoch 13, Train Loss: 0.4828, Train Acc: 0.7672, Val Acc: 0.7083
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6928, Train Acc: 0.5103, Val Acc: 0.5028
# Epoch 2, Train Loss: 0.6876, Train Acc: 0.5633, Val Acc: 0.5929
# Epoch 3, Train Loss: 0.6791, Train Acc: 0.6103, Val Acc: 0.6069
# Epoch 4, Train Loss: 0.6549, Train Acc: 0.6400, Val Acc: 0.5047
# Epoch 5, Train Loss: 0.6042, Train Acc: 0.6717, Val Acc: 0.6623
# Epoch 6, Train Loss: 0.5703, Train Acc: 0.7047, Val Acc: 0.7129
# Epoch 7, Train Loss: 0.5506, Train Acc: 0.7238, Val Acc: 0.6351
# Epoch 8, Train Loss: 0.5419, Train Acc: 0.7288, Val Acc: 0.6942
# Epoch 9, Train Loss: 0.5395, Train Acc: 0.7291, Val Acc: 0.7392
# Epoch 10, Train Loss: 0.5314, Train Acc: 0.7339, Val Acc: 0.7467
# Epoch 11, Train Loss: 0.5257, Train Acc: 0.7383, Val Acc: 0.6135
# Epoch 12, Train Loss: 0.5240, Train Acc: 0.7377, Val Acc: 0.6745
# Epoch 13, Train Loss: 0.5200, Train Acc: 0.7437, Val Acc: 0.6698
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6682, Train Acc: 0.5864, Val Acc: 0.6398
# Epoch 2, Train Loss: 0.5911, Train Acc: 0.6887, Val Acc: 0.7101
# Epoch 3, Train Loss: 0.5866, Train Acc: 0.6887, Val Acc: 0.6848
# Epoch 4, Train Loss: 0.5642, Train Acc: 0.7106, Val Acc: 0.6848
# Epoch 5, Train Loss: 0.5631, Train Acc: 0.7145, Val Acc: 0.7064
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7041, Train Acc: 0.5135, Val Acc: 0.5544
# Epoch 2, Train Loss: 0.6856, Train Acc: 0.5545, Val Acc: 0.5722
# Epoch 3, Train Loss: 0.6743, Train Acc: 0.5784, Val Acc: 0.5732
# Epoch 4, Train Loss: 0.6457, Train Acc: 0.6202, Val Acc: 0.6473
# Epoch 5, Train Loss: 0.6203, Train Acc: 0.6555, Val Acc: 0.6820
# Epoch 6, Train Loss: 0.5926, Train Acc: 0.6879, Val Acc: 0.6811
# Epoch 7, Train Loss: 0.5859, Train Acc: 0.6940, Val Acc: 0.5150
# Epoch 8, Train Loss: 0.5920, Train Acc: 0.6918, Val Acc: 0.5572
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6926, Train Acc: 0.5137, Val Acc: 0.5084
# Epoch 2, Train Loss: 0.6902, Train Acc: 0.5451, Val Acc: 0.5422
# Epoch 3, Train Loss: 0.6877, Train Acc: 0.5644, Val Acc: 0.5929
# Epoch 4, Train Loss: 0.6856, Train Acc: 0.5943, Val Acc: 0.5338
# Epoch 5, Train Loss: 0.6824, Train Acc: 0.6057, Val Acc: 0.5704
# Epoch 6, Train Loss: 0.6785, Train Acc: 0.6226, Val Acc: 0.6510
# Epoch 7, Train Loss: 0.6729, Train Acc: 0.6351, Val Acc: 0.6379
# Epoch 8, Train Loss: 0.6645, Train Acc: 0.6413, Val Acc: 0.6614
# Epoch 9, Train Loss: 0.6421, Train Acc: 0.6572, Val Acc: 0.6595
# Epoch 10, Train Loss: 0.5958, Train Acc: 0.6846, Val Acc: 0.5694
# Epoch 11, Train Loss: 0.5759, Train Acc: 0.6927, Val Acc: 0.5516
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6761, Train Acc: 0.5812, Val Acc: 0.6529
# Epoch 2, Train Loss: 0.6070, Train Acc: 0.6735, Val Acc: 0.6801
# Epoch 3, Train Loss: 0.5887, Train Acc: 0.6916, Val Acc: 0.6529
# Epoch 4, Train Loss: 0.5666, Train Acc: 0.7039, Val Acc: 0.7139
# Epoch 5, Train Loss: 0.5514, Train Acc: 0.7165, Val Acc: 0.7214
# Epoch 6, Train Loss: 0.5468, Train Acc: 0.7197, Val Acc: 0.7270
# Epoch 7, Train Loss: 0.5583, Train Acc: 0.7106, Val Acc: 0.7261
# Epoch 8, Train Loss: 0.5351, Train Acc: 0.7376, Val Acc: 0.7345
# Epoch 9, Train Loss: 0.5491, Train Acc: 0.7209, Val Acc: 0.7392
# Epoch 10, Train Loss: 0.5482, Train Acc: 0.7170, Val Acc: 0.7364
# Epoch 11, Train Loss: 0.5402, Train Acc: 0.7279, Val Acc: 0.7467
# Epoch 12, Train Loss: 0.5320, Train Acc: 0.7414, Val Acc: 0.7036
# Epoch 13, Train Loss: 0.5469, Train Acc: 0.7239, Val Acc: 0.6951
# Epoch 14, Train Loss: 0.5709, Train Acc: 0.7032, Val Acc: 0.7073
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7144, Train Acc: 0.5272, Val Acc: 0.5178
# Epoch 2, Train Loss: 0.6698, Train Acc: 0.5831, Val Acc: 0.5507
# Epoch 3, Train Loss: 0.6800, Train Acc: 0.6054, Val Acc: 0.6679
# Epoch 4, Train Loss: 0.6172, Train Acc: 0.6624, Val Acc: 0.6876
# Epoch 5, Train Loss: 0.5756, Train Acc: 0.7077, Val Acc: 0.7205
# Epoch 6, Train Loss: 0.5590, Train Acc: 0.7195, Val Acc: 0.7251
# Epoch 7, Train Loss: 0.5531, Train Acc: 0.7290, Val Acc: 0.7308
# Epoch 8, Train Loss: 0.5363, Train Acc: 0.7343, Val Acc: 0.7298
# Epoch 9, Train Loss: 0.5335, Train Acc: 0.7373, Val Acc: 0.7430
# Epoch 10, Train Loss: 0.5139, Train Acc: 0.7483, Val Acc: 0.7552
# Epoch 11, Train Loss: 0.5103, Train Acc: 0.7525, Val Acc: 0.7270
# Epoch 12, Train Loss: 0.5028, Train Acc: 0.7545, Val Acc: 0.7420
# Epoch 13, Train Loss: 0.5079, Train Acc: 0.7579, Val Acc: 0.7233
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6947, Train Acc: 0.4808, Val Acc: 0.5019
# Epoch 2, Train Loss: 0.6931, Train Acc: 0.5029, Val Acc: 0.4925
# Epoch 3, Train Loss: 0.6917, Train Acc: 0.5240, Val Acc: 0.5478
# Epoch 4, Train Loss: 0.6907, Train Acc: 0.5482, Val Acc: 0.5319
# Epoch 5, Train Loss: 0.6889, Train Acc: 0.5785, Val Acc: 0.6079
# Epoch 6, Train Loss: 0.6879, Train Acc: 0.5862, Val Acc: 0.5356
# Epoch 7, Train Loss: 0.6861, Train Acc: 0.5885, Val Acc: 0.5938
# Epoch 8, Train Loss: 0.6845, Train Acc: 0.6015, Val Acc: 0.6304
# Epoch 9, Train Loss: 0.6826, Train Acc: 0.6266, Val Acc: 0.5619
# Epoch 10, Train Loss: 0.6809, Train Acc: 0.6229, Val Acc: 0.5750
# Epoch 11, Train Loss: 0.6786, Train Acc: 0.6309, Val Acc: 0.6013
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.6617, Train Acc: 0.6057, Val Acc: 0.6998
# Epoch 2, Train Loss: 0.5621, Train Acc: 0.7169, Val Acc: 0.7233
# Epoch 3, Train Loss: 0.5532, Train Acc: 0.7273, Val Acc: 0.7383
# Epoch 4, Train Loss: 0.5403, Train Acc: 0.7321, Val Acc: 0.7373
# Epoch 5, Train Loss: 0.5279, Train Acc: 0.7415, Val Acc: 0.7355
# Epoch 6, Train Loss: 0.5128, Train Acc: 0.7516, Val Acc: 0.7430
# Epoch 7, Train Loss: 0.5191, Train Acc: 0.7470, Val Acc: 0.7514
# Epoch 8, Train Loss: 0.5118, Train Acc: 0.7524, Val Acc: 0.7486
# Epoch 9, Train Loss: 0.5095, Train Acc: 0.7560, Val Acc: 0.7289
# Epoch 10, Train Loss: 0.5087, Train Acc: 0.7538, Val Acc: 0.7317
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7134, Train Acc: 0.5138, Val Acc: 0.5685
# Epoch 2, Train Loss: 0.6670, Train Acc: 0.6041, Val Acc: 0.5863
# Epoch 3, Train Loss: 0.6272, Train Acc: 0.6621, Val Acc: 0.6576
# Epoch 4, Train Loss: 0.6368, Train Acc: 0.6880, Val Acc: 0.6735
# Epoch 5, Train Loss: 0.5803, Train Acc: 0.6971, Val Acc: 0.6154
# Epoch 6, Train Loss: 0.5606, Train Acc: 0.7145, Val Acc: 0.7317
# Epoch 7, Train Loss: 0.5628, Train Acc: 0.7168, Val Acc: 0.6698
# Epoch 8, Train Loss: 0.5488, Train Acc: 0.7227, Val Acc: 0.7223
# Epoch 9, Train Loss: 0.5537, Train Acc: 0.7199, Val Acc: 0.6341
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6908, Train Acc: 0.5313, Val Acc: 0.5272
# Epoch 2, Train Loss: 0.6800, Train Acc: 0.5801, Val Acc: 0.6473
# Epoch 3, Train Loss: 0.6419, Train Acc: 0.6352, Val Acc: 0.5281
# Epoch 4, Train Loss: 0.5961, Train Acc: 0.6845, Val Acc: 0.6538
# Epoch 5, Train Loss: 0.5718, Train Acc: 0.7062, Val Acc: 0.6998
# Epoch 6, Train Loss: 0.5519, Train Acc: 0.7251, Val Acc: 0.7261
# Epoch 7, Train Loss: 0.5452, Train Acc: 0.7294, Val Acc: 0.6276
# Epoch 8, Train Loss: 0.5446, Train Acc: 0.7302, Val Acc: 0.7017
# Epoch 9, Train Loss: 0.5354, Train Acc: 0.7368, Val Acc: 0.7477
# Epoch 10, Train Loss: 0.5353, Train Acc: 0.7383, Val Acc: 0.7458
# Epoch 11, Train Loss: 0.5305, Train Acc: 0.7322, Val Acc: 0.7570
# Epoch 12, Train Loss: 0.5164, Train Acc: 0.7426, Val Acc: 0.7608
# Epoch 13, Train Loss: 0.5144, Train Acc: 0.7475, Val Acc: 0.7373
# Epoch 14, Train Loss: 0.5138, Train Acc: 0.7509, Val Acc: 0.6970
# Epoch 15, Train Loss: 0.5097, Train Acc: 0.7462, Val Acc: 0.7270
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6862, Train Acc: 0.5586, Val Acc: 0.5460
# Epoch 2, Train Loss: 0.6716, Train Acc: 0.5783, Val Acc: 0.5882
# Epoch 3, Train Loss: 0.7048, Train Acc: 0.5807, Val Acc: 0.5403
# Epoch 4, Train Loss: 0.7142, Train Acc: 0.5764, Val Acc: 0.5929
# Epoch 5, Train Loss: 0.6983, Train Acc: 0.5780, Val Acc: 0.5038
# Epoch 6, Train Loss: 0.6905, Train Acc: 0.5868, Val Acc: 0.6144
# Epoch 7, Train Loss: 0.6836, Train Acc: 0.5914, Val Acc: 0.5300
# Epoch 8, Train Loss: 0.6794, Train Acc: 0.5858, Val Acc: 0.6107
# Epoch 9, Train Loss: 0.6677, Train Acc: 0.5954, Val Acc: 0.5901
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7109, Train Acc: 0.5256, Val Acc: 0.5525
# Epoch 2, Train Loss: 0.7527, Train Acc: 0.5419, Val Acc: 0.5694
# Epoch 3, Train Loss: 0.7429, Train Acc: 0.5607, Val Acc: 0.5366
# Epoch 4, Train Loss: 0.6104, Train Acc: 0.6590, Val Acc: 0.5910
# Epoch 5, Train Loss: 0.5775, Train Acc: 0.7039, Val Acc: 0.6323
# Epoch 6, Train Loss: 0.5679, Train Acc: 0.7104, Val Acc: 0.6642
# Epoch 7, Train Loss: 0.5499, Train Acc: 0.7226, Val Acc: 0.7298
# Epoch 8, Train Loss: 0.5444, Train Acc: 0.7247, Val Acc: 0.7036
# Epoch 9, Train Loss: 0.5510, Train Acc: 0.7157, Val Acc: 0.6867
# Epoch 10, Train Loss: 0.5437, Train Acc: 0.7253, Val Acc: 0.7373
# Epoch 11, Train Loss: 0.5367, Train Acc: 0.7283, Val Acc: 0.7289
# Epoch 12, Train Loss: 0.5361, Train Acc: 0.7315, Val Acc: 0.5863
# Epoch 13, Train Loss: 0.5270, Train Acc: 0.7328, Val Acc: 0.7167
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6924, Train Acc: 0.5225, Val Acc: 0.5225
# Epoch 2, Train Loss: 0.6863, Train Acc: 0.5646, Val Acc: 0.5610
# Epoch 3, Train Loss: 0.6784, Train Acc: 0.6074, Val Acc: 0.6651
# Epoch 4, Train Loss: 0.6525, Train Acc: 0.6382, Val Acc: 0.6829
# Epoch 5, Train Loss: 0.6105, Train Acc: 0.6717, Val Acc: 0.7289
# Epoch 6, Train Loss: 0.5806, Train Acc: 0.6947, Val Acc: 0.7064
# Epoch 7, Train Loss: 0.5627, Train Acc: 0.7096, Val Acc: 0.7280
# Epoch 8, Train Loss: 0.5539, Train Acc: 0.7145, Val Acc: 0.7205
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6993, Train Acc: 0.5311, Val Acc: 0.5235
# Epoch 2, Train Loss: 0.6731, Train Acc: 0.5740, Val Acc: 0.5675
# Epoch 3, Train Loss: 0.6623, Train Acc: 0.5866, Val Acc: 0.5788
# Epoch 4, Train Loss: 0.6518, Train Acc: 0.6046, Val Acc: 0.6088
# Epoch 5, Train Loss: 0.6481, Train Acc: 0.6135, Val Acc: 0.5966
# Epoch 6, Train Loss: 0.6469, Train Acc: 0.6103, Val Acc: 0.5901
# Epoch 7, Train Loss: 0.6405, Train Acc: 0.6225, Val Acc: 0.6126
# Epoch 8, Train Loss: 0.6336, Train Acc: 0.6312, Val Acc: 0.6717
# Epoch 9, Train Loss: 0.5866, Train Acc: 0.6892, Val Acc: 0.6932
# Epoch 10, Train Loss: 0.5665, Train Acc: 0.7042, Val Acc: 0.7120
# Epoch 11, Train Loss: 0.5640, Train Acc: 0.7059, Val Acc: 0.6951
# Epoch 12, Train Loss: 0.5533, Train Acc: 0.7178, Val Acc: 0.7176
# Epoch 13, Train Loss: 0.5539, Train Acc: 0.7122, Val Acc: 0.7392
# Epoch 14, Train Loss: 0.5341, Train Acc: 0.7290, Val Acc: 0.7064
# Epoch 15, Train Loss: 0.5301, Train Acc: 0.7365, Val Acc: 0.7326
# Epoch 16, Train Loss: 0.5266, Train Acc: 0.7399, Val Acc: 0.6961
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7366, Train Acc: 0.5336, Val Acc: 0.5750
# Epoch 2, Train Loss: 0.6942, Train Acc: 0.5800, Val Acc: 0.5553
# Epoch 3, Train Loss: 1.1793, Train Acc: 0.5674, Val Acc: 0.5366
# Epoch 4, Train Loss: 1.0992, Train Acc: 0.5361, Val Acc: 0.5197
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6942, Train Acc: 0.4899, Val Acc: 0.5188
# Epoch 2, Train Loss: 0.6921, Train Acc: 0.5223, Val Acc: 0.5469
# Epoch 3, Train Loss: 0.6898, Train Acc: 0.5509, Val Acc: 0.5075
# Epoch 4, Train Loss: 0.6878, Train Acc: 0.5703, Val Acc: 0.5432
# Epoch 5, Train Loss: 0.6852, Train Acc: 0.5946, Val Acc: 0.6567
# Epoch 6, Train Loss: 0.6815, Train Acc: 0.6141, Val Acc: 0.6144
# Epoch 7, Train Loss: 0.6780, Train Acc: 0.6297, Val Acc: 0.6492
# Epoch 8, Train Loss: 0.6723, Train Acc: 0.6375, Val Acc: 0.6904
# Epoch 9, Train Loss: 0.6609, Train Acc: 0.6505, Val Acc: 0.6623
# Epoch 10, Train Loss: 0.6297, Train Acc: 0.6648, Val Acc: 0.6614
# Epoch 11, Train Loss: 0.6202, Train Acc: 0.6579, Val Acc: 0.5516
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7135, Train Acc: 0.5096, Val Acc: 0.5178
# Epoch 2, Train Loss: 0.6845, Train Acc: 0.5604, Val Acc: 0.6182
# Epoch 3, Train Loss: 0.6807, Train Acc: 0.5676, Val Acc: 0.5779
# Epoch 4, Train Loss: 0.6753, Train Acc: 0.5768, Val Acc: 0.5591
# Epoch 5, Train Loss: 0.6723, Train Acc: 0.5812, Val Acc: 0.5600
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7511, Train Acc: 0.5059, Val Acc: 0.4972
# Epoch 2, Train Loss: 0.6845, Train Acc: 0.5526, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.6636, Train Acc: 0.6070, Val Acc: 0.6304
# Epoch 4, Train Loss: 0.6311, Train Acc: 0.6496, Val Acc: 0.6285
# Epoch 5, Train Loss: 0.6143, Train Acc: 0.6637, Val Acc: 0.6567
# Epoch 6, Train Loss: 0.6332, Train Acc: 0.6676, Val Acc: 0.5816
# Epoch 7, Train Loss: 0.5763, Train Acc: 0.7007, Val Acc: 0.7073
# Epoch 8, Train Loss: 0.6045, Train Acc: 0.6709, Val Acc: 0.6585
# Epoch 9, Train Loss: 0.5827, Train Acc: 0.6921, Val Acc: 0.6979
# Epoch 10, Train Loss: 0.5698, Train Acc: 0.7062, Val Acc: 0.6735
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6799, Train Acc: 0.5647, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6110, Train Acc: 0.6617, Val Acc: 0.6445
# Epoch 3, Train Loss: 0.5643, Train Acc: 0.7095, Val Acc: 0.7186
# Epoch 4, Train Loss: 0.5354, Train Acc: 0.7348, Val Acc: 0.6088
# Epoch 5, Train Loss: 0.5181, Train Acc: 0.7491, Val Acc: 0.5788
# Epoch 6, Train Loss: 0.5105, Train Acc: 0.7571, Val Acc: 0.5863
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.9552, Train Acc: 0.5343, Val Acc: 0.5000
# Epoch 2, Train Loss: 4.9095, Train Acc: 0.5192, Val Acc: 0.5000
# Epoch 3, Train Loss: 2.5699, Train Acc: 0.5117, Val Acc: 0.5122
# Epoch 4, Train Loss: 1.4889, Train Acc: 0.5312, Val Acc: 0.6004
# Epoch 5, Train Loss: 2.4408, Train Acc: 0.5272, Val Acc: 0.5356
# Epoch 6, Train Loss: 1.9640, Train Acc: 0.5299, Val Acc: 0.5441
# Epoch 7, Train Loss: 2.0680, Train Acc: 0.5297, Val Acc: 0.5197
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 3.9147, Train Acc: 0.5064, Val Acc: 0.5141
# Epoch 2, Train Loss: 3.1920, Train Acc: 0.5151, Val Acc: 0.5159
# Epoch 3, Train Loss: 2.7472, Train Acc: 0.5300, Val Acc: 0.5188
# Epoch 4, Train Loss: 4.2350, Train Acc: 0.5210, Val Acc: 0.5225
# Epoch 5, Train Loss: 2.2521, Train Acc: 0.5306, Val Acc: 0.5009
# Epoch 6, Train Loss: 2.3673, Train Acc: 0.5215, Val Acc: 0.5000
# Epoch 7, Train Loss: 2.0965, Train Acc: 0.5298, Val Acc: 0.5094
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6813, Train Acc: 0.5577, Val Acc: 0.5019
# Epoch 2, Train Loss: 0.6412, Train Acc: 0.6365, Val Acc: 0.7195
# Epoch 3, Train Loss: 0.5845, Train Acc: 0.6960, Val Acc: 0.7111
# Epoch 4, Train Loss: 0.5568, Train Acc: 0.7197, Val Acc: 0.7486
# Epoch 5, Train Loss: 0.5322, Train Acc: 0.7401, Val Acc: 0.7186
# Epoch 6, Train Loss: 0.5215, Train Acc: 0.7430, Val Acc: 0.6801
# Epoch 7, Train Loss: 0.5050, Train Acc: 0.7557, Val Acc: 0.6839
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 1.8826, Train Acc: 0.5131, Val Acc: 0.4794
# Epoch 2, Train Loss: 1.7506, Train Acc: 0.5067, Val Acc: 0.5019
# Epoch 3, Train Loss: 1.6916, Train Acc: 0.5175, Val Acc: 0.5047
# Epoch 4, Train Loss: 2.0751, Train Acc: 0.5100, Val Acc: 0.5159
# Epoch 5, Train Loss: 1.6762, Train Acc: 0.5338, Val Acc: 0.5206
# Epoch 6, Train Loss: 1.3625, Train Acc: 0.5294, Val Acc: 0.5028
# Epoch 7, Train Loss: 1.3510, Train Acc: 0.5414, Val Acc: 0.5000
# Epoch 8, Train Loss: 1.4572, Train Acc: 0.5428, Val Acc: 0.5891
# Epoch 9, Train Loss: 1.0982, Train Acc: 0.5485, Val Acc: 0.5000
# Epoch 10, Train Loss: 1.5408, Train Acc: 0.5319, Val Acc: 0.5000
# Epoch 11, Train Loss: 2.1516, Train Acc: 0.5298, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0161, Train Acc: 0.5145, Val Acc: 0.5084
# Epoch 2, Train Loss: 0.8204, Train Acc: 0.5267, Val Acc: 0.5028
# Epoch 3, Train Loss: 0.8968, Train Acc: 0.5260, Val Acc: 0.5666
# Epoch 4, Train Loss: 1.2340, Train Acc: 0.5298, Val Acc: 0.5038
# Epoch 5, Train Loss: 1.0395, Train Acc: 0.5287, Val Acc: 0.5103
# Epoch 6, Train Loss: 1.0244, Train Acc: 0.5351, Val Acc: 0.5356
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6866, Train Acc: 0.5465, Val Acc: 0.5131
# Epoch 2, Train Loss: 0.6677, Train Acc: 0.5975, Val Acc: 0.6904
# Epoch 3, Train Loss: 0.6282, Train Acc: 0.6556, Val Acc: 0.5919
# Epoch 4, Train Loss: 0.5994, Train Acc: 0.6886, Val Acc: 0.6717
# Epoch 5, Train Loss: 0.5710, Train Acc: 0.7123, Val Acc: 0.6004
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7952, Train Acc: 0.5321, Val Acc: 0.5347
# Epoch 2, Train Loss: 0.7340, Train Acc: 0.5440, Val Acc: 0.5131
# Epoch 3, Train Loss: 1.0080, Train Acc: 0.5161, Val Acc: 0.5141
# Epoch 4, Train Loss: 1.5090, Train Acc: 0.5131, Val Acc: 0.5019
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 3.3632, Train Acc: 0.5053, Val Acc: 0.5056
# Epoch 2, Train Loss: 1.4482, Train Acc: 0.5076, Val Acc: 0.5066
# Epoch 3, Train Loss: 1.4615, Train Acc: 0.5129, Val Acc: 0.5272
# Epoch 4, Train Loss: 1.2735, Train Acc: 0.5253, Val Acc: 0.5094
# Epoch 5, Train Loss: 1.4317, Train Acc: 0.5165, Val Acc: 0.5019
# Epoch 6, Train Loss: 1.3016, Train Acc: 0.5181, Val Acc: 0.5272
# Early stopping
# Best Validation Accuracy: 0.8039399624765479
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 64, 'optimizer': 'Adam'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_avg['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_avg = AveragePoolingRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_avg['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
elif best_hyperparams_RNN_avg['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
elif best_hyperparams_RNN_avg['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])

best_model_RNN_avg, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_avg, train_loader, validation_loader,
                                                                                 best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.6331, Train Acc: 0.6460, Val Acc: 0.7355
# Epoch 2, Train Loss: 0.5472, Train Acc: 0.7300, Val Acc: 0.7383
# Epoch 3, Train Loss: 0.5316, Train Acc: 0.7442, Val Acc: 0.7477
# Epoch 4, Train Loss: 0.5038, Train Acc: 0.7593, Val Acc: 0.7458
# Epoch 5, Train Loss: 0.5020, Train Acc: 0.7573, Val Acc: 0.7627
# Epoch 6, Train Loss: 0.4868, Train Acc: 0.7644, Val Acc: 0.7655
# Epoch 7, Train Loss: 0.4814, Train Acc: 0.7678, Val Acc: 0.7617
# Epoch 8, Train Loss: 0.4811, Train Acc: 0.7688, Val Acc: 0.7308
# Epoch 9, Train Loss: 0.4693, Train Acc: 0.7773, Val Acc: 0.7702
# Epoch 10, Train Loss: 0.4688, Train Acc: 0.7699, Val Acc: 0.7674
# Epoch 11, Train Loss: 0.4514, Train Acc: 0.7796, Val Acc: 0.7795
# Epoch 12, Train Loss: 0.4526, Train Acc: 0.7809, Val Acc: 0.7420
# Epoch 13, Train Loss: 0.4582, Train Acc: 0.7821, Val Acc: 0.7345
# Epoch 14, Train Loss: 0.4482, Train Acc: 0.7891, Val Acc: 0.7758
# Early stopping

# %%
epochs_avg = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_avg, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_avg, test_loader)
test_accuracies['RNN Average Pooling'] = test_acc
print(f'Test Accuracy (RNN Average Pooling): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Average Pooling): 0.7674

# %%
test_accuracies
# Out:
# {'RNN Last Hidden State': 0.5159474671669794,
#  'RNN Max Pooling': 0.7720450281425891,
#  'RNN Average Pooling': 0.7673545966228893}

# %% [markdown]
# **Max pooling** achieved the highest test accuracy of 0.7923.
# Thus, in the following sectinos we will apply max pooling to derive the final sentence representation to perform sentiment classification.

# %% [markdown]
# # Part 3: Enhancement

# %% [markdown]
# The RNN model used in Part 2 is a basic model to perform the task of sentiment classification. In  this section, you will design strategies to improve upon the previous model you have built. You ar
#  required to implement the following adjustments:

# %% [markdown]
# 1. Instead of keeping the word embeddings fixed, now update the word embeddings (the same way as model parameters) during the training process.
# 2. As discussed in Question 1(c), apply your solution in mitigating the influence of OOV words and train your model again.
# 3. Keeping the above two adjustments, replace your simple RNN model in Part 2 with a biLSTM model and a biGRU model, incorporating recurrent computations in both directions and stacking multiple layers if possible.
# 4. Keeping the above two adjustments, replace your simple RNN model in Part 2 with a Convolutional Neural Network (CNN) to produce sentence representations and perform sentiment classification.
# 5. Further improve your model. You are free to use any strategy other than the above mentioned solutions. Changing hyper-parameters or stacking more layers is not counted towards a meaningful improvement.

# %% [markdown]
# ## Question 3: Enhancement

# %% [markdown]
# ### (a) Report the accuracy score on the test set when the word embeddings are updated (Part 3.1).

# %% [markdown]
# Set `freeze=False` when initializing the embedding layer to allow word embeddings update.

# %%
class MaxPoolingRNNModelUpdate(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(MaxPoolingRNNModelUpdate, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Max pooling over all hidden states
        max_pooled, _ = torch.max(rnn_output, dim=1)
        output = self.fc(max_pooled)
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# Call grid search
best_hyperparams_RNN_update = run_grid_search(MaxPoolingRNNModelUpdate, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6930, Train Acc: 0.5047, Val Acc: 0.5375
# Epoch 2, Train Loss: 0.6901, Train Acc: 0.5368, Val Acc: 0.5619
# Epoch 3, Train Loss: 0.6866, Train Acc: 0.5624, Val Acc: 0.5929
# Epoch 4, Train Loss: 0.6831, Train Acc: 0.5804, Val Acc: 0.6154
# Epoch 5, Train Loss: 0.6802, Train Acc: 0.6016, Val Acc: 0.5338
# Epoch 6, Train Loss: 0.6766, Train Acc: 0.6103, Val Acc: 0.6248
# Epoch 7, Train Loss: 0.6720, Train Acc: 0.6442, Val Acc: 0.6445
# Epoch 8, Train Loss: 0.6673, Train Acc: 0.6528, Val Acc: 0.6801
# Epoch 9, Train Loss: 0.6621, Train Acc: 0.6535, Val Acc: 0.6651
# Epoch 10, Train Loss: 0.6545, Train Acc: 0.6812, Val Acc: 0.6998
# Epoch 11, Train Loss: 0.6456, Train Acc: 0.6896, Val Acc: 0.7054
# Epoch 12, Train Loss: 0.6352, Train Acc: 0.6950, Val Acc: 0.7120
# Epoch 13, Train Loss: 0.6230, Train Acc: 0.7025, Val Acc: 0.7139
# Epoch 14, Train Loss: 0.6052, Train Acc: 0.7086, Val Acc: 0.7036
# Epoch 15, Train Loss: 0.5850, Train Acc: 0.7111, Val Acc: 0.7083
# Epoch 16, Train Loss: 0.5641, Train Acc: 0.7168, Val Acc: 0.7148
# Epoch 17, Train Loss: 0.5514, Train Acc: 0.7219, Val Acc: 0.7148
# Epoch 18, Train Loss: 0.5403, Train Acc: 0.7295, Val Acc: 0.7214
# Epoch 19, Train Loss: 0.5334, Train Acc: 0.7346, Val Acc: 0.7186
# Epoch 20, Train Loss: 0.5279, Train Acc: 0.7362, Val Acc: 0.7111
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5152, Train Acc: 0.7411, Val Acc: 0.7861
# Epoch 2, Train Loss: 0.3656, Train Acc: 0.8363, Val Acc: 0.7955
# Epoch 3, Train Loss: 0.2453, Train Acc: 0.9033, Val Acc: 0.7692
# Epoch 4, Train Loss: 0.1479, Train Acc: 0.9441, Val Acc: 0.7861
# Epoch 5, Train Loss: 0.0919, Train Acc: 0.9692, Val Acc: 0.7570
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5322, Train Acc: 0.7264, Val Acc: 0.6970
# Epoch 2, Train Loss: 0.3925, Train Acc: 0.8200, Val Acc: 0.7120
# Epoch 3, Train Loss: 0.3035, Train Acc: 0.8667, Val Acc: 0.7861
# Epoch 4, Train Loss: 0.2284, Train Acc: 0.9084, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.1724, Train Acc: 0.9307, Val Acc: 0.7955
# Epoch 6, Train Loss: 0.1323, Train Acc: 0.9495, Val Acc: 0.7946
# Epoch 7, Train Loss: 0.0963, Train Acc: 0.9619, Val Acc: 0.7589
# Epoch 8, Train Loss: 0.0705, Train Acc: 0.9746, Val Acc: 0.7580
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6960, Train Acc: 0.5073, Val Acc: 0.5028
# Epoch 2, Train Loss: 0.6920, Train Acc: 0.5188, Val Acc: 0.5291
# Epoch 3, Train Loss: 0.6902, Train Acc: 0.5348, Val Acc: 0.5422
# Epoch 4, Train Loss: 0.6880, Train Acc: 0.5544, Val Acc: 0.5591
# Epoch 5, Train Loss: 0.6863, Train Acc: 0.5590, Val Acc: 0.5863
# Epoch 6, Train Loss: 0.6845, Train Acc: 0.5729, Val Acc: 0.6023
# Epoch 7, Train Loss: 0.6824, Train Acc: 0.5909, Val Acc: 0.6032
# Epoch 8, Train Loss: 0.6818, Train Acc: 0.5944, Val Acc: 0.6323
# Epoch 9, Train Loss: 0.6786, Train Acc: 0.6090, Val Acc: 0.6417
# Epoch 10, Train Loss: 0.6770, Train Acc: 0.6175, Val Acc: 0.6276
# Epoch 11, Train Loss: 0.6744, Train Acc: 0.6274, Val Acc: 0.6651
# Epoch 12, Train Loss: 0.6722, Train Acc: 0.6354, Val Acc: 0.6632
# Epoch 13, Train Loss: 0.6705, Train Acc: 0.6450, Val Acc: 0.6801
# Epoch 14, Train Loss: 0.6679, Train Acc: 0.6542, Val Acc: 0.6801
# Epoch 15, Train Loss: 0.6642, Train Acc: 0.6652, Val Acc: 0.6857
# Epoch 16, Train Loss: 0.6615, Train Acc: 0.6720, Val Acc: 0.6961
# Epoch 17, Train Loss: 0.6575, Train Acc: 0.6763, Val Acc: 0.6914
# Epoch 18, Train Loss: 0.6544, Train Acc: 0.6805, Val Acc: 0.6989
# Epoch 19, Train Loss: 0.6503, Train Acc: 0.6865, Val Acc: 0.7092
# Epoch 20, Train Loss: 0.6458, Train Acc: 0.6937, Val Acc: 0.6961
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5255, Train Acc: 0.7288, Val Acc: 0.7946
# Epoch 2, Train Loss: 0.3740, Train Acc: 0.8326, Val Acc: 0.8021
# Epoch 3, Train Loss: 0.2585, Train Acc: 0.8928, Val Acc: 0.7936
# Epoch 4, Train Loss: 0.1663, Train Acc: 0.9373, Val Acc: 0.7758
# Epoch 5, Train Loss: 0.1000, Train Acc: 0.9665, Val Acc: 0.7664
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5305, Train Acc: 0.7288, Val Acc: 0.7598
# Epoch 2, Train Loss: 0.3828, Train Acc: 0.8275, Val Acc: 0.7992
# Epoch 3, Train Loss: 0.2953, Train Acc: 0.8754, Val Acc: 0.7861
# Epoch 4, Train Loss: 0.2205, Train Acc: 0.9111, Val Acc: 0.7974
# Epoch 5, Train Loss: 0.1624, Train Acc: 0.9346, Val Acc: 0.7767
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6933, Train Acc: 0.5089, Val Acc: 0.5347
# Epoch 2, Train Loss: 0.6923, Train Acc: 0.5193, Val Acc: 0.5272
# Epoch 3, Train Loss: 0.6914, Train Acc: 0.5220, Val Acc: 0.5441
# Epoch 4, Train Loss: 0.6910, Train Acc: 0.5224, Val Acc: 0.5525
# Epoch 5, Train Loss: 0.6901, Train Acc: 0.5324, Val Acc: 0.5666
# Epoch 6, Train Loss: 0.6895, Train Acc: 0.5421, Val Acc: 0.5713
# Epoch 7, Train Loss: 0.6886, Train Acc: 0.5504, Val Acc: 0.5797
# Epoch 8, Train Loss: 0.6873, Train Acc: 0.5597, Val Acc: 0.5816
# Epoch 9, Train Loss: 0.6875, Train Acc: 0.5576, Val Acc: 0.5816
# Epoch 10, Train Loss: 0.6855, Train Acc: 0.5717, Val Acc: 0.5882
# Epoch 11, Train Loss: 0.6851, Train Acc: 0.5682, Val Acc: 0.6051
# Epoch 12, Train Loss: 0.6850, Train Acc: 0.5722, Val Acc: 0.6069
# Epoch 13, Train Loss: 0.6840, Train Acc: 0.5826, Val Acc: 0.6238
# Epoch 14, Train Loss: 0.6841, Train Acc: 0.5754, Val Acc: 0.6276
# Epoch 15, Train Loss: 0.6826, Train Acc: 0.5924, Val Acc: 0.6445
# Epoch 16, Train Loss: 0.6813, Train Acc: 0.6020, Val Acc: 0.6482
# Epoch 17, Train Loss: 0.6803, Train Acc: 0.6076, Val Acc: 0.6529
# Epoch 18, Train Loss: 0.6794, Train Acc: 0.6083, Val Acc: 0.6567
# Epoch 19, Train Loss: 0.6784, Train Acc: 0.6136, Val Acc: 0.6585
# Epoch 20, Train Loss: 0.6778, Train Acc: 0.6168, Val Acc: 0.6642
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5383, Train Acc: 0.7186, Val Acc: 0.7486
# Epoch 2, Train Loss: 0.3962, Train Acc: 0.8174, Val Acc: 0.7917
# Epoch 3, Train Loss: 0.2857, Train Acc: 0.8823, Val Acc: 0.7927
# Epoch 4, Train Loss: 0.2117, Train Acc: 0.9149, Val Acc: 0.7833
# Epoch 5, Train Loss: 0.1341, Train Acc: 0.9523, Val Acc: 0.7777
# Epoch 6, Train Loss: 0.0916, Train Acc: 0.9685, Val Acc: 0.7683
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5594, Train Acc: 0.7074, Val Acc: 0.7495
# Epoch 2, Train Loss: 0.3909, Train Acc: 0.8177, Val Acc: 0.7430
# Epoch 3, Train Loss: 0.3026, Train Acc: 0.8713, Val Acc: 0.8002
# Epoch 4, Train Loss: 0.2322, Train Acc: 0.9095, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.1725, Train Acc: 0.9359, Val Acc: 0.7814
# Epoch 6, Train Loss: 0.1341, Train Acc: 0.9502, Val Acc: 0.7805
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6870, Train Acc: 0.5433, Val Acc: 0.5066
# Epoch 2, Train Loss: 0.6711, Train Acc: 0.6090, Val Acc: 0.6811
# Epoch 3, Train Loss: 0.6380, Train Acc: 0.6730, Val Acc: 0.7176
# Epoch 4, Train Loss: 0.5726, Train Acc: 0.7165, Val Acc: 0.6876
# Epoch 5, Train Loss: 0.5277, Train Acc: 0.7325, Val Acc: 0.7383
# Epoch 6, Train Loss: 0.5085, Train Acc: 0.7487, Val Acc: 0.6088
# Epoch 7, Train Loss: 0.4977, Train Acc: 0.7542, Val Acc: 0.7120
# Epoch 8, Train Loss: 0.4860, Train Acc: 0.7637, Val Acc: 0.7505
# Epoch 9, Train Loss: 0.4771, Train Acc: 0.7662, Val Acc: 0.7561
# Epoch 10, Train Loss: 0.4707, Train Acc: 0.7685, Val Acc: 0.7645
# Epoch 11, Train Loss: 0.4665, Train Acc: 0.7751, Val Acc: 0.7167
# Epoch 12, Train Loss: 0.4603, Train Acc: 0.7756, Val Acc: 0.7786
# Epoch 13, Train Loss: 0.4527, Train Acc: 0.7825, Val Acc: 0.7739
# Epoch 14, Train Loss: 0.4449, Train Acc: 0.7877, Val Acc: 0.7795
# Epoch 15, Train Loss: 0.4435, Train Acc: 0.7892, Val Acc: 0.7842
# Epoch 16, Train Loss: 0.4370, Train Acc: 0.7936, Val Acc: 0.7758
# Epoch 17, Train Loss: 0.4279, Train Acc: 0.8039, Val Acc: 0.7767
# Epoch 18, Train Loss: 0.4237, Train Acc: 0.8025, Val Acc: 0.7589
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6178, Train Acc: 0.6578, Val Acc: 0.7261
# Epoch 2, Train Loss: 0.4491, Train Acc: 0.7917, Val Acc: 0.7008
# Epoch 3, Train Loss: 0.3152, Train Acc: 0.8666, Val Acc: 0.7411
# Epoch 4, Train Loss: 0.2467, Train Acc: 0.8967, Val Acc: 0.7373
# Epoch 5, Train Loss: 0.2020, Train Acc: 0.9223, Val Acc: 0.7280
# Epoch 6, Train Loss: 0.1587, Train Acc: 0.9376, Val Acc: 0.7317
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8449, Train Acc: 0.5519, Val Acc: 0.5188
# Epoch 2, Train Loss: 0.6487, Train Acc: 0.6694, Val Acc: 0.5600
# Epoch 3, Train Loss: 0.5585, Train Acc: 0.7518, Val Acc: 0.5591
# Epoch 4, Train Loss: 0.4287, Train Acc: 0.8161, Val Acc: 0.7289
# Epoch 5, Train Loss: 0.3605, Train Acc: 0.8511, Val Acc: 0.7045
# Epoch 6, Train Loss: 0.3073, Train Acc: 0.8791, Val Acc: 0.7186
# Epoch 7, Train Loss: 0.2664, Train Acc: 0.8955, Val Acc: 0.7289
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6933, Train Acc: 0.5154, Val Acc: 0.5150
# Epoch 2, Train Loss: 0.6870, Train Acc: 0.5462, Val Acc: 0.6220
# Epoch 3, Train Loss: 0.6818, Train Acc: 0.5751, Val Acc: 0.5075
# Epoch 4, Train Loss: 0.6741, Train Acc: 0.6077, Val Acc: 0.6726
# Epoch 5, Train Loss: 0.6641, Train Acc: 0.6454, Val Acc: 0.7017
# Epoch 6, Train Loss: 0.6491, Train Acc: 0.6775, Val Acc: 0.6754
# Epoch 7, Train Loss: 0.6281, Train Acc: 0.6943, Val Acc: 0.7139
# Epoch 8, Train Loss: 0.5926, Train Acc: 0.7130, Val Acc: 0.7186
# Epoch 9, Train Loss: 0.5550, Train Acc: 0.7191, Val Acc: 0.7270
# Epoch 10, Train Loss: 0.5307, Train Acc: 0.7321, Val Acc: 0.7439
# Epoch 11, Train Loss: 0.5157, Train Acc: 0.7435, Val Acc: 0.7392
# Epoch 12, Train Loss: 0.5018, Train Acc: 0.7536, Val Acc: 0.7495
# Epoch 13, Train Loss: 0.4946, Train Acc: 0.7592, Val Acc: 0.7514
# Epoch 14, Train Loss: 0.4913, Train Acc: 0.7589, Val Acc: 0.7345
# Epoch 15, Train Loss: 0.4863, Train Acc: 0.7591, Val Acc: 0.7533
# Epoch 16, Train Loss: 0.4800, Train Acc: 0.7611, Val Acc: 0.7617
# Epoch 17, Train Loss: 0.4736, Train Acc: 0.7694, Val Acc: 0.7692
# Epoch 18, Train Loss: 0.4702, Train Acc: 0.7723, Val Acc: 0.7711
# Epoch 19, Train Loss: 0.4681, Train Acc: 0.7728, Val Acc: 0.7720
# Epoch 20, Train Loss: 0.4637, Train Acc: 0.7763, Val Acc: 0.7655
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6721, Train Acc: 0.5863, Val Acc: 0.6651
# Epoch 2, Train Loss: 0.5087, Train Acc: 0.7614, Val Acc: 0.7045
# Epoch 3, Train Loss: 0.3722, Train Acc: 0.8423, Val Acc: 0.7167
# Epoch 4, Train Loss: 0.3085, Train Acc: 0.8776, Val Acc: 0.7176
# Epoch 5, Train Loss: 0.2227, Train Acc: 0.9163, Val Acc: 0.7158
# Epoch 6, Train Loss: 0.1814, Train Acc: 0.9336, Val Acc: 0.7195
# Epoch 7, Train Loss: 0.1482, Train Acc: 0.9458, Val Acc: 0.7139
# Epoch 8, Train Loss: 0.1058, Train Acc: 0.9625, Val Acc: 0.7289
# Epoch 9, Train Loss: 0.0859, Train Acc: 0.9686, Val Acc: 0.7214
# Epoch 10, Train Loss: 0.0569, Train Acc: 0.9795, Val Acc: 0.7026
# Epoch 11, Train Loss: 0.0575, Train Acc: 0.9783, Val Acc: 0.7186
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8337, Train Acc: 0.5469, Val Acc: 0.6867
# Epoch 2, Train Loss: 0.6002, Train Acc: 0.6977, Val Acc: 0.6792
# Epoch 3, Train Loss: 0.4733, Train Acc: 0.7856, Val Acc: 0.7251
# Epoch 4, Train Loss: 0.3895, Train Acc: 0.8358, Val Acc: 0.7355
# Epoch 5, Train Loss: 0.3239, Train Acc: 0.8653, Val Acc: 0.6942
# Epoch 6, Train Loss: 0.2568, Train Acc: 0.8968, Val Acc: 0.7420
# Epoch 7, Train Loss: 0.2142, Train Acc: 0.9182, Val Acc: 0.7308
# Epoch 8, Train Loss: 0.1832, Train Acc: 0.9281, Val Acc: 0.7214
# Epoch 9, Train Loss: 0.1601, Train Acc: 0.9402, Val Acc: 0.7214
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6917, Train Acc: 0.5239, Val Acc: 0.5216
# Epoch 2, Train Loss: 0.6880, Train Acc: 0.5436, Val Acc: 0.5685
# Epoch 3, Train Loss: 0.6832, Train Acc: 0.5728, Val Acc: 0.5319
# Epoch 4, Train Loss: 0.6800, Train Acc: 0.5962, Val Acc: 0.6098
# Epoch 5, Train Loss: 0.6744, Train Acc: 0.6215, Val Acc: 0.5910
# Epoch 6, Train Loss: 0.6704, Train Acc: 0.6375, Val Acc: 0.6585
# Epoch 7, Train Loss: 0.6615, Train Acc: 0.6532, Val Acc: 0.6792
# Epoch 8, Train Loss: 0.6537, Train Acc: 0.6758, Val Acc: 0.6548
# Epoch 9, Train Loss: 0.6427, Train Acc: 0.6880, Val Acc: 0.6876
# Epoch 10, Train Loss: 0.6290, Train Acc: 0.7040, Val Acc: 0.6970
# Epoch 11, Train Loss: 0.6104, Train Acc: 0.7110, Val Acc: 0.7176
# Epoch 12, Train Loss: 0.5868, Train Acc: 0.7122, Val Acc: 0.7176
# Epoch 13, Train Loss: 0.5636, Train Acc: 0.7163, Val Acc: 0.7064
# Epoch 14, Train Loss: 0.5461, Train Acc: 0.7227, Val Acc: 0.7101
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5532, Train Acc: 0.7077, Val Acc: 0.7523
# Epoch 2, Train Loss: 0.3489, Train Acc: 0.8508, Val Acc: 0.7749
# Epoch 3, Train Loss: 0.1987, Train Acc: 0.9267, Val Acc: 0.7786
# Epoch 4, Train Loss: 0.1006, Train Acc: 0.9646, Val Acc: 0.7636
# Epoch 5, Train Loss: 0.0667, Train Acc: 0.9770, Val Acc: 0.7533
# Epoch 6, Train Loss: 0.0407, Train Acc: 0.9844, Val Acc: 0.7402
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8752, Train Acc: 0.5720, Val Acc: 0.6698
# Epoch 2, Train Loss: 0.5731, Train Acc: 0.7127, Val Acc: 0.6942
# Epoch 3, Train Loss: 0.4014, Train Acc: 0.8244, Val Acc: 0.6829
# Epoch 4, Train Loss: 0.3066, Train Acc: 0.8725, Val Acc: 0.7251
# Epoch 5, Train Loss: 0.2387, Train Acc: 0.9038, Val Acc: 0.7364
# Epoch 6, Train Loss: 0.1793, Train Acc: 0.9274, Val Acc: 0.7355
# Epoch 7, Train Loss: 0.1556, Train Acc: 0.9394, Val Acc: 0.7439
# Epoch 8, Train Loss: 0.1121, Train Acc: 0.9552, Val Acc: 0.7392
# Epoch 9, Train Loss: 0.0986, Train Acc: 0.9633, Val Acc: 0.7430
# Epoch 10, Train Loss: 0.0808, Train Acc: 0.9709, Val Acc: 0.7261
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6850, Train Acc: 0.5538, Val Acc: 0.5826
# Epoch 2, Train Loss: 0.6084, Train Acc: 0.6844, Val Acc: 0.7280
# Epoch 3, Train Loss: 0.5374, Train Acc: 0.7267, Val Acc: 0.5319
# Epoch 4, Train Loss: 0.4996, Train Acc: 0.7543, Val Acc: 0.7430
# Epoch 5, Train Loss: 0.4845, Train Acc: 0.7600, Val Acc: 0.7523
# Epoch 6, Train Loss: 0.4693, Train Acc: 0.7722, Val Acc: 0.7589
# Epoch 7, Train Loss: 0.4592, Train Acc: 0.7811, Val Acc: 0.7552
# Epoch 8, Train Loss: 0.4465, Train Acc: 0.7860, Val Acc: 0.7364
# Epoch 9, Train Loss: 0.4335, Train Acc: 0.7982, Val Acc: 0.7298
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.8108, Train Acc: 0.4959, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7160, Train Acc: 0.5735, Val Acc: 0.6191
# Epoch 3, Train Loss: 0.6797, Train Acc: 0.6267, Val Acc: 0.5066
# Epoch 4, Train Loss: 0.6446, Train Acc: 0.6771, Val Acc: 0.6379
# Epoch 5, Train Loss: 0.5752, Train Acc: 0.7224, Val Acc: 0.6426
# Epoch 6, Train Loss: 0.5536, Train Acc: 0.7477, Val Acc: 0.6557
# Epoch 7, Train Loss: 0.4854, Train Acc: 0.7846, Val Acc: 0.6548
# Epoch 8, Train Loss: 0.4831, Train Acc: 0.7911, Val Acc: 0.6548
# Epoch 9, Train Loss: 0.4600, Train Acc: 0.8056, Val Acc: 0.6782
# Epoch 10, Train Loss: 0.4284, Train Acc: 0.8172, Val Acc: 0.6698
# Epoch 11, Train Loss: 0.4256, Train Acc: 0.8270, Val Acc: 0.6764
# Epoch 12, Train Loss: 0.4199, Train Acc: 0.8322, Val Acc: 0.6932
# Epoch 13, Train Loss: 0.3569, Train Acc: 0.8502, Val Acc: 0.6989
# Epoch 14, Train Loss: 0.3612, Train Acc: 0.8570, Val Acc: 0.6923
# Epoch 15, Train Loss: 0.3668, Train Acc: 0.8601, Val Acc: 0.6735
# Epoch 16, Train Loss: 0.3458, Train Acc: 0.8586, Val Acc: 0.7148
# Epoch 17, Train Loss: 0.3172, Train Acc: 0.8708, Val Acc: 0.7176
# Epoch 18, Train Loss: 0.3211, Train Acc: 0.8787, Val Acc: 0.7101
# Epoch 19, Train Loss: 0.3086, Train Acc: 0.8811, Val Acc: 0.6782
# Epoch 20, Train Loss: 0.3199, Train Acc: 0.8791, Val Acc: 0.7054
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1349, Train Acc: 0.5218, Val Acc: 0.4925
# Epoch 2, Train Loss: 0.8922, Train Acc: 0.5894, Val Acc: 0.5516
# Epoch 3, Train Loss: 0.8270, Train Acc: 0.6544, Val Acc: 0.6144
# Epoch 4, Train Loss: 0.7590, Train Acc: 0.7042, Val Acc: 0.6107
# Epoch 5, Train Loss: 0.6631, Train Acc: 0.7483, Val Acc: 0.5263
# Epoch 6, Train Loss: 0.6237, Train Acc: 0.7829, Val Acc: 0.7036
# Epoch 7, Train Loss: 0.5725, Train Acc: 0.8046, Val Acc: 0.5610
# Epoch 8, Train Loss: 0.5388, Train Acc: 0.8191, Val Acc: 0.5009
# Epoch 9, Train Loss: 0.4973, Train Acc: 0.8369, Val Acc: 0.7111
# Epoch 10, Train Loss: 0.4465, Train Acc: 0.8584, Val Acc: 0.6829
# Epoch 11, Train Loss: 0.4046, Train Acc: 0.8678, Val Acc: 0.6501
# Epoch 12, Train Loss: 0.4001, Train Acc: 0.8722, Val Acc: 0.7008
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6895, Train Acc: 0.5340, Val Acc: 0.6107
# Epoch 2, Train Loss: 0.6703, Train Acc: 0.6093, Val Acc: 0.6942
# Epoch 3, Train Loss: 0.6291, Train Acc: 0.6784, Val Acc: 0.5910
# Epoch 4, Train Loss: 0.5648, Train Acc: 0.7096, Val Acc: 0.6229
# Epoch 5, Train Loss: 0.5307, Train Acc: 0.7304, Val Acc: 0.7373
# Epoch 6, Train Loss: 0.5113, Train Acc: 0.7430, Val Acc: 0.7317
# Epoch 7, Train Loss: 0.4963, Train Acc: 0.7552, Val Acc: 0.7533
# Epoch 8, Train Loss: 0.4854, Train Acc: 0.7594, Val Acc: 0.7589
# Epoch 9, Train Loss: 0.4747, Train Acc: 0.7682, Val Acc: 0.7589
# Epoch 10, Train Loss: 0.4708, Train Acc: 0.7700, Val Acc: 0.7683
# Epoch 11, Train Loss: 0.4666, Train Acc: 0.7734, Val Acc: 0.7608
# Epoch 12, Train Loss: 0.4528, Train Acc: 0.7828, Val Acc: 0.7814
# Epoch 13, Train Loss: 0.4536, Train Acc: 0.7836, Val Acc: 0.7795
# Epoch 14, Train Loss: 0.4449, Train Acc: 0.7850, Val Acc: 0.7880
# Epoch 15, Train Loss: 0.4363, Train Acc: 0.7930, Val Acc: 0.7589
# Epoch 16, Train Loss: 0.4361, Train Acc: 0.7928, Val Acc: 0.7674
# Epoch 17, Train Loss: 0.4294, Train Acc: 0.8000, Val Acc: 0.7964
# Epoch 18, Train Loss: 0.4206, Train Acc: 0.8004, Val Acc: 0.7505
# Epoch 19, Train Loss: 0.4227, Train Acc: 0.8076, Val Acc: 0.7758
# Epoch 20, Train Loss: 0.4143, Train Acc: 0.8063, Val Acc: 0.7927
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7464, Train Acc: 0.5020, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7143, Train Acc: 0.5628, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.6372, Train Acc: 0.6423, Val Acc: 0.5009
# Epoch 4, Train Loss: 0.5917, Train Acc: 0.6808, Val Acc: 0.6379
# Epoch 5, Train Loss: 0.6058, Train Acc: 0.6909, Val Acc: 0.6285
# Epoch 6, Train Loss: 0.5864, Train Acc: 0.7242, Val Acc: 0.6501
# Epoch 7, Train Loss: 0.5734, Train Acc: 0.7325, Val Acc: 0.6735
# Epoch 8, Train Loss: 0.5212, Train Acc: 0.7580, Val Acc: 0.5450
# Epoch 9, Train Loss: 0.5098, Train Acc: 0.7590, Val Acc: 0.6632
# Epoch 10, Train Loss: 0.5034, Train Acc: 0.7660, Val Acc: 0.6567
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.2019, Train Acc: 0.5250, Val Acc: 0.5507
# Epoch 2, Train Loss: 0.8389, Train Acc: 0.5957, Val Acc: 0.5797
# Epoch 3, Train Loss: 0.7614, Train Acc: 0.6596, Val Acc: 0.5478
# Epoch 4, Train Loss: 0.6272, Train Acc: 0.7286, Val Acc: 0.6135
# Epoch 5, Train Loss: 0.5637, Train Acc: 0.7715, Val Acc: 0.6510
# Epoch 6, Train Loss: 0.5685, Train Acc: 0.7877, Val Acc: 0.6323
# Epoch 7, Train Loss: 0.4558, Train Acc: 0.8322, Val Acc: 0.6848
# Epoch 8, Train Loss: 0.4181, Train Acc: 0.8481, Val Acc: 0.7373
# Epoch 9, Train Loss: 0.3795, Train Acc: 0.8666, Val Acc: 0.6857
# Epoch 10, Train Loss: 0.3241, Train Acc: 0.8866, Val Acc: 0.7317
# Epoch 11, Train Loss: 0.2797, Train Acc: 0.9021, Val Acc: 0.7129
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6915, Train Acc: 0.5224, Val Acc: 0.5760
# Epoch 2, Train Loss: 0.6840, Train Acc: 0.5687, Val Acc: 0.5422
# Epoch 3, Train Loss: 0.6750, Train Acc: 0.6075, Val Acc: 0.6717
# Epoch 4, Train Loss: 0.6637, Train Acc: 0.6381, Val Acc: 0.6707
# Epoch 5, Train Loss: 0.6471, Train Acc: 0.6780, Val Acc: 0.6792
# Epoch 6, Train Loss: 0.6189, Train Acc: 0.7020, Val Acc: 0.7120
# Epoch 7, Train Loss: 0.5713, Train Acc: 0.7116, Val Acc: 0.7251
# Epoch 8, Train Loss: 0.5430, Train Acc: 0.7300, Val Acc: 0.7233
# Epoch 9, Train Loss: 0.5285, Train Acc: 0.7329, Val Acc: 0.7308
# Epoch 10, Train Loss: 0.5122, Train Acc: 0.7457, Val Acc: 0.7439
# Epoch 11, Train Loss: 0.5051, Train Acc: 0.7489, Val Acc: 0.7373
# Epoch 12, Train Loss: 0.5037, Train Acc: 0.7455, Val Acc: 0.7495
# Epoch 13, Train Loss: 0.4900, Train Acc: 0.7569, Val Acc: 0.7505
# Epoch 14, Train Loss: 0.4848, Train Acc: 0.7617, Val Acc: 0.7580
# Epoch 15, Train Loss: 0.4819, Train Acc: 0.7638, Val Acc: 0.7655
# Epoch 16, Train Loss: 0.4723, Train Acc: 0.7698, Val Acc: 0.7552
# Epoch 17, Train Loss: 0.4755, Train Acc: 0.7660, Val Acc: 0.7486
# Epoch 18, Train Loss: 0.4711, Train Acc: 0.7701, Val Acc: 0.7533
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.6715, Train Acc: 0.5964, Val Acc: 0.6801
# Epoch 2, Train Loss: 0.4967, Train Acc: 0.7627, Val Acc: 0.7083
# Epoch 3, Train Loss: 0.3927, Train Acc: 0.8326, Val Acc: 0.7205
# Epoch 4, Train Loss: 0.2792, Train Acc: 0.8862, Val Acc: 0.7280
# Epoch 5, Train Loss: 0.2149, Train Acc: 0.9159, Val Acc: 0.7148
# Epoch 6, Train Loss: 0.1645, Train Acc: 0.9347, Val Acc: 0.7251
# Epoch 7, Train Loss: 0.1301, Train Acc: 0.9504, Val Acc: 0.7111
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4703, Train Acc: 0.5128, Val Acc: 0.5666
# Epoch 2, Train Loss: 0.7914, Train Acc: 0.6098, Val Acc: 0.6107
# Epoch 3, Train Loss: 0.6006, Train Acc: 0.7192, Val Acc: 0.6492
# Epoch 4, Train Loss: 0.5636, Train Acc: 0.7580, Val Acc: 0.6876
# Epoch 5, Train Loss: 0.4638, Train Acc: 0.8038, Val Acc: 0.6360
# Epoch 6, Train Loss: 0.4120, Train Acc: 0.8294, Val Acc: 0.6773
# Epoch 7, Train Loss: 0.3648, Train Acc: 0.8557, Val Acc: 0.7008
# Epoch 8, Train Loss: 0.3171, Train Acc: 0.8798, Val Acc: 0.6792
# Epoch 9, Train Loss: 0.2845, Train Acc: 0.8880, Val Acc: 0.6820
# Epoch 10, Train Loss: 0.2589, Train Acc: 0.9050, Val Acc: 0.7326
# Epoch 11, Train Loss: 0.2451, Train Acc: 0.9127, Val Acc: 0.7223
# Epoch 12, Train Loss: 0.2303, Train Acc: 0.9271, Val Acc: 0.7298
# Epoch 13, Train Loss: 0.1788, Train Acc: 0.9380, Val Acc: 0.7205
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6126, Train Acc: 0.6639, Val Acc: 0.7251
# Epoch 2, Train Loss: 0.5084, Train Acc: 0.7494, Val Acc: 0.7589
# Epoch 3, Train Loss: 0.4649, Train Acc: 0.7764, Val Acc: 0.6773
# Epoch 4, Train Loss: 0.4526, Train Acc: 0.7825, Val Acc: 0.7795
# Epoch 5, Train Loss: 0.4261, Train Acc: 0.8029, Val Acc: 0.7383
# Epoch 6, Train Loss: 0.4237, Train Acc: 0.8116, Val Acc: 0.5178
# Epoch 7, Train Loss: 0.4276, Train Acc: 0.8038, Val Acc: 0.6285
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 2.8417, Train Acc: 0.5014, Val Acc: 0.5009
# Epoch 2, Train Loss: 2.7042, Train Acc: 0.4970, Val Acc: 0.5047
# Epoch 3, Train Loss: 2.3283, Train Acc: 0.5004, Val Acc: 0.5000
# Epoch 4, Train Loss: 2.8176, Train Acc: 0.4972, Val Acc: 0.5066
# Epoch 5, Train Loss: 2.2095, Train Acc: 0.5059, Val Acc: 0.5000
# Epoch 6, Train Loss: 2.3140, Train Acc: 0.4981, Val Acc: 0.5038
# Epoch 7, Train Loss: 2.1701, Train Acc: 0.4930, Val Acc: 0.5009
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 16.3603, Train Acc: 0.4950, Val Acc: 0.4991
# Epoch 2, Train Loss: 13.0101, Train Acc: 0.4967, Val Acc: 0.5000
# Epoch 3, Train Loss: 12.9963, Train Acc: 0.4971, Val Acc: 0.5000
# Epoch 4, Train Loss: 12.5441, Train Acc: 0.5096, Val Acc: 0.5056
# Epoch 5, Train Loss: 12.9903, Train Acc: 0.4995, Val Acc: 0.4962
# Epoch 6, Train Loss: 12.6061, Train Acc: 0.5075, Val Acc: 0.5047
# Epoch 7, Train Loss: 12.8814, Train Acc: 0.4971, Val Acc: 0.4991
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6549, Train Acc: 0.6288, Val Acc: 0.6398
# Epoch 2, Train Loss: 0.5177, Train Acc: 0.7413, Val Acc: 0.7345
# Epoch 3, Train Loss: 0.4738, Train Acc: 0.7692, Val Acc: 0.7373
# Epoch 4, Train Loss: 0.4561, Train Acc: 0.7835, Val Acc: 0.7739
# Epoch 5, Train Loss: 0.4315, Train Acc: 0.7987, Val Acc: 0.7477
# Epoch 6, Train Loss: 0.4081, Train Acc: 0.8086, Val Acc: 0.7992
# Epoch 7, Train Loss: 0.3777, Train Acc: 0.8265, Val Acc: 0.7627
# Epoch 8, Train Loss: 0.3856, Train Acc: 0.8254, Val Acc: 0.7664
# Epoch 9, Train Loss: 0.3455, Train Acc: 0.8464, Val Acc: 0.8002
# Epoch 10, Train Loss: 0.3328, Train Acc: 0.8535, Val Acc: 0.6942
# Epoch 11, Train Loss: 0.3551, Train Acc: 0.8444, Val Acc: 0.7054
# Epoch 12, Train Loss: 0.3457, Train Acc: 0.8501, Val Acc: 0.6754
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 1.8914, Train Acc: 0.5143, Val Acc: 0.5169
# Epoch 2, Train Loss: 1.7555, Train Acc: 0.5120, Val Acc: 0.5000
# Epoch 3, Train Loss: 1.8590, Train Acc: 0.5072, Val Acc: 0.5056
# Epoch 4, Train Loss: 1.6866, Train Acc: 0.5140, Val Acc: 0.5094
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 19.0771, Train Acc: 0.4980, Val Acc: 0.5066
# Epoch 2, Train Loss: 12.4227, Train Acc: 0.5069, Val Acc: 0.5028
# Epoch 3, Train Loss: 12.7182, Train Acc: 0.5022, Val Acc: 0.5084
# Epoch 4, Train Loss: 12.4000, Train Acc: 0.5100, Val Acc: 0.5047
# Epoch 5, Train Loss: 13.0512, Train Acc: 0.4946, Val Acc: 0.5000
# Epoch 6, Train Loss: 12.3281, Train Acc: 0.5114, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.7280, Train Acc: 0.5618, Val Acc: 0.6126
# Epoch 2, Train Loss: 0.5640, Train Acc: 0.7027, Val Acc: 0.7477
# Epoch 3, Train Loss: 0.5033, Train Acc: 0.7504, Val Acc: 0.7205
# Epoch 4, Train Loss: 0.4757, Train Acc: 0.7695, Val Acc: 0.7824
# Epoch 5, Train Loss: 0.4600, Train Acc: 0.7858, Val Acc: 0.7580
# Epoch 6, Train Loss: 0.4308, Train Acc: 0.7993, Val Acc: 0.7477
# Epoch 7, Train Loss: 0.4285, Train Acc: 0.7951, Val Acc: 0.7795
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 1.6668, Train Acc: 0.5120, Val Acc: 0.4972
# Epoch 2, Train Loss: 2.3842, Train Acc: 0.5166, Val Acc: 0.5338
# Epoch 3, Train Loss: 1.4498, Train Acc: 0.5131, Val Acc: 0.5019
# Epoch 4, Train Loss: 1.3160, Train Acc: 0.5379, Val Acc: 0.5131
# Epoch 5, Train Loss: 2.3498, Train Acc: 0.5302, Val Acc: 0.5113
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 24.2149, Train Acc: 0.4974, Val Acc: 0.5009
# Epoch 2, Train Loss: 13.4285, Train Acc: 0.5047, Val Acc: 0.5047
# Epoch 3, Train Loss: 12.9472, Train Acc: 0.5061, Val Acc: 0.5000
# Epoch 4, Train Loss: 12.3852, Train Acc: 0.5074, Val Acc: 0.4981
# Epoch 5, Train Loss: 12.6926, Train Acc: 0.5011, Val Acc: 0.5000
# Early stopping
# Best Validation Accuracy: 0.8020637898686679
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'Adam'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_update['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_update = MaxPoolingRNNModelUpdate(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_update['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
elif best_hyperparams_RNN_update['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
elif best_hyperparams_RNN_update['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])

best_model_RNN_update, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_update, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5253, Train Acc: 0.7231, Val Acc: 0.7739
# Epoch 2, Train Loss: 0.3737, Train Acc: 0.8329, Val Acc: 0.7758
# Epoch 3, Train Loss: 0.2532, Train Acc: 0.8943, Val Acc: 0.7711
# Epoch 4, Train Loss: 0.1566, Train Acc: 0.9409, Val Acc: 0.7880
# Epoch 5, Train Loss: 0.1002, Train Acc: 0.9644, Val Acc: 0.7711
# Epoch 6, Train Loss: 0.0599, Train Acc: 0.9788, Val Acc: 0.7542
# Epoch 7, Train Loss: 0.0451, Train Acc: 0.9855, Val Acc: 0.7711
# Early stopping

# %%
epochs_mp = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_mp, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_update, test_loader)
test_accuracies['RNN (Update Word Embeddings)'] = test_acc
print(f'Test Accuracy (Update Word Embeddings): {test_acc:.4f}')
# Out:
# Test Accuracy (Update Word Embeddings): 0.7814

# %% [markdown]
# ### (b) Report the accuracy score on the test set when applying your method to deal with OOV words in Part 3.2.

# %%
# # Initialize the embedding matrix
# embedding_matrix_cosine_sim = np.zeros((vocab_size, embedding_dim))

# # Map vocabulary to embedding matrix
# word_to_idx = {word: idx for idx, word in enumerate(vocab)}

# # Populate embedding matrix and handle OOV words
# for word, idx in word_to_idx.items():
#     if word in word2vec_model:
#         embedding_matrix_cosine_sim[idx] = word2vec_model[word]
#     else:
#         # Handle OOV words
#         replacement_word = find_replacement_word(word, word2vec_model)

#         if replacement_word:
#             embedding_matrix_cosine_sim[idx] = word2vec_model[replacement_word]  # Use replacement word vector
#         else:
#             embedding_matrix_cosine_sim[idx] = np.random.normal(size=(embedding_dim,))  # Random initialization if no replacement found

# %%
# Initialize the embedding matrix
embedding_matrix_cosine_sim = np.zeros((vocab_size, embedding_dim))

# Map vocabulary to embedding matrix
word_to_idx = {word: idx for idx, word in enumerate(vocab)}

# Populate embedding matrix and handle OOV words
for word, idx in word_to_idx.items():
    if word in glove_model:
        embedding_matrix_cosine_sim[idx] = glove_model[word]
    else:
        # Handle OOV words
        replacement_word = find_replacement_word(word, glove_model)

        if replacement_word:
            embedding_matrix_cosine_sim[idx] = glove_model[replacement_word]  # Use replacement word vector
        else:
            embedding_matrix_cosine_sim[idx] = np.random.normal(size=(embedding_dim,))  # Random initialization if no replacement found
# Out:
# c:\Users\JamesYS\Desktop\SC4002_project\.venv\Lib\site-packages\gensim\models\keyedvectors.py:849: RuntimeWarning: invalid value encountered in divide
#   dists = dot(self.vectors[clip_start:clip_end], mean) / self.norms[clip_start:clip_end]

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) Freeze Word Embeddings

# %%
# Call grid search
best_hyperparams_OOV_freeze = run_grid_search(MaxPoolingRNNModel, embedding_matrix_cosine_sim, hidden_dim, output_dim, train_sequences, train_labels,
                                              validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6917, Train Acc: 0.5244, Val Acc: 0.5084
# Epoch 2, Train Loss: 0.6887, Train Acc: 0.5421, Val Acc: 0.5722
# Epoch 3, Train Loss: 0.6846, Train Acc: 0.5787, Val Acc: 0.5826
# Epoch 4, Train Loss: 0.6814, Train Acc: 0.5864, Val Acc: 0.6295
# Epoch 5, Train Loss: 0.6765, Train Acc: 0.6054, Val Acc: 0.6426
# Epoch 6, Train Loss: 0.6730, Train Acc: 0.6335, Val Acc: 0.6529
# Epoch 7, Train Loss: 0.6676, Train Acc: 0.6462, Val Acc: 0.6698
# Epoch 8, Train Loss: 0.6609, Train Acc: 0.6742, Val Acc: 0.6801
# Epoch 9, Train Loss: 0.6534, Train Acc: 0.6797, Val Acc: 0.6717
# Epoch 10, Train Loss: 0.6467, Train Acc: 0.6853, Val Acc: 0.6923
# Epoch 11, Train Loss: 0.6361, Train Acc: 0.7011, Val Acc: 0.6717
# Epoch 12, Train Loss: 0.6243, Train Acc: 0.6998, Val Acc: 0.7083
# Epoch 13, Train Loss: 0.6121, Train Acc: 0.7064, Val Acc: 0.6895
# Epoch 14, Train Loss: 0.5934, Train Acc: 0.7148, Val Acc: 0.7008
# Epoch 15, Train Loss: 0.5720, Train Acc: 0.7219, Val Acc: 0.7251
# Epoch 16, Train Loss: 0.5541, Train Acc: 0.7253, Val Acc: 0.7251
# Epoch 17, Train Loss: 0.5402, Train Acc: 0.7354, Val Acc: 0.7054
# Epoch 18, Train Loss: 0.5305, Train Acc: 0.7336, Val Acc: 0.7251
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5367, Train Acc: 0.7233, Val Acc: 0.7664
# Epoch 2, Train Loss: 0.4723, Train Acc: 0.7678, Val Acc: 0.7730
# Epoch 3, Train Loss: 0.4496, Train Acc: 0.7839, Val Acc: 0.7655
# Epoch 4, Train Loss: 0.4274, Train Acc: 0.7979, Val Acc: 0.7636
# Epoch 5, Train Loss: 0.4190, Train Acc: 0.8049, Val Acc: 0.7008
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5420, Train Acc: 0.7185, Val Acc: 0.7045
# Epoch 2, Train Loss: 0.4717, Train Acc: 0.7739, Val Acc: 0.6904
# Epoch 3, Train Loss: 0.4549, Train Acc: 0.7773, Val Acc: 0.7645
# Epoch 4, Train Loss: 0.4298, Train Acc: 0.7995, Val Acc: 0.7833
# Epoch 5, Train Loss: 0.4160, Train Acc: 0.8086, Val Acc: 0.7251
# Epoch 6, Train Loss: 0.4001, Train Acc: 0.8116, Val Acc: 0.5985
# Epoch 7, Train Loss: 0.3834, Train Acc: 0.8208, Val Acc: 0.7824
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6983, Train Acc: 0.5147, Val Acc: 0.5094
# Epoch 2, Train Loss: 0.6915, Train Acc: 0.5206, Val Acc: 0.5206
# Epoch 3, Train Loss: 0.6898, Train Acc: 0.5354, Val Acc: 0.5291
# Epoch 4, Train Loss: 0.6880, Train Acc: 0.5538, Val Acc: 0.5450
# Epoch 5, Train Loss: 0.6866, Train Acc: 0.5558, Val Acc: 0.5497
# Epoch 6, Train Loss: 0.6853, Train Acc: 0.5708, Val Acc: 0.5675
# Epoch 7, Train Loss: 0.6837, Train Acc: 0.5883, Val Acc: 0.5647
# Epoch 8, Train Loss: 0.6821, Train Acc: 0.5873, Val Acc: 0.5788
# Epoch 9, Train Loss: 0.6805, Train Acc: 0.6004, Val Acc: 0.5563
# Epoch 10, Train Loss: 0.6803, Train Acc: 0.6038, Val Acc: 0.5929
# Epoch 11, Train Loss: 0.6773, Train Acc: 0.6193, Val Acc: 0.6107
# Epoch 12, Train Loss: 0.6754, Train Acc: 0.6305, Val Acc: 0.6004
# Epoch 13, Train Loss: 0.6743, Train Acc: 0.6298, Val Acc: 0.6595
# Epoch 14, Train Loss: 0.6726, Train Acc: 0.6419, Val Acc: 0.6135
# Epoch 15, Train Loss: 0.6697, Train Acc: 0.6525, Val Acc: 0.6585
# Epoch 16, Train Loss: 0.6672, Train Acc: 0.6584, Val Acc: 0.6839
# Epoch 17, Train Loss: 0.6647, Train Acc: 0.6618, Val Acc: 0.5947
# Epoch 18, Train Loss: 0.6623, Train Acc: 0.6657, Val Acc: 0.6942
# Epoch 19, Train Loss: 0.6592, Train Acc: 0.6763, Val Acc: 0.6942
# Epoch 20, Train Loss: 0.6571, Train Acc: 0.6717, Val Acc: 0.6876
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5406, Train Acc: 0.7198, Val Acc: 0.7702
# Epoch 2, Train Loss: 0.4647, Train Acc: 0.7776, Val Acc: 0.7805
# Epoch 3, Train Loss: 0.4381, Train Acc: 0.7928, Val Acc: 0.7720
# Epoch 4, Train Loss: 0.4204, Train Acc: 0.8059, Val Acc: 0.7955
# Epoch 5, Train Loss: 0.3971, Train Acc: 0.8149, Val Acc: 0.7580
# Epoch 6, Train Loss: 0.3886, Train Acc: 0.8227, Val Acc: 0.7767
# Epoch 7, Train Loss: 0.3613, Train Acc: 0.8393, Val Acc: 0.7767
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5592, Train Acc: 0.7103, Val Acc: 0.7711
# Epoch 2, Train Loss: 0.4681, Train Acc: 0.7767, Val Acc: 0.7683
# Epoch 3, Train Loss: 0.4359, Train Acc: 0.7953, Val Acc: 0.7636
# Epoch 4, Train Loss: 0.4207, Train Acc: 0.8030, Val Acc: 0.7664
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6951, Train Acc: 0.4955, Val Acc: 0.5197
# Epoch 2, Train Loss: 0.6940, Train Acc: 0.5091, Val Acc: 0.5253
# Epoch 3, Train Loss: 0.6932, Train Acc: 0.5117, Val Acc: 0.5291
# Epoch 4, Train Loss: 0.6922, Train Acc: 0.5134, Val Acc: 0.5328
# Epoch 5, Train Loss: 0.6921, Train Acc: 0.5152, Val Acc: 0.5488
# Epoch 6, Train Loss: 0.6914, Train Acc: 0.5256, Val Acc: 0.5507
# Epoch 7, Train Loss: 0.6907, Train Acc: 0.5317, Val Acc: 0.5553
# Epoch 8, Train Loss: 0.6901, Train Acc: 0.5346, Val Acc: 0.5572
# Epoch 9, Train Loss: 0.6890, Train Acc: 0.5448, Val Acc: 0.5619
# Epoch 10, Train Loss: 0.6883, Train Acc: 0.5532, Val Acc: 0.5816
# Epoch 11, Train Loss: 0.6878, Train Acc: 0.5592, Val Acc: 0.5863
# Epoch 12, Train Loss: 0.6865, Train Acc: 0.5680, Val Acc: 0.5816
# Epoch 13, Train Loss: 0.6868, Train Acc: 0.5653, Val Acc: 0.6060
# Epoch 14, Train Loss: 0.6855, Train Acc: 0.5753, Val Acc: 0.6173
# Epoch 15, Train Loss: 0.6848, Train Acc: 0.5800, Val Acc: 0.6154
# Epoch 16, Train Loss: 0.6840, Train Acc: 0.5870, Val Acc: 0.6266
# Epoch 17, Train Loss: 0.6842, Train Acc: 0.5807, Val Acc: 0.6332
# Epoch 18, Train Loss: 0.6825, Train Acc: 0.5894, Val Acc: 0.6313
# Epoch 19, Train Loss: 0.6815, Train Acc: 0.5991, Val Acc: 0.6417
# Epoch 20, Train Loss: 0.6807, Train Acc: 0.6041, Val Acc: 0.6407
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5478, Train Acc: 0.7118, Val Acc: 0.7589
# Epoch 2, Train Loss: 0.4711, Train Acc: 0.7736, Val Acc: 0.7692
# Epoch 3, Train Loss: 0.4446, Train Acc: 0.7872, Val Acc: 0.7767
# Epoch 4, Train Loss: 0.4201, Train Acc: 0.8080, Val Acc: 0.7505
# Epoch 5, Train Loss: 0.4035, Train Acc: 0.8170, Val Acc: 0.7880
# Epoch 6, Train Loss: 0.3857, Train Acc: 0.8260, Val Acc: 0.7758
# Epoch 7, Train Loss: 0.3599, Train Acc: 0.8397, Val Acc: 0.7805
# Epoch 8, Train Loss: 0.3465, Train Acc: 0.8490, Val Acc: 0.7936
# Epoch 9, Train Loss: 0.3282, Train Acc: 0.8538, Val Acc: 0.8021
# Epoch 10, Train Loss: 0.3167, Train Acc: 0.8605, Val Acc: 0.7852
# Epoch 11, Train Loss: 0.2983, Train Acc: 0.8694, Val Acc: 0.7964
# Epoch 12, Train Loss: 0.2663, Train Acc: 0.8909, Val Acc: 0.7899
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5825, Train Acc: 0.6933, Val Acc: 0.6886
# Epoch 2, Train Loss: 0.4720, Train Acc: 0.7706, Val Acc: 0.7664
# Epoch 3, Train Loss: 0.4455, Train Acc: 0.7875, Val Acc: 0.7842
# Epoch 4, Train Loss: 0.4279, Train Acc: 0.7948, Val Acc: 0.7326
# Epoch 5, Train Loss: 0.4046, Train Acc: 0.8152, Val Acc: 0.7373
# Epoch 6, Train Loss: 0.3876, Train Acc: 0.8246, Val Acc: 0.7758
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6915, Train Acc: 0.5252, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6778, Train Acc: 0.5866, Val Acc: 0.5469
# Epoch 3, Train Loss: 0.6510, Train Acc: 0.6570, Val Acc: 0.7064
# Epoch 4, Train Loss: 0.6009, Train Acc: 0.6985, Val Acc: 0.7298
# Epoch 5, Train Loss: 0.5399, Train Acc: 0.7297, Val Acc: 0.7054
# Epoch 6, Train Loss: 0.5147, Train Acc: 0.7408, Val Acc: 0.7514
# Epoch 7, Train Loss: 0.4989, Train Acc: 0.7513, Val Acc: 0.7439
# Epoch 8, Train Loss: 0.4872, Train Acc: 0.7594, Val Acc: 0.7008
# Epoch 9, Train Loss: 0.4795, Train Acc: 0.7668, Val Acc: 0.7580
# Epoch 10, Train Loss: 0.4742, Train Acc: 0.7695, Val Acc: 0.7617
# Epoch 11, Train Loss: 0.4662, Train Acc: 0.7764, Val Acc: 0.7786
# Epoch 12, Train Loss: 0.4625, Train Acc: 0.7801, Val Acc: 0.7749
# Epoch 13, Train Loss: 0.4564, Train Acc: 0.7788, Val Acc: 0.6998
# Epoch 14, Train Loss: 0.4492, Train Acc: 0.7839, Val Acc: 0.7598
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7337, Train Acc: 0.5147, Val Acc: 0.5028
# Epoch 2, Train Loss: 0.7235, Train Acc: 0.5148, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7634, Train Acc: 0.4971, Val Acc: 0.5038
# Epoch 4, Train Loss: 0.7611, Train Acc: 0.5019, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.7476, Train Acc: 0.4945, Val Acc: 0.5000
# Epoch 6, Train Loss: 0.7548, Train Acc: 0.5061, Val Acc: 0.5000
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8178, Train Acc: 0.5408, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7223, Train Acc: 0.6042, Val Acc: 0.5338
# Epoch 3, Train Loss: 0.6958, Train Acc: 0.6395, Val Acc: 0.6454
# Epoch 4, Train Loss: 0.6714, Train Acc: 0.6545, Val Acc: 0.6482
# Epoch 5, Train Loss: 0.6590, Train Acc: 0.6701, Val Acc: 0.6829
# Epoch 6, Train Loss: 0.6465, Train Acc: 0.6769, Val Acc: 0.7129
# Epoch 7, Train Loss: 0.6413, Train Acc: 0.6803, Val Acc: 0.7036
# Epoch 8, Train Loss: 0.6390, Train Acc: 0.6836, Val Acc: 0.5507
# Epoch 9, Train Loss: 0.6366, Train Acc: 0.6938, Val Acc: 0.6642
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6938, Train Acc: 0.5120, Val Acc: 0.5816
# Epoch 2, Train Loss: 0.6862, Train Acc: 0.5488, Val Acc: 0.5432
# Epoch 3, Train Loss: 0.6784, Train Acc: 0.6001, Val Acc: 0.6717
# Epoch 4, Train Loss: 0.6670, Train Acc: 0.6387, Val Acc: 0.6961
# Epoch 5, Train Loss: 0.6504, Train Acc: 0.6657, Val Acc: 0.7036
# Epoch 6, Train Loss: 0.6263, Train Acc: 0.6991, Val Acc: 0.7054
# Epoch 7, Train Loss: 0.5879, Train Acc: 0.7144, Val Acc: 0.7270
# Epoch 8, Train Loss: 0.5462, Train Acc: 0.7237, Val Acc: 0.7364
# Epoch 9, Train Loss: 0.5291, Train Acc: 0.7363, Val Acc: 0.7251
# Epoch 10, Train Loss: 0.5169, Train Acc: 0.7421, Val Acc: 0.7345
# Epoch 11, Train Loss: 0.5059, Train Acc: 0.7490, Val Acc: 0.7533
# Epoch 12, Train Loss: 0.4975, Train Acc: 0.7552, Val Acc: 0.7570
# Epoch 13, Train Loss: 0.4927, Train Acc: 0.7604, Val Acc: 0.7523
# Epoch 14, Train Loss: 0.4870, Train Acc: 0.7613, Val Acc: 0.7345
# Epoch 15, Train Loss: 0.4788, Train Acc: 0.7680, Val Acc: 0.7383
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.6284, Train Acc: 0.6433, Val Acc: 0.7101
# Epoch 2, Train Loss: 0.5591, Train Acc: 0.7109, Val Acc: 0.5985
# Epoch 3, Train Loss: 0.5515, Train Acc: 0.7168, Val Acc: 0.7336
# Epoch 4, Train Loss: 0.5549, Train Acc: 0.7145, Val Acc: 0.7008
# Epoch 5, Train Loss: 0.5614, Train Acc: 0.7166, Val Acc: 0.7158
# Epoch 6, Train Loss: 0.5492, Train Acc: 0.7234, Val Acc: 0.7280
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8909, Train Acc: 0.5285, Val Acc: 0.5066
# Epoch 2, Train Loss: 0.7093, Train Acc: 0.5994, Val Acc: 0.6820
# Epoch 3, Train Loss: 0.6909, Train Acc: 0.6281, Val Acc: 0.6126
# Epoch 4, Train Loss: 0.6586, Train Acc: 0.6589, Val Acc: 0.6295
# Epoch 5, Train Loss: 0.6609, Train Acc: 0.6685, Val Acc: 0.6557
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6942, Train Acc: 0.5021, Val Acc: 0.5131
# Epoch 2, Train Loss: 0.6902, Train Acc: 0.5321, Val Acc: 0.5788
# Epoch 3, Train Loss: 0.6850, Train Acc: 0.5620, Val Acc: 0.5704
# Epoch 4, Train Loss: 0.6823, Train Acc: 0.5883, Val Acc: 0.6351
# Epoch 5, Train Loss: 0.6767, Train Acc: 0.6121, Val Acc: 0.6482
# Epoch 6, Train Loss: 0.6724, Train Acc: 0.6311, Val Acc: 0.6614
# Epoch 7, Train Loss: 0.6656, Train Acc: 0.6421, Val Acc: 0.6576
# Epoch 8, Train Loss: 0.6570, Train Acc: 0.6635, Val Acc: 0.6942
# Epoch 9, Train Loss: 0.6479, Train Acc: 0.6750, Val Acc: 0.6951
# Epoch 10, Train Loss: 0.6350, Train Acc: 0.6898, Val Acc: 0.7008
# Epoch 11, Train Loss: 0.6151, Train Acc: 0.7019, Val Acc: 0.6998
# Epoch 12, Train Loss: 0.5884, Train Acc: 0.7101, Val Acc: 0.6764
# Epoch 13, Train Loss: 0.5612, Train Acc: 0.7148, Val Acc: 0.7083
# Epoch 14, Train Loss: 0.5456, Train Acc: 0.7257, Val Acc: 0.7111
# Epoch 15, Train Loss: 0.5363, Train Acc: 0.7254, Val Acc: 0.7242
# Epoch 16, Train Loss: 0.5259, Train Acc: 0.7346, Val Acc: 0.7298
# Epoch 17, Train Loss: 0.5186, Train Acc: 0.7435, Val Acc: 0.7195
# Epoch 18, Train Loss: 0.5141, Train Acc: 0.7441, Val Acc: 0.7308
# Epoch 19, Train Loss: 0.5093, Train Acc: 0.7482, Val Acc: 0.7373
# Epoch 20, Train Loss: 0.5054, Train Acc: 0.7479, Val Acc: 0.7430
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.6440, Train Acc: 0.6236, Val Acc: 0.7064
# Epoch 2, Train Loss: 0.5520, Train Acc: 0.7101, Val Acc: 0.6942
# Epoch 3, Train Loss: 0.5359, Train Acc: 0.7295, Val Acc: 0.6782
# Epoch 4, Train Loss: 0.5205, Train Acc: 0.7377, Val Acc: 0.7111
# Epoch 5, Train Loss: 0.5092, Train Acc: 0.7430, Val Acc: 0.7073
# Epoch 6, Train Loss: 0.5096, Train Acc: 0.7457, Val Acc: 0.7430
# Epoch 7, Train Loss: 0.5004, Train Acc: 0.7457, Val Acc: 0.7242
# Epoch 8, Train Loss: 0.5054, Train Acc: 0.7469, Val Acc: 0.7514
# Epoch 9, Train Loss: 0.5265, Train Acc: 0.7370, Val Acc: 0.7233
# Epoch 10, Train Loss: 0.5183, Train Acc: 0.7413, Val Acc: 0.7364
# Epoch 11, Train Loss: 0.5154, Train Acc: 0.7484, Val Acc: 0.7402
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9331, Train Acc: 0.5426, Val Acc: 0.5375
# Epoch 2, Train Loss: 0.7326, Train Acc: 0.5824, Val Acc: 0.5141
# Epoch 3, Train Loss: 0.7070, Train Acc: 0.6295, Val Acc: 0.6735
# Epoch 4, Train Loss: 0.6146, Train Acc: 0.6769, Val Acc: 0.5432
# Epoch 5, Train Loss: 0.6089, Train Acc: 0.6902, Val Acc: 0.6295
# Epoch 6, Train Loss: 0.6180, Train Acc: 0.6877, Val Acc: 0.6548
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6829, Train Acc: 0.5630, Val Acc: 0.5929
# Epoch 2, Train Loss: 0.5993, Train Acc: 0.6904, Val Acc: 0.7261
# Epoch 3, Train Loss: 0.5205, Train Acc: 0.7362, Val Acc: 0.6417
# Epoch 4, Train Loss: 0.4937, Train Acc: 0.7574, Val Acc: 0.7523
# Epoch 5, Train Loss: 0.4791, Train Acc: 0.7667, Val Acc: 0.7233
# Epoch 6, Train Loss: 0.4651, Train Acc: 0.7767, Val Acc: 0.7758
# Epoch 7, Train Loss: 0.4553, Train Acc: 0.7825, Val Acc: 0.7495
# Epoch 8, Train Loss: 0.4436, Train Acc: 0.7933, Val Acc: 0.6717
# Epoch 9, Train Loss: 0.4394, Train Acc: 0.7920, Val Acc: 0.7467
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.8100, Train Acc: 0.5067, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7674, Train Acc: 0.4903, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7787, Train Acc: 0.5045, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.8205, Train Acc: 0.5108, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1342, Train Acc: 0.5270, Val Acc: 0.5000
# Epoch 2, Train Loss: 1.2194, Train Acc: 0.5280, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.9773, Train Acc: 0.5392, Val Acc: 0.5366
# Epoch 4, Train Loss: 1.0070, Train Acc: 0.5440, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.9386, Train Acc: 0.5723, Val Acc: 0.5994
# Epoch 6, Train Loss: 0.9299, Train Acc: 0.5866, Val Acc: 0.5197
# Epoch 7, Train Loss: 0.9159, Train Acc: 0.5955, Val Acc: 0.5000
# Epoch 8, Train Loss: 0.9659, Train Acc: 0.5916, Val Acc: 0.5038
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6908, Train Acc: 0.5333, Val Acc: 0.5338
# Epoch 2, Train Loss: 0.6726, Train Acc: 0.6023, Val Acc: 0.6811
# Epoch 3, Train Loss: 0.6353, Train Acc: 0.6851, Val Acc: 0.7008
# Epoch 4, Train Loss: 0.5663, Train Acc: 0.7204, Val Acc: 0.7261
# Epoch 5, Train Loss: 0.5304, Train Acc: 0.7278, Val Acc: 0.7223
# Epoch 6, Train Loss: 0.5115, Train Acc: 0.7428, Val Acc: 0.7008
# Epoch 7, Train Loss: 0.4949, Train Acc: 0.7572, Val Acc: 0.7486
# Epoch 8, Train Loss: 0.4871, Train Acc: 0.7655, Val Acc: 0.7514
# Epoch 9, Train Loss: 0.4806, Train Acc: 0.7676, Val Acc: 0.7242
# Epoch 10, Train Loss: 0.4712, Train Acc: 0.7735, Val Acc: 0.7711
# Epoch 11, Train Loss: 0.4631, Train Acc: 0.7758, Val Acc: 0.7570
# Epoch 12, Train Loss: 0.4584, Train Acc: 0.7798, Val Acc: 0.7711
# Epoch 13, Train Loss: 0.4477, Train Acc: 0.7865, Val Acc: 0.7739
# Epoch 14, Train Loss: 0.4480, Train Acc: 0.7868, Val Acc: 0.7617
# Epoch 15, Train Loss: 0.4453, Train Acc: 0.7883, Val Acc: 0.7702
# Epoch 16, Train Loss: 0.4378, Train Acc: 0.7938, Val Acc: 0.7720
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7190, Train Acc: 0.5524, Val Acc: 0.6417
# Epoch 2, Train Loss: 0.6622, Train Acc: 0.6295, Val Acc: 0.6417
# Epoch 3, Train Loss: 0.6541, Train Acc: 0.6465, Val Acc: 0.6248
# Epoch 4, Train Loss: 0.6708, Train Acc: 0.6309, Val Acc: 0.6754
# Epoch 5, Train Loss: 0.6220, Train Acc: 0.6717, Val Acc: 0.6173
# Epoch 6, Train Loss: 0.6462, Train Acc: 0.6706, Val Acc: 0.6013
# Epoch 7, Train Loss: 0.6665, Train Acc: 0.6555, Val Acc: 0.6820
# Epoch 8, Train Loss: 0.6343, Train Acc: 0.6625, Val Acc: 0.6295
# Epoch 9, Train Loss: 0.6450, Train Acc: 0.6671, Val Acc: 0.6285
# Epoch 10, Train Loss: 0.6507, Train Acc: 0.6743, Val Acc: 0.6163
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4310, Train Acc: 0.5178, Val Acc: 0.5000
# Epoch 2, Train Loss: 1.0274, Train Acc: 0.5280, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.9891, Train Acc: 0.5382, Val Acc: 0.5403
# Epoch 4, Train Loss: 0.9314, Train Acc: 0.5562, Val Acc: 0.5113
# Epoch 5, Train Loss: 0.9151, Train Acc: 0.5632, Val Acc: 0.5704
# Epoch 6, Train Loss: 0.8778, Train Acc: 0.5795, Val Acc: 0.5994
# Epoch 7, Train Loss: 0.8425, Train Acc: 0.6081, Val Acc: 0.6182
# Epoch 8, Train Loss: 0.8275, Train Acc: 0.6036, Val Acc: 0.5994
# Epoch 9, Train Loss: 0.8349, Train Acc: 0.6149, Val Acc: 0.6041
# Epoch 10, Train Loss: 0.8124, Train Acc: 0.6256, Val Acc: 0.6463
# Epoch 11, Train Loss: 0.8397, Train Acc: 0.6224, Val Acc: 0.6792
# Epoch 12, Train Loss: 0.8393, Train Acc: 0.6152, Val Acc: 0.5704
# Epoch 13, Train Loss: 0.8593, Train Acc: 0.6171, Val Acc: 0.6388
# Epoch 14, Train Loss: 0.8178, Train Acc: 0.6358, Val Acc: 0.6754
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6935, Train Acc: 0.5138, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6858, Train Acc: 0.5531, Val Acc: 0.6098
# Epoch 3, Train Loss: 0.6775, Train Acc: 0.6061, Val Acc: 0.6098
# Epoch 4, Train Loss: 0.6659, Train Acc: 0.6354, Val Acc: 0.7176
# Epoch 5, Train Loss: 0.6495, Train Acc: 0.6789, Val Acc: 0.7054
# Epoch 6, Train Loss: 0.6234, Train Acc: 0.6980, Val Acc: 0.7345
# Epoch 7, Train Loss: 0.5764, Train Acc: 0.7204, Val Acc: 0.7298
# Epoch 8, Train Loss: 0.5423, Train Acc: 0.7280, Val Acc: 0.6248
# Epoch 9, Train Loss: 0.5335, Train Acc: 0.7325, Val Acc: 0.6163
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.7131, Train Acc: 0.5497, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6568, Train Acc: 0.6287, Val Acc: 0.6492
# Epoch 3, Train Loss: 0.6449, Train Acc: 0.6599, Val Acc: 0.6998
# Epoch 4, Train Loss: 0.6258, Train Acc: 0.6705, Val Acc: 0.6951
# Epoch 5, Train Loss: 0.6474, Train Acc: 0.6664, Val Acc: 0.6520
# Epoch 6, Train Loss: 0.6048, Train Acc: 0.6875, Val Acc: 0.6914
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4944, Train Acc: 0.5209, Val Acc: 0.5291
# Epoch 2, Train Loss: 0.9053, Train Acc: 0.5335, Val Acc: 0.5694
# Epoch 3, Train Loss: 0.9451, Train Acc: 0.5615, Val Acc: 0.5319
# Epoch 4, Train Loss: 0.8429, Train Acc: 0.5721, Val Acc: 0.6426
# Epoch 5, Train Loss: 0.8394, Train Acc: 0.5842, Val Acc: 0.6051
# Epoch 6, Train Loss: 0.7936, Train Acc: 0.6108, Val Acc: 0.6651
# Epoch 7, Train Loss: 0.8044, Train Acc: 0.6159, Val Acc: 0.5169
# Epoch 8, Train Loss: 0.7904, Train Acc: 0.6205, Val Acc: 0.5985
# Epoch 9, Train Loss: 0.7412, Train Acc: 0.6580, Val Acc: 0.6595
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6159, Train Acc: 0.6662, Val Acc: 0.6932
# Epoch 2, Train Loss: 0.5051, Train Acc: 0.7491, Val Acc: 0.7214
# Epoch 3, Train Loss: 0.4755, Train Acc: 0.7698, Val Acc: 0.7270
# Epoch 4, Train Loss: 0.4679, Train Acc: 0.7775, Val Acc: 0.7186
# Epoch 5, Train Loss: 0.4498, Train Acc: 0.7859, Val Acc: 0.7542
# Epoch 6, Train Loss: 0.4369, Train Acc: 0.7982, Val Acc: 0.7749
# Epoch 7, Train Loss: 0.4338, Train Acc: 0.7980, Val Acc: 0.7430
# Epoch 8, Train Loss: 0.4249, Train Acc: 0.8072, Val Acc: 0.7054
# Epoch 9, Train Loss: 0.4130, Train Acc: 0.8192, Val Acc: 0.7223
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 2.1455, Train Acc: 0.5149, Val Acc: 0.4972
# Epoch 2, Train Loss: 2.3721, Train Acc: 0.5147, Val Acc: 0.5009
# Epoch 3, Train Loss: 2.0604, Train Acc: 0.5097, Val Acc: 0.5084
# Epoch 4, Train Loss: 3.1736, Train Acc: 0.4996, Val Acc: 0.5000
# Epoch 5, Train Loss: 3.9166, Train Acc: 0.4979, Val Acc: 0.5000
# Epoch 6, Train Loss: 3.2635, Train Acc: 0.4995, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 13.1879, Train Acc: 0.5020, Val Acc: 0.5000
# Epoch 2, Train Loss: 10.1768, Train Acc: 0.5243, Val Acc: 0.5038
# Epoch 3, Train Loss: 10.4904, Train Acc: 0.5076, Val Acc: 0.5131
# Epoch 4, Train Loss: 10.7174, Train Acc: 0.5140, Val Acc: 0.5328
# Epoch 5, Train Loss: 10.2400, Train Acc: 0.5144, Val Acc: 0.5178
# Epoch 6, Train Loss: 9.9519, Train Acc: 0.5250, Val Acc: 0.5000
# Epoch 7, Train Loss: 10.0777, Train Acc: 0.5148, Val Acc: 0.5347
# Epoch 8, Train Loss: 9.7440, Train Acc: 0.5261, Val Acc: 0.5019
# Epoch 9, Train Loss: 10.1326, Train Acc: 0.5162, Val Acc: 0.5000
# Epoch 10, Train Loss: 9.5368, Train Acc: 0.5177, Val Acc: 0.5310
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6584, Train Acc: 0.6301, Val Acc: 0.7308
# Epoch 2, Train Loss: 0.5172, Train Acc: 0.7395, Val Acc: 0.7552
# Epoch 3, Train Loss: 0.4729, Train Acc: 0.7706, Val Acc: 0.7608
# Epoch 4, Train Loss: 0.4603, Train Acc: 0.7762, Val Acc: 0.7608
# Epoch 5, Train Loss: 0.4325, Train Acc: 0.7914, Val Acc: 0.7739
# Epoch 6, Train Loss: 0.4163, Train Acc: 0.8072, Val Acc: 0.7570
# Epoch 7, Train Loss: 0.3995, Train Acc: 0.8175, Val Acc: 0.7289
# Epoch 8, Train Loss: 0.3983, Train Acc: 0.8184, Val Acc: 0.7720
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 2.1724, Train Acc: 0.5165, Val Acc: 0.5197
# Epoch 2, Train Loss: 1.3889, Train Acc: 0.5267, Val Acc: 0.5272
# Epoch 3, Train Loss: 1.3046, Train Acc: 0.5259, Val Acc: 0.5009
# Epoch 4, Train Loss: 1.8283, Train Acc: 0.5336, Val Acc: 0.5047
# Epoch 5, Train Loss: 1.6160, Train Acc: 0.5246, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 14.5287, Train Acc: 0.5074, Val Acc: 0.5000
# Epoch 2, Train Loss: 9.4655, Train Acc: 0.5215, Val Acc: 0.5000
# Epoch 3, Train Loss: 9.4422, Train Acc: 0.5231, Val Acc: 0.5019
# Epoch 4, Train Loss: 9.4602, Train Acc: 0.5165, Val Acc: 0.5075
# Epoch 5, Train Loss: 9.2868, Train Acc: 0.5242, Val Acc: 0.5122
# Epoch 6, Train Loss: 9.4905, Train Acc: 0.5141, Val Acc: 0.5009
# Epoch 7, Train Loss: 9.0285, Train Acc: 0.5233, Val Acc: 0.5375
# Epoch 8, Train Loss: 8.8973, Train Acc: 0.5280, Val Acc: 0.5338
# Epoch 9, Train Loss: 9.2436, Train Acc: 0.5200, Val Acc: 0.4925
# Epoch 10, Train Loss: 10.0621, Train Acc: 0.5102, Val Acc: 0.5253
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.7158, Train Acc: 0.5682, Val Acc: 0.5713
# Epoch 2, Train Loss: 0.5627, Train Acc: 0.7043, Val Acc: 0.7392
# Epoch 3, Train Loss: 0.4958, Train Acc: 0.7536, Val Acc: 0.7355
# Epoch 4, Train Loss: 0.4761, Train Acc: 0.7698, Val Acc: 0.7533
# Epoch 5, Train Loss: 0.4504, Train Acc: 0.7869, Val Acc: 0.7636
# Epoch 6, Train Loss: 0.4348, Train Acc: 0.7919, Val Acc: 0.7467
# Epoch 7, Train Loss: 0.4278, Train Acc: 0.7981, Val Acc: 0.7120
# Epoch 8, Train Loss: 0.4086, Train Acc: 0.8022, Val Acc: 0.7598
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 2.1196, Train Acc: 0.5256, Val Acc: 0.5197
# Epoch 2, Train Loss: 2.2488, Train Acc: 0.5072, Val Acc: 0.5000
# Epoch 3, Train Loss: 1.6113, Train Acc: 0.5066, Val Acc: 0.5000
# Epoch 4, Train Loss: 1.1088, Train Acc: 0.5355, Val Acc: 0.5188
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 19.2551, Train Acc: 0.5110, Val Acc: 0.5497
# Epoch 2, Train Loss: 10.7257, Train Acc: 0.5106, Val Acc: 0.4981
# Epoch 3, Train Loss: 9.8707, Train Acc: 0.5267, Val Acc: 0.5000
# Epoch 4, Train Loss: 9.5687, Train Acc: 0.5240, Val Acc: 0.5047
# Early stopping
# Best Validation Accuracy: 0.8020637898686679
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 64, 'optimizer': 'Adam'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_OOV_freeze['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_OOV_freeze = MaxPoolingRNNModel(embedding_matrix_cosine_sim, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_OOV_freeze['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
elif best_hyperparams_OOV_freeze['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
elif best_hyperparams_OOV_freeze['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])

best_model_OOV_freeze, train_losses, train_accuracies, val_accuracies = train_model(best_model_OOV_freeze, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5510, Train Acc: 0.7063, Val Acc: 0.7664
# Epoch 2, Train Loss: 0.4657, Train Acc: 0.7761, Val Acc: 0.7852
# Epoch 3, Train Loss: 0.4444, Train Acc: 0.7904, Val Acc: 0.7871
# Epoch 4, Train Loss: 0.4199, Train Acc: 0.8025, Val Acc: 0.7899
# Epoch 5, Train Loss: 0.3974, Train Acc: 0.8176, Val Acc: 0.7842
# Epoch 6, Train Loss: 0.3857, Train Acc: 0.8230, Val Acc: 0.7917
# Epoch 7, Train Loss: 0.3653, Train Acc: 0.8377, Val Acc: 0.7683
# Epoch 8, Train Loss: 0.3514, Train Acc: 0.8450, Val Acc: 0.7964
# Epoch 9, Train Loss: 0.3300, Train Acc: 0.8583, Val Acc: 0.7946
# Epoch 10, Train Loss: 0.3134, Train Acc: 0.8665, Val Acc: 0.7824
# Epoch 11, Train Loss: 0.2954, Train Acc: 0.8741, Val Acc: 0.7777
# Early stopping

# %%
epochs_fw = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_fw, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_OOV_freeze, test_loader)
test_accuracies['RNN (Handle OOV)'] = test_acc
print(f'Test Accuracy (Handle OOV): {test_acc:.4f}')
# Out:
# Test Accuracy (Handle OOV): 0.7805

# %% [markdown]
# ### 2) Update Word Embeddings

# %%
# Call grid search
best_hyperparams_OOV_update = run_grid_search(MaxPoolingRNNModelUpdate, embedding_matrix_cosine_sim, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6991, Train Acc: 0.4828, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.6936, Train Acc: 0.5087, Val Acc: 0.5103
# Epoch 3, Train Loss: 0.6913, Train Acc: 0.5234, Val Acc: 0.5394
# Epoch 4, Train Loss: 0.6888, Train Acc: 0.5482, Val Acc: 0.5675
# Epoch 5, Train Loss: 0.6846, Train Acc: 0.5693, Val Acc: 0.5994
# Epoch 6, Train Loss: 0.6823, Train Acc: 0.5898, Val Acc: 0.6107
# Epoch 7, Train Loss: 0.6781, Train Acc: 0.6115, Val Acc: 0.6360
# Epoch 8, Train Loss: 0.6748, Train Acc: 0.6315, Val Acc: 0.6548
# Epoch 9, Train Loss: 0.6701, Train Acc: 0.6409, Val Acc: 0.6717
# Epoch 10, Train Loss: 0.6647, Train Acc: 0.6675, Val Acc: 0.6576
# Epoch 11, Train Loss: 0.6590, Train Acc: 0.6756, Val Acc: 0.6904
# Epoch 12, Train Loss: 0.6517, Train Acc: 0.6916, Val Acc: 0.7101
# Epoch 13, Train Loss: 0.6418, Train Acc: 0.6984, Val Acc: 0.6979
# Epoch 14, Train Loss: 0.6311, Train Acc: 0.7000, Val Acc: 0.7205
# Epoch 15, Train Loss: 0.6176, Train Acc: 0.7067, Val Acc: 0.7270
# Epoch 16, Train Loss: 0.5981, Train Acc: 0.7234, Val Acc: 0.7326
# Epoch 17, Train Loss: 0.5740, Train Acc: 0.7205, Val Acc: 0.7205
# Epoch 18, Train Loss: 0.5487, Train Acc: 0.7253, Val Acc: 0.7251
# Epoch 19, Train Loss: 0.5392, Train Acc: 0.7288, Val Acc: 0.7280
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5230, Train Acc: 0.7299, Val Acc: 0.7477
# Epoch 2, Train Loss: 0.3640, Train Acc: 0.8343, Val Acc: 0.8002
# Epoch 3, Train Loss: 0.2362, Train Acc: 0.9025, Val Acc: 0.7917
# Epoch 4, Train Loss: 0.1416, Train Acc: 0.9449, Val Acc: 0.7936
# Epoch 5, Train Loss: 0.0936, Train Acc: 0.9655, Val Acc: 0.7598
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5308, Train Acc: 0.7209, Val Acc: 0.7467
# Epoch 2, Train Loss: 0.3882, Train Acc: 0.8263, Val Acc: 0.8114
# Epoch 3, Train Loss: 0.2975, Train Acc: 0.8729, Val Acc: 0.7777
# Epoch 4, Train Loss: 0.2281, Train Acc: 0.9064, Val Acc: 0.6979
# Epoch 5, Train Loss: 0.1717, Train Acc: 0.9341, Val Acc: 0.7767
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6925, Train Acc: 0.5116, Val Acc: 0.5347
# Epoch 2, Train Loss: 0.6909, Train Acc: 0.5347, Val Acc: 0.5478
# Epoch 3, Train Loss: 0.6895, Train Acc: 0.5442, Val Acc: 0.5553
# Epoch 4, Train Loss: 0.6882, Train Acc: 0.5538, Val Acc: 0.5732
# Epoch 5, Train Loss: 0.6863, Train Acc: 0.5714, Val Acc: 0.5947
# Epoch 6, Train Loss: 0.6851, Train Acc: 0.5753, Val Acc: 0.5966
# Epoch 7, Train Loss: 0.6837, Train Acc: 0.5877, Val Acc: 0.6257
# Epoch 8, Train Loss: 0.6816, Train Acc: 0.5970, Val Acc: 0.6341
# Epoch 9, Train Loss: 0.6802, Train Acc: 0.6134, Val Acc: 0.6379
# Epoch 10, Train Loss: 0.6774, Train Acc: 0.6225, Val Acc: 0.6173
# Epoch 11, Train Loss: 0.6762, Train Acc: 0.6318, Val Acc: 0.6595
# Epoch 12, Train Loss: 0.6735, Train Acc: 0.6395, Val Acc: 0.6576
# Epoch 13, Train Loss: 0.6720, Train Acc: 0.6481, Val Acc: 0.6417
# Epoch 14, Train Loss: 0.6701, Train Acc: 0.6498, Val Acc: 0.6717
# Epoch 15, Train Loss: 0.6681, Train Acc: 0.6630, Val Acc: 0.6782
# Epoch 16, Train Loss: 0.6647, Train Acc: 0.6733, Val Acc: 0.6876
# Epoch 17, Train Loss: 0.6621, Train Acc: 0.6727, Val Acc: 0.6914
# Epoch 18, Train Loss: 0.6593, Train Acc: 0.6775, Val Acc: 0.6979
# Epoch 19, Train Loss: 0.6553, Train Acc: 0.6824, Val Acc: 0.7036
# Epoch 20, Train Loss: 0.6525, Train Acc: 0.6868, Val Acc: 0.7073
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5218, Train Acc: 0.7274, Val Acc: 0.7711
# Epoch 2, Train Loss: 0.3726, Train Acc: 0.8334, Val Acc: 0.7720
# Epoch 3, Train Loss: 0.2588, Train Acc: 0.8950, Val Acc: 0.7936
# Epoch 4, Train Loss: 0.1641, Train Acc: 0.9349, Val Acc: 0.7636
# Epoch 5, Train Loss: 0.0978, Train Acc: 0.9665, Val Acc: 0.7805
# Epoch 6, Train Loss: 0.0600, Train Acc: 0.9788, Val Acc: 0.7795
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5494, Train Acc: 0.7124, Val Acc: 0.7664
# Epoch 2, Train Loss: 0.3865, Train Acc: 0.8226, Val Acc: 0.7758
# Epoch 3, Train Loss: 0.3009, Train Acc: 0.8673, Val Acc: 0.7852
# Epoch 4, Train Loss: 0.2240, Train Acc: 0.9109, Val Acc: 0.8011
# Epoch 5, Train Loss: 0.1636, Train Acc: 0.9388, Val Acc: 0.7795
# Epoch 6, Train Loss: 0.1153, Train Acc: 0.9565, Val Acc: 0.7749
# Epoch 7, Train Loss: 0.0825, Train Acc: 0.9708, Val Acc: 0.7871
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6948, Train Acc: 0.5047, Val Acc: 0.5507
# Epoch 2, Train Loss: 0.6921, Train Acc: 0.5127, Val Acc: 0.5563
# Epoch 3, Train Loss: 0.6918, Train Acc: 0.5204, Val Acc: 0.5638
# Epoch 4, Train Loss: 0.6908, Train Acc: 0.5251, Val Acc: 0.5619
# Epoch 5, Train Loss: 0.6897, Train Acc: 0.5379, Val Acc: 0.5769
# Epoch 6, Train Loss: 0.6889, Train Acc: 0.5470, Val Acc: 0.5844
# Epoch 7, Train Loss: 0.6883, Train Acc: 0.5542, Val Acc: 0.5929
# Epoch 8, Train Loss: 0.6873, Train Acc: 0.5586, Val Acc: 0.6032
# Epoch 9, Train Loss: 0.6861, Train Acc: 0.5639, Val Acc: 0.6013
# Epoch 10, Train Loss: 0.6856, Train Acc: 0.5689, Val Acc: 0.6154
# Epoch 11, Train Loss: 0.6853, Train Acc: 0.5747, Val Acc: 0.6173
# Epoch 12, Train Loss: 0.6841, Train Acc: 0.5777, Val Acc: 0.6191
# Epoch 13, Train Loss: 0.6827, Train Acc: 0.5876, Val Acc: 0.6248
# Epoch 14, Train Loss: 0.6829, Train Acc: 0.5882, Val Acc: 0.6341
# Epoch 15, Train Loss: 0.6813, Train Acc: 0.5977, Val Acc: 0.6276
# Epoch 16, Train Loss: 0.6806, Train Acc: 0.5992, Val Acc: 0.6388
# Epoch 17, Train Loss: 0.6796, Train Acc: 0.6098, Val Acc: 0.6398
# Epoch 18, Train Loss: 0.6786, Train Acc: 0.6120, Val Acc: 0.6341
# Epoch 19, Train Loss: 0.6776, Train Acc: 0.6135, Val Acc: 0.6529
# Epoch 20, Train Loss: 0.6770, Train Acc: 0.6150, Val Acc: 0.6501
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5548, Train Acc: 0.7118, Val Acc: 0.7683
# Epoch 2, Train Loss: 0.4015, Train Acc: 0.8179, Val Acc: 0.7974
# Epoch 3, Train Loss: 0.2968, Train Acc: 0.8754, Val Acc: 0.7852
# Epoch 4, Train Loss: 0.2012, Train Acc: 0.9242, Val Acc: 0.7880
# Epoch 5, Train Loss: 0.1358, Train Acc: 0.9504, Val Acc: 0.7908
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5650, Train Acc: 0.7016, Val Acc: 0.7711
# Epoch 2, Train Loss: 0.3905, Train Acc: 0.8203, Val Acc: 0.7683
# Epoch 3, Train Loss: 0.3132, Train Acc: 0.8632, Val Acc: 0.7917
# Epoch 4, Train Loss: 0.2391, Train Acc: 0.9032, Val Acc: 0.7955
# Epoch 5, Train Loss: 0.1755, Train Acc: 0.9320, Val Acc: 0.7561
# Epoch 6, Train Loss: 0.1408, Train Acc: 0.9471, Val Acc: 0.7702
# Epoch 7, Train Loss: 0.0985, Train Acc: 0.9649, Val Acc: 0.7448
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6878, Train Acc: 0.5389, Val Acc: 0.5929
# Epoch 2, Train Loss: 0.6617, Train Acc: 0.6275, Val Acc: 0.6332
# Epoch 3, Train Loss: 0.6064, Train Acc: 0.6907, Val Acc: 0.7308
# Epoch 4, Train Loss: 0.5442, Train Acc: 0.7265, Val Acc: 0.6323
# Epoch 5, Train Loss: 0.5199, Train Acc: 0.7370, Val Acc: 0.6538
# Epoch 6, Train Loss: 0.5016, Train Acc: 0.7537, Val Acc: 0.7477
# Epoch 7, Train Loss: 0.4955, Train Acc: 0.7556, Val Acc: 0.7101
# Epoch 8, Train Loss: 0.4811, Train Acc: 0.7630, Val Acc: 0.7458
# Epoch 9, Train Loss: 0.4767, Train Acc: 0.7687, Val Acc: 0.7542
# Epoch 10, Train Loss: 0.4692, Train Acc: 0.7727, Val Acc: 0.7533
# Epoch 11, Train Loss: 0.4588, Train Acc: 0.7749, Val Acc: 0.7645
# Epoch 12, Train Loss: 0.4578, Train Acc: 0.7792, Val Acc: 0.7233
# Epoch 13, Train Loss: 0.4520, Train Acc: 0.7838, Val Acc: 0.7730
# Epoch 14, Train Loss: 0.4421, Train Acc: 0.7896, Val Acc: 0.7083
# Epoch 15, Train Loss: 0.4398, Train Acc: 0.7891, Val Acc: 0.7674
# Epoch 16, Train Loss: 0.4331, Train Acc: 0.7975, Val Acc: 0.7608
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6961, Train Acc: 0.5887, Val Acc: 0.6332
# Epoch 2, Train Loss: 0.5639, Train Acc: 0.7141, Val Acc: 0.7111
# Epoch 3, Train Loss: 0.4572, Train Acc: 0.7931, Val Acc: 0.7026
# Epoch 4, Train Loss: 0.3622, Train Acc: 0.8490, Val Acc: 0.7205
# Epoch 5, Train Loss: 0.3602, Train Acc: 0.8407, Val Acc: 0.6923
# Epoch 6, Train Loss: 0.3110, Train Acc: 0.8701, Val Acc: 0.7026
# Epoch 7, Train Loss: 0.2657, Train Acc: 0.8925, Val Acc: 0.7158
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9499, Train Acc: 0.5182, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.7703, Train Acc: 0.5687, Val Acc: 0.5797
# Epoch 3, Train Loss: 0.6523, Train Acc: 0.6964, Val Acc: 0.7233
# Epoch 4, Train Loss: 0.5367, Train Acc: 0.7685, Val Acc: 0.7083
# Epoch 5, Train Loss: 0.4311, Train Acc: 0.8199, Val Acc: 0.7308
# Epoch 6, Train Loss: 0.3725, Train Acc: 0.8517, Val Acc: 0.7336
# Epoch 7, Train Loss: 0.3074, Train Acc: 0.8816, Val Acc: 0.7448
# Epoch 8, Train Loss: 0.2627, Train Acc: 0.9000, Val Acc: 0.7477
# Epoch 9, Train Loss: 0.2321, Train Acc: 0.9140, Val Acc: 0.5966
# Epoch 10, Train Loss: 0.2002, Train Acc: 0.9275, Val Acc: 0.7364
# Epoch 11, Train Loss: 0.1753, Train Acc: 0.9373, Val Acc: 0.7336
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6926, Train Acc: 0.5198, Val Acc: 0.5891
# Epoch 2, Train Loss: 0.6841, Train Acc: 0.5680, Val Acc: 0.6417
# Epoch 3, Train Loss: 0.6752, Train Acc: 0.6067, Val Acc: 0.6604
# Epoch 4, Train Loss: 0.6629, Train Acc: 0.6468, Val Acc: 0.6323
# Epoch 5, Train Loss: 0.6443, Train Acc: 0.6819, Val Acc: 0.6970
# Epoch 6, Train Loss: 0.6129, Train Acc: 0.7107, Val Acc: 0.7205
# Epoch 7, Train Loss: 0.5661, Train Acc: 0.7199, Val Acc: 0.7242
# Epoch 8, Train Loss: 0.5340, Train Acc: 0.7291, Val Acc: 0.6839
# Epoch 9, Train Loss: 0.5226, Train Acc: 0.7366, Val Acc: 0.7411
# Epoch 10, Train Loss: 0.5147, Train Acc: 0.7450, Val Acc: 0.7486
# Epoch 11, Train Loss: 0.5025, Train Acc: 0.7529, Val Acc: 0.7495
# Epoch 12, Train Loss: 0.4929, Train Acc: 0.7584, Val Acc: 0.7542
# Epoch 13, Train Loss: 0.4884, Train Acc: 0.7585, Val Acc: 0.7598
# Epoch 14, Train Loss: 0.4871, Train Acc: 0.7620, Val Acc: 0.7636
# Epoch 15, Train Loss: 0.4772, Train Acc: 0.7702, Val Acc: 0.7664
# Epoch 16, Train Loss: 0.4765, Train Acc: 0.7695, Val Acc: 0.7533
# Epoch 17, Train Loss: 0.4706, Train Acc: 0.7740, Val Acc: 0.7702
# Epoch 18, Train Loss: 0.4680, Train Acc: 0.7757, Val Acc: 0.7467
# Epoch 19, Train Loss: 0.4614, Train Acc: 0.7758, Val Acc: 0.7664
# Epoch 20, Train Loss: 0.4629, Train Acc: 0.7785, Val Acc: 0.7749
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5920, Train Acc: 0.6758, Val Acc: 0.7167
# Epoch 2, Train Loss: 0.4194, Train Acc: 0.8090, Val Acc: 0.7261
# Epoch 3, Train Loss: 0.2730, Train Acc: 0.8848, Val Acc: 0.7402
# Epoch 4, Train Loss: 0.2005, Train Acc: 0.9202, Val Acc: 0.7486
# Epoch 5, Train Loss: 0.1411, Train Acc: 0.9448, Val Acc: 0.7439
# Epoch 6, Train Loss: 0.0979, Train Acc: 0.9638, Val Acc: 0.7101
# Epoch 7, Train Loss: 0.0879, Train Acc: 0.9672, Val Acc: 0.7233
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.8404, Train Acc: 0.5526, Val Acc: 0.5178
# Epoch 2, Train Loss: 0.6586, Train Acc: 0.6492, Val Acc: 0.6435
# Epoch 3, Train Loss: 0.5206, Train Acc: 0.7694, Val Acc: 0.7148
# Epoch 4, Train Loss: 0.3774, Train Acc: 0.8370, Val Acc: 0.7223
# Epoch 5, Train Loss: 0.2863, Train Acc: 0.8790, Val Acc: 0.7355
# Epoch 6, Train Loss: 0.2343, Train Acc: 0.9049, Val Acc: 0.7364
# Epoch 7, Train Loss: 0.1953, Train Acc: 0.9258, Val Acc: 0.7373
# Epoch 8, Train Loss: 0.1617, Train Acc: 0.9400, Val Acc: 0.7336
# Epoch 9, Train Loss: 0.1356, Train Acc: 0.9484, Val Acc: 0.7317
# Epoch 10, Train Loss: 0.1115, Train Acc: 0.9587, Val Acc: 0.7289
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6946, Train Acc: 0.5035, Val Acc: 0.5169
# Epoch 2, Train Loss: 0.6898, Train Acc: 0.5396, Val Acc: 0.5722
# Epoch 3, Train Loss: 0.6856, Train Acc: 0.5649, Val Acc: 0.5338
# Epoch 4, Train Loss: 0.6796, Train Acc: 0.5941, Val Acc: 0.6492
# Epoch 5, Train Loss: 0.6755, Train Acc: 0.6227, Val Acc: 0.6707
# Epoch 6, Train Loss: 0.6686, Train Acc: 0.6409, Val Acc: 0.5863
# Epoch 7, Train Loss: 0.6616, Train Acc: 0.6523, Val Acc: 0.6266
# Epoch 8, Train Loss: 0.6523, Train Acc: 0.6826, Val Acc: 0.6764
# Epoch 9, Train Loss: 0.6408, Train Acc: 0.7014, Val Acc: 0.6801
# Epoch 10, Train Loss: 0.6251, Train Acc: 0.7082, Val Acc: 0.7251
# Epoch 11, Train Loss: 0.6057, Train Acc: 0.7136, Val Acc: 0.7242
# Epoch 12, Train Loss: 0.5806, Train Acc: 0.7181, Val Acc: 0.7064
# Epoch 13, Train Loss: 0.5527, Train Acc: 0.7245, Val Acc: 0.7111
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5960, Train Acc: 0.6619, Val Acc: 0.7664
# Epoch 2, Train Loss: 0.3752, Train Acc: 0.8336, Val Acc: 0.7777
# Epoch 3, Train Loss: 0.2183, Train Acc: 0.9164, Val Acc: 0.7683
# Epoch 4, Train Loss: 0.1112, Train Acc: 0.9598, Val Acc: 0.7730
# Epoch 5, Train Loss: 0.0656, Train Acc: 0.9797, Val Acc: 0.7598
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9483, Train Acc: 0.5370, Val Acc: 0.6023
# Epoch 2, Train Loss: 0.5971, Train Acc: 0.6851, Val Acc: 0.6388
# Epoch 3, Train Loss: 0.4618, Train Acc: 0.7804, Val Acc: 0.7223
# Epoch 4, Train Loss: 0.3720, Train Acc: 0.8351, Val Acc: 0.7148
# Epoch 5, Train Loss: 0.2962, Train Acc: 0.8771, Val Acc: 0.6989
# Epoch 6, Train Loss: 0.2632, Train Acc: 0.8937, Val Acc: 0.7158
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6826, Train Acc: 0.5530, Val Acc: 0.6857
# Epoch 2, Train Loss: 0.6032, Train Acc: 0.6834, Val Acc: 0.5244
# Epoch 3, Train Loss: 0.5245, Train Acc: 0.7379, Val Acc: 0.6698
# Epoch 4, Train Loss: 0.4961, Train Acc: 0.7540, Val Acc: 0.7655
# Epoch 5, Train Loss: 0.4811, Train Acc: 0.7648, Val Acc: 0.7383
# Epoch 6, Train Loss: 0.4661, Train Acc: 0.7751, Val Acc: 0.7345
# Epoch 7, Train Loss: 0.4569, Train Acc: 0.7802, Val Acc: 0.7645
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.7958, Train Acc: 0.4965, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.8094, Train Acc: 0.4954, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7915, Train Acc: 0.4968, Val Acc: 0.5000
# Epoch 4, Train Loss: 0.7956, Train Acc: 0.5087, Val Acc: 0.5000
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1265, Train Acc: 0.5284, Val Acc: 0.5488
# Epoch 2, Train Loss: 0.9038, Train Acc: 0.5986, Val Acc: 0.5478
# Epoch 3, Train Loss: 0.8196, Train Acc: 0.6812, Val Acc: 0.5056
# Epoch 4, Train Loss: 0.7215, Train Acc: 0.7120, Val Acc: 0.5469
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6895, Train Acc: 0.5385, Val Acc: 0.6116
# Epoch 2, Train Loss: 0.6719, Train Acc: 0.6032, Val Acc: 0.7026
# Epoch 3, Train Loss: 0.6293, Train Acc: 0.6828, Val Acc: 0.7251
# Epoch 4, Train Loss: 0.5603, Train Acc: 0.7211, Val Acc: 0.7280
# Epoch 5, Train Loss: 0.5260, Train Acc: 0.7354, Val Acc: 0.6707
# Epoch 6, Train Loss: 0.5091, Train Acc: 0.7512, Val Acc: 0.7533
# Epoch 7, Train Loss: 0.4931, Train Acc: 0.7574, Val Acc: 0.7495
# Epoch 8, Train Loss: 0.4859, Train Acc: 0.7660, Val Acc: 0.7608
# Epoch 9, Train Loss: 0.4754, Train Acc: 0.7689, Val Acc: 0.7664
# Epoch 10, Train Loss: 0.4663, Train Acc: 0.7748, Val Acc: 0.6595
# Epoch 11, Train Loss: 0.4577, Train Acc: 0.7796, Val Acc: 0.7589
# Epoch 12, Train Loss: 0.4549, Train Acc: 0.7805, Val Acc: 0.7392
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.7826, Train Acc: 0.4953, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6798, Train Acc: 0.5802, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.5736, Train Acc: 0.7175, Val Acc: 0.6839
# Epoch 4, Train Loss: 0.4659, Train Acc: 0.7958, Val Acc: 0.6923
# Epoch 5, Train Loss: 0.3958, Train Acc: 0.8343, Val Acc: 0.6951
# Epoch 6, Train Loss: 0.3362, Train Acc: 0.8661, Val Acc: 0.6970
# Epoch 7, Train Loss: 0.2835, Train Acc: 0.8885, Val Acc: 0.7101
# Epoch 8, Train Loss: 0.2367, Train Acc: 0.9073, Val Acc: 0.6979
# Epoch 9, Train Loss: 0.2297, Train Acc: 0.9140, Val Acc: 0.6932
# Epoch 10, Train Loss: 0.2029, Train Acc: 0.9236, Val Acc: 0.6829
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4313, Train Acc: 0.5163, Val Acc: 0.5150
# Epoch 2, Train Loss: 0.8714, Train Acc: 0.5883, Val Acc: 0.5976
# Epoch 3, Train Loss: 0.7837, Train Acc: 0.6578, Val Acc: 0.6407
# Epoch 4, Train Loss: 0.6657, Train Acc: 0.7182, Val Acc: 0.6660
# Epoch 5, Train Loss: 0.6075, Train Acc: 0.7571, Val Acc: 0.7026
# Epoch 6, Train Loss: 0.5056, Train Acc: 0.8027, Val Acc: 0.7101
# Epoch 7, Train Loss: 0.4332, Train Acc: 0.8294, Val Acc: 0.6417
# Epoch 8, Train Loss: 0.3853, Train Acc: 0.8591, Val Acc: 0.6942
# Epoch 9, Train Loss: 0.3312, Train Acc: 0.8801, Val Acc: 0.7111
# Epoch 10, Train Loss: 0.3800, Train Acc: 0.8776, Val Acc: 0.7139
# Epoch 11, Train Loss: 0.2927, Train Acc: 0.9005, Val Acc: 0.7289
# Epoch 12, Train Loss: 0.2733, Train Acc: 0.9125, Val Acc: 0.7233
# Epoch 13, Train Loss: 0.2563, Train Acc: 0.9176, Val Acc: 0.7148
# Epoch 14, Train Loss: 0.2215, Train Acc: 0.9294, Val Acc: 0.6820
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6900, Train Acc: 0.5272, Val Acc: 0.5253
# Epoch 2, Train Loss: 0.6823, Train Acc: 0.5681, Val Acc: 0.6398
# Epoch 3, Train Loss: 0.6732, Train Acc: 0.6171, Val Acc: 0.5826
# Epoch 4, Train Loss: 0.6597, Train Acc: 0.6497, Val Acc: 0.6689
# Epoch 5, Train Loss: 0.6413, Train Acc: 0.6839, Val Acc: 0.7148
# Epoch 6, Train Loss: 0.6163, Train Acc: 0.6994, Val Acc: 0.7223
# Epoch 7, Train Loss: 0.5793, Train Acc: 0.7197, Val Acc: 0.7280
# Epoch 8, Train Loss: 0.5422, Train Acc: 0.7286, Val Acc: 0.7289
# Epoch 9, Train Loss: 0.5240, Train Acc: 0.7355, Val Acc: 0.6989
# Epoch 10, Train Loss: 0.5122, Train Acc: 0.7463, Val Acc: 0.7289
# Epoch 11, Train Loss: 0.4994, Train Acc: 0.7519, Val Acc: 0.6923
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.6869, Train Acc: 0.5873, Val Acc: 0.7289
# Epoch 2, Train Loss: 0.5116, Train Acc: 0.7579, Val Acc: 0.7158
# Epoch 3, Train Loss: 0.3892, Train Acc: 0.8339, Val Acc: 0.7064
# Epoch 4, Train Loss: 0.3130, Train Acc: 0.8750, Val Acc: 0.7139
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.4850, Train Acc: 0.5317, Val Acc: 0.5535
# Epoch 2, Train Loss: 0.8537, Train Acc: 0.5957, Val Acc: 0.5403
# Epoch 3, Train Loss: 0.6739, Train Acc: 0.7019, Val Acc: 0.5910
# Epoch 4, Train Loss: 0.5337, Train Acc: 0.7774, Val Acc: 0.7064
# Epoch 5, Train Loss: 0.5104, Train Acc: 0.8095, Val Acc: 0.5994
# Epoch 6, Train Loss: 0.4332, Train Acc: 0.8411, Val Acc: 0.7205
# Epoch 7, Train Loss: 0.3236, Train Acc: 0.8830, Val Acc: 0.7289
# Epoch 8, Train Loss: 0.2684, Train Acc: 0.9039, Val Acc: 0.7336
# Epoch 9, Train Loss: 0.2400, Train Acc: 0.9143, Val Acc: 0.7420
# Epoch 10, Train Loss: 0.2259, Train Acc: 0.9268, Val Acc: 0.7280
# Epoch 11, Train Loss: 0.1630, Train Acc: 0.9428, Val Acc: 0.7233
# Epoch 12, Train Loss: 0.1638, Train Acc: 0.9431, Val Acc: 0.7223
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6127, Train Acc: 0.6659, Val Acc: 0.7655
# Epoch 2, Train Loss: 0.5099, Train Acc: 0.7454, Val Acc: 0.7570
# Epoch 3, Train Loss: 0.4745, Train Acc: 0.7750, Val Acc: 0.6567
# Epoch 4, Train Loss: 0.4495, Train Acc: 0.7858, Val Acc: 0.7411
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 2.5248, Train Acc: 0.5157, Val Acc: 0.5009
# Epoch 2, Train Loss: 2.2912, Train Acc: 0.5110, Val Acc: 0.5206
# Epoch 3, Train Loss: 2.3341, Train Acc: 0.5103, Val Acc: 0.5000
# Epoch 4, Train Loss: 2.8396, Train Acc: 0.5089, Val Acc: 0.5131
# Epoch 5, Train Loss: 2.4952, Train Acc: 0.5056, Val Acc: 0.5122
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 15.8415, Train Acc: 0.4973, Val Acc: 0.5000
# Epoch 2, Train Loss: 12.6391, Train Acc: 0.4988, Val Acc: 0.5000
# Epoch 3, Train Loss: 12.2416, Train Acc: 0.5137, Val Acc: 0.5009
# Epoch 4, Train Loss: 12.7921, Train Acc: 0.4999, Val Acc: 0.5019
# Epoch 5, Train Loss: 12.6567, Train Acc: 0.5061, Val Acc: 0.4981
# Epoch 6, Train Loss: 12.6396, Train Acc: 0.5070, Val Acc: 0.5000
# Epoch 7, Train Loss: 12.9853, Train Acc: 0.4977, Val Acc: 0.5009
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6590, Train Acc: 0.6232, Val Acc: 0.7298
# Epoch 2, Train Loss: 0.5134, Train Acc: 0.7471, Val Acc: 0.7580
# Epoch 3, Train Loss: 0.4778, Train Acc: 0.7693, Val Acc: 0.7627
# Epoch 4, Train Loss: 0.4394, Train Acc: 0.7928, Val Acc: 0.7871
# Epoch 5, Train Loss: 0.4181, Train Acc: 0.8053, Val Acc: 0.7692
# Epoch 6, Train Loss: 0.4017, Train Acc: 0.8171, Val Acc: 0.7908
# Epoch 7, Train Loss: 0.4013, Train Acc: 0.8172, Val Acc: 0.7589
# Epoch 8, Train Loss: 0.3595, Train Acc: 0.8397, Val Acc: 0.8058
# Epoch 9, Train Loss: 0.3499, Train Acc: 0.8422, Val Acc: 0.7805
# Epoch 10, Train Loss: 0.3510, Train Acc: 0.8421, Val Acc: 0.7824
# Epoch 11, Train Loss: 0.3284, Train Acc: 0.8558, Val Acc: 0.7373
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 2.0225, Train Acc: 0.5032, Val Acc: 0.4934
# Epoch 2, Train Loss: 2.3276, Train Acc: 0.5048, Val Acc: 0.5000
# Epoch 3, Train Loss: 1.6884, Train Acc: 0.5075, Val Acc: 0.5103
# Epoch 4, Train Loss: 1.5614, Train Acc: 0.5148, Val Acc: 0.5356
# Epoch 5, Train Loss: 2.0046, Train Acc: 0.5179, Val Acc: 0.5075
# Epoch 6, Train Loss: 2.8400, Train Acc: 0.5170, Val Acc: 0.5038
# Epoch 7, Train Loss: 1.4932, Train Acc: 0.5183, Val Acc: 0.5225
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 18.7822, Train Acc: 0.4964, Val Acc: 0.4962
# Epoch 2, Train Loss: 12.7304, Train Acc: 0.5033, Val Acc: 0.4953
# Epoch 3, Train Loss: 12.3899, Train Acc: 0.5096, Val Acc: 0.5009
# Epoch 4, Train Loss: 12.8591, Train Acc: 0.5022, Val Acc: 0.4972
# Epoch 5, Train Loss: 12.4824, Train Acc: 0.5048, Val Acc: 0.4991
# Epoch 6, Train Loss: 12.6701, Train Acc: 0.5004, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.7253, Train Acc: 0.5667, Val Acc: 0.7158
# Epoch 2, Train Loss: 0.5585, Train Acc: 0.7098, Val Acc: 0.7486
# Epoch 3, Train Loss: 0.5033, Train Acc: 0.7457, Val Acc: 0.6548
# Epoch 4, Train Loss: 0.4854, Train Acc: 0.7675, Val Acc: 0.7570
# Epoch 5, Train Loss: 0.4535, Train Acc: 0.7830, Val Acc: 0.7852
# Epoch 6, Train Loss: 0.4286, Train Acc: 0.7991, Val Acc: 0.7711
# Epoch 7, Train Loss: 0.4192, Train Acc: 0.8041, Val Acc: 0.7974
# Epoch 8, Train Loss: 0.4061, Train Acc: 0.8100, Val Acc: 0.8002
# Epoch 9, Train Loss: 0.3807, Train Acc: 0.8273, Val Acc: 0.8039
# Epoch 10, Train Loss: 0.3733, Train Acc: 0.8290, Val Acc: 0.7777
# Epoch 11, Train Loss: 0.3650, Train Acc: 0.8368, Val Acc: 0.7861
# Epoch 12, Train Loss: 0.3325, Train Acc: 0.8532, Val Acc: 0.8021
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 2.2877, Train Acc: 0.5055, Val Acc: 0.5131
# Epoch 2, Train Loss: 1.7223, Train Acc: 0.5165, Val Acc: 0.5319
# Epoch 3, Train Loss: 1.7858, Train Acc: 0.5205, Val Acc: 0.5028
# Epoch 4, Train Loss: 2.8312, Train Acc: 0.5129, Val Acc: 0.5216
# Epoch 5, Train Loss: 2.0731, Train Acc: 0.5174, Val Acc: 0.5056
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 23.8666, Train Acc: 0.5021, Val Acc: 0.5000
# Epoch 2, Train Loss: 13.6774, Train Acc: 0.5020, Val Acc: 0.4991
# Epoch 3, Train Loss: 13.0431, Train Acc: 0.5016, Val Acc: 0.5019
# Epoch 4, Train Loss: 12.8169, Train Acc: 0.4981, Val Acc: 0.5000
# Epoch 5, Train Loss: 12.6906, Train Acc: 0.4978, Val Acc: 0.5000
# Epoch 6, Train Loss: 12.3865, Train Acc: 0.5053, Val Acc: 0.4981
# Early stopping
# Best Validation Accuracy: 0.8114446529080676
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 16, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_OOV_update['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_OOV_update = MaxPoolingRNNModelUpdate(embedding_matrix_cosine_sim, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_OOV_update['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
elif best_hyperparams_OOV_update['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
elif best_hyperparams_OOV_update['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])

best_model_OOV_update, train_losses, train_accuracies, val_accuracies = train_model(best_model_OOV_update, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5404, Train Acc: 0.7223, Val Acc: 0.7336
# Epoch 2, Train Loss: 0.3867, Train Acc: 0.8216, Val Acc: 0.7805
# Epoch 3, Train Loss: 0.3002, Train Acc: 0.8715, Val Acc: 0.8011
# Epoch 4, Train Loss: 0.2317, Train Acc: 0.9056, Val Acc: 0.7786
# Epoch 5, Train Loss: 0.1737, Train Acc: 0.9325, Val Acc: 0.7739
# Epoch 6, Train Loss: 0.1307, Train Acc: 0.9489, Val Acc: 0.7833
# Early stopping

# %%
epochs_w = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_w, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_OOV_update, test_loader)
test_accuracies['RNN (Handle OOV with Word Embeddings Update)'] = test_acc
print(f'Test Accuracy (Handle OOV with Word Embeddings Update): {test_acc:.4f}')
# Out:
# Test Accuracy (Handle OOV with Word Embeddings Update): 0.8058

# %% [markdown]
# ### (c) Report the accuracy scores of biLSTM and biGRU on the test set (Part 3.3).

# %%
# Define BiLSTM and BiGRU models
class BiLSTMModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(BiLSTMModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, bidirectional=True).to(device)
        self.fc = nn.Linear(hidden_dim * 2, output_dim).to(device)  # Multiplied by 2 for bidirection
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        lstm_output, _ = self.lstm(embedded)  # Shape: [batch_size, seq_len, hidden_dim * 2]
        # Apply max pooling over the output of the LSTM
        max_pooled, _ = torch.max(lstm_output, dim=1)  # Shape: [batch_size, hidden_dim * 2]
        output = self.fc(max_pooled)
        return output

class BiGRUModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(BiGRUModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True, bidirectional=True).to(device)
        self.fc = nn.Linear(hidden_dim * 2, output_dim).to(device)  # Multiplied by 2 for bidirection
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        gru_output, _ = self.gru(embedded)  # Shape: [batch_size, seq_len, hidden_dim * 2]
        # Apply max pooling over the output of the GRU
        max_pooled, _ = torch.max(gru_output, dim=1)  # Shape: [batch_size, hidden_dim * 2]
        output = self.fc(max_pooled)
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) biLSTM

# %%
# Call grid search
best_hyperparams_biLSTM = run_grid_search(BiLSTMModel, embedding_matrix_cosine_sim, hidden_dim, output_dim, train_sequences, train_labels,
                                          validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6925, Train Acc: 0.5159, Val Acc: 0.5638
# Epoch 2, Train Loss: 0.6913, Train Acc: 0.5476, Val Acc: 0.5460
# Epoch 3, Train Loss: 0.6905, Train Acc: 0.5529, Val Acc: 0.6144
# Epoch 4, Train Loss: 0.6899, Train Acc: 0.5819, Val Acc: 0.6201
# Epoch 5, Train Loss: 0.6889, Train Acc: 0.5828, Val Acc: 0.6135
# Epoch 6, Train Loss: 0.6882, Train Acc: 0.5989, Val Acc: 0.6473
# Epoch 7, Train Loss: 0.6874, Train Acc: 0.6130, Val Acc: 0.6557
# Epoch 8, Train Loss: 0.6869, Train Acc: 0.6209, Val Acc: 0.6341
# Epoch 9, Train Loss: 0.6859, Train Acc: 0.6297, Val Acc: 0.6811
# Epoch 10, Train Loss: 0.6848, Train Acc: 0.6457, Val Acc: 0.6745
# Epoch 11, Train Loss: 0.6844, Train Acc: 0.6380, Val Acc: 0.6735
# Epoch 12, Train Loss: 0.6835, Train Acc: 0.6505, Val Acc: 0.6886
# Epoch 13, Train Loss: 0.6823, Train Acc: 0.6521, Val Acc: 0.6801
# Epoch 14, Train Loss: 0.6817, Train Acc: 0.6522, Val Acc: 0.7017
# Epoch 15, Train Loss: 0.6806, Train Acc: 0.6689, Val Acc: 0.7083
# Epoch 16, Train Loss: 0.6797, Train Acc: 0.6798, Val Acc: 0.6979
# Epoch 17, Train Loss: 0.6785, Train Acc: 0.6603, Val Acc: 0.6970
# Epoch 18, Train Loss: 0.6779, Train Acc: 0.6683, Val Acc: 0.7120
# Epoch 19, Train Loss: 0.6763, Train Acc: 0.6825, Val Acc: 0.7064
# Epoch 20, Train Loss: 0.6754, Train Acc: 0.6821, Val Acc: 0.6970
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.4921, Train Acc: 0.7540, Val Acc: 0.7974
# Epoch 2, Train Loss: 0.3040, Train Acc: 0.8717, Val Acc: 0.8068
# Epoch 3, Train Loss: 0.1605, Train Acc: 0.9408, Val Acc: 0.8049
# Epoch 4, Train Loss: 0.0732, Train Acc: 0.9741, Val Acc: 0.7899
# Epoch 5, Train Loss: 0.0360, Train Acc: 0.9893, Val Acc: 0.7880
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.4769, Train Acc: 0.7666, Val Acc: 0.6614
# Epoch 2, Train Loss: 0.3168, Train Acc: 0.8613, Val Acc: 0.7805
# Epoch 3, Train Loss: 0.2077, Train Acc: 0.9155, Val Acc: 0.8086
# Epoch 4, Train Loss: 0.1216, Train Acc: 0.9560, Val Acc: 0.7917
# Epoch 5, Train Loss: 0.0730, Train Acc: 0.9742, Val Acc: 0.7852
# Epoch 6, Train Loss: 0.0400, Train Acc: 0.9855, Val Acc: 0.7908
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6929, Train Acc: 0.5118, Val Acc: 0.4972
# Epoch 2, Train Loss: 0.6927, Train Acc: 0.5089, Val Acc: 0.5263
# Epoch 3, Train Loss: 0.6922, Train Acc: 0.5209, Val Acc: 0.5394
# Epoch 4, Train Loss: 0.6919, Train Acc: 0.5367, Val Acc: 0.5225
# Epoch 5, Train Loss: 0.6916, Train Acc: 0.5411, Val Acc: 0.5507
# Epoch 6, Train Loss: 0.6913, Train Acc: 0.5539, Val Acc: 0.5450
# Epoch 7, Train Loss: 0.6909, Train Acc: 0.5526, Val Acc: 0.5666
# Epoch 8, Train Loss: 0.6907, Train Acc: 0.5685, Val Acc: 0.5638
# Epoch 9, Train Loss: 0.6904, Train Acc: 0.5632, Val Acc: 0.5694
# Epoch 10, Train Loss: 0.6901, Train Acc: 0.5758, Val Acc: 0.5769
# Epoch 11, Train Loss: 0.6900, Train Acc: 0.5790, Val Acc: 0.5685
# Epoch 12, Train Loss: 0.6893, Train Acc: 0.5807, Val Acc: 0.5947
# Epoch 13, Train Loss: 0.6889, Train Acc: 0.5917, Val Acc: 0.5919
# Epoch 14, Train Loss: 0.6887, Train Acc: 0.6082, Val Acc: 0.5957
# Epoch 15, Train Loss: 0.6883, Train Acc: 0.6123, Val Acc: 0.5994
# Epoch 16, Train Loss: 0.6881, Train Acc: 0.6118, Val Acc: 0.6023
# Epoch 17, Train Loss: 0.6877, Train Acc: 0.6212, Val Acc: 0.6154
# Epoch 18, Train Loss: 0.6875, Train Acc: 0.6158, Val Acc: 0.6135
# Epoch 19, Train Loss: 0.6870, Train Acc: 0.6306, Val Acc: 0.6107
# Epoch 20, Train Loss: 0.6866, Train Acc: 0.6299, Val Acc: 0.6248
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5113, Train Acc: 0.7347, Val Acc: 0.7786
# Epoch 2, Train Loss: 0.3406, Train Acc: 0.8490, Val Acc: 0.8058
# Epoch 3, Train Loss: 0.2075, Train Acc: 0.9182, Val Acc: 0.7917
# Epoch 4, Train Loss: 0.1037, Train Acc: 0.9608, Val Acc: 0.7917
# Epoch 5, Train Loss: 0.0569, Train Acc: 0.9814, Val Acc: 0.7842
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.4984, Train Acc: 0.7485, Val Acc: 0.7917
# Epoch 2, Train Loss: 0.3283, Train Acc: 0.8570, Val Acc: 0.8124
# Epoch 3, Train Loss: 0.2236, Train Acc: 0.9084, Val Acc: 0.8039
# Epoch 4, Train Loss: 0.1420, Train Acc: 0.9453, Val Acc: 0.8021
# Epoch 5, Train Loss: 0.0873, Train Acc: 0.9678, Val Acc: 0.8049
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6941, Train Acc: 0.4999, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6934, Train Acc: 0.4965, Val Acc: 0.5113
# Epoch 3, Train Loss: 0.6934, Train Acc: 0.4991, Val Acc: 0.4962
# Epoch 4, Train Loss: 0.6930, Train Acc: 0.5132, Val Acc: 0.5028
# Epoch 5, Train Loss: 0.6929, Train Acc: 0.5096, Val Acc: 0.5103
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5241, Train Acc: 0.7263, Val Acc: 0.7824
# Epoch 2, Train Loss: 0.3688, Train Acc: 0.8290, Val Acc: 0.7964
# Epoch 3, Train Loss: 0.2507, Train Acc: 0.8959, Val Acc: 0.7880
# Epoch 4, Train Loss: 0.1565, Train Acc: 0.9399, Val Acc: 0.7861
# Epoch 5, Train Loss: 0.0885, Train Acc: 0.9673, Val Acc: 0.7852
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5166, Train Acc: 0.7402, Val Acc: 0.7946
# Epoch 2, Train Loss: 0.3380, Train Acc: 0.8549, Val Acc: 0.7964
# Epoch 3, Train Loss: 0.2396, Train Acc: 0.9032, Val Acc: 0.7674
# Epoch 4, Train Loss: 0.1635, Train Acc: 0.9362, Val Acc: 0.7964
# Epoch 5, Train Loss: 0.1074, Train Acc: 0.9589, Val Acc: 0.7946
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6909, Train Acc: 0.5359, Val Acc: 0.5244
# Epoch 2, Train Loss: 0.6870, Train Acc: 0.5750, Val Acc: 0.5094
# Epoch 3, Train Loss: 0.6830, Train Acc: 0.6086, Val Acc: 0.6154
# Epoch 4, Train Loss: 0.6777, Train Acc: 0.6443, Val Acc: 0.6051
# Epoch 5, Train Loss: 0.6726, Train Acc: 0.6601, Val Acc: 0.6970
# Epoch 6, Train Loss: 0.6647, Train Acc: 0.6812, Val Acc: 0.7129
# Epoch 7, Train Loss: 0.6555, Train Acc: 0.6853, Val Acc: 0.7083
# Epoch 8, Train Loss: 0.6451, Train Acc: 0.7117, Val Acc: 0.7242
# Epoch 9, Train Loss: 0.6321, Train Acc: 0.7169, Val Acc: 0.7242
# Epoch 10, Train Loss: 0.6163, Train Acc: 0.7242, Val Acc: 0.7242
# Epoch 11, Train Loss: 0.5988, Train Acc: 0.7292, Val Acc: 0.7280
# Epoch 12, Train Loss: 0.5821, Train Acc: 0.7334, Val Acc: 0.7373
# Epoch 13, Train Loss: 0.5633, Train Acc: 0.7382, Val Acc: 0.7205
# Epoch 14, Train Loss: 0.5481, Train Acc: 0.7447, Val Acc: 0.7411
# Epoch 15, Train Loss: 0.5307, Train Acc: 0.7499, Val Acc: 0.7402
# Epoch 16, Train Loss: 0.5206, Train Acc: 0.7524, Val Acc: 0.7345
# Epoch 17, Train Loss: 0.5082, Train Acc: 0.7532, Val Acc: 0.7505
# Epoch 18, Train Loss: 0.5021, Train Acc: 0.7570, Val Acc: 0.7561
# Epoch 19, Train Loss: 0.4909, Train Acc: 0.7632, Val Acc: 0.7514
# Epoch 20, Train Loss: 0.4852, Train Acc: 0.7653, Val Acc: 0.7608
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.4711, Train Acc: 0.7694, Val Acc: 0.7767
# Epoch 2, Train Loss: 0.2069, Train Acc: 0.9202, Val Acc: 0.7852
# Epoch 3, Train Loss: 0.0567, Train Acc: 0.9792, Val Acc: 0.7739
# Epoch 4, Train Loss: 0.0190, Train Acc: 0.9932, Val Acc: 0.7749
# Epoch 5, Train Loss: 0.0064, Train Acc: 0.9975, Val Acc: 0.7730
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5682, Train Acc: 0.7376, Val Acc: 0.7542
# Epoch 2, Train Loss: 0.2709, Train Acc: 0.8933, Val Acc: 0.7223
# Epoch 3, Train Loss: 0.1224, Train Acc: 0.9539, Val Acc: 0.7927
# Epoch 4, Train Loss: 0.0552, Train Acc: 0.9801, Val Acc: 0.7720
# Epoch 5, Train Loss: 0.0284, Train Acc: 0.9898, Val Acc: 0.7861
# Epoch 6, Train Loss: 0.0081, Train Acc: 0.9972, Val Acc: 0.7655
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6927, Train Acc: 0.5247, Val Acc: 0.5366
# Epoch 2, Train Loss: 0.6907, Train Acc: 0.5430, Val Acc: 0.6041
# Epoch 3, Train Loss: 0.6891, Train Acc: 0.5661, Val Acc: 0.6332
# Epoch 4, Train Loss: 0.6876, Train Acc: 0.5950, Val Acc: 0.6379
# Epoch 5, Train Loss: 0.6859, Train Acc: 0.6168, Val Acc: 0.6679
# Epoch 6, Train Loss: 0.6840, Train Acc: 0.6376, Val Acc: 0.6689
# Epoch 7, Train Loss: 0.6817, Train Acc: 0.6354, Val Acc: 0.6867
# Epoch 8, Train Loss: 0.6799, Train Acc: 0.6518, Val Acc: 0.6942
# Epoch 9, Train Loss: 0.6772, Train Acc: 0.6600, Val Acc: 0.6895
# Epoch 10, Train Loss: 0.6746, Train Acc: 0.6741, Val Acc: 0.7036
# Epoch 11, Train Loss: 0.6713, Train Acc: 0.6749, Val Acc: 0.6989
# Epoch 12, Train Loss: 0.6685, Train Acc: 0.6828, Val Acc: 0.7026
# Epoch 13, Train Loss: 0.6640, Train Acc: 0.6984, Val Acc: 0.7120
# Epoch 14, Train Loss: 0.6596, Train Acc: 0.6992, Val Acc: 0.7251
# Epoch 15, Train Loss: 0.6548, Train Acc: 0.7060, Val Acc: 0.7251
# Epoch 16, Train Loss: 0.6487, Train Acc: 0.7095, Val Acc: 0.7214
# Epoch 17, Train Loss: 0.6430, Train Acc: 0.7103, Val Acc: 0.7336
# Epoch 18, Train Loss: 0.6355, Train Acc: 0.7226, Val Acc: 0.7326
# Epoch 19, Train Loss: 0.6279, Train Acc: 0.7256, Val Acc: 0.7373
# Epoch 20, Train Loss: 0.6202, Train Acc: 0.7232, Val Acc: 0.7251
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.4851, Train Acc: 0.7587, Val Acc: 0.8030
# Epoch 2, Train Loss: 0.2176, Train Acc: 0.9106, Val Acc: 0.7683
# Epoch 3, Train Loss: 0.0599, Train Acc: 0.9785, Val Acc: 0.7674
# Epoch 4, Train Loss: 0.0147, Train Acc: 0.9950, Val Acc: 0.7561
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6386, Train Acc: 0.6975, Val Acc: 0.7636
# Epoch 2, Train Loss: 0.2826, Train Acc: 0.8836, Val Acc: 0.7767
# Epoch 3, Train Loss: 0.1254, Train Acc: 0.9505, Val Acc: 0.7758
# Epoch 4, Train Loss: 0.0458, Train Acc: 0.9836, Val Acc: 0.7617
# Epoch 5, Train Loss: 0.0210, Train Acc: 0.9918, Val Acc: 0.7617
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6945, Train Acc: 0.5004, Val Acc: 0.5159
# Epoch 2, Train Loss: 0.6927, Train Acc: 0.5166, Val Acc: 0.5159
# Epoch 3, Train Loss: 0.6922, Train Acc: 0.5249, Val Acc: 0.5675
# Epoch 4, Train Loss: 0.6909, Train Acc: 0.5542, Val Acc: 0.6135
# Epoch 5, Train Loss: 0.6897, Train Acc: 0.5856, Val Acc: 0.6341
# Epoch 6, Train Loss: 0.6891, Train Acc: 0.5807, Val Acc: 0.5938
# Epoch 7, Train Loss: 0.6881, Train Acc: 0.6068, Val Acc: 0.6529
# Epoch 8, Train Loss: 0.6871, Train Acc: 0.6172, Val Acc: 0.6689
# Epoch 9, Train Loss: 0.6863, Train Acc: 0.6346, Val Acc: 0.6829
# Epoch 10, Train Loss: 0.6851, Train Acc: 0.6375, Val Acc: 0.6220
# Epoch 11, Train Loss: 0.6842, Train Acc: 0.6570, Val Acc: 0.6867
# Epoch 12, Train Loss: 0.6828, Train Acc: 0.6658, Val Acc: 0.6876
# Epoch 13, Train Loss: 0.6818, Train Acc: 0.6769, Val Acc: 0.6979
# Epoch 14, Train Loss: 0.6808, Train Acc: 0.6729, Val Acc: 0.6998
# Epoch 15, Train Loss: 0.6795, Train Acc: 0.6882, Val Acc: 0.7064
# Epoch 16, Train Loss: 0.6782, Train Acc: 0.6902, Val Acc: 0.7083
# Epoch 17, Train Loss: 0.6765, Train Acc: 0.6977, Val Acc: 0.7129
# Epoch 18, Train Loss: 0.6750, Train Acc: 0.6885, Val Acc: 0.7148
# Epoch 19, Train Loss: 0.6737, Train Acc: 0.6937, Val Acc: 0.6698
# Epoch 20, Train Loss: 0.6718, Train Acc: 0.7094, Val Acc: 0.7214
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5034, Train Acc: 0.7441, Val Acc: 0.7899
# Epoch 2, Train Loss: 0.2320, Train Acc: 0.9055, Val Acc: 0.7871
# Epoch 3, Train Loss: 0.0703, Train Acc: 0.9766, Val Acc: 0.7758
# Epoch 4, Train Loss: 0.0214, Train Acc: 0.9937, Val Acc: 0.7683
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6960, Train Acc: 0.6952, Val Acc: 0.7505
# Epoch 2, Train Loss: 0.2829, Train Acc: 0.8817, Val Acc: 0.7814
# Epoch 3, Train Loss: 0.1279, Train Acc: 0.9521, Val Acc: 0.7730
# Epoch 4, Train Loss: 0.0470, Train Acc: 0.9843, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.0180, Train Acc: 0.9946, Val Acc: 0.7683
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6919, Train Acc: 0.5188, Val Acc: 0.5797
# Epoch 2, Train Loss: 0.6845, Train Acc: 0.5954, Val Acc: 0.5159
# Epoch 3, Train Loss: 0.6741, Train Acc: 0.6403, Val Acc: 0.6257
# Epoch 4, Train Loss: 0.6592, Train Acc: 0.6800, Val Acc: 0.6576
# Epoch 5, Train Loss: 0.6372, Train Acc: 0.7086, Val Acc: 0.7251
# Epoch 6, Train Loss: 0.6066, Train Acc: 0.7196, Val Acc: 0.7317
# Epoch 7, Train Loss: 0.5712, Train Acc: 0.7331, Val Acc: 0.7345
# Epoch 8, Train Loss: 0.5382, Train Acc: 0.7419, Val Acc: 0.7270
# Epoch 9, Train Loss: 0.5167, Train Acc: 0.7496, Val Acc: 0.7458
# Epoch 10, Train Loss: 0.5018, Train Acc: 0.7536, Val Acc: 0.7467
# Epoch 11, Train Loss: 0.4900, Train Acc: 0.7601, Val Acc: 0.7570
# Epoch 12, Train Loss: 0.4784, Train Acc: 0.7669, Val Acc: 0.7636
# Epoch 13, Train Loss: 0.4725, Train Acc: 0.7733, Val Acc: 0.7730
# Epoch 14, Train Loss: 0.4647, Train Acc: 0.7785, Val Acc: 0.7617
# Epoch 15, Train Loss: 0.4655, Train Acc: 0.7773, Val Acc: 0.7580
# Epoch 16, Train Loss: 0.4580, Train Acc: 0.7818, Val Acc: 0.7711
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5181, Train Acc: 0.7433, Val Acc: 0.7580
# Epoch 2, Train Loss: 0.2345, Train Acc: 0.9060, Val Acc: 0.7711
# Epoch 3, Train Loss: 0.1041, Train Acc: 0.9630, Val Acc: 0.7477
# Epoch 4, Train Loss: 0.0645, Train Acc: 0.9770, Val Acc: 0.7580
# Epoch 5, Train Loss: 0.0409, Train Acc: 0.9871, Val Acc: 0.7552
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9461, Train Acc: 0.6458, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.3857, Train Acc: 0.8464, Val Acc: 0.7814
# Epoch 3, Train Loss: 0.2202, Train Acc: 0.9205, Val Acc: 0.7767
# Epoch 4, Train Loss: 0.1296, Train Acc: 0.9580, Val Acc: 0.7627
# Epoch 5, Train Loss: 0.0812, Train Acc: 0.9761, Val Acc: 0.5788
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6923, Train Acc: 0.5147, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6889, Train Acc: 0.5555, Val Acc: 0.6538
# Epoch 3, Train Loss: 0.6850, Train Acc: 0.5866, Val Acc: 0.6848
# Epoch 4, Train Loss: 0.6805, Train Acc: 0.6216, Val Acc: 0.5657
# Epoch 5, Train Loss: 0.6750, Train Acc: 0.6436, Val Acc: 0.6904
# Epoch 6, Train Loss: 0.6685, Train Acc: 0.6764, Val Acc: 0.6904
# Epoch 7, Train Loss: 0.6604, Train Acc: 0.6869, Val Acc: 0.6904
# Epoch 8, Train Loss: 0.6518, Train Acc: 0.7027, Val Acc: 0.6979
# Epoch 9, Train Loss: 0.6383, Train Acc: 0.7076, Val Acc: 0.7289
# Epoch 10, Train Loss: 0.6253, Train Acc: 0.7216, Val Acc: 0.7073
# Epoch 11, Train Loss: 0.6085, Train Acc: 0.7252, Val Acc: 0.7261
# Epoch 12, Train Loss: 0.5902, Train Acc: 0.7362, Val Acc: 0.7242
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.4950, Train Acc: 0.7578, Val Acc: 0.7955
# Epoch 2, Train Loss: 0.2128, Train Acc: 0.9156, Val Acc: 0.7720
# Epoch 3, Train Loss: 0.0693, Train Acc: 0.9761, Val Acc: 0.7711
# Epoch 4, Train Loss: 0.0235, Train Acc: 0.9926, Val Acc: 0.7683
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0217, Train Acc: 0.6361, Val Acc: 0.7486
# Epoch 2, Train Loss: 0.3709, Train Acc: 0.8515, Val Acc: 0.7580
# Epoch 3, Train Loss: 0.1920, Train Acc: 0.9274, Val Acc: 0.7308
# Epoch 4, Train Loss: 0.0993, Train Acc: 0.9645, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.0575, Train Acc: 0.9803, Val Acc: 0.7702
# Epoch 6, Train Loss: 0.0365, Train Acc: 0.9872, Val Acc: 0.7683
# Epoch 7, Train Loss: 0.0333, Train Acc: 0.9909, Val Acc: 0.7505
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6928, Train Acc: 0.5052, Val Acc: 0.5488
# Epoch 2, Train Loss: 0.6911, Train Acc: 0.5401, Val Acc: 0.5816
# Epoch 3, Train Loss: 0.6895, Train Acc: 0.5652, Val Acc: 0.5488
# Epoch 4, Train Loss: 0.6877, Train Acc: 0.5778, Val Acc: 0.5610
# Epoch 5, Train Loss: 0.6859, Train Acc: 0.6000, Val Acc: 0.5947
# Epoch 6, Train Loss: 0.6840, Train Acc: 0.6283, Val Acc: 0.6295
# Epoch 7, Train Loss: 0.6818, Train Acc: 0.6157, Val Acc: 0.6642
# Epoch 8, Train Loss: 0.6797, Train Acc: 0.6370, Val Acc: 0.5947
# Epoch 9, Train Loss: 0.6772, Train Acc: 0.6487, Val Acc: 0.6660
# Epoch 10, Train Loss: 0.6744, Train Acc: 0.6542, Val Acc: 0.6782
# Epoch 11, Train Loss: 0.6716, Train Acc: 0.6763, Val Acc: 0.6895
# Epoch 12, Train Loss: 0.6686, Train Acc: 0.6795, Val Acc: 0.6811
# Epoch 13, Train Loss: 0.6642, Train Acc: 0.6875, Val Acc: 0.6820
# Epoch 14, Train Loss: 0.6606, Train Acc: 0.6899, Val Acc: 0.6642
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5232, Train Acc: 0.7455, Val Acc: 0.8002
# Epoch 2, Train Loss: 0.2120, Train Acc: 0.9138, Val Acc: 0.7880
# Epoch 3, Train Loss: 0.0594, Train Acc: 0.9781, Val Acc: 0.7786
# Epoch 4, Train Loss: 0.0182, Train Acc: 0.9939, Val Acc: 0.7702
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.2860, Train Acc: 0.5762, Val Acc: 0.7336
# Epoch 2, Train Loss: 0.4163, Train Acc: 0.8159, Val Acc: 0.7373
# Epoch 3, Train Loss: 0.1989, Train Acc: 0.9212, Val Acc: 0.7580
# Epoch 4, Train Loss: 0.0960, Train Acc: 0.9621, Val Acc: 0.7486
# Epoch 5, Train Loss: 0.0411, Train Acc: 0.9853, Val Acc: 0.7552
# Epoch 6, Train Loss: 0.0195, Train Acc: 0.9938, Val Acc: 0.7270
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6222, Train Acc: 0.6392, Val Acc: 0.7477
# Epoch 2, Train Loss: 0.4999, Train Acc: 0.7503, Val Acc: 0.6801
# Epoch 3, Train Loss: 0.4696, Train Acc: 0.7674, Val Acc: 0.7814
# Epoch 4, Train Loss: 0.4419, Train Acc: 0.7937, Val Acc: 0.7580
# Epoch 5, Train Loss: 0.4217, Train Acc: 0.8022, Val Acc: 0.7223
# Epoch 6, Train Loss: 0.4025, Train Acc: 0.8136, Val Acc: 0.7908
# Epoch 7, Train Loss: 0.3890, Train Acc: 0.8162, Val Acc: 0.6548
# Epoch 8, Train Loss: 0.3642, Train Acc: 0.8375, Val Acc: 0.7861
# Epoch 9, Train Loss: 0.3467, Train Acc: 0.8495, Val Acc: 0.7580
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 3.9747, Train Acc: 0.5263, Val Acc: 0.5197
# Epoch 2, Train Loss: 3.5390, Train Acc: 0.5220, Val Acc: 0.5188
# Epoch 3, Train Loss: 3.3042, Train Acc: 0.5338, Val Acc: 0.5750
# Epoch 4, Train Loss: 3.3879, Train Acc: 0.5379, Val Acc: 0.5038
# Epoch 5, Train Loss: 3.0596, Train Acc: 0.5509, Val Acc: 0.5460
# Epoch 6, Train Loss: 2.7222, Train Acc: 0.5525, Val Acc: 0.5750
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 24.2285, Train Acc: 0.5068, Val Acc: 0.5000
# Epoch 2, Train Loss: 19.6497, Train Acc: 0.5093, Val Acc: 0.5000
# Epoch 3, Train Loss: 18.9574, Train Acc: 0.5189, Val Acc: 0.5009
# Epoch 4, Train Loss: 19.0613, Train Acc: 0.5091, Val Acc: 0.5009
# Epoch 5, Train Loss: 18.6006, Train Acc: 0.5189, Val Acc: 0.5038
# Epoch 6, Train Loss: 17.8972, Train Acc: 0.5189, Val Acc: 0.5638
# Epoch 7, Train Loss: 17.5464, Train Acc: 0.5370, Val Acc: 0.5385
# Epoch 8, Train Loss: 16.7152, Train Acc: 0.5454, Val Acc: 0.5075
# Epoch 9, Train Loss: 16.4262, Train Acc: 0.5469, Val Acc: 0.5535
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6718, Train Acc: 0.5830, Val Acc: 0.5994
# Epoch 2, Train Loss: 0.5595, Train Acc: 0.7131, Val Acc: 0.6670
# Epoch 3, Train Loss: 0.5009, Train Acc: 0.7517, Val Acc: 0.7326
# Epoch 4, Train Loss: 0.4745, Train Acc: 0.7687, Val Acc: 0.7158
# Epoch 5, Train Loss: 0.4579, Train Acc: 0.7796, Val Acc: 0.7777
# Epoch 6, Train Loss: 0.4448, Train Acc: 0.7885, Val Acc: 0.7674
# Epoch 7, Train Loss: 0.4319, Train Acc: 0.7960, Val Acc: 0.7946
# Epoch 8, Train Loss: 0.4172, Train Acc: 0.8109, Val Acc: 0.7814
# Epoch 9, Train Loss: 0.4078, Train Acc: 0.8125, Val Acc: 0.7946
# Epoch 10, Train Loss: 0.3968, Train Acc: 0.8124, Val Acc: 0.8021
# Epoch 11, Train Loss: 0.3855, Train Acc: 0.8223, Val Acc: 0.8114
# Epoch 12, Train Loss: 0.3730, Train Acc: 0.8304, Val Acc: 0.8077
# Epoch 13, Train Loss: 0.3601, Train Acc: 0.8383, Val Acc: 0.7786
# Epoch 14, Train Loss: 0.3501, Train Acc: 0.8428, Val Acc: 0.7120
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 2.1918, Train Acc: 0.5320, Val Acc: 0.5422
# Epoch 2, Train Loss: 3.3204, Train Acc: 0.5516, Val Acc: 0.5919
# Epoch 3, Train Loss: 2.2432, Train Acc: 0.5640, Val Acc: 0.5844
# Epoch 4, Train Loss: 3.0878, Train Acc: 0.5789, Val Acc: 0.5366
# Epoch 5, Train Loss: 1.9740, Train Acc: 0.5993, Val Acc: 0.5103
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 28.8740, Train Acc: 0.5066, Val Acc: 0.5000
# Epoch 2, Train Loss: 20.2579, Train Acc: 0.5035, Val Acc: 0.5084
# Epoch 3, Train Loss: 19.8350, Train Acc: 0.5050, Val Acc: 0.5000
# Epoch 4, Train Loss: 19.2702, Train Acc: 0.5096, Val Acc: 0.5310
# Epoch 5, Train Loss: 19.4184, Train Acc: 0.5052, Val Acc: 0.5047
# Epoch 6, Train Loss: 18.5378, Train Acc: 0.5176, Val Acc: 0.5066
# Epoch 7, Train Loss: 18.8216, Train Acc: 0.5049, Val Acc: 0.5141
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6850, Train Acc: 0.5599, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6485, Train Acc: 0.6552, Val Acc: 0.6463
# Epoch 3, Train Loss: 0.5729, Train Acc: 0.7128, Val Acc: 0.7326
# Epoch 4, Train Loss: 0.5156, Train Acc: 0.7453, Val Acc: 0.7364
# Epoch 5, Train Loss: 0.4938, Train Acc: 0.7539, Val Acc: 0.7026
# Epoch 6, Train Loss: 0.4820, Train Acc: 0.7662, Val Acc: 0.7552
# Epoch 7, Train Loss: 0.4707, Train Acc: 0.7693, Val Acc: 0.7176
# Epoch 8, Train Loss: 0.4618, Train Acc: 0.7778, Val Acc: 0.7664
# Epoch 9, Train Loss: 0.4458, Train Acc: 0.7923, Val Acc: 0.7786
# Epoch 10, Train Loss: 0.4437, Train Acc: 0.7873, Val Acc: 0.7730
# Epoch 11, Train Loss: 0.4376, Train Acc: 0.7959, Val Acc: 0.6557
# Epoch 12, Train Loss: 0.4251, Train Acc: 0.8035, Val Acc: 0.7880
# Epoch 13, Train Loss: 0.4162, Train Acc: 0.8077, Val Acc: 0.7214
# Epoch 14, Train Loss: 0.4158, Train Acc: 0.8053, Val Acc: 0.7833
# Epoch 15, Train Loss: 0.4048, Train Acc: 0.8110, Val Acc: 0.7786
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 1.9205, Train Acc: 0.5513, Val Acc: 0.5422
# Epoch 2, Train Loss: 1.7111, Train Acc: 0.6258, Val Acc: 0.5938
# Epoch 3, Train Loss: 1.8814, Train Acc: 0.6365, Val Acc: 0.5938
# Epoch 4, Train Loss: 1.4261, Train Acc: 0.6743, Val Acc: 0.6473
# Epoch 5, Train Loss: 1.3648, Train Acc: 0.6686, Val Acc: 0.6238
# Epoch 6, Train Loss: 1.1857, Train Acc: 0.6834, Val Acc: 0.6295
# Epoch 7, Train Loss: 1.1520, Train Acc: 0.6985, Val Acc: 0.5750
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 19.8018, Train Acc: 0.5073, Val Acc: 0.5113
# Epoch 2, Train Loss: 9.5163, Train Acc: 0.5334, Val Acc: 0.5629
# Epoch 3, Train Loss: 8.6602, Train Acc: 0.5563, Val Acc: 0.5319
# Epoch 4, Train Loss: 8.6010, Train Acc: 0.5769, Val Acc: 0.5872
# Epoch 5, Train Loss: 8.2171, Train Acc: 0.6122, Val Acc: 0.6248
# Epoch 6, Train Loss: 8.5528, Train Acc: 0.6259, Val Acc: 0.6576
# Epoch 7, Train Loss: 8.5086, Train Acc: 0.6448, Val Acc: 0.5553
# Epoch 8, Train Loss: 8.6042, Train Acc: 0.6614, Val Acc: 0.6238
# Epoch 9, Train Loss: 8.6872, Train Acc: 0.6598, Val Acc: 0.5582
# Early stopping
# Best Validation Accuracy: 0.8123827392120075
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_biLSTM['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_biLSTM = BiLSTMModel(embedding_matrix_cosine_sim, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_biLSTM['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
elif best_hyperparams_biLSTM['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
elif best_hyperparams_biLSTM['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])

best_model_biLSTM, train_losses, train_accuracies, val_accuracies = train_model(best_model_biLSTM, train_loader, validation_loader,
                                                                                best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.4997, Train Acc: 0.7522, Val Acc: 0.7927
# Epoch 2, Train Loss: 0.3263, Train Acc: 0.8598, Val Acc: 0.7992
# Epoch 3, Train Loss: 0.2146, Train Acc: 0.9156, Val Acc: 0.7992
# Epoch 4, Train Loss: 0.1410, Train Acc: 0.9474, Val Acc: 0.7992
# Epoch 5, Train Loss: 0.0831, Train Acc: 0.9695, Val Acc: 0.7955
# Early stopping

# %%
epochs_bi = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_bi, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_biLSTM, test_loader)
test_accuracies['biLSTM'] = test_acc
print(f'Test Accuracy (biLSTM): {test_acc:.4f}')
# Out:
# Test Accuracy (biLSTM): 0.8039

# %% [markdown]
# ### 2) biGRU

# %%
# Call grid search
best_hyperparams_biGRU = run_grid_search(BiGRUModel, embedding_matrix_cosine_sim, hidden_dim, output_dim, train_sequences, train_labels,
                                         validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6941, Train Acc: 0.5036, Val Acc: 0.5197
# Epoch 2, Train Loss: 0.6914, Train Acc: 0.5253, Val Acc: 0.5553
# Epoch 3, Train Loss: 0.6894, Train Acc: 0.5501, Val Acc: 0.5460
# Epoch 4, Train Loss: 0.6867, Train Acc: 0.5736, Val Acc: 0.5131
# Epoch 5, Train Loss: 0.6841, Train Acc: 0.5921, Val Acc: 0.6351
# Epoch 6, Train Loss: 0.6816, Train Acc: 0.6210, Val Acc: 0.6764
# Epoch 7, Train Loss: 0.6782, Train Acc: 0.6356, Val Acc: 0.6689
# Epoch 8, Train Loss: 0.6753, Train Acc: 0.6474, Val Acc: 0.6473
# Epoch 9, Train Loss: 0.6721, Train Acc: 0.6614, Val Acc: 0.6182
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.4956, Train Acc: 0.7536, Val Acc: 0.7946
# Epoch 2, Train Loss: 0.3080, Train Acc: 0.8646, Val Acc: 0.8058
# Epoch 3, Train Loss: 0.1590, Train Acc: 0.9372, Val Acc: 0.7917
# Epoch 4, Train Loss: 0.0721, Train Acc: 0.9751, Val Acc: 0.7692
# Epoch 5, Train Loss: 0.0393, Train Acc: 0.9857, Val Acc: 0.7720
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.4865, Train Acc: 0.7625, Val Acc: 0.7861
# Epoch 2, Train Loss: 0.3168, Train Acc: 0.8621, Val Acc: 0.8068
# Epoch 3, Train Loss: 0.2060, Train Acc: 0.9170, Val Acc: 0.8021
# Epoch 4, Train Loss: 0.1263, Train Acc: 0.9506, Val Acc: 0.8199
# Epoch 5, Train Loss: 0.0697, Train Acc: 0.9742, Val Acc: 0.7992
# Epoch 6, Train Loss: 0.0401, Train Acc: 0.9859, Val Acc: 0.7955
# Epoch 7, Train Loss: 0.0228, Train Acc: 0.9914, Val Acc: 0.7739
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6954, Train Acc: 0.5094, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6914, Train Acc: 0.5308, Val Acc: 0.5310
# Epoch 3, Train Loss: 0.6900, Train Acc: 0.5449, Val Acc: 0.5826
# Epoch 4, Train Loss: 0.6884, Train Acc: 0.5683, Val Acc: 0.5844
# Epoch 5, Train Loss: 0.6868, Train Acc: 0.5835, Val Acc: 0.5976
# Epoch 6, Train Loss: 0.6858, Train Acc: 0.5920, Val Acc: 0.5741
# Epoch 7, Train Loss: 0.6847, Train Acc: 0.5982, Val Acc: 0.6060
# Epoch 8, Train Loss: 0.6834, Train Acc: 0.5987, Val Acc: 0.6341
# Epoch 9, Train Loss: 0.6817, Train Acc: 0.6164, Val Acc: 0.6567
# Epoch 10, Train Loss: 0.6808, Train Acc: 0.6224, Val Acc: 0.6642
# Epoch 11, Train Loss: 0.6797, Train Acc: 0.6252, Val Acc: 0.6538
# Epoch 12, Train Loss: 0.6776, Train Acc: 0.6362, Val Acc: 0.6707
# Epoch 13, Train Loss: 0.6764, Train Acc: 0.6538, Val Acc: 0.6745
# Epoch 14, Train Loss: 0.6752, Train Acc: 0.6543, Val Acc: 0.6735
# Epoch 15, Train Loss: 0.6736, Train Acc: 0.6662, Val Acc: 0.6792
# Epoch 16, Train Loss: 0.6719, Train Acc: 0.6638, Val Acc: 0.6829
# Epoch 17, Train Loss: 0.6703, Train Acc: 0.6673, Val Acc: 0.6735
# Epoch 18, Train Loss: 0.6691, Train Acc: 0.6655, Val Acc: 0.6867
# Epoch 19, Train Loss: 0.6672, Train Acc: 0.6691, Val Acc: 0.6932
# Epoch 20, Train Loss: 0.6657, Train Acc: 0.6791, Val Acc: 0.6932
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5129, Train Acc: 0.7404, Val Acc: 0.7974
# Epoch 2, Train Loss: 0.3424, Train Acc: 0.8460, Val Acc: 0.7992
# Epoch 3, Train Loss: 0.1986, Train Acc: 0.9209, Val Acc: 0.7917
# Epoch 4, Train Loss: 0.1052, Train Acc: 0.9632, Val Acc: 0.7861
# Epoch 5, Train Loss: 0.0547, Train Acc: 0.9803, Val Acc: 0.7842
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5119, Train Acc: 0.7499, Val Acc: 0.7645
# Epoch 2, Train Loss: 0.3295, Train Acc: 0.8551, Val Acc: 0.8068
# Epoch 3, Train Loss: 0.2214, Train Acc: 0.9088, Val Acc: 0.8086
# Epoch 4, Train Loss: 0.1376, Train Acc: 0.9496, Val Acc: 0.7974
# Epoch 5, Train Loss: 0.0825, Train Acc: 0.9695, Val Acc: 0.7964
# Epoch 6, Train Loss: 0.0482, Train Acc: 0.9819, Val Acc: 0.7777
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6958, Train Acc: 0.4746, Val Acc: 0.4887
# Epoch 2, Train Loss: 0.6949, Train Acc: 0.4795, Val Acc: 0.4962
# Epoch 3, Train Loss: 0.6942, Train Acc: 0.4906, Val Acc: 0.5141
# Epoch 4, Train Loss: 0.6938, Train Acc: 0.4944, Val Acc: 0.5141
# Epoch 5, Train Loss: 0.6933, Train Acc: 0.5011, Val Acc: 0.5385
# Epoch 6, Train Loss: 0.6926, Train Acc: 0.5181, Val Acc: 0.5403
# Epoch 7, Train Loss: 0.6917, Train Acc: 0.5244, Val Acc: 0.5610
# Epoch 8, Train Loss: 0.6908, Train Acc: 0.5351, Val Acc: 0.5675
# Epoch 9, Train Loss: 0.6901, Train Acc: 0.5395, Val Acc: 0.5797
# Epoch 10, Train Loss: 0.6894, Train Acc: 0.5607, Val Acc: 0.5872
# Epoch 11, Train Loss: 0.6889, Train Acc: 0.5632, Val Acc: 0.5910
# Epoch 12, Train Loss: 0.6879, Train Acc: 0.5717, Val Acc: 0.6032
# Epoch 13, Train Loss: 0.6877, Train Acc: 0.5757, Val Acc: 0.6135
# Epoch 14, Train Loss: 0.6868, Train Acc: 0.5877, Val Acc: 0.6191
# Epoch 15, Train Loss: 0.6862, Train Acc: 0.5927, Val Acc: 0.6173
# Epoch 16, Train Loss: 0.6855, Train Acc: 0.5947, Val Acc: 0.6435
# Epoch 17, Train Loss: 0.6851, Train Acc: 0.5987, Val Acc: 0.6492
# Epoch 18, Train Loss: 0.6840, Train Acc: 0.6106, Val Acc: 0.6313
# Epoch 19, Train Loss: 0.6833, Train Acc: 0.6089, Val Acc: 0.6548
# Epoch 20, Train Loss: 0.6826, Train Acc: 0.6223, Val Acc: 0.6642
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5279, Train Acc: 0.7270, Val Acc: 0.7824
# Epoch 2, Train Loss: 0.3687, Train Acc: 0.8347, Val Acc: 0.7739
# Epoch 3, Train Loss: 0.2496, Train Acc: 0.8982, Val Acc: 0.7946
# Epoch 4, Train Loss: 0.1495, Train Acc: 0.9443, Val Acc: 0.7889
# Epoch 5, Train Loss: 0.0843, Train Acc: 0.9702, Val Acc: 0.7917
# Epoch 6, Train Loss: 0.0464, Train Acc: 0.9863, Val Acc: 0.7880
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5342, Train Acc: 0.7416, Val Acc: 0.7880
# Epoch 2, Train Loss: 0.3417, Train Acc: 0.8490, Val Acc: 0.7786
# Epoch 3, Train Loss: 0.2469, Train Acc: 0.8989, Val Acc: 0.7983
# Epoch 4, Train Loss: 0.1644, Train Acc: 0.9362, Val Acc: 0.7936
# Epoch 5, Train Loss: 0.1034, Train Acc: 0.9621, Val Acc: 0.7946
# Epoch 6, Train Loss: 0.0686, Train Acc: 0.9756, Val Acc: 0.7627
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6899, Train Acc: 0.5320, Val Acc: 0.6567
# Epoch 2, Train Loss: 0.6767, Train Acc: 0.6069, Val Acc: 0.6867
# Epoch 3, Train Loss: 0.6588, Train Acc: 0.6479, Val Acc: 0.7111
# Epoch 4, Train Loss: 0.6385, Train Acc: 0.6857, Val Acc: 0.7036
# Epoch 5, Train Loss: 0.6112, Train Acc: 0.7159, Val Acc: 0.7317
# Epoch 6, Train Loss: 0.5827, Train Acc: 0.7266, Val Acc: 0.7430
# Epoch 7, Train Loss: 0.5557, Train Acc: 0.7423, Val Acc: 0.7495
# Epoch 8, Train Loss: 0.5333, Train Acc: 0.7478, Val Acc: 0.7298
# Epoch 9, Train Loss: 0.5156, Train Acc: 0.7537, Val Acc: 0.7486
# Epoch 10, Train Loss: 0.5037, Train Acc: 0.7556, Val Acc: 0.7589
# Epoch 11, Train Loss: 0.4928, Train Acc: 0.7618, Val Acc: 0.7458
# Epoch 12, Train Loss: 0.4825, Train Acc: 0.7651, Val Acc: 0.7655
# Epoch 13, Train Loss: 0.4787, Train Acc: 0.7667, Val Acc: 0.7598
# Epoch 14, Train Loss: 0.4734, Train Acc: 0.7729, Val Acc: 0.7664
# Epoch 15, Train Loss: 0.4677, Train Acc: 0.7775, Val Acc: 0.7674
# Epoch 16, Train Loss: 0.4658, Train Acc: 0.7789, Val Acc: 0.7655
# Epoch 17, Train Loss: 0.4613, Train Acc: 0.7770, Val Acc: 0.7730
# Epoch 18, Train Loss: 0.4577, Train Acc: 0.7824, Val Acc: 0.7749
# Epoch 19, Train Loss: 0.4527, Train Acc: 0.7824, Val Acc: 0.7692
# Epoch 20, Train Loss: 0.4538, Train Acc: 0.7818, Val Acc: 0.7692
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.4980, Train Acc: 0.7549, Val Acc: 0.7805
# Epoch 2, Train Loss: 0.2296, Train Acc: 0.9069, Val Acc: 0.7974
# Epoch 3, Train Loss: 0.0673, Train Acc: 0.9769, Val Acc: 0.7739
# Epoch 4, Train Loss: 0.0219, Train Acc: 0.9925, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.0144, Train Acc: 0.9945, Val Acc: 0.7645
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6664, Train Acc: 0.7035, Val Acc: 0.7120
# Epoch 2, Train Loss: 0.3239, Train Acc: 0.8660, Val Acc: 0.6276
# Epoch 3, Train Loss: 0.1666, Train Acc: 0.9381, Val Acc: 0.5478
# Epoch 4, Train Loss: 0.0779, Train Acc: 0.9729, Val Acc: 0.7580
# Epoch 5, Train Loss: 0.0320, Train Acc: 0.9885, Val Acc: 0.7655
# Epoch 6, Train Loss: 0.0215, Train Acc: 0.9937, Val Acc: 0.7552
# Epoch 7, Train Loss: 0.0135, Train Acc: 0.9962, Val Acc: 0.7486
# Epoch 8, Train Loss: 0.0143, Train Acc: 0.9966, Val Acc: 0.7045
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6915, Train Acc: 0.5283, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6847, Train Acc: 0.5701, Val Acc: 0.5281
# Epoch 3, Train Loss: 0.6783, Train Acc: 0.6174, Val Acc: 0.6689
# Epoch 4, Train Loss: 0.6710, Train Acc: 0.6448, Val Acc: 0.6848
# Epoch 5, Train Loss: 0.6613, Train Acc: 0.6625, Val Acc: 0.7036
# Epoch 6, Train Loss: 0.6522, Train Acc: 0.6771, Val Acc: 0.6660
# Epoch 7, Train Loss: 0.6415, Train Acc: 0.6906, Val Acc: 0.7064
# Epoch 8, Train Loss: 0.6286, Train Acc: 0.7082, Val Acc: 0.7101
# Epoch 9, Train Loss: 0.6155, Train Acc: 0.7136, Val Acc: 0.7317
# Epoch 10, Train Loss: 0.6005, Train Acc: 0.7208, Val Acc: 0.7439
# Epoch 11, Train Loss: 0.5845, Train Acc: 0.7278, Val Acc: 0.7467
# Epoch 12, Train Loss: 0.5705, Train Acc: 0.7360, Val Acc: 0.7467
# Epoch 13, Train Loss: 0.5564, Train Acc: 0.7444, Val Acc: 0.7280
# Epoch 14, Train Loss: 0.5441, Train Acc: 0.7426, Val Acc: 0.7505
# Epoch 15, Train Loss: 0.5328, Train Acc: 0.7492, Val Acc: 0.7467
# Epoch 16, Train Loss: 0.5214, Train Acc: 0.7498, Val Acc: 0.7523
# Epoch 17, Train Loss: 0.5136, Train Acc: 0.7549, Val Acc: 0.7505
# Epoch 18, Train Loss: 0.5070, Train Acc: 0.7540, Val Acc: 0.7514
# Epoch 19, Train Loss: 0.5003, Train Acc: 0.7587, Val Acc: 0.7533
# Epoch 20, Train Loss: 0.4982, Train Acc: 0.7618, Val Acc: 0.7570
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.4922, Train Acc: 0.7563, Val Acc: 0.7964
# Epoch 2, Train Loss: 0.2243, Train Acc: 0.9122, Val Acc: 0.7955
# Epoch 3, Train Loss: 0.0584, Train Acc: 0.9804, Val Acc: 0.7824
# Epoch 4, Train Loss: 0.0221, Train Acc: 0.9924, Val Acc: 0.7908
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7226, Train Acc: 0.6945, Val Acc: 0.7439
# Epoch 2, Train Loss: 0.3026, Train Acc: 0.8734, Val Acc: 0.7739
# Epoch 3, Train Loss: 0.1320, Train Acc: 0.9506, Val Acc: 0.7655
# Epoch 4, Train Loss: 0.0525, Train Acc: 0.9808, Val Acc: 0.7533
# Epoch 5, Train Loss: 0.0343, Train Acc: 0.9906, Val Acc: 0.7627
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6922, Train Acc: 0.5176, Val Acc: 0.5178
# Epoch 2, Train Loss: 0.6896, Train Acc: 0.5431, Val Acc: 0.5225
# Epoch 3, Train Loss: 0.6865, Train Acc: 0.5649, Val Acc: 0.5488
# Epoch 4, Train Loss: 0.6834, Train Acc: 0.5946, Val Acc: 0.6182
# Epoch 5, Train Loss: 0.6803, Train Acc: 0.6190, Val Acc: 0.6670
# Epoch 6, Train Loss: 0.6768, Train Acc: 0.6366, Val Acc: 0.6567
# Epoch 7, Train Loss: 0.6732, Train Acc: 0.6454, Val Acc: 0.6942
# Epoch 8, Train Loss: 0.6696, Train Acc: 0.6639, Val Acc: 0.6970
# Epoch 9, Train Loss: 0.6660, Train Acc: 0.6709, Val Acc: 0.6764
# Epoch 10, Train Loss: 0.6606, Train Acc: 0.6824, Val Acc: 0.6857
# Epoch 11, Train Loss: 0.6563, Train Acc: 0.6865, Val Acc: 0.6876
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.4961, Train Acc: 0.7552, Val Acc: 0.7936
# Epoch 2, Train Loss: 0.2360, Train Acc: 0.9014, Val Acc: 0.7899
# Epoch 3, Train Loss: 0.0755, Train Acc: 0.9748, Val Acc: 0.7758
# Epoch 4, Train Loss: 0.0246, Train Acc: 0.9919, Val Acc: 0.7739
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9186, Train Acc: 0.6634, Val Acc: 0.7026
# Epoch 2, Train Loss: 0.2992, Train Acc: 0.8736, Val Acc: 0.7589
# Epoch 3, Train Loss: 0.1301, Train Acc: 0.9513, Val Acc: 0.7636
# Epoch 4, Train Loss: 0.0489, Train Acc: 0.9846, Val Acc: 0.7552
# Epoch 5, Train Loss: 0.0221, Train Acc: 0.9926, Val Acc: 0.7561
# Epoch 6, Train Loss: 0.0108, Train Acc: 0.9959, Val Acc: 0.7514
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6875, Train Acc: 0.5455, Val Acc: 0.5225
# Epoch 2, Train Loss: 0.6566, Train Acc: 0.6449, Val Acc: 0.5263
# Epoch 3, Train Loss: 0.6109, Train Acc: 0.7000, Val Acc: 0.6426
# Epoch 4, Train Loss: 0.5547, Train Acc: 0.7294, Val Acc: 0.7251
# Epoch 5, Train Loss: 0.5198, Train Acc: 0.7485, Val Acc: 0.7317
# Epoch 6, Train Loss: 0.4971, Train Acc: 0.7533, Val Acc: 0.7308
# Epoch 7, Train Loss: 0.4831, Train Acc: 0.7623, Val Acc: 0.7589
# Epoch 8, Train Loss: 0.4735, Train Acc: 0.7717, Val Acc: 0.7383
# Epoch 9, Train Loss: 0.4683, Train Acc: 0.7764, Val Acc: 0.7589
# Epoch 10, Train Loss: 0.4590, Train Acc: 0.7794, Val Acc: 0.7430
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5576, Train Acc: 0.7334, Val Acc: 0.7411
# Epoch 2, Train Loss: 0.3090, Train Acc: 0.8828, Val Acc: 0.7448
# Epoch 3, Train Loss: 0.1821, Train Acc: 0.9366, Val Acc: 0.6585
# Epoch 4, Train Loss: 0.2672, Train Acc: 0.9196, Val Acc: 0.7402
# Epoch 5, Train Loss: 0.3457, Train Acc: 0.8860, Val Acc: 0.7045
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.1317, Train Acc: 0.6306, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.5388, Train Acc: 0.8087, Val Acc: 0.5131
# Epoch 3, Train Loss: 0.3225, Train Acc: 0.8913, Val Acc: 0.5272
# Epoch 4, Train Loss: 0.2136, Train Acc: 0.9362, Val Acc: 0.7270
# Epoch 5, Train Loss: 0.1540, Train Acc: 0.9557, Val Acc: 0.7326
# Epoch 6, Train Loss: 0.1213, Train Acc: 0.9700, Val Acc: 0.7176
# Epoch 7, Train Loss: 0.0937, Train Acc: 0.9761, Val Acc: 0.7505
# Epoch 8, Train Loss: 0.0864, Train Acc: 0.9809, Val Acc: 0.7486
# Epoch 9, Train Loss: 0.0576, Train Acc: 0.9857, Val Acc: 0.7477
# Epoch 10, Train Loss: 0.0754, Train Acc: 0.9857, Val Acc: 0.7458
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6893, Train Acc: 0.5393, Val Acc: 0.6642
# Epoch 2, Train Loss: 0.6741, Train Acc: 0.6038, Val Acc: 0.6435
# Epoch 3, Train Loss: 0.6574, Train Acc: 0.6583, Val Acc: 0.7008
# Epoch 4, Train Loss: 0.6340, Train Acc: 0.6936, Val Acc: 0.7073
# Epoch 5, Train Loss: 0.6074, Train Acc: 0.7208, Val Acc: 0.7167
# Epoch 6, Train Loss: 0.5785, Train Acc: 0.7277, Val Acc: 0.7439
# Epoch 7, Train Loss: 0.5525, Train Acc: 0.7385, Val Acc: 0.7355
# Epoch 8, Train Loss: 0.5280, Train Acc: 0.7518, Val Acc: 0.7364
# Epoch 9, Train Loss: 0.5136, Train Acc: 0.7518, Val Acc: 0.7495
# Epoch 10, Train Loss: 0.4964, Train Acc: 0.7613, Val Acc: 0.7458
# Epoch 11, Train Loss: 0.4906, Train Acc: 0.7642, Val Acc: 0.7514
# Epoch 12, Train Loss: 0.4846, Train Acc: 0.7673, Val Acc: 0.7542
# Epoch 13, Train Loss: 0.4789, Train Acc: 0.7675, Val Acc: 0.7495
# Epoch 14, Train Loss: 0.4713, Train Acc: 0.7717, Val Acc: 0.7598
# Epoch 15, Train Loss: 0.4678, Train Acc: 0.7760, Val Acc: 0.7617
# Epoch 16, Train Loss: 0.4629, Train Acc: 0.7783, Val Acc: 0.7598
# Epoch 17, Train Loss: 0.4615, Train Acc: 0.7763, Val Acc: 0.7645
# Epoch 18, Train Loss: 0.4592, Train Acc: 0.7777, Val Acc: 0.7589
# Epoch 19, Train Loss: 0.4507, Train Acc: 0.7883, Val Acc: 0.7683
# Epoch 20, Train Loss: 0.4508, Train Acc: 0.7823, Val Acc: 0.7627
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5308, Train Acc: 0.7399, Val Acc: 0.7852
# Epoch 2, Train Loss: 0.2184, Train Acc: 0.9157, Val Acc: 0.7702
# Epoch 3, Train Loss: 0.0869, Train Acc: 0.9689, Val Acc: 0.7711
# Epoch 4, Train Loss: 0.0533, Train Acc: 0.9819, Val Acc: 0.7749
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0784, Train Acc: 0.6423, Val Acc: 0.7158
# Epoch 2, Train Loss: 0.3729, Train Acc: 0.8506, Val Acc: 0.7402
# Epoch 3, Train Loss: 0.1973, Train Acc: 0.9273, Val Acc: 0.7458
# Epoch 4, Train Loss: 0.1171, Train Acc: 0.9594, Val Acc: 0.7383
# Epoch 5, Train Loss: 0.0817, Train Acc: 0.9712, Val Acc: 0.7251
# Epoch 6, Train Loss: 0.0529, Train Acc: 0.9822, Val Acc: 0.7439
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6910, Train Acc: 0.5218, Val Acc: 0.5141
# Epoch 2, Train Loss: 0.6839, Train Acc: 0.5809, Val Acc: 0.6557
# Epoch 3, Train Loss: 0.6774, Train Acc: 0.6206, Val Acc: 0.6182
# Epoch 4, Train Loss: 0.6697, Train Acc: 0.6281, Val Acc: 0.6904
# Epoch 5, Train Loss: 0.6612, Train Acc: 0.6682, Val Acc: 0.7073
# Epoch 6, Train Loss: 0.6525, Train Acc: 0.6801, Val Acc: 0.6951
# Epoch 7, Train Loss: 0.6407, Train Acc: 0.6940, Val Acc: 0.6867
# Epoch 8, Train Loss: 0.6278, Train Acc: 0.7046, Val Acc: 0.7242
# Epoch 9, Train Loss: 0.6154, Train Acc: 0.7104, Val Acc: 0.7195
# Epoch 10, Train Loss: 0.6002, Train Acc: 0.7234, Val Acc: 0.7317
# Epoch 11, Train Loss: 0.5871, Train Acc: 0.7205, Val Acc: 0.7308
# Epoch 12, Train Loss: 0.5712, Train Acc: 0.7376, Val Acc: 0.7326
# Epoch 13, Train Loss: 0.5593, Train Acc: 0.7336, Val Acc: 0.7392
# Epoch 14, Train Loss: 0.5437, Train Acc: 0.7392, Val Acc: 0.7383
# Epoch 15, Train Loss: 0.5337, Train Acc: 0.7474, Val Acc: 0.7439
# Epoch 16, Train Loss: 0.5241, Train Acc: 0.7468, Val Acc: 0.7448
# Epoch 17, Train Loss: 0.5178, Train Acc: 0.7504, Val Acc: 0.7514
# Epoch 18, Train Loss: 0.5084, Train Acc: 0.7544, Val Acc: 0.7420
# Epoch 19, Train Loss: 0.5051, Train Acc: 0.7543, Val Acc: 0.7505
# Epoch 20, Train Loss: 0.4986, Train Acc: 0.7604, Val Acc: 0.7552
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5346, Train Acc: 0.7464, Val Acc: 0.7899
# Epoch 2, Train Loss: 0.1970, Train Acc: 0.9206, Val Acc: 0.7373
# Epoch 3, Train Loss: 0.0691, Train Acc: 0.9743, Val Acc: 0.7795
# Epoch 4, Train Loss: 0.0263, Train Acc: 0.9903, Val Acc: 0.7814
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.5986, Train Acc: 0.6046, Val Acc: 0.7120
# Epoch 2, Train Loss: 0.3254, Train Acc: 0.8642, Val Acc: 0.7383
# Epoch 3, Train Loss: 0.1505, Train Acc: 0.9426, Val Acc: 0.7364
# Epoch 4, Train Loss: 0.0748, Train Acc: 0.9716, Val Acc: 0.7383
# Epoch 5, Train Loss: 0.0427, Train Acc: 0.9845, Val Acc: 0.7589
# Epoch 6, Train Loss: 0.0577, Train Acc: 0.9866, Val Acc: 0.7533
# Epoch 7, Train Loss: 0.0172, Train Acc: 0.9936, Val Acc: 0.6632
# Epoch 8, Train Loss: 0.0158, Train Acc: 0.9951, Val Acc: 0.7383
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6009, Train Acc: 0.6592, Val Acc: 0.7542
# Epoch 2, Train Loss: 0.4853, Train Acc: 0.7617, Val Acc: 0.6773
# Epoch 3, Train Loss: 0.4534, Train Acc: 0.7837, Val Acc: 0.6660
# Epoch 4, Train Loss: 0.4259, Train Acc: 0.8030, Val Acc: 0.7251
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 5.6223, Train Acc: 0.5120, Val Acc: 0.5000
# Epoch 2, Train Loss: 5.1245, Train Acc: 0.5028, Val Acc: 0.5103
# Epoch 3, Train Loss: 4.6523, Train Acc: 0.5118, Val Acc: 0.4991
# Epoch 4, Train Loss: 5.5798, Train Acc: 0.5043, Val Acc: 0.5009
# Epoch 5, Train Loss: 5.5632, Train Acc: 0.5114, Val Acc: 0.5019
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 30.0027, Train Acc: 0.5020, Val Acc: 0.5000
# Epoch 2, Train Loss: 24.8216, Train Acc: 0.4965, Val Acc: 0.4972
# Epoch 3, Train Loss: 24.6090, Train Acc: 0.5020, Val Acc: 0.5009
# Epoch 4, Train Loss: 24.5845, Train Acc: 0.5060, Val Acc: 0.5000
# Epoch 5, Train Loss: 24.5071, Train Acc: 0.5072, Val Acc: 0.5066
# Epoch 6, Train Loss: 24.5204, Train Acc: 0.4965, Val Acc: 0.5000
# Epoch 7, Train Loss: 25.3617, Train Acc: 0.4886, Val Acc: 0.5188
# Epoch 8, Train Loss: 24.0152, Train Acc: 0.5115, Val Acc: 0.5038
# Epoch 9, Train Loss: 23.5770, Train Acc: 0.5132, Val Acc: 0.5028
# Epoch 10, Train Loss: 24.1493, Train Acc: 0.5089, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6389, Train Acc: 0.6245, Val Acc: 0.7298
# Epoch 2, Train Loss: 0.5092, Train Acc: 0.7455, Val Acc: 0.7139
# Epoch 3, Train Loss: 0.4812, Train Acc: 0.7633, Val Acc: 0.7495
# Epoch 4, Train Loss: 0.4543, Train Acc: 0.7797, Val Acc: 0.7608
# Epoch 5, Train Loss: 0.4384, Train Acc: 0.7923, Val Acc: 0.7664
# Epoch 6, Train Loss: 0.4177, Train Acc: 0.8043, Val Acc: 0.7889
# Epoch 7, Train Loss: 0.4043, Train Acc: 0.8111, Val Acc: 0.7889
# Epoch 8, Train Loss: 0.3886, Train Acc: 0.8216, Val Acc: 0.7889
# Epoch 9, Train Loss: 0.3794, Train Acc: 0.8304, Val Acc: 0.7917
# Epoch 10, Train Loss: 0.3659, Train Acc: 0.8329, Val Acc: 0.7992
# Epoch 11, Train Loss: 0.3365, Train Acc: 0.8494, Val Acc: 0.8058
# Epoch 12, Train Loss: 0.3298, Train Acc: 0.8563, Val Acc: 0.7730
# Epoch 13, Train Loss: 0.3155, Train Acc: 0.8625, Val Acc: 0.8011
# Epoch 14, Train Loss: 0.3058, Train Acc: 0.8673, Val Acc: 0.7486
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 3.1779, Train Acc: 0.5236, Val Acc: 0.4972
# Epoch 2, Train Loss: 5.5519, Train Acc: 0.5169, Val Acc: 0.5338
# Epoch 3, Train Loss: 4.4192, Train Acc: 0.5101, Val Acc: 0.4962
# Epoch 4, Train Loss: 4.9580, Train Acc: 0.5200, Val Acc: 0.5047
# Epoch 5, Train Loss: 3.4918, Train Acc: 0.5066, Val Acc: 0.5094
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 34.3408, Train Acc: 0.5011, Val Acc: 0.5328
# Epoch 2, Train Loss: 22.7100, Train Acc: 0.5115, Val Acc: 0.5009
# Epoch 3, Train Loss: 23.0230, Train Acc: 0.5106, Val Acc: 0.5009
# Epoch 4, Train Loss: 23.5581, Train Acc: 0.5052, Val Acc: 0.5591
# Epoch 5, Train Loss: 23.4842, Train Acc: 0.5052, Val Acc: 0.5000
# Epoch 6, Train Loss: 23.4824, Train Acc: 0.5062, Val Acc: 0.5338
# Epoch 7, Train Loss: 23.6664, Train Acc: 0.5090, Val Acc: 0.5047
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6852, Train Acc: 0.5807, Val Acc: 0.6951
# Epoch 2, Train Loss: 0.5725, Train Acc: 0.6966, Val Acc: 0.7402
# Epoch 3, Train Loss: 0.5134, Train Acc: 0.7402, Val Acc: 0.6735
# Epoch 4, Train Loss: 0.4944, Train Acc: 0.7537, Val Acc: 0.7486
# Epoch 5, Train Loss: 0.4788, Train Acc: 0.7726, Val Acc: 0.7430
# Epoch 6, Train Loss: 0.4564, Train Acc: 0.7822, Val Acc: 0.7420
# Epoch 7, Train Loss: 0.4479, Train Acc: 0.7877, Val Acc: 0.6698
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 2.2722, Train Acc: 0.5374, Val Acc: 0.5619
# Epoch 2, Train Loss: 2.6598, Train Acc: 0.5693, Val Acc: 0.5572
# Epoch 3, Train Loss: 3.8032, Train Acc: 0.5294, Val Acc: 0.5244
# Epoch 4, Train Loss: 3.3920, Train Acc: 0.5297, Val Acc: 0.5657
# Epoch 5, Train Loss: 2.8058, Train Acc: 0.5462, Val Acc: 0.5150
# Epoch 6, Train Loss: 4.4459, Train Acc: 0.5339, Val Acc: 0.5253
# Epoch 7, Train Loss: 3.6200, Train Acc: 0.5278, Val Acc: 0.5197
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 44.5995, Train Acc: 0.5001, Val Acc: 0.5000
# Epoch 2, Train Loss: 26.4314, Train Acc: 0.4995, Val Acc: 0.5009
# Epoch 3, Train Loss: 24.9290, Train Acc: 0.4996, Val Acc: 0.5000
# Epoch 4, Train Loss: 24.3119, Train Acc: 0.4989, Val Acc: 0.5028
# Epoch 5, Train Loss: 23.8788, Train Acc: 0.5036, Val Acc: 0.5056
# Epoch 6, Train Loss: 23.9121, Train Acc: 0.4999, Val Acc: 0.5075
# Epoch 7, Train Loss: 23.3680, Train Acc: 0.5087, Val Acc: 0.5038
# Epoch 8, Train Loss: 23.9736, Train Acc: 0.5039, Val Acc: 0.5038
# Epoch 9, Train Loss: 24.3451, Train Acc: 0.5014, Val Acc: 0.5028
# Early stopping
# Best Validation Accuracy: 0.8198874296435272
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 16, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_biGRU['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_biGRU = BiGRUModel(embedding_matrix_cosine_sim, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_biGRU['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
elif best_hyperparams_biGRU['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
elif best_hyperparams_biGRU['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])

best_model_biGRU, train_losses, train_accuracies, val_accuracies = train_model(best_model_biGRU, train_loader, validation_loader,
                                                                               best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.4830, Train Acc: 0.7682, Val Acc: 0.7730
# Epoch 2, Train Loss: 0.3133, Train Acc: 0.8637, Val Acc: 0.7533
# Epoch 3, Train Loss: 0.2093, Train Acc: 0.9162, Val Acc: 0.7326
# Epoch 4, Train Loss: 0.1259, Train Acc: 0.9533, Val Acc: 0.7964
# Epoch 5, Train Loss: 0.0773, Train Acc: 0.9700, Val Acc: 0.7917
# Epoch 6, Train Loss: 0.0418, Train Acc: 0.9859, Val Acc: 0.7889
# Epoch 7, Train Loss: 0.0228, Train Acc: 0.9919, Val Acc: 0.7871
# Early stopping

# %%
epochs_big = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_big, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_biGRU, test_loader)
test_accuracies['biGRU'] = test_acc
print(f'Test Accuracy (biGRU): {test_acc:.4f}')
# Out:
# Test Accuracy (biGRU): 0.8143

# %% [markdown]
# ### (d) Report the accuracy scores of CNN on the test set (Part 3.4).

# %%
# Define CNN Model
class CNNModel(nn.Module):
    def __init__(self, embedding_matrix, output_dim):
        super(CNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.conv1 = nn.Conv2d(1, 100, (3, embedding_dim)).to(device)  # 1 input channel, 100 output channels
        self.fc = nn.Linear(100, output_dim).to(device)
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x).unsqueeze(1)  # Add channel dimension
        conv_out = self.conv1(embedded).squeeze(3)  # Shape: (batch_size, 100, sequence_length - filter_size + 1)
        conv_out = torch.relu(conv_out)  # Apply ReLU
        pooled = nn.functional.max_pool1d(conv_out, conv_out.size(2)).squeeze(2)  # Max pooling
        output = self.fc(self.dropout(pooled))
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %%
best_val_acc = 0
best_hyperparams_CNN = {}

# Prepare datasets
train_data = TensorDataset(train_sequences.to(device), train_labels.to(device))
validation_data = TensorDataset(validation_sequences.to(device), validation_labels.to(device))

# Grid search
for lr in learning_rates:
    for batch_size in batch_sizes:
        for opt in optimizers:
            print(f"Training with lr={lr}, batch_size={batch_size}, optimizer={opt}")

            # Set up DataLoader with the current batch size
            train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
            validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)

            # Initialize a new model for each set of hyperparameters
            model = CNNModel(embedding_matrix=embedding_matrix_cosine_sim, output_dim=output_dim)  # Reinitialize model
            model = model.to(device)

            # Choose optimizer
            if opt == 'SGD':
                optimizer = optim.SGD(model.parameters(), lr=lr)
            elif opt == 'Adam':
                optimizer = optim.Adam(model.parameters(), lr=lr)
            elif opt == 'RMSprop':
                optimizer = optim.RMSprop(model.parameters(), lr=lr)

            # Train and evaluate the model
            val_acc, _, _, _ = train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)


            # Track the best configuration based on validation accuracy
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_hyperparams = {'lr': lr, 'batch_size': batch_size, 'optimizer': opt}

print(f"Best Validation Accuracy: {best_val_acc}")
print(f"Best Hyperparameters: {best_hyperparams}")
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6974, Train Acc: 0.5222, Val Acc: 0.5994
# Epoch 2, Train Loss: 0.6857, Train Acc: 0.5544, Val Acc: 0.6126
# Epoch 3, Train Loss: 0.6770, Train Acc: 0.5815, Val Acc: 0.6717
# Epoch 4, Train Loss: 0.6708, Train Acc: 0.6041, Val Acc: 0.6857
# Epoch 5, Train Loss: 0.6629, Train Acc: 0.6212, Val Acc: 0.6914
# Epoch 6, Train Loss: 0.6516, Train Acc: 0.6553, Val Acc: 0.7139
# Epoch 7, Train Loss: 0.6418, Train Acc: 0.6757, Val Acc: 0.7280
# Epoch 8, Train Loss: 0.6306, Train Acc: 0.6863, Val Acc: 0.7195
# Epoch 9, Train Loss: 0.6183, Train Acc: 0.6978, Val Acc: 0.7364
# Epoch 10, Train Loss: 0.6040, Train Acc: 0.7106, Val Acc: 0.7392
# Epoch 11, Train Loss: 0.5915, Train Acc: 0.7233, Val Acc: 0.7458
# Epoch 12, Train Loss: 0.5801, Train Acc: 0.7271, Val Acc: 0.7420
# Epoch 13, Train Loss: 0.5666, Train Acc: 0.7349, Val Acc: 0.7430
# Epoch 14, Train Loss: 0.5546, Train Acc: 0.7360, Val Acc: 0.7486
# Epoch 15, Train Loss: 0.5466, Train Acc: 0.7434, Val Acc: 0.7477
# Epoch 16, Train Loss: 0.5380, Train Acc: 0.7499, Val Acc: 0.7495
# Epoch 17, Train Loss: 0.5271, Train Acc: 0.7471, Val Acc: 0.7505
# Epoch 18, Train Loss: 0.5181, Train Acc: 0.7589, Val Acc: 0.7514
# Epoch 19, Train Loss: 0.5113, Train Acc: 0.7607, Val Acc: 0.7514
# Epoch 20, Train Loss: 0.5037, Train Acc: 0.7658, Val Acc: 0.7514
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5059, Train Acc: 0.7469, Val Acc: 0.7833
# Epoch 2, Train Loss: 0.3030, Train Acc: 0.8742, Val Acc: 0.7627
# Epoch 3, Train Loss: 0.1234, Train Acc: 0.9596, Val Acc: 0.7711
# Epoch 4, Train Loss: 0.0447, Train Acc: 0.9866, Val Acc: 0.7871
# Epoch 5, Train Loss: 0.0194, Train Acc: 0.9954, Val Acc: 0.7795
# Epoch 6, Train Loss: 0.0079, Train Acc: 0.9988, Val Acc: 0.7833
# Epoch 7, Train Loss: 0.0054, Train Acc: 0.9987, Val Acc: 0.7842
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5027, Train Acc: 0.7531, Val Acc: 0.7955
# Epoch 2, Train Loss: 0.3158, Train Acc: 0.8625, Val Acc: 0.7983
# Epoch 3, Train Loss: 0.1698, Train Acc: 0.9351, Val Acc: 0.7852
# Epoch 4, Train Loss: 0.0782, Train Acc: 0.9722, Val Acc: 0.7917
# Epoch 5, Train Loss: 0.0382, Train Acc: 0.9875, Val Acc: 0.7749
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6927, Train Acc: 0.5264, Val Acc: 0.6041
# Epoch 2, Train Loss: 0.6893, Train Acc: 0.5359, Val Acc: 0.6266
# Epoch 3, Train Loss: 0.6838, Train Acc: 0.5703, Val Acc: 0.6501
# Epoch 4, Train Loss: 0.6793, Train Acc: 0.5815, Val Acc: 0.6660
# Epoch 5, Train Loss: 0.6766, Train Acc: 0.5977, Val Acc: 0.6679
# Epoch 6, Train Loss: 0.6729, Train Acc: 0.6084, Val Acc: 0.6717
# Epoch 7, Train Loss: 0.6683, Train Acc: 0.6206, Val Acc: 0.6829
# Epoch 8, Train Loss: 0.6639, Train Acc: 0.6373, Val Acc: 0.6886
# Epoch 9, Train Loss: 0.6581, Train Acc: 0.6518, Val Acc: 0.6970
# Epoch 10, Train Loss: 0.6535, Train Acc: 0.6571, Val Acc: 0.7064
# Epoch 11, Train Loss: 0.6500, Train Acc: 0.6608, Val Acc: 0.7111
# Epoch 12, Train Loss: 0.6444, Train Acc: 0.6755, Val Acc: 0.7195
# Epoch 13, Train Loss: 0.6395, Train Acc: 0.6841, Val Acc: 0.7214
# Epoch 14, Train Loss: 0.6332, Train Acc: 0.6892, Val Acc: 0.7223
# Epoch 15, Train Loss: 0.6284, Train Acc: 0.6971, Val Acc: 0.7251
# Epoch 16, Train Loss: 0.6196, Train Acc: 0.7067, Val Acc: 0.7223
# Epoch 17, Train Loss: 0.6135, Train Acc: 0.7140, Val Acc: 0.7289
# Epoch 18, Train Loss: 0.6094, Train Acc: 0.7089, Val Acc: 0.7308
# Epoch 19, Train Loss: 0.6008, Train Acc: 0.7198, Val Acc: 0.7280
# Epoch 20, Train Loss: 0.5938, Train Acc: 0.7227, Val Acc: 0.7326
# Training with lr=0.001, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5127, Train Acc: 0.7376, Val Acc: 0.7814
# Epoch 2, Train Loss: 0.3226, Train Acc: 0.8621, Val Acc: 0.7927
# Epoch 3, Train Loss: 0.1593, Train Acc: 0.9443, Val Acc: 0.7805
# Epoch 4, Train Loss: 0.0618, Train Acc: 0.9830, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.0268, Train Acc: 0.9945, Val Acc: 0.7749
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5082, Train Acc: 0.7443, Val Acc: 0.7992
# Epoch 2, Train Loss: 0.3156, Train Acc: 0.8668, Val Acc: 0.7861
# Epoch 3, Train Loss: 0.1783, Train Acc: 0.9335, Val Acc: 0.7767
# Epoch 4, Train Loss: 0.0869, Train Acc: 0.9729, Val Acc: 0.7824
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6997, Train Acc: 0.4952, Val Acc: 0.4869
# Epoch 2, Train Loss: 0.6946, Train Acc: 0.5156, Val Acc: 0.5038
# Epoch 3, Train Loss: 0.6927, Train Acc: 0.5247, Val Acc: 0.5197
# Epoch 4, Train Loss: 0.6916, Train Acc: 0.5275, Val Acc: 0.5347
# Epoch 5, Train Loss: 0.6910, Train Acc: 0.5308, Val Acc: 0.5553
# Epoch 6, Train Loss: 0.6880, Train Acc: 0.5377, Val Acc: 0.5600
# Epoch 7, Train Loss: 0.6869, Train Acc: 0.5607, Val Acc: 0.5741
# Epoch 8, Train Loss: 0.6859, Train Acc: 0.5545, Val Acc: 0.5891
# Epoch 9, Train Loss: 0.6843, Train Acc: 0.5552, Val Acc: 0.6004
# Epoch 10, Train Loss: 0.6836, Train Acc: 0.5587, Val Acc: 0.6154
# Epoch 11, Train Loss: 0.6804, Train Acc: 0.5771, Val Acc: 0.6182
# Epoch 12, Train Loss: 0.6794, Train Acc: 0.5764, Val Acc: 0.6360
# Epoch 13, Train Loss: 0.6779, Train Acc: 0.5808, Val Acc: 0.6360
# Epoch 14, Train Loss: 0.6758, Train Acc: 0.5912, Val Acc: 0.6407
# Epoch 15, Train Loss: 0.6755, Train Acc: 0.5855, Val Acc: 0.6585
# Epoch 16, Train Loss: 0.6725, Train Acc: 0.6057, Val Acc: 0.6585
# Epoch 17, Train Loss: 0.6696, Train Acc: 0.6106, Val Acc: 0.6754
# Epoch 18, Train Loss: 0.6706, Train Acc: 0.6106, Val Acc: 0.6707
# Epoch 19, Train Loss: 0.6657, Train Acc: 0.6266, Val Acc: 0.6698
# Epoch 20, Train Loss: 0.6641, Train Acc: 0.6307, Val Acc: 0.6764
# Training with lr=0.001, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5288, Train Acc: 0.7302, Val Acc: 0.7805
# Epoch 2, Train Loss: 0.3547, Train Acc: 0.8436, Val Acc: 0.7908
# Epoch 3, Train Loss: 0.2173, Train Acc: 0.9193, Val Acc: 0.7833
# Epoch 4, Train Loss: 0.1047, Train Acc: 0.9702, Val Acc: 0.7767
# Epoch 5, Train Loss: 0.0484, Train Acc: 0.9889, Val Acc: 0.7777
# Early stopping
# Training with lr=0.001, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.5136, Train Acc: 0.7422, Val Acc: 0.7889
# Epoch 2, Train Loss: 0.3261, Train Acc: 0.8625, Val Acc: 0.7824
# Epoch 3, Train Loss: 0.2036, Train Acc: 0.9261, Val Acc: 0.7627
# Epoch 4, Train Loss: 0.1127, Train Acc: 0.9657, Val Acc: 0.7655
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6841, Train Acc: 0.5576, Val Acc: 0.6904
# Epoch 2, Train Loss: 0.6388, Train Acc: 0.6727, Val Acc: 0.7148
# Epoch 3, Train Loss: 0.5797, Train Acc: 0.7215, Val Acc: 0.7420
# Epoch 4, Train Loss: 0.5278, Train Acc: 0.7463, Val Acc: 0.7514
# Epoch 5, Train Loss: 0.4995, Train Acc: 0.7642, Val Acc: 0.7495
# Epoch 6, Train Loss: 0.4766, Train Acc: 0.7760, Val Acc: 0.7636
# Epoch 7, Train Loss: 0.4609, Train Acc: 0.7855, Val Acc: 0.7636
# Epoch 8, Train Loss: 0.4472, Train Acc: 0.7933, Val Acc: 0.7552
# Epoch 9, Train Loss: 0.4312, Train Acc: 0.8053, Val Acc: 0.7758
# Epoch 10, Train Loss: 0.4227, Train Acc: 0.8070, Val Acc: 0.7720
# Epoch 11, Train Loss: 0.4058, Train Acc: 0.8192, Val Acc: 0.7767
# Epoch 12, Train Loss: 0.3953, Train Acc: 0.8266, Val Acc: 0.7777
# Epoch 13, Train Loss: 0.3868, Train Acc: 0.8327, Val Acc: 0.7730
# Epoch 14, Train Loss: 0.3708, Train Acc: 0.8426, Val Acc: 0.7795
# Epoch 15, Train Loss: 0.3615, Train Acc: 0.8488, Val Acc: 0.7749
# Epoch 16, Train Loss: 0.3423, Train Acc: 0.8579, Val Acc: 0.7889
# Epoch 17, Train Loss: 0.3352, Train Acc: 0.8625, Val Acc: 0.7852
# Epoch 18, Train Loss: 0.3222, Train Acc: 0.8707, Val Acc: 0.7786
# Epoch 19, Train Loss: 0.3126, Train Acc: 0.8707, Val Acc: 0.7758
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.5398, Train Acc: 0.7295, Val Acc: 0.7720
# Epoch 2, Train Loss: 0.2589, Train Acc: 0.8965, Val Acc: 0.7683
# Epoch 3, Train Loss: 0.1227, Train Acc: 0.9590, Val Acc: 0.7598
# Epoch 4, Train Loss: 0.0810, Train Acc: 0.9766, Val Acc: 0.7458
# Early stopping
# Training with lr=0.005, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6092, Train Acc: 0.7314, Val Acc: 0.7683
# Epoch 2, Train Loss: 0.3135, Train Acc: 0.8775, Val Acc: 0.7430
# Epoch 3, Train Loss: 0.1422, Train Acc: 0.9496, Val Acc: 0.7570
# Epoch 4, Train Loss: 0.0922, Train Acc: 0.9710, Val Acc: 0.7523
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6896, Train Acc: 0.5322, Val Acc: 0.6051
# Epoch 2, Train Loss: 0.6685, Train Acc: 0.6068, Val Acc: 0.6670
# Epoch 3, Train Loss: 0.6423, Train Acc: 0.6639, Val Acc: 0.7261
# Epoch 4, Train Loss: 0.6143, Train Acc: 0.6957, Val Acc: 0.7392
# Epoch 5, Train Loss: 0.5812, Train Acc: 0.7271, Val Acc: 0.7458
# Epoch 6, Train Loss: 0.5537, Train Acc: 0.7369, Val Acc: 0.7458
# Epoch 7, Train Loss: 0.5283, Train Acc: 0.7449, Val Acc: 0.7392
# Epoch 8, Train Loss: 0.5139, Train Acc: 0.7531, Val Acc: 0.7514
# Epoch 9, Train Loss: 0.4971, Train Acc: 0.7647, Val Acc: 0.7533
# Epoch 10, Train Loss: 0.4854, Train Acc: 0.7730, Val Acc: 0.7533
# Epoch 11, Train Loss: 0.4740, Train Acc: 0.7774, Val Acc: 0.7523
# Epoch 12, Train Loss: 0.4657, Train Acc: 0.7816, Val Acc: 0.7636
# Epoch 13, Train Loss: 0.4590, Train Acc: 0.7890, Val Acc: 0.7580
# Epoch 14, Train Loss: 0.4509, Train Acc: 0.7893, Val Acc: 0.7570
# Epoch 15, Train Loss: 0.4418, Train Acc: 0.7943, Val Acc: 0.7664
# Epoch 16, Train Loss: 0.4326, Train Acc: 0.8049, Val Acc: 0.7758
# Epoch 17, Train Loss: 0.4261, Train Acc: 0.8081, Val Acc: 0.7739
# Epoch 18, Train Loss: 0.4226, Train Acc: 0.8106, Val Acc: 0.7683
# Epoch 19, Train Loss: 0.4128, Train Acc: 0.8186, Val Acc: 0.7692
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5203, Train Acc: 0.7438, Val Acc: 0.7749
# Epoch 2, Train Loss: 0.2339, Train Acc: 0.9094, Val Acc: 0.7664
# Epoch 3, Train Loss: 0.0777, Train Acc: 0.9737, Val Acc: 0.7523
# Epoch 4, Train Loss: 0.0428, Train Acc: 0.9860, Val Acc: 0.7608
# Early stopping
# Training with lr=0.005, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 0.6250, Train Acc: 0.7326, Val Acc: 0.7833
# Epoch 2, Train Loss: 0.2606, Train Acc: 0.8961, Val Acc: 0.7598
# Epoch 3, Train Loss: 0.1108, Train Acc: 0.9586, Val Acc: 0.7542
# Epoch 4, Train Loss: 0.0499, Train Acc: 0.9837, Val Acc: 0.7655
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6981, Train Acc: 0.5016, Val Acc: 0.5657
# Epoch 2, Train Loss: 0.6908, Train Acc: 0.5309, Val Acc: 0.6229
# Epoch 3, Train Loss: 0.6799, Train Acc: 0.5732, Val Acc: 0.6585
# Epoch 4, Train Loss: 0.6743, Train Acc: 0.5947, Val Acc: 0.6792
# Epoch 5, Train Loss: 0.6644, Train Acc: 0.6264, Val Acc: 0.7008
# Epoch 6, Train Loss: 0.6537, Train Acc: 0.6547, Val Acc: 0.7092
# Epoch 7, Train Loss: 0.6400, Train Acc: 0.6741, Val Acc: 0.7251
# Epoch 8, Train Loss: 0.6252, Train Acc: 0.6986, Val Acc: 0.7345
# Epoch 9, Train Loss: 0.6096, Train Acc: 0.7066, Val Acc: 0.7411
# Epoch 10, Train Loss: 0.5944, Train Acc: 0.7154, Val Acc: 0.7420
# Epoch 11, Train Loss: 0.5790, Train Acc: 0.7192, Val Acc: 0.7458
# Epoch 12, Train Loss: 0.5647, Train Acc: 0.7278, Val Acc: 0.7430
# Epoch 13, Train Loss: 0.5511, Train Acc: 0.7369, Val Acc: 0.7430
# Epoch 14, Train Loss: 0.5395, Train Acc: 0.7399, Val Acc: 0.7477
# Epoch 15, Train Loss: 0.5299, Train Acc: 0.7427, Val Acc: 0.7458
# Epoch 16, Train Loss: 0.5203, Train Acc: 0.7512, Val Acc: 0.7514
# Epoch 17, Train Loss: 0.5134, Train Acc: 0.7581, Val Acc: 0.7486
# Epoch 18, Train Loss: 0.5039, Train Acc: 0.7601, Val Acc: 0.7570
# Epoch 19, Train Loss: 0.4978, Train Acc: 0.7619, Val Acc: 0.7552
# Epoch 20, Train Loss: 0.4912, Train Acc: 0.7665, Val Acc: 0.7523
# Training with lr=0.005, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5030, Train Acc: 0.7429, Val Acc: 0.7955
# Epoch 2, Train Loss: 0.2242, Train Acc: 0.9120, Val Acc: 0.7627
# Epoch 3, Train Loss: 0.0727, Train Acc: 0.9756, Val Acc: 0.7767
# Epoch 4, Train Loss: 0.0337, Train Acc: 0.9896, Val Acc: 0.7495
# Early stopping
# Training with lr=0.005, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7094, Train Acc: 0.7250, Val Acc: 0.7430
# Epoch 2, Train Loss: 0.2377, Train Acc: 0.9060, Val Acc: 0.7477
# Epoch 3, Train Loss: 0.0807, Train Acc: 0.9723, Val Acc: 0.7598
# Epoch 4, Train Loss: 0.0407, Train Acc: 0.9870, Val Acc: 0.7542
# Epoch 5, Train Loss: 0.0261, Train Acc: 0.9925, Val Acc: 0.7636
# Epoch 6, Train Loss: 0.0305, Train Acc: 0.9924, Val Acc: 0.7505
# Epoch 7, Train Loss: 0.0169, Train Acc: 0.9940, Val Acc: 0.7411
# Epoch 8, Train Loss: 0.0163, Train Acc: 0.9959, Val Acc: 0.7655
# Epoch 9, Train Loss: 0.0327, Train Acc: 0.9924, Val Acc: 0.7552
# Epoch 10, Train Loss: 0.0088, Train Acc: 0.9971, Val Acc: 0.7495
# Epoch 11, Train Loss: 0.0145, Train Acc: 0.9967, Val Acc: 0.7580
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6657, Train Acc: 0.5988, Val Acc: 0.6135
# Epoch 2, Train Loss: 0.5635, Train Acc: 0.7321, Val Acc: 0.7467
# Epoch 3, Train Loss: 0.4998, Train Acc: 0.7581, Val Acc: 0.7298
# Epoch 4, Train Loss: 0.4681, Train Acc: 0.7733, Val Acc: 0.7542
# Epoch 5, Train Loss: 0.4452, Train Acc: 0.7973, Val Acc: 0.7505
# Epoch 6, Train Loss: 0.4186, Train Acc: 0.8109, Val Acc: 0.7448
# Epoch 7, Train Loss: 0.3996, Train Acc: 0.8211, Val Acc: 0.7786
# Epoch 8, Train Loss: 0.3814, Train Acc: 0.8353, Val Acc: 0.7158
# Epoch 9, Train Loss: 0.3573, Train Acc: 0.8498, Val Acc: 0.7861
# Epoch 10, Train Loss: 0.3375, Train Acc: 0.8563, Val Acc: 0.7805
# Epoch 11, Train Loss: 0.3188, Train Acc: 0.8703, Val Acc: 0.7917
# Epoch 12, Train Loss: 0.2963, Train Acc: 0.8816, Val Acc: 0.7842
# Epoch 13, Train Loss: 0.2766, Train Acc: 0.8923, Val Acc: 0.7589
# Epoch 14, Train Loss: 0.2618, Train Acc: 0.9005, Val Acc: 0.7402
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6289, Train Acc: 0.6948, Val Acc: 0.6886
# Epoch 2, Train Loss: 0.5276, Train Acc: 0.8142, Val Acc: 0.7139
# Epoch 3, Train Loss: 0.3955, Train Acc: 0.8805, Val Acc: 0.7036
# Epoch 4, Train Loss: 0.3570, Train Acc: 0.9029, Val Acc: 0.7120
# Epoch 5, Train Loss: 0.3410, Train Acc: 0.9137, Val Acc: 0.7092
# Early stopping
# Training with lr=0.01, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 1.0343, Train Acc: 0.6951, Val Acc: 0.6801
# Epoch 2, Train Loss: 0.4432, Train Acc: 0.8321, Val Acc: 0.7486
# Epoch 3, Train Loss: 0.3306, Train Acc: 0.8954, Val Acc: 0.7195
# Epoch 4, Train Loss: 0.2783, Train Acc: 0.9232, Val Acc: 0.7317
# Epoch 5, Train Loss: 0.2320, Train Acc: 0.9403, Val Acc: 0.7214
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.6802, Train Acc: 0.5700, Val Acc: 0.7073
# Epoch 2, Train Loss: 0.6348, Train Acc: 0.6788, Val Acc: 0.6707
# Epoch 3, Train Loss: 0.5780, Train Acc: 0.7238, Val Acc: 0.7570
# Epoch 4, Train Loss: 0.5311, Train Acc: 0.7474, Val Acc: 0.7439
# Epoch 5, Train Loss: 0.4977, Train Acc: 0.7603, Val Acc: 0.7467
# Epoch 6, Train Loss: 0.4773, Train Acc: 0.7725, Val Acc: 0.7589
# Epoch 7, Train Loss: 0.4616, Train Acc: 0.7845, Val Acc: 0.7739
# Epoch 8, Train Loss: 0.4436, Train Acc: 0.7936, Val Acc: 0.7617
# Epoch 9, Train Loss: 0.4361, Train Acc: 0.8005, Val Acc: 0.7608
# Epoch 10, Train Loss: 0.4234, Train Acc: 0.8122, Val Acc: 0.7758
# Epoch 11, Train Loss: 0.4082, Train Acc: 0.8132, Val Acc: 0.7720
# Epoch 12, Train Loss: 0.3969, Train Acc: 0.8264, Val Acc: 0.7777
# Epoch 13, Train Loss: 0.3859, Train Acc: 0.8315, Val Acc: 0.7749
# Epoch 14, Train Loss: 0.3716, Train Acc: 0.8396, Val Acc: 0.7749
# Epoch 15, Train Loss: 0.3605, Train Acc: 0.8494, Val Acc: 0.7795
# Epoch 16, Train Loss: 0.3471, Train Acc: 0.8537, Val Acc: 0.7833
# Epoch 17, Train Loss: 0.3367, Train Acc: 0.8610, Val Acc: 0.7805
# Epoch 18, Train Loss: 0.3237, Train Acc: 0.8660, Val Acc: 0.7814
# Epoch 19, Train Loss: 0.3144, Train Acc: 0.8730, Val Acc: 0.7767
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 0.5894, Train Acc: 0.7084, Val Acc: 0.7523
# Epoch 2, Train Loss: 0.3323, Train Acc: 0.8734, Val Acc: 0.7439
# Epoch 3, Train Loss: 0.2062, Train Acc: 0.9308, Val Acc: 0.7233
# Epoch 4, Train Loss: 0.1806, Train Acc: 0.9475, Val Acc: 0.7214
# Early stopping
# Training with lr=0.01, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 1.3517, Train Acc: 0.7052, Val Acc: 0.6557
# Epoch 2, Train Loss: 0.2986, Train Acc: 0.8916, Val Acc: 0.7402
# Epoch 3, Train Loss: 0.1924, Train Acc: 0.9361, Val Acc: 0.7561
# Epoch 4, Train Loss: 0.1527, Train Acc: 0.9570, Val Acc: 0.7542
# Epoch 5, Train Loss: 0.1104, Train Acc: 0.9682, Val Acc: 0.7533
# Epoch 6, Train Loss: 0.1494, Train Acc: 0.9695, Val Acc: 0.7674
# Epoch 7, Train Loss: 0.1277, Train Acc: 0.9754, Val Acc: 0.7373
# Epoch 8, Train Loss: 0.1133, Train Acc: 0.9776, Val Acc: 0.7430
# Epoch 9, Train Loss: 0.1240, Train Acc: 0.9822, Val Acc: 0.7411
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6898, Train Acc: 0.5308, Val Acc: 0.5976
# Epoch 2, Train Loss: 0.6677, Train Acc: 0.6093, Val Acc: 0.6829
# Epoch 3, Train Loss: 0.6433, Train Acc: 0.6652, Val Acc: 0.6951
# Epoch 4, Train Loss: 0.6119, Train Acc: 0.7059, Val Acc: 0.7101
# Epoch 5, Train Loss: 0.5818, Train Acc: 0.7159, Val Acc: 0.7242
# Epoch 6, Train Loss: 0.5526, Train Acc: 0.7404, Val Acc: 0.7364
# Epoch 7, Train Loss: 0.5315, Train Acc: 0.7445, Val Acc: 0.7355
# Epoch 8, Train Loss: 0.5073, Train Acc: 0.7604, Val Acc: 0.7448
# Epoch 9, Train Loss: 0.4975, Train Acc: 0.7637, Val Acc: 0.7514
# Epoch 10, Train Loss: 0.4869, Train Acc: 0.7702, Val Acc: 0.7486
# Epoch 11, Train Loss: 0.4752, Train Acc: 0.7787, Val Acc: 0.7467
# Epoch 12, Train Loss: 0.4652, Train Acc: 0.7860, Val Acc: 0.7542
# Epoch 13, Train Loss: 0.4561, Train Acc: 0.7897, Val Acc: 0.7552
# Epoch 14, Train Loss: 0.4468, Train Acc: 0.7984, Val Acc: 0.7570
# Epoch 15, Train Loss: 0.4443, Train Acc: 0.7991, Val Acc: 0.7636
# Epoch 16, Train Loss: 0.4363, Train Acc: 0.8011, Val Acc: 0.7655
# Epoch 17, Train Loss: 0.4276, Train Acc: 0.8080, Val Acc: 0.7692
# Epoch 18, Train Loss: 0.4221, Train Acc: 0.8136, Val Acc: 0.7711
# Epoch 19, Train Loss: 0.4115, Train Acc: 0.8226, Val Acc: 0.7730
# Epoch 20, Train Loss: 0.4081, Train Acc: 0.8172, Val Acc: 0.7720
# Training with lr=0.01, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.5467, Train Acc: 0.7338, Val Acc: 0.7674
# Epoch 2, Train Loss: 0.2451, Train Acc: 0.9045, Val Acc: 0.7561
# Epoch 3, Train Loss: 0.1050, Train Acc: 0.9641, Val Acc: 0.7514
# Epoch 4, Train Loss: 0.0640, Train Acc: 0.9803, Val Acc: 0.7692
# Epoch 5, Train Loss: 0.0580, Train Acc: 0.9829, Val Acc: 0.7223
# Epoch 6, Train Loss: 0.0807, Train Acc: 0.9816, Val Acc: 0.7336
# Epoch 7, Train Loss: 0.1844, Train Acc: 0.9644, Val Acc: 0.7373
# Early stopping
# Training with lr=0.01, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 0.9215, Train Acc: 0.6755, Val Acc: 0.6182
# Epoch 2, Train Loss: 0.3268, Train Acc: 0.8679, Val Acc: 0.7505
# Epoch 3, Train Loss: 0.1518, Train Acc: 0.9436, Val Acc: 0.6679
# Epoch 4, Train Loss: 0.0990, Train Acc: 0.9639, Val Acc: 0.7514
# Epoch 5, Train Loss: 0.0969, Train Acc: 0.9713, Val Acc: 0.7176
# Epoch 6, Train Loss: 0.0757, Train Acc: 0.9753, Val Acc: 0.7280
# Epoch 7, Train Loss: 0.0858, Train Acc: 0.9794, Val Acc: 0.7129
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.5675, Train Acc: 0.6980, Val Acc: 0.5056
# Epoch 2, Train Loss: 0.4821, Train Acc: 0.7695, Val Acc: 0.6951
# Epoch 3, Train Loss: 0.4294, Train Acc: 0.7998, Val Acc: 0.5507
# Epoch 4, Train Loss: 0.3896, Train Acc: 0.8252, Val Acc: 0.5666
# Epoch 5, Train Loss: 0.3283, Train Acc: 0.8603, Val Acc: 0.7514
# Epoch 6, Train Loss: 0.2902, Train Acc: 0.8771, Val Acc: 0.7355
# Epoch 7, Train Loss: 0.2424, Train Acc: 0.8987, Val Acc: 0.5713
# Epoch 8, Train Loss: 0.2183, Train Acc: 0.9103, Val Acc: 0.5807
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 61.1708, Train Acc: 0.5016, Val Acc: 0.4962
# Epoch 2, Train Loss: 166.8173, Train Acc: 0.5055, Val Acc: 0.5019
# Epoch 3, Train Loss: 297.8010, Train Acc: 0.5149, Val Acc: 0.5122
# Epoch 4, Train Loss: 151.7817, Train Acc: 0.5178, Val Acc: 0.5000
# Epoch 5, Train Loss: 149.9067, Train Acc: 0.5159, Val Acc: 0.5056
# Epoch 6, Train Loss: 100.4200, Train Acc: 0.5372, Val Acc: 0.5075
# Early stopping
# Training with lr=0.1, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 83.1714, Train Acc: 0.5036, Val Acc: 0.4934
# Epoch 2, Train Loss: 61.5612, Train Acc: 0.4998, Val Acc: 0.5084
# Epoch 3, Train Loss: 45.8583, Train Acc: 0.5197, Val Acc: 0.5009
# Epoch 4, Train Loss: 29.6297, Train Acc: 0.5120, Val Acc: 0.5056
# Epoch 5, Train Loss: 37.6604, Train Acc: 0.5374, Val Acc: 0.5056
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.5777, Train Acc: 0.6859, Val Acc: 0.7420
# Epoch 2, Train Loss: 0.4808, Train Acc: 0.7691, Val Acc: 0.7598
# Epoch 3, Train Loss: 0.4349, Train Acc: 0.7966, Val Acc: 0.7749
# Epoch 4, Train Loss: 0.3942, Train Acc: 0.8189, Val Acc: 0.7805
# Epoch 5, Train Loss: 0.3537, Train Acc: 0.8403, Val Acc: 0.7139
# Epoch 6, Train Loss: 0.3152, Train Acc: 0.8632, Val Acc: 0.7786
# Epoch 7, Train Loss: 0.2860, Train Acc: 0.8783, Val Acc: 0.6735
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=Adam
# Epoch 1, Train Loss: 21.2397, Train Acc: 0.4995, Val Acc: 0.5028
# Epoch 2, Train Loss: 92.8827, Train Acc: 0.5145, Val Acc: 0.5094
# Epoch 3, Train Loss: 91.7160, Train Acc: 0.5123, Val Acc: 0.4944
# Epoch 4, Train Loss: 55.3087, Train Acc: 0.5118, Val Acc: 0.5009
# Epoch 5, Train Loss: 33.9928, Train Acc: 0.5249, Val Acc: 0.5009
# Early stopping
# Training with lr=0.1, batch_size=32, optimizer=RMSprop
# Epoch 1, Train Loss: 301.5105, Train Acc: 0.5363, Val Acc: 0.5206
# Epoch 2, Train Loss: 29.8714, Train Acc: 0.5599, Val Acc: 0.5131
# Epoch 3, Train Loss: 26.2707, Train Acc: 0.5385, Val Acc: 0.4991
# Epoch 4, Train Loss: 21.8776, Train Acc: 0.5393, Val Acc: 0.4906
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6107, Train Acc: 0.6550, Val Acc: 0.7120
# Epoch 2, Train Loss: 0.5077, Train Acc: 0.7490, Val Acc: 0.7692
# Epoch 3, Train Loss: 0.4631, Train Acc: 0.7822, Val Acc: 0.6201
# Epoch 4, Train Loss: 0.4357, Train Acc: 0.7940, Val Acc: 0.6735
# Epoch 5, Train Loss: 0.4024, Train Acc: 0.8200, Val Acc: 0.6360
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 8.0792, Train Acc: 0.5081, Val Acc: 0.4991
# Epoch 2, Train Loss: 24.3684, Train Acc: 0.5170, Val Acc: 0.5000
# Epoch 3, Train Loss: 37.4988, Train Acc: 0.5197, Val Acc: 0.5066
# Epoch 4, Train Loss: 33.6381, Train Acc: 0.5183, Val Acc: 0.5000
# Epoch 5, Train Loss: 24.7242, Train Acc: 0.5324, Val Acc: 0.5066
# Epoch 6, Train Loss: 29.1799, Train Acc: 0.5342, Val Acc: 0.5075
# Epoch 7, Train Loss: 8.9157, Train Acc: 0.5393, Val Acc: 0.4991
# Epoch 8, Train Loss: 14.2078, Train Acc: 0.5188, Val Acc: 0.5094
# Epoch 9, Train Loss: 14.1507, Train Acc: 0.5291, Val Acc: 0.5094
# Epoch 10, Train Loss: 12.4287, Train Acc: 0.5379, Val Acc: 0.5075
# Epoch 11, Train Loss: 16.4417, Train Acc: 0.5307, Val Acc: 0.5047
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 235.6601, Train Acc: 0.5326, Val Acc: 0.5150
# Epoch 2, Train Loss: 12.3304, Train Acc: 0.5858, Val Acc: 0.5422
# Epoch 3, Train Loss: 15.2092, Train Acc: 0.5860, Val Acc: 0.5432
# Epoch 4, Train Loss: 10.5875, Train Acc: 0.5858, Val Acc: 0.5338
# Epoch 5, Train Loss: 7.5537, Train Acc: 0.5816, Val Acc: 0.5066
# Epoch 6, Train Loss: 9.2978, Train Acc: 0.5687, Val Acc: 0.5047
# Early stopping
# Best Validation Accuracy: 0.799249530956848
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'RMSprop'}

# %%
best_hyperparams_CNN = best_hyperparams

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_CNN['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_CNN = CNNModel(embedding_matrix_cosine_sim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_CNN['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
elif best_hyperparams_CNN['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
elif best_hyperparams_CNN['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])

best_model_CNN, train_losses, train_accuracies, val_accuracies = train_model(best_model_CNN, train_loader, validation_loader,
                                                                             best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5045, Train Acc: 0.7525, Val Acc: 0.7842
# Epoch 2, Train Loss: 0.3153, Train Acc: 0.8652, Val Acc: 0.7927
# Epoch 3, Train Loss: 0.1823, Train Acc: 0.9327, Val Acc: 0.7908
# Epoch 4, Train Loss: 0.0914, Train Acc: 0.9706, Val Acc: 0.7917
# Epoch 5, Train Loss: 0.0414, Train Acc: 0.9878, Val Acc: 0.7120
# Early stopping

# %%
epochs_cnn = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_cnn, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_CNN, test_loader)
test_accuracies['CNN'] = test_acc
print(f'Test Accuracy (CNN): {test_acc:.4f}')
# Out:
# Test Accuracy (CNN): 0.7411

# %% [markdown]
# ### (e) Describe your final improvement strategy in Part 3.5. Report the accuracy on the test set using your improved model.

# %% [markdown]
# ### Ensemble Methods

# %% [markdown]
# This setup aggregates the model predictions by averaging the class probabilities across each model, then assigns the final prediction based on the highest average probability. This approach should increase overall stability and potentially improve the test accuracy of your sentiment classification task by leveraging the diverse perspectives of different models.

# %%
def ensemble_predict(models, data_loader):
    all_probs = []

    # Collect prediction probabilities from each model
    for model in models:
        model.eval()  # Set to evaluation mode
        model_probs = []
        with torch.no_grad():
            for inputs, _ in data_loader:
                inputs = inputs.to(device)
                outputs = model(inputs)
                model_probs.append(torch.softmax(outputs, dim=1).cpu().numpy())
        all_probs.append(np.vstack(model_probs))

    # Average the probabilities across models
    avg_probs = np.mean(all_probs, axis=0)
    final_preds = np.argmax(avg_probs, axis=1)
    
    return final_preds

# %%
def compute_ensemble_accuracy(models, test_loader, test_labels):
    # Get ensemble predictions
    ensemble_preds = ensemble_predict(models, test_loader)

    # Calculate accuracy
    accuracy = np.mean(ensemble_preds == test_labels.cpu().numpy())
    print(f'Test Accuracy (Ensemble): {accuracy:.4f}')
    
    return accuracy

# %%
trained_models = [best_model_biGRU, best_model_OOV_update, best_model_biLSTM, best_model_RNN_update]

# Compute ensemble accuracy on the test set
test_acc = compute_ensemble_accuracy(trained_models, test_loader, test_labels)
test_accuracies['Ensemble'] = test_acc
# Out:
# Test Accuracy (Ensemble): 0.8208

# %% [markdown]
# From the test accuracies, we see that when employing **ensemble method with soft voting (probability averaging)** gives us a higher test accuracy compared to the test accuracies of each individual model.

# %% [markdown]
# ###  (f) Compare the results across different solutions above and describe your observations with possible discussions.

# %%
test_accuracies
# Out:
# {'RNN Last Hidden State': 0.5159474671669794,
#  'RNN Max Pooling': 0.7720450281425891,
#  'RNN Average Pooling': 0.7673545966228893,
#  'RNN (Update Word Embeddings)': 0.7814258911819888,
#  'RNN (Handle OOV)': 0.7804878048780488,
#  'RNN (Handle OOV with Word Embeddings Update)': 0.8058161350844277,
#  'biLSTM': 0.8039399624765479,
#  'biGRU': 0.8142589118198874,
#  'CNN': 0.7410881801125704,
#  'Ensemble': 0.8208255159474672}
