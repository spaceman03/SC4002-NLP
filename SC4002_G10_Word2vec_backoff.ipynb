# %% [markdown]
# # Part 0: Data Preparation

# %%
# !pip install datasets
# !pip install nltk
# !pip install datasets
# !pip install sentencepiece
# !pip install fasttext
# !pip install fuzzywuzzy
# !pip install jellyfish
# !pip install --upgrade pyspellchecker
# !pip install spacy
# !pip install Metaphone
# !pip install symspellpy

# %%
# !pip install fuzzy

# %%
from datasets import load_dataset
dataset = load_dataset("rotten_tomatoes")
train_dataset = dataset['train']
validation_dataset = dataset['validation']
test_dataset = dataset['test']

# %% [markdown]
# # Part 1: Preparing Word Embeddings

# %% [markdown]
# As the first step of building your model, you need to prepare the word embeddings to form the input layer of your model. You are required to choose only from **Word2vec** or **Glove** to initialize your word embedding matrix. The word embedding matrix stores the pre-trained word vectors (taken from Word2vec or Glove) where each row corresponds to a vector for a specific word in the vocabulary formed from your task dataset.set.

# %%
import gensim.downloader
import matplotlib.pyplot as plt
import nltk
import jellyfish
import logging
import numpy as np
import sentencepiece as spm
import tensorflow as tf
from tensorflow.keras import layers
from gensim.models import KeyedVectors
import gensim.downloader as api
import re
import requests

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from symspellpy.symspellpy import SymSpell, Verbosity

nltk.download('punkt')
# Out:
# 2024-11-06 12:36:56.140147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-06 12:36:56.150178: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-06 12:36:56.150199: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 12:36:56.156384: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-06 12:36:56.592566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to /home/eddyckq/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Question 1. Word Embedding

# %% [markdown]
# ### (a) What is the size of the vocabulary formed from your training data?

# %%
tokens = []
tokenized_sentences = [nltk.tokenize.word_tokenize(sentence['text'].lower()) for sentence in train_dataset]

for sentence in train_dataset:
    tokens.extend(nltk.tokenize.word_tokenize(sentence['text'].lower()))

print ('Number of tokens: '+ str(len(tokens)))
# Out:
# Number of tokens: 183968

# %%
word2vec_model = gensim.downloader.load('word2vec-google-news-300')
embedding_dim = word2vec_model.vector_size
print("Embedding dimension:", embedding_dim)
# Out:
# Embedding dimension: 300

# %%
# List of all distinct words found in the tokens list
vocab = list(set(tokens))
vocab_size = len(vocab)
print ('Number of token types (Vocabulary Size): '+ str(vocab_size))
# Out:
# Number of token types (Vocabulary Size): 18029

# %% [markdown]
# (a) The size of vocabulary formed from the training data is 18029.

# %% [markdown]
# ### (b) We use OOV (out-of-vocabulary) to refer to those words appeared in the training data but  not in the Word2vec (or Glove) dictionary. How many OOV words exist in your training data?

# %%
# Initialize the embedding matrix
embedding_matrix = np.zeros((vocab_size, embedding_dim))
oov_words = []

# Map vocabulary to embedding matrix
word_to_idx = {word: idx for idx, word in enumerate(vocab)}

for word, idx in word_to_idx.items():
    if word in word2vec_model:
        embedding_matrix[idx] = word2vec_model[word]
    else:
        # Count OOV words
        oov_words.append(word)

# OOV words count
oov_count = len(oov_words)
print("Number of OOV words:", oov_count)
# Out:
# Number of OOV words: 3612

# %% [markdown]
# (b) There are **3612** OOV words in the training data.

# %% [markdown]
# ### (c) The existence of the OOV words is one of the well-known limitations of Word2vec (or Glove). Without using any transformer-based language models (e.g., BERT, GPT, T5), what do you think is the best strategy to mitigate such limitation? Implement your solution in your source code. Show the corresponding code snippet.

# %% [markdown]
# #### Method: Back-off

# %% [markdown]
# 1. Word Preprocessing: Split compound words with dashes/hyphens (e.g., "super-man" to "super" and "man") and remove punctuation.
# 2. Spelling Correction (SymSpell): Apply the Symmetric Delete Spelling Correction algorithm for fast, efficient spelling corrections.
# 3. Direct Word2Vec Lookup: Check each preprocessed and corrected token in Word2Vec, returning the longest match for maximum semantic relevance.
# 4. Byte Pair Encoding (BPE): For tokens not found in Word2Vec, break them into subwords using Byte Pair Encoding.
# 5. Subword Lookup in Word2Vec: Check each BPE subword in Word2Vec, returning the longest valid subword if found.
# 6. Stopword Handling: Skip processing stopwords entirely, returning None for them as they generally lack semantic value.

# %% [markdown]
# (c) Explanation
# Word Preprocessing: This initial step simplifies complex tokens by removing unnecessary punctuation and splitting compound words. By handling these irregularities early, the algorithm can better match tokens with the Word2Vec vocabulary. This preprocessing also reduces complexity in later stages by standardizing tokens, which improves the accuracy and efficiency of matching.
#
# SymSpell for Spelling Correction: SymSpell is a highly efficient spelling correction algorithm based on the symmetric delete approach. Unlike traditional spell checkers, which generate all possible edit variations, SymSpell only generates deletions, making it computationally faster. SymSpell’s design ensures that even when dealing with a large dictionary or a high edit distance, the lookup time remains minimal. This efficiency is crucial when handling large text corpora or applications requiring real-time processing.
#
# Direct Word2Vec Lookup: After preprocessing and spelling correction, each token is checked directly against Word2Vec, a computationally lightweight, vector-based word embedding model. Unlike models like BERT or Transformers that involve heavy attention mechanisms and complex architectures, Word2Vec relies on efficient vector comparisons for word lookup. By prioritizing the longest matching word in Word2Vec, the method retains more semantic content with minimal computation.
#
# Byte Pair Encoding (BPE): BPE breaks down unknown tokens into subword units, making it effective for handling out-of-vocabulary (OOV) tokens. Unlike Transformer-based models, where subwords are used within an attention-based structure, BPE here functions solely as a fallback strategy to approximate word meanings without heavy computation. This avoids the high memory and processing requirements of transformers by focusing only on efficient token decomposition.
#
# Subword Lookup: After BPE segmentation, each subword is checked in Word2Vec, with the algorithm selecting the longest valid subword available. By checking for subword matches in Word2Vec, the method preserves as much meaning as possible while avoiding the extensive computational overhead associated with Transformers’ multi-layered attention calculations. This ensures a balance between coverage and efficiency, making it suitable for large-scale or real-time applications.
#
# Stopword Handling: Stopwords are excluded from processing because they contribute little semantic value. This decision not only saves processing time but also reduces the load on memory and lookup functions. By avoiding unnecessary operations on stopwords, the method further optimizes performance.
#
# Why This Approach is Efficient
# This backoff method is designed with efficiency in mind, leveraging lightweight preprocessing steps, SymSpell, Word2Vec, and BPE, which all require significantly less computational power than Transformer models like BERT. Transformer-based models rely on multi-layered self-attention mechanisms to capture relationships between words, which is computationally expensive. Each layer in a Transformer processes tokens with high-dimensional matrices, requiring substantial GPU/TPU power and memory.
#
# In contrast, this approach does not involve any attention mechanisms or heavy matrix operations. Word2Vec embeddings allow for quick, straightforward vector comparisons, and SymSpell’s delete-only approach drastically reduces the number of candidates to process for spelling corrections. Furthermore, using BPE solely as a token decomposition method (without embedding these subwords in a Transformer context) further reduces computational load.
#
# This efficient design makes it suitable for applications where speed and lower resource consumption are crucial, such as real-time text processing, mobile applications, or low-resource environments.

# %%
# Load the dataset
train_texts = dataset['train']['text']

# Save the train texts to a file
with open("train_texts.txt", "w", encoding="utf-8") as f:
    for line in train_texts:
        f.write(line + "\n")

# %%
spm.SentencePieceTrainer.train(
    input="train_texts.txt",
    model_prefix="bpe_model",
    vocab_size=18029,
    model_type="bpe"
)

# %%
sp = spm.SentencePieceProcessor(model_file="bpe_model.model")

# Example usage
encoded_text = sp.encode("badly-rendered", out_type=str)
print(encoded_text)  # Output will be a list of subword tokens
# Out:
# ['▁badly', '-', 'rendered']

# %%
nltk.download('stopwords')

# Load English stopwords from nltk
stopword_set = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eddyckq/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopword_set
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# URLs for the pre-built dictionaries from the SymSpell GitHub repository
frequency_dict_url = "https://raw.githubusercontent.com/mammothb/symspellpy/master/symspellpy/frequency_dictionary_en_82_765.txt"
bigram_dict_url = "https://raw.githubusercontent.com/mammothb/symspellpy/master/symspellpy/frequency_bigramdictionary_en_243_342.txt"

# File names for saving the dictionaries
frequency_dict_filename = "frequency_dictionary_en_82_765.txt"
bigram_dict_filename = "frequency_bigramdictionary_en_243_342.txt"

# Function to download a file from a URL
def download_file(url, filename):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(filename, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)
        print(f"Downloaded {filename}")
    else:
        print(f"Failed to download {filename}")

# Download the frequency dictionary
download_file(frequency_dict_url, frequency_dict_filename)

# Download the bigram dictionary
download_file(bigram_dict_url, bigram_dict_filename)
# Out:
# Downloaded frequency_dictionary_en_82_765.txt
# Downloaded frequency_bigramdictionary_en_243_342.txt

# %%
# Initialize SymSpell
max_edit_distance = 2
prefix_length = 7
sym_spell = SymSpell(max_edit_distance, prefix_length)

# Load the dictionaries from the local file path
frequency_dictionary_path = "frequency_dictionary_en_82_765.txt"
bigram_dictionary_path = "frequency_bigramdictionary_en_243_342.txt"

# Load the frequency dictionary
sym_spell.load_dictionary(frequency_dictionary_path, term_index=0, count_index=1)

# Optionally load the bigram dictionary for improved correction suggestions
sym_spell.load_bigram_dictionary(bigram_dictionary_path, term_index=0, count_index=2)
# Out:
# True

# %%
# Initialize SymSpell with maximum edit distance and prefix length
def initialize_symspell(max_edit_distance=2, prefix_length=7):
    sym_spell = SymSpell(max_edit_distance, prefix_length)
    # Load the frequency dictionary
    frequency_dict_path = "frequency_dictionary_en_82_765.txt"
    sym_spell.load_dictionary(frequency_dict_path, term_index=0, count_index=1)
    return sym_spell

# Function to get the best correction
def get_best_correction(word, sym_spell):
    # Get the highest-frequency suggestion for the word
    suggestions = sym_spell.lookup(word, Verbosity.CLOSEST, max_edit_distance=2)
    # Return the term with the highest frequency if suggestions are found
    if suggestions:
        return suggestions[0].term
    else:
        return word  # Return the original word if no suggestions are found

# Example usage:
# Initialize SymSpell (do this only once at the start of your program)
sym_spell = initialize_symspell()

# Get the best correction for a misspelled word
misspelled_word = "diferença"
best_correction = get_best_correction(misspelled_word, sym_spell)
print(f"Best correction for '{misspelled_word}': {best_correction}")
# Out:
# Best correction for 'diferença': diferença

# %%
def preprocess_token(token):
    # Replace separators like '-' or '/' with whitespace
    token = re.sub(r"[-/]", " ", token)
    # Remove underscores and all other punctuation
    token = re.sub(r"[^\w\s]", "", token)
    print(f"Preprocessed token: {token}")
    return token

def find_best_valid_subword(subwords, model):
    longest_valid_subword = None
    for subword in subwords:
        if subword in model and (longest_valid_subword is None or len(subword) > len(longest_valid_subword)):
            longest_valid_subword = subword
    print(f"Best valid subword found: {longest_valid_subword}")
    return longest_valid_subword

def find_longest_match_in_model(tokens, model):
    # Check each token against the model and return the longest valid match
    longest_match = None
    for token in tokens:
        if token in model and (longest_match is None or len(token) > len(longest_match)):
            longest_match = token
    print(f"Longest match in model: {longest_match}")
    return longest_match


def find_replacement_word(token, model, sp,sym_spell):
    print(f"\nProcessing token: '{token}'")

    if token.lower() in stopword_set:
        print(f"'{token}' is a stopword; skipping replacement.")
        return None

    # Preprocess token to handle punctuation and separators
    cleaned_token = preprocess_token(token)
    # Split cleaned token into individual words if it's a multi-token string
    individual_tokens = cleaned_token.split()
    individual_tokens = [
    get_best_correction(word, sym_spell) if get_best_correction(word, sym_spell) else word for word in individual_tokens]

    print(f"Individual tokens: {individual_tokens}")

    # 1. Direct model check for each individual token
    longest_match = find_longest_match_in_model(individual_tokens, model)
    if longest_match:
        return longest_match

    # 2. Stem each token and check in the model
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(t) for t in individual_tokens]
    print(f"Stemmed tokens: {stemmed_tokens}")

    longest_match = find_longest_match_in_model(stemmed_tokens, model)
    if longest_match:
        return longest_match

    # 3. Encode each individual token to get subwords and check for the best valid subword
    subwords = []
    for t in individual_tokens:
        try:
            token_subwords = sp.encode(t, out_type=str)
            print(f"Subwords for '{t}': {token_subwords}")
            subwords.extend(token_subwords)
        except Exception as e:
            print(f"Error in encoding subwords for '{t}': {e}")

    # Find the best valid subword in the model
    longest_subword = find_best_valid_subword(subwords, model)
    if longest_subword:
        return longest_subword
    print("No valid replacement found.")
    return None


# Initialize SentencePiece model
sp = spm.SentencePieceProcessor(model_file="bpe_model.model")

# %%
# Sample token to find replacement for
token = "leopar"

# Use the function to find a replacement
replacement = find_replacement_word(token, word2vec_model, sp,sym_spell)
print("Replacement word:", replacement)
# Out:
# Processing token: 'leopar'
# Preprocessed token: leopar
# Individual tokens: ['leopard']
# Longest match in model: leopard
# Replacement word: leopard

# %%
# Sample token stopword
token = "a"
#the stem words shou
# Use the function to find a replacement
replacement = find_replacement_word(token, word2vec_model, sp,sym_spell)
print("Replacement word:", replacement)
# Out:
# Processing token: 'a'
# 'a' is a stopword; skipping replacement.
# Replacement word: None

# %% [markdown]
# # Part 2: Model Training & Evaluation - RNN

# %% [markdown]
# Now with the pretrained word embeddings acquired from Part 1 and the dataset acquired from Part 0, you need to train a deep learning model for sentiment classification using the training set, conforming to these requirements:
# - Use the pretrained word embeddings from Part 1 as inputs; do not update them during training (they are “frozen”).
# - Design a simple recurrent neural network (RNN), taking the input word embeddings, and predicting a sentiment label for each sentence. To do that, you need to consider how to aggregate the word representations to represent a sentence.
# - Use the validation set to gauge the performance of the model for each epoch during training. You are required to use **accuracy** as the performance metric during validation and evaluation.
# - Use the mini-batch strategy during training. You may choose any preferred optimizer (e.g., SGD, Adagrad, Adam, RMSprop). Be careful when you choose your initial learning rate and mini-batch size. (You should use the validation set to determine the optimal configuration.) Train the model until the **accuracy** score on the validation set is not increasing for a few epochs.
# - Evaluate your trained model on the test dataset, observing the **accuracy** score.

# %% [markdown]
# ## Question 2: RNN

# %% [markdown]
# ### (a) Report the final configuration of your best model, namely the number of training epochs, learning rate, optimizer, batch size.

# %% [markdown]
# ### (b) Report the **accuracy** score on the test set, as well as the accuracy score on the validation  set for each epoch during training.

# %% [markdown]
# ### (c) RNNs produce a hidden vector for each word, instead of the entire sentence. Which methods have you tried in deriving the final sentence representation to perform sentiment classification? Describe all the strategies you have implemented, together with their accuracy scores on the test set.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
from torch.nn.utils.rnn import pad_sequence

# %%
# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print(f"Using device: {device}")
# device = 'cpu'

# %%
# Initialize an empty dictionary to store test accuracies
test_accuracies = {}

# %%
max_length = max(len(item) for item in tokens)

# %%
def prepare_data(dataset, word_to_idx, max_len):
    sequences = []
    labels = []

    for sentence in dataset:
        tokenized = nltk.tokenize.word_tokenize(sentence['text'].lower())
        indices = [word_to_idx[word] for word in tokenized if word in word_to_idx]
        sequences.append(torch.tensor(indices[:max_len]))  # Trim to max_len
        labels.append(sentence['label'])

    # Pad sequences to ensure all are the same length
    padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=0)

    # Convert labels to tensor
    labels = torch.tensor(labels)

    return padded_sequences, labels

# %% [markdown]
# (c) For deriving sentence representations, we implemented different strategies:
# - **Last Hidden State**: Use the last hidden state of the RNN.
# - **Max Pooling**: Take the maximum hidden state across all words.
# - **Average Pooling**: Average the hidden states across all words.

# %%
class LastHiddenRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(LastHiddenRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Aggregate using the last hidden state
        last_hidden = hidden[-1]
        output = self.fc(last_hidden)
        return output

class MaxPoolingRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(MaxPoolingRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Max pooling over all hidden states
        max_pooled, _ = torch.max(rnn_output, dim=1)
        output = self.fc(max_pooled)
        return output

class AveragePoolingRNNModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(AveragePoolingRNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=True).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, _ = self.rnn(embedded)

        # Average pooling over the hidden states
        mean_pooled = rnn_output.mean(dim=1)  # Take the mean across the sequence length dimension
        output = self.fc(mean_pooled)  # Pass through the fully connected layer
        return output

# %%
# Training function
def train_one_epoch(model, train_loader, optimizer, criterion):
    model.train()  # Set model to training mode
    train_loss = 0
    train_correct = 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to device
        optimizer.zero_grad()  # Clear gradients
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights

        # Accumulate loss and accuracy
        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    # Calculate average accuracy and loss
    train_acc = train_correct / total_train
    train_loss /= len(train_loader)  # Average loss per batch

    return train_loss, train_acc

# Validation function
def evaluate_model(model, loader):
    model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():  # Disable gradient computation for validation
        for inputs, labels in loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    return correct / total  # Return validation accuracy

# Training loop with validation
def train_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience=3):
    best_val_acc = 0
    epochs_no_improve = 0

    train_losses = []
    train_accuracies = []
    val_accuracies = []

    model = model.to(device)

    for epoch in range(epochs):
        # Training step
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Validation step
        val_acc = evaluate_model(model, validation_loader)
        val_accuracies.append(val_acc)

        # Print training and validation results
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}')

        # Early stopping logic
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            epochs_no_improve = 0
            best_model = model.state_dict()  # Save best model
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print("Early stopping")
            break

    model.load_state_dict(best_model)  # Load the best model weights

    return model, train_losses, train_accuracies, val_accuracies

# %%
# Define hyperparameter search space
learning_rates = [0.001, 0.005, 0.01, 0.1]
batch_sizes = [16, 32, 64]
optimizers = ['SGD', 'Adam', 'RMSprop','Adagrad']

# %%
def train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience):
    # Training the model (uses functions defined earlier for training and evaluation)
    model, train_losses, train_accuracies, val_accuracies = train_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)

    # Get best validation accuracy
    best_val_acc = max(val_accuracies)

    return best_val_acc, train_losses, train_accuracies, val_accuracies

# %%
def run_grid_search(model_class, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                    validation_sequences, validation_labels, criterion, epochs, patience):

    best_val_acc = 0
    best_hyperparams = {}

    # Prepare datasets
    train_data = TensorDataset(train_sequences.to(device), train_labels.to(device))
    validation_data = TensorDataset(validation_sequences.to(device), validation_labels.to(device))

    for lr in learning_rates:
        for batch_size in batch_sizes:
            for opt in optimizers:
                print(f"Training with lr={lr}, batch_size={batch_size}, optimizer={opt}")

                # Set up DataLoader with the current batch size
                train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
                validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)

                # Initialize a new model for each set of hyperparameters
                model = model_class(embedding_matrix=embedding_matrix, hidden_dim=hidden_dim, output_dim=output_dim)  # Reinitialize model
                model = model.to(device)

                # Choose optimizer
                if opt == 'SGD':
                    optimizer = optim.SGD(model.parameters(), lr=lr)
                elif opt == 'Adam':
                    optimizer = optim.Adam(model.parameters(), lr=lr)
                elif opt == 'RMSprop':
                    optimizer = optim.RMSprop(model.parameters(), lr=lr)
                elif opt == 'Adagrad':
                    optimizer = optim.Adagrad(model.parameters(), lr=lr)

                # Train and evaluate the model
                val_acc, _, _, _ = train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)


                # Track the best configuration based on validation accuracy
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_hyperparams = {'lr': lr, 'batch_size': batch_size, 'optimizer': opt}

    print(f"Best Validation Accuracy: {best_val_acc}")
    print(f"Best Hyperparameters: {best_hyperparams}")

    return best_hyperparams

# %%
# Prepare the train, validation, and test datasets
train_sequences, train_labels = prepare_data(train_dataset, word_to_idx, max_length)
validation_sequences, validation_labels = prepare_data(validation_dataset, word_to_idx, max_length)
test_sequences, test_labels = prepare_data(test_dataset, word_to_idx, max_length)

# %%
train_sequences = train_sequences.to(device)
train_labels = train_labels.to(device)
validation_sequences = validation_sequences.to(device)
validation_labels = validation_labels.to(device)
test_sequences = test_sequences.to(device)
test_labels = test_labels.to(device)

# %%
# Plot accuracy scores
def plot_metrics(epochs, train_losses, train_accuracies, val_accuracies):
    # Epochs range
    epoch_range = range(1, epochs + 1)

    # Plot Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epoch_range, train_losses, label='Train Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Epoch vs Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epoch_range, train_accuracies, label='Train Accuracy')
    plt.plot(epoch_range, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Epoch vs Accuracy')
    plt.legend()

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) RNN Last Hidden State

# %%
# Call grid search
best_hyperparams_RNN_last = run_grid_search(LastHiddenRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                            validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6936, Train Acc: 0.4944, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.6938, Train Acc: 0.4952, Val Acc: 0.4869
# Epoch 3, Train Loss: 0.6939, Train Acc: 0.5013, Val Acc: 0.5047
# Epoch 4, Train Loss: 0.6934, Train Acc: 0.5096, Val Acc: 0.4859
# Epoch 5, Train Loss: 0.6931, Train Acc: 0.5110, Val Acc: 0.4831
# Epoch 6, Train Loss: 0.6934, Train Acc: 0.5000, Val Acc: 0.4850
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6974, Train Acc: 0.5079, Val Acc: 0.5019
# Epoch 2, Train Loss: 0.7201, Train Acc: 0.5029, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.7050, Train Acc: 0.5033, Val Acc: 0.4991
# Epoch 4, Train Loss: 0.7085, Train Acc: 0.4900, Val Acc: 0.4962
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7231, Train Acc: 0.4988, Val Acc: 0.5038
# Epoch 2, Train Loss: 0.7083, Train Acc: 0.5068, Val Acc: 0.5122
# Epoch 3, Train Loss: 0.7066, Train Acc: 0.5015, Val Acc: 0.5009
# Epoch 4, Train Loss: 0.7065, Train Acc: 0.5028, Val Acc: 0.5009
# Epoch 5, Train Loss: 0.7065, Train Acc: 0.4977, Val Acc: 0.5066
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adagrad
# Epoch 1, Train Loss: 0.6948, Train Acc: 0.4984, Val Acc: 0.5047
# Epoch 2, Train Loss: 0.6936, Train Acc: 0.5062, Val Acc: 0.4981
# Epoch 3, Train Loss: 0.6937, Train Acc: 0.4986, Val Acc: 0.5113
# Epoch 4, Train Loss: 0.6925, Train Acc: 0.5093, Val Acc: 0.5103
# Epoch 5, Train Loss: 0.6933, Train Acc: 0.5006, Val Acc: 0.5056
# Epoch 6, Train Loss: 0.6922, Train Acc: 0.5113, Val Acc: 0.5103
# Early stopping
# Training with lr=0.001, batch_size=32, optimizer=SGD
# Epoch 1, Train Loss: 0.
Val Acc: 0.5000
# Epoch 2, Train Loss: 0.9805, Train Acc: 0.5096, Val Acc: 0.5056
# Epoch 3, Train Loss: 0.8338, Train Acc: 0.4907, Val Acc: 0.4972
# Epoch 4, Train Loss: 0.7575, Train Acc: 0.5060, Val Acc: 0.5000
# Epoch 5, Train Loss: 0.7418, Train Acc: 0.5016, Val Acc: 0.5066
# Epoch 6, Train Loss: 0.7393, Train Acc: 0.5034, Val Acc: 0.5000
# Epoch 7, Train Loss: 0.7194, Train Acc: 0.5050, Val Acc: 0.5000
# Epoch 8, Train Loss: 0.7228, Train Acc: 0.5035, Val Acc: 0.5000
# Early stopping
# Best Validation Accuracy: 0.5450281425891182
# Best Hyperparameters: {'lr': 0.01, 'batch_size': 32, 'optimizer': 'Adagrad'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_last['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_last = LastHiddenRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_last['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])
elif best_hyperparams_RNN_last['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])
elif best_hyperparams_RNN_last['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])
elif best_hyperparams_RNN_last['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_RNN_last.parameters(), lr=best_hyperparams_RNN_last['lr'])

best_model_RNN_last, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_last, train_loader, validation_loader,
                                                                                  best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.7246, Train Acc: 0.5070, Val Acc: 0.5516
# Epoch 2, Train Loss: 0.6960, Train Acc: 0.5175, Val Acc: 0.5478
# Epoch 3, Train Loss: 0.6959, Train Acc: 0.5125, Val Acc: 0.5103
# Epoch 4, Train Loss: 0.6936, Train Acc: 0.5284, Val Acc: 0.5582
# Epoch 5, Train Loss: 0.6929, Train Acc: 0.5219, Val Acc: 0.4597
# Epoch 6, Train Loss: 0.6926, Train Acc: 0.5312, Val Acc: 0.5516
# Epoch 7, Train Loss: 0.6915, Train Acc: 0.5297, Val Acc: 0.5084
# Early stopping

# %%
epochs_LHS = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_LHS, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_last, test_loader)
test_accuracies['RNN Last Hidden State'] = test_acc
print(f'Test Accuracy (RNN Last Hidden State): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Last Hidden State): 0.4981

# %% [markdown]
# ### 2) RNN Max Pooling

# %%
# Call grid search
best_hyperparams_RNN_max = run_grid_search(MaxPoolingRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                           validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 23.7617, Train Acc: 0.5084, Val Acc: 0.5000
# Epoch 2, Train Loss: 14.3473, Train Acc: 0.4948, Val Acc: 0.5000
# Epoch 3, Train Loss: 12.4755, Train Acc: 0.5102, Val Acc: 0.5000
# Epoch 4, Train Loss: 13.4547, Train Acc: 0.4848, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adagrad
# Epoch 1, Train Loss: 1.3802, Train Acc: 0.5150, Val Acc: 0.5694
# Epoch 2, Train Loss: 0.7040, Train Acc: 0.5662, Val Acc: 0.5788
# Epoch 3, Train Loss: 0.6740, Train Acc: 0.5998, Val Acc: 0.6520
# Epoch 4, Train Loss: 0.6509, Train Acc: 0.6311, Val Acc: 0.5328
# Epoch 5, Train Loss: 0.6227, Train Acc: 0.6571, Val Acc: 0.5947
# Epoch 6, Train Loss: 0.5906, Train Acc: 0.6953, Val Acc: 0.7083
# Epoch 7, Train Loss: 0.5729, Train Acc: 0.7079, Val Acc: 0.6998
# Epoch 8, Train Loss: 0.5509, Train Acc: 0.7302, Val Acc: 0.7158
# Epoch 9, Train Loss: 0.5376, Train Acc: 0.7285, Val Acc: 0.7514
# Epoch 10, Train Loss: 0.5117, Train Acc: 0.7434, Val Acc: 0.7186
# Epoch 11, Train Loss: 0.5110, Train Acc: 0.7478, Val Acc: 0.7158
# Epoch 12, Train Loss: 0.5033, Train Acc: 0.7572, Val Acc: 0.6698
# Early stopping
# Best Validation Accuracy: 0.797373358348968
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'Adam'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_max['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_max = MaxPoolingRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_max['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])
elif best_hyperparams_RNN_max['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])
elif best_hyperparams_RNN_max['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])
elif best_hyperparams_RNN_max['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_RNN_max.parameters(), lr=best_hyperparams_RNN_max['lr'])

best_model_RNN_max, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_max, train_loader, validation_loader,
                                                                                 best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5469, Train Acc: 0.7169, Val Acc: 0.7561
# Epoch 2, Train Loss: 0.4697, Train Acc: 0.7766, Val Acc: 0.7448
# Epoch 3, Train Loss: 0.4436, Train Acc: 0.7938, Val Acc: 0.7814
# Epoch 4, Train Loss: 0.4277, Train Acc: 0.7994, Val Acc: 0.7767
# Epoch 5, Train Loss: 0.4127, Train Acc: 0.8142, Val Acc: 0.7674
# Epoch 6, Train Loss: 0.3957, Train Acc: 0.8231, Val Acc: 0.7842
# Epoch 7, Train Loss: 0.3864, Train Acc: 0.8311, Val Acc: 0.7805
# Epoch 8, Train Loss: 0.3601, Train Acc: 0.8436, Val Acc: 0.7936
# Epoch 9, Train Loss: 0.3471, Train Acc: 0.8475, Val Acc: 0.7871
# Epoch 10, Train Loss: 0.3337, Train Acc: 0.8537, Val Acc: 0.7927
# Epoch 11, Train Loss: 0.3184, Train Acc: 0.8653, Val Acc: 0.7824
# Early stopping

# %%
epochs_max = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_max, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_max, test_loader)
test_accuracies['RNN Max Pooling'] = test_acc
print(f'Test Accuracy (RNN Max Pooling): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Max Pooling): 0.7871

# %% [markdown]
# ### 3) RNN Average Pooling

# %%
# Call grid search
best_hyperparams_RNN_avg = run_grid_search(AveragePoolingRNNModel, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6938, Train Acc: 0.4852, Val Acc: 0.5066
# Epoch 2, Train Loss: 0.6935, Train Acc: 0.4930, Val Acc: 0.4916
# Epoch 3, Train Loss: 0.6933, Train Acc: 0.4988, Val Acc: 0.4944
# Epoch 4, Train Loss: 0.6931, Train Acc: 0.5077, Val Acc: 0.5253
# Epoch 5, Train Loss: 0.6928, Train Acc: 0.5141, Val Acc: 0.5291
# Epoch 6, Train Loss: 0.6927, Train Acc: 0.5118, Val Acc: 0.5310
# Epoch 7, Train Loss: 0.6925, Train Acc: 0.5317, Val Acc: 0.5403
# Epoch 8, Train Loss: 0.6923, Train Acc: 0.5413, Val Acc: 0.5750
# Epoch 9, Train Loss: 0.6920, Train Acc: 0.5569, Val Acc: 0.5826
# Epoch 10, Train Loss: 0.6919, Train Acc: 0.5685, Val Acc: 0.5863
# Epoch 11, Train Loss: 0.6917, Train Acc: 0.5727, Val Acc: 0.5619
# Epoch 12, Train Loss: 0.6915, Train Acc: 0.5699, Val Acc: 0.6126
# Epoch 13, Train Loss: 0.6913, Train Acc: 0.5898, Val Acc: 0.6313
# Epoch 14, Train Loss: 0.6911, Train Acc: 0.5979, Val Acc: 0.6004
# Epoch 15, Train Loss: 0.6908, Train Acc: 0.5896, Val Acc: 0.5872
# Epoch 16, Train Loss: 0.6906, Train Acc: 0.6083, Val Acc: 0.5854
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 0.8624, Train Acc: 0.5048, Val Acc: 0.5009
# Epoch 2, Train Loss: 0.7881, Train Acc: 0.5188, Val Acc: 0.5281
# Epoch 3, Train Loss: 0.7493, Train Acc: 0.5229, Val Acc: 0.5478
# Epoch 4, Train Loss: 0.7443, Train Acc: 0.5334, Val Acc: 0.5310
# Epoch 5, Train Loss: 0.7552, Train Acc: 0.5365, Val Acc: 0.5009
# Epoch 6, Train Loss: 0.7107, Train Acc: 0.5454, Val Acc: 0.5516
# Epoch 7, Train Loss: 0.7086, Train Acc: 0.5512, Val Acc: 0.5131
# Epoch 8, Train Loss: 0.7261, Train Acc: 0.5431, Val Acc: 0.5685
# Epoch 9, Train Loss: 0.7080, Train Acc: 0.5569, Val Acc: 0.5019
# Epoch 10, Train Loss: 0.7068, Train Acc: 0.5509, Val Acc: 0.5310
# Epoch 11, Train Loss: 0.7160, Train Acc: 0.5529, Val Acc: 0.5600
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 1.2085, Train Acc: 0.4914, Val Acc: 0.4953
# Epoch 2, Train Loss: 0.8011, Train Acc: 0.5076, Val Acc: 0.5009
# Epoch 3, Train Loss: 0.8161, Train Acc: 0.5101, Val Acc: 0.5403
# Epoch 4, Train Loss: 0.7973, Train Acc: 0.5175, Val Acc: 0.5188
# Epoch 5, Train Loss: 0.8169, Train Acc: 0.5305, Val Acc: 0.5600
# Epoch 6, Train Loss: 0.8170, Train Acc: 0.5324, Val Acc: 0.5028
# Epoch 7, Train Loss: 0.7853, Train Acc: 0.5445, Val Acc: 0.5356
# Epoch 8, Train Loss: 0.7477, Train Acc: 0.5556, Val Acc: 0.5178
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adagrad
# Epoch 1, Train Loss: 0.6881, Train Acc: 0.5498, Val Acc: 0.5732
# Epoch 2, Train Loss: 0.6691, Train Acc: 0.5801, Val Acc: 0.5722
# Epoch 3, Train Loss: 0.6617, Train Acc: 0.5859, Val Acc: 0.5685
# Epoch 4, Train Loss: 0.6582, Train Acc: 0.5931, Val Acc: 0.5835
# Epoch 5, Train Loss: 0.6563, Train Acc: 0.5966, Val Acc: 0.5619
# Epoch 6, Train Loss: 0.6556, Train Acc: 0.5892, Val Acc: 0.5788
# Epoch 7, Train Loss: 0.6526, Train Acc: 0.5996, Val Acc: 0.5966
# Epoch 8, Train Loss: 0.6477, Train Acc: 0.6088, Val Acc: 0.5929
# Epoch 9, Train Loss: 0.6487, Train Acc: 0.6107, Val Acc: 0.6060
# Epoch 10, Train Loss: 0.6500, Train Acc: 0.6098, Val Acc: 0.5816
# Epoch 11, Train Loss: 0.6447, Train Acc: 0.6183, Val Acc: 0.6023
# Epoch 12, Train Loss: 0.6433, Train Acc: 0.6205, Val Acc: 0.6004
# Early stopping
# Best Validation Accuracy: 0.7682926829268293
# Best Hyperparameters: {'lr': 0.1, 'batch_size': 32, 'optimizer': 'SGD'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_avg['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_avg = AveragePoolingRNNModel(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_avg['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
elif best_hyperparams_RNN_avg['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
elif best_hyperparams_RNN_avg['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
elif best_hyperparams_RNN_avg['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_RNN_avg.parameters(), lr=best_hyperparams_RNN_avg['lr'])
best_model_RNN_avg, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_avg, train_loader, validation_loader,
                                                                                 best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.6917, Train Acc: 0.5295, Val Acc: 0.5572
# Epoch 2, Train Loss: 0.6775, Train Acc: 0.5803, Val Acc: 0.5572
# Epoch 3, Train Loss: 0.6676, Train Acc: 0.6080, Val Acc: 0.6154
# Epoch 4, Train Loss: 0.6685, Train Acc: 0.5910, Val Acc: 0.5272
# Epoch 5, Train Loss: 0.6612, Train Acc: 0.6114, Val Acc: 0.6773
# Epoch 6, Train Loss: 0.6297, Train Acc: 0.6653, Val Acc: 0.5854
# Epoch 7, Train Loss: 0.6231, Train Acc: 0.6661, Val Acc: 0.6529
# Epoch 8, Train Loss: 0.6188, Train Acc: 0.6789, Val Acc: 0.7223
# Epoch 9, Train Loss: 0.5846, Train Acc: 0.7046, Val Acc: 0.6585
# Epoch 10, Train Loss: 0.5723, Train Acc: 0.7091, Val Acc: 0.7261
# Epoch 11, Train Loss: 0.5594, Train Acc: 0.7177, Val Acc: 0.7364
# Epoch 12, Train Loss: 0.5533, Train Acc: 0.7250, Val Acc: 0.7420
# Epoch 13, Train Loss: 0.5421, Train Acc: 0.7315, Val Acc: 0.7392
# Epoch 14, Train Loss: 0.5446, Train Acc: 0.7319, Val Acc: 0.5413
# Epoch 15, Train Loss: 0.5356, Train Acc: 0.7394, Val Acc: 0.6970
# Early stopping

# %%
epochs_avg = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_avg, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_avg, test_loader)
test_accuracies['RNN Average Pooling'] = test_acc
print(f'Test Accuracy (RNN Average Pooling): {test_acc:.4f}')
# Out:
# Test Accuracy (RNN Average Pooling): 0.6970

# %%
test_accuracies
# Out:
# {'RNN Last Hidden State': 0.4981238273921201,
#  'RNN Max Pooling': 0.7870544090056285,
#  'RNN Average Pooling': 0.6969981238273921}

# %% [markdown]
# **Max pooling** achieved the highest test accuracy of 0.7870.
# Thus, in the following sectinos we will apply max pooling to derive the final sentence representation to perform sentiment classification.

# %% [markdown]
# # Part 3: Enhancement

# %% [markdown]
# The RNN model used in Part 2 is a basic model to perform the task of sentiment classification. In  this section, you will design strategies to improve upon the previous model you have built. You ar
#  required to implement the following adjustments:

# %% [markdown]
# 1. Instead of keeping the word embeddings fixed, now update the word embeddings (the same way as model parameters) during the training process.
# 2. As discussed in Question 1(c), apply your solution in mitigating the influence of OOV words and train your model again.
# 3. Keeping the above two adjustments, replace your simple RNN model in Part 2 with a biLSTM model and a biGRU model, incorporating recurrent computations in both directions and stacking multiple layers if possible.
# 4. Keeping the above two adjustments, replace your simple RNN model in Part 2 with a Convolutional Neural Network (CNN) to produce sentence representations and perform sentiment classification.
# 5. Further improve your model. You are free to use any strategy other than the above mentioned solutions. Changing hyper-parameters or stacking more layers is not counted towards a meaningful improvement.

# %% [markdown]
# ## Question 3: Enhancement

# %% [markdown]
# ### (a) Report the accuracy score on the test set when the word embeddings are updated (Part 3.1).

# %% [markdown]
# Set `freeze=False` when initializing the embedding layer to allow word embeddings update.

# %%
class MaxPoolingRNNModelUpdate(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(MaxPoolingRNNModelUpdate, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape

        # Embedding layer with pretrained weights, frozen during training
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)

        # RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True).to(device)

        # Fully connected layer to predict sentiment from hidden state
        self.fc = nn.Linear(hidden_dim, output_dim).to(device)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        rnn_output, hidden = self.rnn(embedded)
        # Max pooling over all hidden states
        max_pooled, _ = torch.max(rnn_output, dim=1)
        output = self.fc(max_pooled)
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# Call grid search
best_hyperparams_RNN_update = run_grid_search(MaxPoolingRNNModelUpdate, embedding_matrix, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6940, Train Acc: 0.4950, Val Acc: 0.5122
# Epoch 2, Train Loss: 0.6932, Train Acc: 0.5048, Val Acc: 0.5356
# Epoch 3, Train Loss: 0.6924, Train Acc: 0.5087, Val Acc: 0.5056
# Epoch 4, Train Loss: 0.6914, Train Acc: 0.5293, Val Acc: 0.5197
# Epoch 5, Train Loss: 0.6910, Train Acc: 0.5327, Val Acc: 0.5863
# Epoch 6, Train Loss: 0.6902, Train Acc: 0.5471, Val Acc: 0.5572
# Epoch 7, Train Loss: 0.6891, Train Acc: 0.5590, Val Acc: 0.5929
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=SGD
# Epoch 1, Train Loss: 0.6856, Train Acc: 0.5469, Val Acc: 0.5019
# Epoch 2, Train Loss: 0.6076, Train Acc: 0.6739, Val Acc: 0.7064
# Epoch 3, Train Loss: 0.5230, Train Acc: 0.7356, Val Acc: 0.6839
# Epoch 4, Train Loss: 0.4779, Train Acc: 0.7717, Val Acc: 0.7749
# Epoch 5, Train Loss: 0.4506, Train Acc: 0.7866, Val Acc: 0.7833
# Epoch 6, Train Loss: 0.4334, Train Acc: 0.7974, Val Acc: 0.7711
# Epoch 7, Train Loss: 0.4137, Train Acc: 0.8074, Val Acc: 0.7777
# Epoch 8, Train Loss: 0.3957, Train Acc: 0.8203, Val Acc: 0.7917
# Epoch 9, Train Loss: 0.3872, Train Acc: 0.8272, Val Acc: 0.6604
# Epoch 10, Train Loss: 0.3693, Train Acc: 0.8349, Val Acc: 0.7908
# Epoch 11, Train Loss: 0.3517, Train Acc: 0.8462, Val Acc: 0.7899
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adam
# Epoch 1, Train Loss: 2.4982, Train Acc: 0.5032, Val Acc: 0.5122
# Epoch 2, Train Loss: 1.7375, Train Acc: 0.5166, Val Acc: 0.4962
# Epoch 3, Train Loss: 2.1861, Train Acc: 0.5205, Val Acc: 0.5159
# Epoch 4, Train Loss: 1.0286, Train Acc: 0.5163, Val Acc: 0.5066
# Epoch 5, Train Loss: 1.1865, Train Acc: 0.5137, Val Acc: 0.5066
# Epoch 6, Train Loss: 1.9959, Train Acc: 0.5073, Val Acc: 0.5066
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 23.9188, Train Acc: 0.5018, Val Acc: 0.5131
# Epoch 2, Train Loss: 13.6563, Train Acc: 0.5060, Val Acc: 0.5056
# Epoch 3, Train Loss: 13.0864, Train Acc: 0.4958, Val Acc: 0.5028
# Epoch 4, Train Loss: 12.9649, Train Acc: 0.4975, Val Acc: 0.5028
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adagrad
# Epoch 1, Train Loss: 2.0906, Train Acc: 0.4957, Val Acc: 0.5000
# Epoch 2, Train Loss: 0.9293, Train Acc: 0.4986, Val Acc: 0.5000
# Epoch 3, Train Loss: 0.5899, Train Acc: 0.7082, Val Acc: 0.5797
# Epoch 4, Train Loss: 0.4072, Train Acc: 0.8250, Val Acc: 0.6726
# Epoch 5, Train Loss: 0.3150, Train Acc: 0.8741, Val Acc: 0.6961
# Epoch 6, Train Loss: 0.2561, Train Acc: 0.8970, Val Acc: 0.6773
# Epoch 7, Train Loss: 0.2122, Train Acc: 0.9164, Val Acc: 0.6745
# Epoch 8, Train Loss: 0.1812, Train Acc: 0.9320, Val Acc: 0.6932
# Early stopping
# Best Validation Accuracy: 0.8020637898686679
# Best Hyperparameters: {'lr': 0.005, 'batch_size': 32, 'optimizer': 'Adagrad'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_RNN_update['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_RNN_update = MaxPoolingRNNModelUpdate(embedding_matrix, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_RNN_update['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
elif best_hyperparams_RNN_update['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
elif best_hyperparams_RNN_update['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
elif best_hyperparams_RNN_update['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_RNN_update.parameters(), lr=best_hyperparams_RNN_update['lr'])
best_model_RNN_update, train_losses, train_accuracies, val_accuracies = train_model(best_model_RNN_update, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5305, Train Acc: 0.7319, Val Acc: 0.7833
# Epoch 2, Train Loss: 0.3661, Train Acc: 0.8401, Val Acc: 0.7861
# Epoch 3, Train Loss: 0.2895, Train Acc: 0.8821, Val Acc: 0.7927
# Epoch 4, Train Loss: 0.2312, Train Acc: 0.9110, Val Acc: 0.7861
# Epoch 5, Train Loss: 0.1810, Train Acc: 0.9304, Val Acc: 0.7824
# Epoch 6, Train Loss: 0.1504, Train Acc: 0.9456, Val Acc: 0.7927
# Early stopping

# %%
epochs_mp = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_mp, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_RNN_update, test_loader)
test_accuracies['RNN (Update Word Embeddings)'] = test_acc
print(f'Test Accuracy (Update Word Embeddings): {test_acc:.4f}')
# Out:
# Test Accuracy (Update Word Embeddings): 0.8096

# %% [markdown]
# ### (b) Report the accuracy score on the test set when applying your method to deal with OOV words in Part 3.2.

# %%
# Initialize logging to log the replacement process
logging.basicConfig(filename="oov_handling.log", level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

# Initialize the embedding matrix with zeros
embedding_matrix_spelling_bpe = np.zeros((vocab_size, embedding_dim))

# Map vocabulary to indices in the embedding matrix
word_to_idx = {word: idx for idx, word in enumerate(vocab)}

# Populate embedding matrix and handle OOV words
for word, idx in word_to_idx.items():
    if word in word2vec_model:
        embedding_matrix_spelling_bpe[idx] = word2vec_model[word]
    else:
        # Attempt to find a replacement for OOV words
        replacement_word = find_replacement_word(word, word2vec_model,sp,sym_spell)
        if replacement_word and replacement_word in word2vec_model:
            embedding_matrix_spelling_bpe[idx] = word2vec_model[replacement_word]  # Use replacement word vector
            logging.info(f"Replaced OOV word '{word}' with '{replacement_word}' in embedding matrix.")
        else:
            # Initialize with a random vector if no suitable replacement is found
            embedding_matrix_spelling_bpe[idx] = np.random.normal(size=(embedding_dim,))
            logging.info(f"OOV word '{word}' was not replaced; initialized with random vector.")
# Out:
# Processing token: 'crime-film'
# Preprocessed token: crime film
# Individual tokens: ['crime', 'film']
# Longest match in model: crime
#
# Processing token: 'front-loaded'
# Preprocessed token: front loaded
# Individual tokens: ['front', 'loaded']
# Longest match in model: loaded
#
# Processing token: 'no-frills'
# Preprocessed token: no frills
# Individual tokens: ['no', 'frills']
# Longest match in model: frills
#
# Processing token: 'collosum'
# Preprocessed token: collosum
# Individual tokens: ['colloquy']
# Longest match in model: colloquy
#
# Processing token: 'soberbio'
# Preprocessed token: soberbio
# Individual tokens: ['soberbio']
# Longest match in model: None
# Stemmed tokens: ['soberbio']
# Longest match in model: None
# Subwords for 'soberbio': ['▁soberbio']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'existência'
# Preprocessed token: existência
# Individual tokens: ['existência']
# Longest match in model: None
# Stemmed tokens: ['existência']
# Longest match in model: None
# Subwords for 'existência': ['▁exist', 'ê', 'ncia']
# Best valid subword found: ê
#
# Processing token: 'self-made'
# Preprocessed token: self made
# Individual tokens: ['self', 'made']
# Longest match in model: self
#
# Processing token: 'all-stars'
# Preprocessed token: all stars
# Individual tokens: ['all', 'stars']
# Longest match in model: stars
#
# Processing token: 'feardotcom'
# Preprocessed token: feardotcom
# Individual tokens: ['feardotcom']
# Longest match in model: None
# Stemmed tokens: ['feardotcom']
# Longest match in model: None
# Subwords for 'feardotcom': ['▁feardotcom']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'out-of-field'
# Preprocessed token: out of field
# Individual tokens: ['out', 'of', 'field']
# Longest match in model: field
#
# Processing token: 'ultra-loud'
# Preprocessed token: ultra loud
# Individual tokens: ['ultra', 'loud']
# Longest match in model: ultra
#
# Processing token: 'right-hand'
# Preprocessed token: right hand
# Individual tokens: ['right', 'hand']
# Longest match in model: right
#
# Processing token: 'hammily'
# Preprocessed token: hammily
# Individual tokens: ['family']
# Longest match in model: family
#
# Processing token: 'derrida'
# Preprocessed token: derrida
# Individual tokens: ['derrida']
# Longest match in model: None
# Stemmed tokens: ['derrida']
# Longest match in model: None
# Subwords for 'derrida': ['▁derrida']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'off-the-wall'
# Preprocessed token: off the wall
# Individual tokens: ['off', 'the', 'wall']
# Longest match in model: wall
#
# Processing token: 'lived-in'
# Preprocessed token: lived in
# Individual tokens: ['lived', 'in']
# Longest match in model: lived
#
# Processing token: 'ready-made'
# Preprocessed token: ready made
# Individual tokens: ['ready', 'made']
# Longest match in model: ready
#
# Processing token: 'yawn-provoking'
# Preprocessed token: yawn provoking
# Individual tokens: ['yawn', 'provoking']
# Longest match in model: provoking
#
# Processing token: 'pop-cyber'
# Preprocessed token: pop cyber
# Individual tokens: ['pop', 'caber']
# Longest match in model: caber
#
# Processing token: 'sandlerian'
# Preprocessed token: sandlerian
# Individual tokens: ['adlerian']
# Longest match in model: None
# Stemmed tokens: ['adlerian']
# Longest match in model: None
# Subwords for 'adlerian': ['▁ad', 'ler', 'ian']
# Best valid subword found: ler
#
# Processing token: 'ilya'
# Preprocessed token: ilya
# Individual tokens: ['ila']
# Longest match in model: ila
#
# Processing token: 'everlyn'
# Preprocessed token: everlyn
# Individual tokens: ['evelyn']
# Longest match in model: evelyn
#
# Processing token: 'pg-rated'
# Preprocessed token: pg rated
# Individual tokens: ['pm', 'rated']
# Longest match in model: rated
#
# Processing token: 'categorisation'
# Preprocessed token: categorisation
# Individual tokens: ['categorisation']
# Longest match in model: None
# Stemmed tokens: ['categoris']
# Longest match in model: None
# Subwords for 'categorisation': ['▁categor', 'is', 'ation']
# Best valid subword found: ation
#
# Processing token: 'big-budget'
# Preprocessed token: big budget
# Individual tokens: ['big', 'budget']
# Longest match in model: budget
#
# Processing token: 'schiffer'
# Preprocessed token: schiffer
# Individual tokens: ['sniffer']
# Longest match in model: sniffer
#
# Processing token: '77'
# Preprocessed token: 77
# Individual tokens: ['of']
# Longest match in model: None
# Stemmed tokens: ['of']
# Longest match in model: None
# Subwords for 'of': ['▁of']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'krawczyk'
# Preprocessed token: krawczyk
# Individual tokens: ['krawczyk']
# Longest match in model: None
# Stemmed tokens: ['krawczyk']
# Longest match in model: None
# Subwords for 'krawczyk': ['▁k', 'raw', 'c', 'zy', 'k']
# Best valid subword found: raw
#
# Processing token: 'not-so-hot'
# Preprocessed token: not so hot
# Individual tokens: ['not', 'so', 'hot']
# Longest match in model: not
#
# Processing token: 'janey'
# Preprocessed token: janey
# Individual tokens: ['jane']
# Longest match in model: jane
#
# Processing token: 'phoned-in'
# Preprocessed token: phoned in
# Individual tokens: ['phoned', 'in']
# Longest match in model: phoned
#
# Processing token: 'direct-to-video'
# Preprocessed token: direct to video
# Individual tokens: ['direct', 'to', 'video']
# Longest match in model: direct
#
# Processing token: 'anti-semitism'
# Preprocessed token: anti semitism
# Individual tokens: ['anti', 'semitism']
# Longest match in model: semitism
#
# Processing token: 'woman-'
# Preprocessed token: woman
# Individual tokens: ['woman']
# Longest match in model: woman
#
# Processing token: 'zealanders'
# Preprocessed token: zealanders
# Individual tokens: ['zealanders']
# Longest match in model: None
# Stemmed tokens: ['zealand']
# Longest match in model: zealand
#
# Processing token: 'minute-by-minute'
# Preprocessed token: minute by minute
# Individual tokens: ['minute', 'by', 'minute']
# Longest match in model: minute
#
# Processing token: 'brecht'
# Preprocessed token: brecht
# Individual tokens: ['brecht']
# Longest match in model: None
# Stemmed tokens: ['brecht']
# Longest match in model: None
# Subwords for 'brecht': ['▁brecht']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'near-xenophobic'
# Preprocessed token: near xenophobic
# Individual tokens: ['near', 'xenophobic']
# Longest match in model: xenophobic
#
# Processing token: 'shoe-loving'
# Preprocessed token: shoe loving
# Individual tokens: ['shoe', 'loving']
# Longest match in model: loving
#
# Processing token: 'shoot-outs'
# Preprocessed token: shoot outs
# Individual tokens: ['shoot', 'outs']
# Longest match in model: shoot
#
# Processing token: 'schweig'
# Preprocessed token: schweig
# Individual tokens: ['schweiz']
# Longest match in model: None
# Stemmed tokens: ['schweiz']
# Longest match in model: None
# Subwords for 'schweiz': ['▁sch', 'we', 'iz']
# Best valid subword found: we
#
# Processing token: 'well-oiled'
# Preprocessed token: well oiled
# Individual tokens: ['well', 'oiled']
# Longest match in model: oiled
#
# Processing token: 'tampoco'
# Preprocessed token: tampoco
# Individual tokens: ['tampico']
# Longest match in model: None
# Stemmed tokens: ['tampico']
# Longest match in model: None
# Subwords for 'tampico': ['▁t', 'amp', 'ico']
# Best valid subword found: amp
#
# Processing token: 'hitchens'
# Preprocessed token: hitchens
# Individual tokens: ['kitchens']
# Longest match in model: kitchens
#
# Processing token: 'non-britney'
# Preprocessed token: non britney
# Individual tokens: ['non', 'britney']
# Longest match in model: britney
#
# Processing token: 'so-so'
# Preprocessed token: so so
# Individual tokens: ['so', 'so']
# Longest match in model: so
#
# Processing token: 'techno-tripe'
# Preprocessed token: techno tripe
# Individual tokens: ['techno', 'tripe']
# Longest match in model: techno
#
# Processing token: 'conflict-powered'
# Preprocessed token: conflict powered
# Individual tokens: ['conflict', 'powered']
# Longest match in model: conflict
#
# Processing token: 'talk-show'
# Preprocessed token: talk show
# Individual tokens: ['talk', 'show']
# Longest match in model: talk
#
# Processing token: 'stiff-upper-lip'
# Preprocessed token: stiff upper lip
# Individual tokens: ['stiff', 'upper', 'lip']
# Longest match in model: stiff
#
# Processing token: 'made-up'
# Preprocessed token: made up
# Individual tokens: ['made', 'up']
# Longest match in model: made
#
# Processing token: 'cold-blooded'
# Preprocessed token: cold blooded
# Individual tokens: ['cold', 'blooded']
# Longest match in model: blooded
#
# Processing token: 'nadia'
# Preprocessed token: nadia
# Individual tokens: ['nadia']
# Longest match in model: None
# Stemmed tokens: ['nadia']
# Longest match in model: None
# Subwords for 'nadia': ['▁nadia']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'beloved-major-'
# Preprocessed token: beloved major
# Individual tokens: ['beloved', 'major']
# Longest match in model: beloved
#
# Processing token: 'kahlories'
# Preprocessed token: kahlories
# Individual tokens: ['calories']
# Longest match in model: calories
#
# Processing token: 'começamos'
# Preprocessed token: começamos
# Individual tokens: ['começamos']
# Longest match in model: None
# Stemmed tokens: ['começamo']
# Longest match in model: None
# Subwords for 'começamos': ['▁come', 'ç', 'amos']
# Best valid subword found: amos
#
# Processing token: 'mass-market'
# Preprocessed token: mass market
# Individual tokens: ['mass', 'market']
# Longest match in model: market
#
# Processing token: 'finding-herself'
# Preprocessed token: finding herself
# Individual tokens: ['finding', 'herself']
# Longest match in model: finding
#
# Processing token: '25'
# Preprocessed token: 25
# Individual tokens: ['of']
# Longest match in model: None
# Stemmed tokens: ['of']
# Longest match in model: None
# Subwords for 'of': ['▁of']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'post-colonialist'
# Preprocessed token: post colonialist
# Individual tokens: ['post', 'colonialist']
# Longest match in model: colonialist
#
# Processing token: '1997'
# Preprocessed token: 1997
# Individual tokens: ['1997']
# Longest match in model: None
# Stemmed tokens: ['1997']
# Longest match in model: None
# Subwords for '1997': ['▁199', '7']
# Best valid subword found: 7
#
# Processing token: 'social/economic/urban'
# Preprocessed token: social economic urban
# Individual tokens: ['social', 'economic', 'urban']
# Longest match in model: economic
#
# Processing token: 'tolkien'
# Preprocessed token: tolkien
# Individual tokens: ['tolkien']
# Longest match in model: None
# Stemmed tokens: ['tolkien']
# Longest match in model: None
# Subwords for 'tolkien': ['▁tolkien']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'matter-of-fact'
# Preprocessed token: matter of fact
# Individual tokens: ['matter', 'of', 'fact']
# Longest match in model: matter
#
# Processing token: 'trend-hoppy'
# Preprocessed token: trend hoppy
# Individual tokens: ['trend', 'happy']
# Longest match in model: trend
#
# Processing token: 'single-mindedness'
# Preprocessed token: single mindedness
# Individual tokens: ['single', 'mindedness']
# Longest match in model: mindedness
#
# Processing token: 'alientation'
# Preprocessed token: alientation
# Individual tokens: ['alienation']
# Longest match in model: alienation
#
# Processing token: 'wimmer'
# Preprocessed token: wimmer
# Individual tokens: ['simmer']
# Longest match in model: simmer
#
# Processing token: 'non-bondish'
# Preprocessed token: non bondish
# Individual tokens: ['non', 'bonds']
# Longest match in model: bonds
#
# Processing token: 'rocky-like'
# Preprocessed token: rocky like
# Individual tokens: ['rocky', 'like']
# Longest match in model: rocky
#
# Processing token: 'fun-for-fun's-sake'
# Preprocessed token: fun for funs sake
# Individual tokens: ['fun', 'for', 'fun', 'sake']
# Longest match in model: sake
#
# Processing token: 'surfer-girl'
# Preprocessed token: surfer girl
# Individual tokens: ['surfer', 'girl']
# Longest match in model: surfer
#
# Processing token: 'massoud'
# Preprocessed token: massoud
# Individual tokens: ['massed']
# Longest match in model: massed
#
# Processing token: 'elizabethan'
# Preprocessed token: elizabethan
# Individual tokens: ['elizabethan']
# Longest match in model: None
# Stemmed tokens: ['elizabethan']
# Longest match in model: None
# Subwords for 'elizabethan': ['▁elizabeth', 'an']
# Best valid subword found: an
#
# Processing token: 'wladyslaw'
# Preprocessed token: wladyslaw
# Individual tokens: ['wladyslaw']
# Longest match in model: None
# Stemmed tokens: ['wladyslaw']
# Longest match in model: None
# Subwords for 'wladyslaw': ['▁wladys', 'law']
# Best valid subword found: law
#
# Processing token: 'truncheoning'
# Preprocessed token: truncheoning
# Individual tokens: ['truncheoning']
# Longest match in model: None
# Stemmed tokens: ['truncheon']
# Longest match in model: truncheon
#
# Processing token: 'teen-gang'
# Preprocessed token: teen gang
# Individual tokens: ['teen', 'gang']
# Longest match in model: teen
#
# Processing token: 'goose-pimple'
# Preprocessed token: goose pimple
# Individual tokens: ['goose', 'pimple']
# Longest match in model: pimple
#
# Processing token: 'mistaken-identity'
# Preprocessed token: mistaken identity
# Individual tokens: ['mistaken', 'identity']
# Longest match in model: mistaken
#
# Processing token: 'psychodramatics'
# Preprocessed token: psychodramatics
# Individual tokens: ['psychodramatics']
# Longest match in model: None
# Stemmed tokens: ['psychodramat']
# Longest match in model: None
# Subwords for 'psychodramatics': ['▁psychodram', 'atics']
# Best valid subword found: atics
#
# Processing token: '179-minute'
# Preprocessed token: 179 minute
# Individual tokens: ['179', 'minute']
# Longest match in model: minute
#
# Processing token: 'non-threatening'
# Preprocessed token: non threatening
# Individual tokens: ['non', 'threatening']
# Longest match in model: threatening
#
# Processing token: 'fassbinder'
# Preprocessed token: fassbinder
# Individual tokens: ['fassbinder']
# Longest match in model: None
# Stemmed tokens: ['fassbind']
# Longest match in model: None
# Subwords for 'fassbinder': ['▁f', 'assbinder']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'lip-non-synching'
# Preprocessed token: lip non synching
# Individual tokens: ['lip', 'non', 'synching']
# Longest match in model: synching
#
# Processing token: 'olympus'
# Preprocessed token: olympus
# Individual tokens: ['olympus']
# Longest match in model: None
# Stemmed tokens: ['olympu']
# Longest match in model: None
# Subwords for 'olympus': ['▁olympus']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'tv-movie'
# Preprocessed token: tv movie
# Individual tokens: ['to', 'movie']
# Longest match in model: movie
#
# Processing token: 'good-humored'
# Preprocessed token: good humored
# Individual tokens: ['good', 'humoured']
# Longest match in model: good
#
# Processing token: 'fine-looking'
# Preprocessed token: fine looking
# Individual tokens: ['fine', 'looking']
# Longest match in model: looking
#
# Processing token: '1873'
# Preprocessed token: 1873
# Individual tokens: ['1873']
# Longest match in model: None
# Stemmed tokens: ['1873']
# Longest match in model: None
# Subwords for '1873': ['▁18', '73']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'juwanna'
# Preprocessed token: juwanna
# Individual tokens: ['wanna']
# Longest match in model: wanna
#
# Processing token: 'interesantes'
# Preprocessed token: interesantes
# Individual tokens: ['interesantes']
# Longest match in model: None
# Stemmed tokens: ['interesant']
# Longest match in model: None
# Subwords for 'interesantes': ['▁inter', 'es', 'antes']
# Best valid subword found: antes
#
# Processing token: 'hyper-artificiality'
# Preprocessed token: hyper artificiality
# Individual tokens: ['hyper', 'artificiality']
# Longest match in model: artificiality
#
# Processing token: 'roteiro'
# Preprocessed token: roteiro
# Individual tokens: ['romero']
# Longest match in model: None
# Stemmed tokens: ['romero']
# Longest match in model: None
# Subwords for 'romero': ['▁rom', 'ero']
# Best valid subword found: ero
#
# Processing token: ''ejemplo'
# Preprocessed token: ejemplo
# Individual tokens: ['exempla']
# Longest match in model: None
# Stemmed tokens: ['exempla']
# Longest match in model: None
# Subwords for 'exempla': ['▁exempl', 'a']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'travel-agency'
# Preprocessed token: travel agency
# Individual tokens: ['travel', 'agency']
# Longest match in model: travel
#
# Processing token: 'neo-noir'
# Preprocessed token: neo noir
# Individual tokens: ['new', 'nor']
# Longest match in model: new
#
# Processing token: 'grenier'
# Preprocessed token: grenier
# Individual tokens: ['greater']
# Longest match in model: greater
#
# Processing token: 'waldo'
# Preprocessed token: waldo
# Individual tokens: ['waldo']
# Longest match in model: None
# Stemmed tokens: ['waldo']
# Longest match in model: None
# Subwords for 'waldo': ['▁waldo']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'münch'
# Preprocessed token: münch
# Individual tokens: ['munch']
# Longest match in model: munch
#
# Processing token: 'mctiernan'
# Preprocessed token: mctiernan
# Individual tokens: ['mctiernan']
# Longest match in model: None
# Stemmed tokens: ['mctiernan']
# Longest match in model: None
# Subwords for 'mctiernan': ['▁mctiernan']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'genial-rogue'
# Preprocessed token: genial rogue
# Individual tokens: ['genial', 'rogue']
# Longest match in model: genial
#
# Processing token: ''carente'
# Preprocessed token: carente
# Individual tokens: ['charente']
# Longest match in model: None
# Stemmed tokens: ['charent']
# Longest match in model: None
# Subwords for 'charente': ['▁ch', 'aren', 'te']
# Best valid subword found: aren
#
# Processing token: 'bad-luck'
# Preprocessed token: bad luck
# Individual tokens: ['bad', 'luck']
# Longest match in model: luck
#
# Processing token: 'good-looking'
# Preprocessed token: good looking
# Individual tokens: ['good', 'looking']
# Longest match in model: looking
#
# Processing token: 'fallas'
# Preprocessed token: fallas
# Individual tokens: ['falls']
# Longest match in model: falls
#
# Processing token: 'beatrice'
# Preprocessed token: beatrice
# Individual tokens: ['beatrice']
# Longest match in model: None
# Stemmed tokens: ['beatric']
# Longest match in model: None
# Subwords for 'beatrice': ['▁beat', 'r', 'ice']
# Best valid subword found: ice
#
# Processing token: 'less-compelling'
# Preprocessed token: less compelling
# Individual tokens: ['less', 'compelling']
# Longest match in model: compelling
#
# Processing token: 'still-raw'
# Preprocessed token: still raw
# Individual tokens: ['still', 'raw']
# Longest match in model: still
#
# Processing token: ''synthetic'
# Preprocessed token: synthetic
# Individual tokens: ['synthetic']
# Longest match in model: synthetic
#
# Processing token: '105'
# Preprocessed token: 105
# Individual tokens: ['105']
# Longest match in model: None
# Stemmed tokens: ['105']
# Longest match in model: None
# Subwords for '105': ['▁10', '5']
# Best valid subword found: 5
#
# Processing token: 'bowel-curdling'
# Preprocessed token: bowel curdling
# Individual tokens: ['bowel', 'curdling']
# Longest match in model: curdling
#
# Processing token: 'poderosa'
# Preprocessed token: poderosa
# Individual tokens: ['ponderosa']
# Longest match in model: ponderosa
#
# Processing token: 'lasker'
# Preprocessed token: lasker
# Individual tokens: ['lasker']
# Longest match in model: None
# Stemmed tokens: ['lasker']
# Longest match in model: None
# Subwords for 'lasker': ['▁lasker']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'término'
# Preprocessed token: término
# Individual tokens: ['torino']
# Longest match in model: None
# Stemmed tokens: ['torino']
# Longest match in model: None
# Subwords for 'torino': ['▁tor', 'ino']
# Best valid subword found: ino
#
# Processing token: 'stadium-seat'
# Preprocessed token: stadium seat
# Individual tokens: ['stadium', 'seat']
# Longest match in model: stadium
#
# Processing token: '--'
# Preprocessed token:
# Individual tokens: []
# Longest match in model: None
# Stemmed tokens: []
# Longest match in model: None
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'old-fashioned-movie'
# Preprocessed token: old fashioned movie
# Individual tokens: ['old', 'fashioned', 'movie']
# Longest match in model: fashioned
#
# Processing token: 'crummles'
# Preprocessed token: crummles
# Individual tokens: ['crumbles']
# Longest match in model: crumbles
#
# Processing token: 'witch-style'
# Preprocessed token: witch style
# Individual tokens: ['witch', 'style']
# Longest match in model: witch
#
# Processing token: 'pabst'
# Preprocessed token: pabst
# Individual tokens: ['pabst']
# Longest match in model: None
# Stemmed tokens: ['pabst']
# Longest match in model: None
# Subwords for 'pabst': ['▁pab', 'st']
# Best valid subword found: st
#
# Processing token: 'provocatuers'
# Preprocessed token: provocatuers
# Individual tokens: ['provocateurs']
# Longest match in model: provocateurs
#
# Processing token: 'grabowsky'
# Preprocessed token: grabowsky
# Individual tokens: ['grabowsky']
# Longest match in model: None
# Stemmed tokens: ['grabowski']
# Longest match in model: None
# Subwords for 'grabowsky': ['▁grab', 'ows', 'ky']
# Best valid subword found: ows
#
# Processing token: '96'
# Preprocessed token: 96
# Individual tokens: ['of']
# Longest match in model: None
# Stemmed tokens: ['of']
# Longest match in model: None
# Subwords for 'of': ['▁of']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'gerbosi'
# Preprocessed token: gerbosi
# Individual tokens: ['verbose']
# Longest match in model: verbose
#
# Processing token: 'esteticamente'
# Preprocessed token: esteticamente
# Individual tokens: ['esteticamente']
# Longest match in model: None
# Stemmed tokens: ['esteticament']
# Longest match in model: None
# Subwords for 'esteticamente': ['▁est', 'etic', 'amente']
# Best valid subword found: etic
#
# Processing token: 'smack-dab'
# Preprocessed token: smack dab
# Individual tokens: ['smack', 'dab']
# Longest match in model: smack
#
# Processing token: 'well-deserved'
# Preprocessed token: well deserved
# Individual tokens: ['well', 'deserved']
# Longest match in model: deserved
#
# Processing token: 'high-minded'
# Preprocessed token: high minded
# Individual tokens: ['high', 'minded']
# Longest match in model: minded
#
# Processing token: 'seventy-minute'
# Preprocessed token: seventy minute
# Individual tokens: ['seventy', 'minute']
# Longest match in model: seventy
#
# Processing token: 'unsalvageability'
# Preprocessed token: unsalvageability
# Individual tokens: ['unsalvageability']
# Longest match in model: None
# Stemmed tokens: ['unsalvag']
# Longest match in model: None
# Subwords for 'unsalvageability': ['▁uns', 'al', 'v', 'age', 'ability']
# Best valid subword found: ability
#
# Processing token: 'sarcástica'
# Preprocessed token: sarcástica
# Individual tokens: ['sarcastic']
# Longest match in model: sarcastic
#
# Processing token: 'half-dozen'
# Preprocessed token: half dozen
# Individual tokens: ['half', 'dozen']
# Longest match in model: dozen
#
# Processing token: 'dead-center'
# Preprocessed token: dead center
# Individual tokens: ['dead', 'center']
# Longest match in model: center
#
# Processing token: 'to-do'
# Preprocessed token: to do
# Individual tokens: ['to', 'do']
# Longest match in model: do
#
# Processing token: 'fast-edit'
# Preprocessed token: fast edit
# Individual tokens: ['fast', 'edit']
# Longest match in model: fast
#
# Processing token: 'misty-eyed'
# Preprocessed token: misty eyed
# Individual tokens: ['misty', 'eyed']
# Longest match in model: misty
#
# Processing token: 'over-amorous'
# Preprocessed token: over amorous
# Individual tokens: ['over', 'amorous']
# Longest match in model: amorous
#
# Processing token: 'thornberry'
# Preprocessed token: thornberry
# Individual tokens: ['thornberry']
# Longest match in model: None
# Stemmed tokens: ['thornberri']
# Longest match in model: None
# Subwords for 'thornberry': ['▁thornberry']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 're-do'
# Preprocessed token: re do
# Individual tokens: ['re', 'do']
# Longest match in model: re
#
# Processing token: 'dafoe'
# Preprocessed token: dafoe
# Individual tokens: ['defoe']
# Longest match in model: defoe
#
# Processing token: 'yosuke'
# Preprocessed token: yosuke
# Individual tokens: ['yoke']
# Longest match in model: yoke
#
# Processing token: 'laugh-filled'
# Preprocessed token: laugh filled
# Individual tokens: ['laugh', 'filled']
# Longest match in model: filled
#
# Processing token: 'reel-to-reel'
# Preprocessed token: reel to reel
# Individual tokens: ['reel', 'to', 'reel']
# Longest match in model: reel
#
# Processing token: 'são'
# Preprocessed token: são
# Individual tokens: ['so']
# Longest match in model: so
#
# Processing token: 'in-depth'
# Preprocessed token: in depth
# Individual tokens: ['in', 'depth']
# Longest match in model: depth
#
# Processing token: 'genevieve'
# Preprocessed token: genevieve
# Individual tokens: ['genevieve']
# Longest match in model: None
# Stemmed tokens: ['geneviev']
# Longest match in model: None
# Subwords for 'genevieve': ['▁gen', 'e', 'vie', 've']
# Best valid subword found: vie
#
# Processing token: 'larson'
# Preprocessed token: larson
# Individual tokens: ['larson']
# Longest match in model: None
# Stemmed tokens: ['larson']
# Longest match in model: None
# Subwords for 'larson': ['▁larson']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'wishy-washy'
# Preprocessed token: wishy washy
# Individual tokens: ['wish', 'washy']
# Longest match in model: washy
#
# Processing token: 'time-travel'
# Preprocessed token: time travel
# Individual tokens: ['time', 'travel']
# Longest match in model: travel
#
# Processing token: 'nebrida'
# Preprocessed token: nebrida
# Individual tokens: ['merida']
# Longest match in model: None
# Stemmed tokens: ['merida']
# Longest match in model: None
# Subwords for 'merida': ['▁mer', 'ida']
# Best valid subword found: ida
#
# Processing token: 'sub-sophomoric'
# Preprocessed token: sub sophomoric
# Individual tokens: ['sub', 'sophomoric']
# Longest match in model: sophomoric
#
# Processing token: 'by-the-numbers'
# Preprocessed token: by the numbers
# Individual tokens: ['by', 'the', 'numbers']
# Longest match in model: numbers
#
# Processing token: 're-creation'
# Preprocessed token: re creation
# Individual tokens: ['re', 'creation']
# Longest match in model: creation
#
# Processing token: 'full-throated'
# Preprocessed token: full throated
# Individual tokens: ['full', 'throated']
# Longest match in model: throated
#
# Processing token: 'apallingly'
# Preprocessed token: apallingly
# Individual tokens: ['appallingly']
# Longest match in model: appallingly
#
# Processing token: 'much-anticipated'
# Preprocessed token: much anticipated
# Individual tokens: ['much', 'anticipated']
# Longest match in model: anticipated
#
# Processing token: 'pseudo-witty'
# Preprocessed token: pseudo witty
# Individual tokens: ['pseudo', 'witty']
# Longest match in model: pseudo
#
# Processing token: '1984'
# Preprocessed token: 1984
# Individual tokens: ['1984']
# Longest match in model: None
# Stemmed tokens: ['1984']
# Longest match in model: None
# Subwords for '1984': ['▁198', '4']
# Best valid subword found: 4
#
# Processing token: 'inner-city'
# Preprocessed token: inner city
# Individual tokens: ['inner', 'city']
# Longest match in model: inner
#
# Processing token: 'warm-blooded'
# Preprocessed token: warm blooded
# Individual tokens: ['warm', 'blooded']
# Longest match in model: blooded
#
# Processing token: 'iben'
# Preprocessed token: iben
# Individual tokens: ['ben']
# Longest match in model: ben
#
# Processing token: 'hard-to-swallow'
# Preprocessed token: hard to swallow
# Individual tokens: ['hard', 'to', 'swallow']
# Longest match in model: swallow
#
# Processing token: 'nesbitt'
# Preprocessed token: nesbitt
# Individual tokens: ['nesbitt']
# Longest match in model: None
# Stemmed tokens: ['nesbitt']
# Longest match in model: None
# Subwords for 'nesbitt': ['▁n', 'es', 'bitt']
# Best valid subword found: es
#
# Processing token: ''magnifique'
# Preprocessed token: magnifique
# Individual tokens: ['magnifique']
# Longest match in model: magnifique
#
# Processing token: 'highly-praised'
# Preprocessed token: highly praised
# Individual tokens: ['highly', 'praised']
# Longest match in model: praised
#
# Processing token: 'imponderably'
# Preprocessed token: imponderably
# Individual tokens: ['imponderable']
# Longest match in model: imponderable
#
# Processing token: 'scarpia'
# Preprocessed token: scarpia
# Individual tokens: ['scorpio']
# Longest match in model: scorpio
#
# Processing token: 'cringe-inducing'
# Preprocessed token: cringe inducing
# Individual tokens: ['cringe', 'inducing']
# Longest match in model: inducing
#
# Processing token: 'star-power'
# Preprocessed token: star power
# Individual tokens: ['star', 'power']
# Longest match in model: power
#
# Processing token: 'wham-bam'
# Preprocessed token: wham bam
# Individual tokens: ['wham', 'am']
# Longest match in model: wham
#
# Processing token: 'on-screen'
# Preprocessed token: on screen
# Individual tokens: ['on', 'screen']
# Longest match in model: screen
#
# Processing token: 'hard-bitten'
# Preprocessed token: hard bitten
# Individual tokens: ['hard', 'bitten']
# Longest match in model: bitten
#
# Processing token: 'black-and-white'
# Preprocessed token: black and white
# Individual tokens: ['black', 'and', 'white']
# Longest match in model: black
#
# Processing token: 'ice-t'
# Preprocessed token: ice t
# Individual tokens: ['ice', 'to']
# Longest match in model: ice
#
# Processing token: 'badly-rendered'
# Preprocessed token: badly rendered
# Individual tokens: ['badly', 'rendered']
# Longest match in model: rendered
#
# Processing token: 'brosnan'
# Preprocessed token: brosnan
# Individual tokens: ['brennan']
# Longest match in model: brennan
#
# Processing token: 'feature-length'
# Preprocessed token: feature length
# Individual tokens: ['feature', 'length']
# Longest match in model: feature
#
# Processing token: '-'
# Preprocessed token:
# Individual tokens: []
# Longest match in model: None
# Stemmed tokens: []
# Longest match in model: None
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'ho-hum'
# Preprocessed token: ho hum
# Individual tokens: ['to', 'hum']
# Longest match in model: hum
#
# Processing token: 'diferença'
# Preprocessed token: diferença
# Individual tokens: ['diferença']
# Longest match in model: None
# Stemmed tokens: ['diferença']
# Longest match in model: None
# Subwords for 'diferença': ['▁diferen', 'ç', 'a']
# Best valid subword found: ç
#
# Processing token: 'grade-grubbers'
# Preprocessed token: grade grubbers
# Individual tokens: ['grade', 'rubbers']
# Longest match in model: rubbers
#
# Processing token: ''this'
# Preprocessed token: this
# Individual tokens: ['this']
# Longest match in model: this
#
# Processing token: 'heavy-handed'
# Preprocessed token: heavy handed
# Individual tokens: ['heavy', 'handed']
# Longest match in model: handed
#
# Processing token: 'morvern'
# Preprocessed token: morvern
# Individual tokens: ['modern']
# Longest match in model: modern
#
# Processing token: 'audience-abuse'
# Preprocessed token: audience abuse
# Individual tokens: ['audience', 'abuse']
# Longest match in model: audience
#
# Processing token: 'molony'
# Preprocessed token: molony
# Individual tokens: ['colony']
# Longest match in model: colony
#
# Processing token: 'well-structured'
# Preprocessed token: well structured
# Individual tokens: ['well', 'structured']
# Longest match in model: structured
#
# Processing token: 'pseudo-bio'
# Preprocessed token: pseudo bio
# Individual tokens: ['pseudo', 'bio']
# Longest match in model: pseudo
#
# Processing token: 'dark-as-pitch'
# Preprocessed token: dark as pitch
# Individual tokens: ['dark', 'as', 'pitch']
# Longest match in model: pitch
#
# Processing token: ''literary'
# Preprocessed token: literary
# Individual tokens: ['literary']
# Longest match in model: literary
#
# Processing token: 'half-formed'
# Preprocessed token: half formed
# Individual tokens: ['half', 'formed']
# Longest match in model: formed
#
# Processing token: 'acabamos'
# Preprocessed token: acabamos
# Individual tokens: ['acabamos']
# Longest match in model: None
# Stemmed tokens: ['acabamo']
# Longest match in model: None
# Subwords for 'acabamos': ['▁ac', 'abamos']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: ''top'
# Preprocessed token: top
# Individual tokens: ['top']
# Longest match in model: top
#
# Processing token: 'clancy'
# Preprocessed token: clancy
# Individual tokens: ['clancy']
# Longest match in model: None
# Stemmed tokens: ['clanci']
# Longest match in model: None
# Subwords for 'clancy': ['▁clancy']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'self-aggrandizing'
# Preprocessed token: self aggrandizing
# Individual tokens: ['self', 'aggrandizing']
# Longest match in model: aggrandizing
#
# Processing token: 'mass-murdering'
# Preprocessed token: mass murdering
# Individual tokens: ['mass', 'murdering']
# Longest match in model: murdering
#
# Processing token: 'self-parody'
# Preprocessed token: self parody
# Individual tokens: ['self', 'parody']
# Longest match in model: parody
#
# Processing token: ''reality'
# Preprocessed token: reality
# Individual tokens: ['reality']
# Longest match in model: reality
#
# Processing token: 'screeching-metal'
# Preprocessed token: screeching metal
# Individual tokens: ['screeching', 'metal']
# Longest match in model: screeching
#
# Processing token: 'desplechin'
# Preprocessed token: desplechin
# Individual tokens: ['desplechin']
# Longest match in model: None
# Stemmed tokens: ['desplechin']
# Longest match in model: None
# Subwords for 'desplechin': ['▁desp', 'le', 'ch', 'in']
# Best valid subword found: le
#
# Processing token: ''frailty'
# Preprocessed token: frailty
# Individual tokens: ['frailty']
# Longest match in model: frailty
#
# Processing token: 'francophiles'
# Preprocessed token: francophiles
# Individual tokens: ['francophile']
# Longest match in model: francophile
#
# Processing token: 'dahmer'
# Preprocessed token: dahmer
# Individual tokens: ['danger']
# Longest match in model: danger
#
# Processing token: 'kirshner'
# Preprocessed token: kirshner
# Individual tokens: ['kirchner']
# Longest match in model: None
# Stemmed tokens: ['kirchner']
# Longest match in model: None
# Subwords for 'kirchner': ['▁kir', 'ch', 'ner']
# Best valid subword found: ner
#
# Processing token: 'matrix'-style'
# Preprocessed token: matrix style
# Individual tokens: ['matrix', 'style']
# Longest match in model: matrix
#
# Processing token: 'luhrmann'
# Preprocessed token: luhrmann
# Individual tokens: ['lehmann']
# Longest match in model: None
# Stemmed tokens: ['lehmann']
# Longest match in model: None
# Subwords for 'lehmann': ['▁le', 'h', 'mann']
# Best valid subword found: mann
#
# Processing token: 'tv-to-movie'
# Preprocessed token: tv to movie
# Individual tokens: ['to', 'to', 'movie']
# Longest match in model: movie
#
# Processing token: 'half-sleep'
# Preprocessed token: half sleep
# Individual tokens: ['half', 'sleep']
# Longest match in model: sleep
#
# Processing token: 'life-affirming'
# Preprocessed token: life affirming
# Individual tokens: ['life', 'affirming']
# Longest match in model: affirming
#
# Processing token: 'turkey-on-rolls'
# Preprocessed token: turkey on rolls
# Individual tokens: ['turkey', 'on', 'rolls']
# Longest match in model: turkey
#
# Processing token: '1920'
# Preprocessed token: 1920
# Individual tokens: ['1920']
# Longest match in model: None
# Stemmed tokens: ['1920']
# Longest match in model: None
# Subwords for '1920': ['▁19', '2', '0']
# Best valid subword found: 2
#
# Processing token: 'would-be'
# Preprocessed token: would be
# Individual tokens: ['would', 'be']
# Longest match in model: would
#
# Processing token: 'over-dramatic'
# Preprocessed token: over dramatic
# Individual tokens: ['over', 'dramatic']
# Longest match in model: dramatic
#
# Processing token: 'open-minded'
# Preprocessed token: open minded
# Individual tokens: ['open', 'minded']
# Longest match in model: minded
#
# Processing token: 'sinta'
# Preprocessed token: sinta
# Individual tokens: ['santa']
# Longest match in model: santa
#
# Processing token: 'penotti'
# Preprocessed token: penotti
# Individual tokens: ['menotti']
# Longest match in model: None
# Stemmed tokens: ['menotti']
# Longest match in model: None
# Subwords for 'menotti': ['▁men', 'otti']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'talking-head'
# Preprocessed token: talking head
# Individual tokens: ['talking', 'head']
# Longest match in model: talking
#
# Processing token: 'director-writer'
# Preprocessed token: director writer
# Individual tokens: ['director', 'writer']
# Longest match in model: director
#
# Processing token: 'a-knocking'
# Preprocessed token: a knocking
# Individual tokens: ['a', 'knocking']
# Longest match in model: knocking
#
# Processing token: 'wolodarsky'
# Preprocessed token: wolodarsky
# Individual tokens: ['wolodarsky']
# Longest match in model: None
# Stemmed tokens: ['wolodarski']
# Longest match in model: None
# Subwords for 'wolodarsky': ['▁wolodarsky']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: '12-step'
# Preprocessed token: 12 step
# Individual tokens: ['of', 'step']
# Longest match in model: step
#
# Processing token: ''the'
# Preprocessed token: the
# Individual tokens: ['the']
# Longest match in model: the
#
# Processing token: 'aren't-kids-cute'
# Preprocessed token: arent kids cute
# Individual tokens: ['agent', 'kids', 'cute']
# Longest match in model: agent
#
# Processing token: 'again-courage'
# Preprocessed token: again courage
# Individual tokens: ['again', 'courage']
# Longest match in model: courage
#
# Processing token: 'resultan'
# Preprocessed token: resultan
# Individual tokens: ['resultant']
# Longest match in model: resultant
#
# Processing token: 'b-minus'
# Preprocessed token: b minus
# Individual tokens: ['a', 'minus']
# Longest match in model: minus
#
# Processing token: 'soul-killing'
# Preprocessed token: soul killing
# Individual tokens: ['soul', 'killing']
# Longest match in model: killing
#
# Processing token: 'kid-empowerment'
# Preprocessed token: kid empowerment
# Individual tokens: ['kid', 'empowerment']
# Longest match in model: empowerment
#
# Processing token: 'achronological'
# Preprocessed token: achronological
# Individual tokens: ['chronological']
# Longest match in model: chronological
#
# Processing token: 'career-best'
# Preprocessed token: career best
# Individual tokens: ['career', 'best']
# Longest match in model: career
#
# Processing token: 'hit-or-miss'
# Preprocessed token: hit or miss
# Individual tokens: ['hit', 'or', 'miss']
# Longest match in model: miss
#
# Processing token: 'audacious-impossible'
# Preprocessed token: audacious impossible
# Individual tokens: ['audacious', 'impossible']
# Longest match in model: impossible
#
# Processing token: '3000'
# Preprocessed token: 3000
# Individual tokens: ['3000']
# Longest match in model: None
# Stemmed tokens: ['3000']
# Longest match in model: None
# Subwords for '3000': ['▁', '3', '000']
# Best valid subword found: 3
#
# Processing token: ':'
# Preprocessed token:
# Individual tokens: []
# Longest match in model: None
# Stemmed tokens: []
# Longest match in model: None
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'espectacular'
# Preprocessed token: espectacular
# Individual tokens: ['spectacular']
# Longest match in model: spectacular
#
# Processing token: 'bugsy'
# Preprocessed token: bugsy
# Individual tokens: ['bugs']
# Longest match in model: bugs
#
# Processing token: ''anyone'
# Preprocessed token: anyone
# Individual tokens: ['anyone']
# Longest match in model: anyone
#
# Processing token: 'middle-fingered'
# Preprocessed token: middle fingered
# Individual tokens: ['middle', 'fingered']
# Longest match in model: fingered
#
# Processing token: 'miike'
# Preprocessed token: miike
# Individual tokens: ['mike']
# Longest match in model: mike
#
# Processing token: 'herek'
# Preprocessed token: herek
# Individual tokens: ['here']
# Longest match in model: here
#
# Processing token: 'arquette'
# Preprocessed token: arquette
# Individual tokens: ['marquette']
# Longest match in model: None
# Stemmed tokens: ['marquett']
# Longest match in model: None
# Subwords for 'marquette': ['▁mar', 'quette']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'ziyi'
# Preprocessed token: ziyi
# Individual tokens: ['ziti']
# Longest match in model: ziti
#
# Processing token: 'fleet-footed'
# Preprocessed token: fleet footed
# Individual tokens: ['fleet', 'footed']
# Longest match in model: footed
#
# Processing token: 'nettelbeck'
# Preprocessed token: nettelbeck
# Individual tokens: ['nettelbeck']
# Longest match in model: None
# Stemmed tokens: ['nettelbeck']
# Longest match in model: None
# Subwords for 'nettelbeck': ['▁nettelbeck']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'three-ring'
# Preprocessed token: three ring
# Individual tokens: ['three', 'ring']
# Longest match in model: three
#
# Processing token: 'ayres'
# Preprocessed token: ayres
# Individual tokens: ['acres']
# Longest match in model: acres
#
# Processing token: 'nenette'
# Preprocessed token: nenette
# Individual tokens: ['nanette']
# Longest match in model: None
# Stemmed tokens: ['nanett']
# Longest match in model: None
# Subwords for 'nanette': ['▁nanette']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'first-rate'
# Preprocessed token: first rate
# Individual tokens: ['first', 'rate']
# Longest match in model: first
#
# Processing token: 'wild-and-woolly'
# Preprocessed token: wild and woolly
# Individual tokens: ['wild', 'and', 'woolly']
# Longest match in model: woolly
#
# Processing token: 'dead-end'
# Preprocessed token: dead end
# Individual tokens: ['dead', 'end']
# Longest match in model: dead
#
# Processing token: 'astoria'
# Preprocessed token: astoria
# Individual tokens: ['astoria']
# Longest match in model: None
# Stemmed tokens: ['astoria']
# Longest match in model: None
# Subwords for 'astoria': ['▁astoria']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'twohy'
# Preprocessed token: twohy
# Individual tokens: ['two']
# Longest match in model: two
#
# Processing token: 'actress-producer'
# Preprocessed token: actress producer
# Individual tokens: ['actress', 'producer']
# Longest match in model: producer
#
# Processing token: 'pompeo'
# Preprocessed token: pompeo
# Individual tokens: ['pompey']
# Longest match in model: pompey
#
# Processing token: 'wewannour'
# Preprocessed token: wewannour
# Individual tokens: ['wewannour']
# Longest match in model: None
# Stemmed tokens: ['wewannour']
# Longest match in model: None
# Subwords for 'wewannour': ['▁wewann', 'our']
# Best valid subword found: our
#
# Processing token: 'unrecommendable'
# Preprocessed token: unrecommendable
# Individual tokens: ['recommendable']
# Longest match in model: recommendable
#
# Processing token: 'over-familiarity'
# Preprocessed token: over familiarity
# Individual tokens: ['over', 'familiarity']
# Longest match in model: familiarity
#
# Processing token: 'one-liners'
# Preprocessed token: one liners
# Individual tokens: ['one', 'liners']
# Longest match in model: liners
#
# Processing token: '10-year-old'
# Preprocessed token: 10 year old
# Individual tokens: ['of', 'year', 'old']
# Longest match in model: year
#
# Processing token: 'arnie'
# Preprocessed token: arnie
# Individual tokens: ['annie']
# Longest match in model: annie
#
# Processing token: 'anti-virus'
# Preprocessed token: anti virus
# Individual tokens: ['anti', 'virus']
# Longest match in model: virus
#
# Processing token: 'maelström'
# Preprocessed token: maelström
# Individual tokens: ['maelstrom']
# Longest match in model: maelstrom
#
# Processing token: 'jelinek'
# Preprocessed token: jelinek
# Individual tokens: ['feline']
# Longest match in model: feline
#
# Processing token: 'send-up'
# Preprocessed token: send up
# Individual tokens: ['send', 'up']
# Longest match in model: send
#
# Processing token: 'ferrera'
# Preprocessed token: ferrera
# Individual tokens: ['herrera']
# Longest match in model: None
# Stemmed tokens: ['herrera']
# Longest match in model: None
# Subwords for 'herrera': ['▁herr', 'era']
# Best valid subword found: era
#
# Processing token: ''moore'
# Preprocessed token: moore
# Individual tokens: ['moore']
# Longest match in model: moore
#
# Processing token: 'christmas-tree'
# Preprocessed token: christmas tree
# Individual tokens: ['christmas', 'tree']
# Longest match in model: christmas
#
# Processing token: 'sandrine'
# Preprocessed token: sandrine
# Individual tokens: ['sanding']
# Longest match in model: sanding
#
# Processing token: 'camera-work'
# Preprocessed token: camera work
# Individual tokens: ['camera', 'work']
# Longest match in model: camera
#
# Processing token: 'must-own'
# Preprocessed token: must own
# Individual tokens: ['must', 'own']
# Longest match in model: must
#
# Processing token: 'desee'
# Preprocessed token: desee
# Individual tokens: ['see']
# Longest match in model: see
#
# Processing token: 'oh-those-wacky-brits'
# Preprocessed token: oh those wacky brits
# Individual tokens: ['of', 'those', 'wacky', 'brits']
# Longest match in model: those
#
# Processing token: '20th'
# Preprocessed token: 20th
# Individual tokens: ['with']
# Longest match in model: with
#
# Processing token: 'cliche-ridden'
# Preprocessed token: cliche ridden
# Individual tokens: ['cliche', 'ridden']
# Longest match in model: cliche
#
# Processing token: 'working-class'
# Preprocessed token: working class
# Individual tokens: ['working', 'class']
# Longest match in model: working
#
# Processing token: 'clericks'
# Preprocessed token: clericks
# Individual tokens: ['clerics']
# Longest match in model: clerics
#
# Processing token: 'sitcomishly'
# Preprocessed token: sitcomishly
# Individual tokens: ['sitcomishly']
# Longest match in model: None
# Stemmed tokens: ['sitcomishli']
# Longest match in model: None
# Subwords for 'sitcomishly': ['▁sitcom', 'ishly']
# Best valid subword found: ishly
#
# Processing token: ''triumph'
# Preprocessed token: triumph
# Individual tokens: ['triumph']
# Longest match in model: triumph
#
# Processing token: 'grey'
# Preprocessed token: grey
# Individual tokens: ['grey']
# Longest match in model: None
# Stemmed tokens: ['grey']
# Longest match in model: None
# Subwords for 'grey': ['▁grey']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'andersson'
# Preprocessed token: andersson
# Individual tokens: ['anderson']
# Longest match in model: anderson
#
# Processing token: 'ming-liang'
# Preprocessed token: ming liang
# Individual tokens: ['ming', 'lang']
# Longest match in model: ming
#
# Processing token: 'sequel-for-the-sake-'
# Preprocessed token: sequel for the sake
# Individual tokens: ['sequel', 'for', 'the', 'sake']
# Longest match in model: sequel
#
# Processing token: 'techno-sex'
# Preprocessed token: techno sex
# Individual tokens: ['techno', 'sex']
# Longest match in model: techno
#
# Processing token: 'beavis'
# Preprocessed token: beavis
# Individual tokens: ['leavis']
# Longest match in model: None
# Stemmed tokens: ['leavi']
# Longest match in model: None
# Subwords for 'leavis': ['▁le', 'avis']
# Best valid subword found: avis
#
# Processing token: 'near-masterpiece'
# Preprocessed token: near masterpiece
# Individual tokens: ['near', 'masterpiece']
# Longest match in model: masterpiece
#
# Processing token: 'fincher'
# Preprocessed token: fincher
# Individual tokens: ['fischer']
# Longest match in model: fischer
#
# Processing token: 'navajos'
# Preprocessed token: navajos
# Individual tokens: ['navajos']
# Longest match in model: None
# Stemmed tokens: ['navajo']
# Longest match in model: None
# Subwords for 'navajos': ['▁nava', 'jos']
# Best valid subword found: jos
#
# Processing token: ''unfaithful'
# Preprocessed token: unfaithful
# Individual tokens: ['unfaithful']
# Longest match in model: unfaithful
#
# Processing token: 'non-starter'
# Preprocessed token: non starter
# Individual tokens: ['non', 'starter']
# Longest match in model: starter
#
# Processing token: 'raimi'
# Preprocessed token: raimi
# Individual tokens: ['miami']
# Longest match in model: miami
#
# Processing token: 'pode'
# Preprocessed token: pode
# Individual tokens: ['code']
# Longest match in model: code
#
# Processing token: 'estrogen-free'
# Preprocessed token: estrogen free
# Individual tokens: ['oestrogen', 'free']
# Longest match in model: free
#
# Processing token: 'channel-style'
# Preprocessed token: channel style
# Individual tokens: ['channel', 'style']
# Longest match in model: channel
#
# Processing token: '11-year-old'
# Preprocessed token: 11 year old
# Individual tokens: ['of', 'year', 'old']
# Longest match in model: year
#
# Processing token: 'strafings'
# Preprocessed token: strafings
# Individual tokens: ['strafing']
# Longest match in model: strafing
#
# Processing token: 'prep-school'
# Preprocessed token: prep school
# Individual tokens: ['prep', 'school']
# Longest match in model: school
#
# Processing token: 'complejos'
# Preprocessed token: complejos
# Individual tokens: ['complexes']
# Longest match in model: complexes
#
# Processing token: 'certamente'
# Preprocessed token: certamente
# Individual tokens: ['certamente']
# Longest match in model: None
# Stemmed tokens: ['certament']
# Longest match in model: None
# Subwords for 'certamente': ['▁cert', 'amente']
# Best valid subword found: None
# No valid replacement found.
#
# ...
# Best valid subword found: ink
#
# Processing token: 'nuttgens'
# Preprocessed token: nuttgens
# Individual tokens: ['nutters']
# Longest match in model: nutters
#
# Processing token: 'gut-wrenching'
# Preprocessed token: gut wrenching
# Individual tokens: ['gut', 'wrenching']
# Longest match in model: wrenching
#
# Processing token: 'viveka'
# Preprocessed token: viveka
# Individual tokens: ['viva']
# Longest match in model: viva
#
# Processing token: 'navel-gazing'
# Preprocessed token: navel gazing
# Individual tokens: ['navel', 'gazing']
# Longest match in model: gazing
#
# Processing token: 'clearasil'
# Preprocessed token: clearasil
# Individual tokens: ['clearasil']
# Longest match in model: None
# Stemmed tokens: ['clearasil']
# Longest match in model: None
# Subwords for 'clearasil': ['▁clear', 'as', 'il']
# Best valid subword found: as
#
# Processing token: 'sydow'
# Preprocessed token: sydow
# Individual tokens: ['show']
# Longest match in model: show
#
# Processing token: 'point-and-shoot'
# Preprocessed token: point and shoot
# Individual tokens: ['point', 'and', 'shoot']
# Longest match in model: point
#
# Processing token: 'kinetically-charged'
# Preprocessed token: kinetically charged
# Individual tokens: ['kinetically', 'charged']
# Longest match in model: kinetically
#
# Processing token: 'yakusho'
# Preprocessed token: yakusho
# Individual tokens: ['yakusho']
# Longest match in model: None
# Stemmed tokens: ['yakusho']
# Longest match in model: None
# Subwords for 'yakusho': ['▁yakusho']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'semi-coherent'
# Preprocessed token: semi coherent
# Individual tokens: ['semi', 'coherent']
# Longest match in model: coherent
#
# Processing token: 'augustine'
# Preprocessed token: augustine
# Individual tokens: ['augustine']
# Longest match in model: None
# Stemmed tokens: ['augustin']
# Longest match in model: None
# Subwords for 'augustine': ['▁augustine']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'old-movie'
# Preprocessed token: old movie
# Individual tokens: ['old', 'movie']
# Longest match in model: movie
#
# Processing token: 'fizzability'
# Preprocessed token: fizzability
# Individual tokens: ['fizzability']
# Longest match in model: None
# Stemmed tokens: ['fizzabl']
# Longest match in model: None
# Subwords for 'fizzability': ['▁fizz', 'ability']
# Best valid subword found: ability
#
# Processing token: 'bone-dry'
# Preprocessed token: bone dry
# Individual tokens: ['bone', 'dry']
# Longest match in model: bone
#
# Processing token: 'accordion/harmonica/banjo'
# Preprocessed token: accordion harmonica banjo
# Individual tokens: ['accordion', 'harmonica', 'banjo']
# Longest match in model: accordion
#
# Processing token: ''bowling'
# Preprocessed token: bowling
# Individual tokens: ['bowling']
# Longest match in model: bowling
#
# Processing token: 'not-quite'
# Preprocessed token: not quite
# Individual tokens: ['not', 'quite']
# Longest match in model: quite
#
# Processing token: 'long-running'
# Preprocessed token: long running
# Individual tokens: ['long', 'running']
# Longest match in model: running
#
# Processing token: 'repellantly'
# Preprocessed token: repellantly
# Individual tokens: ['repellantly']
# Longest match in model: None
# Stemmed tokens: ['repellantli']
# Longest match in model: None
# Subwords for 'repellantly': ['▁rep', 'ell', 'antly']
# Best valid subword found: ell
#
# Processing token: 'saímos'
# Preprocessed token: saímos
# Individual tokens: ['samos']
# Longest match in model: None
# Stemmed tokens: ['samo']
# Longest match in model: samo
#
# Processing token: 'leontine'
# Preprocessed token: leontine
# Individual tokens: ['leonine']
# Longest match in model: leonine
#
# Processing token: ''deadly'
# Preprocessed token: deadly
# Individual tokens: ['deadly']
# Longest match in model: deadly
#
# Processing token: 'esforço'
# Preprocessed token: esforço
# Individual tokens: ['esforço']
# Longest match in model: None
# Stemmed tokens: ['esforço']
# Longest match in model: None
# Subwords for 'esforço': ['▁es', 'for', 'ç', 'o']
# Best valid subword found: for
#
# Processing token: ''assassin'
# Preprocessed token: assassin
# Individual tokens: ['assassin']
# Longest match in model: assassin
#
# Processing token: 'three-hour'
# Preprocessed token: three hour
# Individual tokens: ['three', 'hour']
# Longest match in model: three
#
# Processing token: '1899'
# Preprocessed token: 1899
# Individual tokens: ['1899']
# Longest match in model: None
# Stemmed tokens: ['1899']
# Longest match in model: None
# Subwords for '1899': ['▁18', '99']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: '401'
# Preprocessed token: 401
# Individual tokens: ['401']
# Longest match in model: None
# Stemmed tokens: ['401']
# Longest match in model: None
# Subwords for '401': ['▁', '4', '0', '1']
# Best valid subword found: 4
#
# Processing token: 'entretiene'
# Preprocessed token: entretiene
# Individual tokens: ['entretiene']
# Longest match in model: None
# Stemmed tokens: ['entretien']
# Longest match in model: None
# Subwords for 'entretiene': ['▁ent', 'ret', 'ien', 'e']
# Best valid subword found: ret
#
# Processing token: 'soul-stripping'
# Preprocessed token: soul stripping
# Individual tokens: ['soul', 'stripping']
# Longest match in model: stripping
#
# Processing token: 'new-agey'
# Preprocessed token: new agey
# Individual tokens: ['new', 'age']
# Longest match in model: new
#
# Processing token: 'shreve'
# Preprocessed token: shreve
# Individual tokens: ['three']
# Longest match in model: three
#
# Processing token: ''analyze'
# Preprocessed token: analyze
# Individual tokens: ['analyse']
# Longest match in model: None
# Stemmed tokens: ['analys']
# Longest match in model: analys
#
# Processing token: ''difficult'
# Preprocessed token: difficult
# Individual tokens: ['difficult']
# Longest match in model: difficult
#
# Processing token: 'huge-screen'
# Preprocessed token: huge screen
# Individual tokens: ['huge', 'screen']
# Longest match in model: screen
#
# Processing token: 'road-trip'
# Preprocessed token: road trip
# Individual tokens: ['road', 'trip']
# Longest match in model: road
#
# Processing token: 'outgag'
# Preprocessed token: outgag
# Individual tokens: ['outlaw']
# Longest match in model: outlaw
#
# Processing token: 'l'avventura'
# Preprocessed token: lavventura
# Individual tokens: ['lavventura']
# Longest match in model: None
# Stemmed tokens: ['lavventura']
# Longest match in model: None
# Subwords for 'lavventura': ['▁lav', 'vent', 'ura']
# Best valid subword found: vent
#
# Processing token: 'non-stop'
# Preprocessed token: non stop
# Individual tokens: ['non', 'stop']
# Longest match in model: stop
#
# Processing token: 'hopped-up'
# Preprocessed token: hopped up
# Individual tokens: ['hopped', 'up']
# Longest match in model: hopped
#
# Processing token: 'schrader'
# Preprocessed token: schrader
# Individual tokens: ['schroeder']
# Longest match in model: None
# Stemmed tokens: ['schroeder']
# Longest match in model: None
# Subwords for 'schroeder': ['▁sch', 'ro', 'ed', 'er']
# Best valid subword found: ro
#
# Processing token: 'well-realized'
# Preprocessed token: well realized
# Individual tokens: ['well', 'realized']
# Longest match in model: realized
#
# Processing token: 'tongue-in-cheek'
# Preprocessed token: tongue in cheek
# Individual tokens: ['tongue', 'in', 'cheek']
# Longest match in model: tongue
#
# Processing token: ''wayne'
# Preprocessed token: wayne
# Individual tokens: ['wayne']
# Longest match in model: wayne
#
# Processing token: 'old-world'
# Preprocessed token: old world
# Individual tokens: ['old', 'world']
# Longest match in model: world
#
# Processing token: 'shuck-and-jive'
# Preprocessed token: shuck and jive
# Individual tokens: ['shuck', 'and', 'jive']
# Longest match in model: shuck
#
# Processing token: '12-year-old'
# Preprocessed token: 12 year old
# Individual tokens: ['of', 'year', 'old']
# Longest match in model: year
#
# Processing token: 'b-12'
# Preprocessed token: b 12
# Individual tokens: ['a', 'of']
# Longest match in model: None
# Stemmed tokens: ['a', 'of']
# Longest match in model: None
# Subwords for 'a': ['▁a']
# Subwords for 'of': ['▁of']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'self-assured'
# Preprocessed token: self assured
# Individual tokens: ['self', 'assured']
# Longest match in model: assured
#
# Processing token: 'sweet-tempered'
# Preprocessed token: sweet tempered
# Individual tokens: ['sweet', 'tempered']
# Longest match in model: tempered
#
# Processing token: 'quasi-original'
# Preprocessed token: quasi original
# Individual tokens: ['quasi', 'original']
# Longest match in model: original
#
# Processing token: 'brazil-like'
# Preprocessed token: brazil like
# Individual tokens: ['brazil', 'like']
# Longest match in model: brazil
#
# Processing token: 'minac'
# Preprocessed token: minac
# Individual tokens: ['final']
# Longest match in model: final
#
# Processing token: 'revigorates'
# Preprocessed token: revigorates
# Individual tokens: ['invigorates']
# Longest match in model: invigorates
#
# Processing token: 'mad-libs'
# Preprocessed token: mad libs
# Individual tokens: ['mad', 'lib']
# Longest match in model: mad
#
# Processing token: 'less-than-thrilling'
# Preprocessed token: less than thrilling
# Individual tokens: ['less', 'than', 'thrilling']
# Longest match in model: thrilling
#
# Processing token: 'contando'
# Preprocessed token: contando
# Individual tokens: ['contango']
# Longest match in model: contango
#
# Processing token: 'felinni'
# Preprocessed token: felinni
# Individual tokens: ['feline']
# Longest match in model: feline
#
# Processing token: 'jaglom'
# Preprocessed token: jaglom
# Individual tokens: ['aglow']
# Longest match in model: aglow
#
# Processing token: 'hitchcockian'
# Preprocessed token: hitchcockian
# Individual tokens: ['hitchcockian']
# Longest match in model: None
# Stemmed tokens: ['hitchcockian']
# Longest match in model: None
# Subwords for 'hitchcockian': ['▁hitchcockian']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'munchausen-by-proxy'
# Preprocessed token: munchausen by proxy
# Individual tokens: ['munchausen', 'by', 'proxy']
# Longest match in model: proxy
#
# Processing token: 'headbangingly'
# Preprocessed token: headbangingly
# Individual tokens: ['headbanging']
# Longest match in model: headbanging
#
# Processing token: ''70'
# Preprocessed token: 70
# Individual tokens: ['of']
# Longest match in model: None
# Stemmed tokens: ['of']
# Longest match in model: None
# Subwords for 'of': ['▁of']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'leguizamo'
# Preprocessed token: leguizamo
# Individual tokens: ['leguizamo']
# Longest match in model: None
# Stemmed tokens: ['leguizamo']
# Longest match in model: None
# Subwords for 'leguizamo': ['▁leguizamo']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'ruggero'
# Preprocessed token: ruggero
# Individual tokens: ['rugger']
# Longest match in model: rugger
#
# Processing token: 'walking-dead'
# Preprocessed token: walking dead
# Individual tokens: ['walking', 'dead']
# Longest match in model: walking
#
# Processing token: 'thulani'
# Preprocessed token: thulani
# Individual tokens: ['tulane']
# Longest match in model: None
# Stemmed tokens: ['tulan']
# Longest match in model: None
# Subwords for 'tulane': ['▁t', 'ul', 'ane']
# Best valid subword found: ane
#
# Processing token: 'cleanflicks'
# Preprocessed token: cleanflicks
# Individual tokens: ['cleanflicks']
# Longest match in model: None
# Stemmed tokens: ['cleanflick']
# Longest match in model: None
# Subwords for 'cleanflicks': ['▁cleanfl', 'icks']
# Best valid subword found: icks
#
# Processing token: 'cagney'
# Preprocessed token: cagney
# Individual tokens: ['cagney']
# Longest match in model: None
# Stemmed tokens: ['cagney']
# Longest match in model: None
# Subwords for 'cagney': ['▁c', 'ag', 'ney']
# Best valid subword found: ney
#
# Processing token: 'mcbeal-style'
# Preprocessed token: mcbeal style
# Individual tokens: ['meal', 'style']
# Longest match in model: style
#
# Processing token: 'giovanni'
# Preprocessed token: giovanni
# Individual tokens: ['giovanni']
# Longest match in model: None
# Stemmed tokens: ['giovanni']
# Longest match in model: None
# Subwords for 'giovanni': ['▁gi', 'ov', 'anni']
# Best valid subword found: anni
#
# Processing token: 'sandler'
# Preprocessed token: sandler
# Individual tokens: ['handler']
# Longest match in model: handler
#
# Processing token: 'redneck-versus-blueblood'
# Preprocessed token: redneck versus blueblood
# Individual tokens: ['redneck', 'versus', 'blueblood']
# Longest match in model: blueblood
#
# Processing token: 'pie-type'
# Preprocessed token: pie type
# Individual tokens: ['pie', 'type']
# Longest match in model: type
#
# Processing token: 'musset'
# Preprocessed token: musset
# Individual tokens: ['musset']
# Longest match in model: None
# Stemmed tokens: ['musset']
# Longest match in model: None
# Subwords for 'musset': ['▁musset']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'gasp-inducing'
# Preprocessed token: gasp inducing
# Individual tokens: ['gasp', 'inducing']
# Longest match in model: inducing
#
# Processing token: 'well-paced'
# Preprocessed token: well paced
# Individual tokens: ['well', 'paced']
# Longest match in model: paced
#
# Processing token: 'oscar-caliber'
# Preprocessed token: oscar caliber
# Individual tokens: ['oscar', 'caliper']
# Longest match in model: caliper
#
# Processing token: 'neuwirth'
# Preprocessed token: neuwirth
# Individual tokens: ['neuwirth']
# Longest match in model: None
# Stemmed tokens: ['neuwirth']
# Longest match in model: None
# Subwords for 'neuwirth': ['▁ne', 'uwirth']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'gyllenhaal'
# Preprocessed token: gyllenhaal
# Individual tokens: ['gyllenhaal']
# Longest match in model: None
# Stemmed tokens: ['gyllenha']
# Longest match in model: None
# Subwords for 'gyllenhaal': ['▁gyllenhaal']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'bigelow'
# Preprocessed token: bigelow
# Individual tokens: ['below']
# Longest match in model: below
#
# Processing token: 'two-actor'
# Preprocessed token: two actor
# Individual tokens: ['two', 'actor']
# Longest match in model: actor
#
# Processing token: ''brazil'
# Preprocessed token: brazil
# Individual tokens: ['brazil']
# Longest match in model: brazil
#
# Processing token: ''chick'
# Preprocessed token: chick
# Individual tokens: ['chick']
# Longest match in model: chick
#
# Processing token: '2455'
# Preprocessed token: 2455
# Individual tokens: ['2455']
# Longest match in model: None
# Stemmed tokens: ['2455']
# Longest match in model: None
# Subwords for '2455': ['▁2', '4', '5', '5']
# Best valid subword found: 4
#
# Processing token: 'full-bodied'
# Preprocessed token: full bodied
# Individual tokens: ['full', 'bodied']
# Longest match in model: bodied
#
# Processing token: 'behaviour'
# Preprocessed token: behaviour
# Individual tokens: ['behaviour']
# Longest match in model: None
# Stemmed tokens: ['behaviour']
# Longest match in model: None
# Subwords for 'behaviour': ['▁behaviour']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'macgraw'
# Preprocessed token: macgraw
# Individual tokens: ['macaw']
# Longest match in model: macaw
#
# Processing token: 'action/comedy'
# Preprocessed token: action comedy
# Individual tokens: ['action', 'comedy']
# Longest match in model: action
#
# Processing token: 'hellstenius'
# Preprocessed token: hellstenius
# Individual tokens: ['hellstenius']
# Longest match in model: None
# Stemmed tokens: ['hellsteniu']
# Longest match in model: None
# Subwords for 'hellstenius': ['▁hell', 'stenius']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: 'freundlich'
# Preprocessed token: freundlich
# Individual tokens: ['freundlich']
# Longest match in model: None
# Stemmed tokens: ['freundlich']
# Longest match in model: None
# Subwords for 'freundlich': ['▁freundlich']
# Best valid subword found: None
# No valid replacement found.
#
# Processing token: ''we'
# Preprocessed token: we
# Individual tokens: ['we']
# Longest match in model: we
#
# Processing token: 'sixties-style'
# Preprocessed token: sixties style
# Individual tokens: ['sixties', 'style']
# Longest match in model: sixties
#
# Processing token: 'snazziness'
# Preprocessed token: snazziness
# Individual tokens: ['snazziness']
# Longest match in model: None
# Stemmed tokens: ['snazzi']
# Longest match in model: None
# Subwords for 'snazziness': ['▁sn', 'azz', 'iness']
# Best valid subword found: iness

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) Freeze Word Embeddings

# %%
# Call grid search
best_hyperparams_OOV_freeze = run_grid_search(MaxPoolingRNNModel, embedding_matrix_spelling_bpe, hidden_dim, output_dim, train_sequences, train_labels,
                                              validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6938, Train Acc: 0.5090, Val Acc: 0.5113
# Epoch 2, Train Loss: 0.6908, Train Acc: 0.5375, Val Acc: 0.5235
# Epoch 3, Train Loss: 0.6885, Train Acc: 0.5387, Val Acc: 0.5347
# Epoch 4, Train Loss: 0.6879, Train Acc: 0.5453, Val Acc: 0.5385
# Epoch 5, Train Loss: 0.6856, Train Acc: 0.5495, Val Acc: 0.5375
# Epoch 6, Train Loss: 0.6862, Train Acc: 0.5521, Val Acc: 0.5403
# Epoch 7, Train Loss: 0.6842, Train Acc: 0.5519, Val Acc: 0.5478
# Epoch 8, Train Loss: 0.6844, Train Acc: 0.5511, Val Acc: 0.5525
# Epoch 9, Train Loss: 0.6828, Train Acc: 0.5610, Val Acc: 0.5441
# Epoch 10, Train Loss: 0.6831, Train Acc: 0.5618, Val Acc: 0.5413
# Epoch 11, Train Loss: 0.6816, Train Acc: 0.5605, Val Acc: 0.5469
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6943, Train Acc: 0.5434, Val Acc: 0.5582
# Epoch 2, Train Loss: 0.6723, Train Acc: 0.5876, Val Acc: 0.5835
# Epoch 3, Train Loss: 0.6035, Train Acc: 0.6667, Val Acc: 0.7148
# Epoch 4, Train Loss: 0.5402, Train Acc: 0.7218, Val Acc: 0.7233
# Epoch 5, Train Loss: 0.5242, Train Acc: 0.7345, Val Acc: 0.7251
# Epoch 6, Train Loss: 0.5155, Train Acc: 0.7420, Val Acc: 0.7289
# Epoch 7, Train Loss: 0.5081, Train Acc: 0.7451, Val Acc: 0.7430
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=RMSprop
# Epoch 1, Train Loss: 23.0139, Train Acc: 0.4993, Val Acc: 0.5000
# Epoch 2, Train Loss: 13.0388, Train Acc: 0.4993, Val Acc: 0.5000
# Epoch 3, Train Loss: 12.4917, Train Acc: 0.4974, Val Acc: 0.5000
# Epoch 4, Train Loss: 11.5557, Train Acc: 0.5005, Val Acc: 0.5009
# Epoch 5, Train Loss: 11.2822, Train Acc: 0.5015, Val Acc: 0.4991
# Epoch 6, Train Loss: 11.6200, Train Acc: 0.5053, Val Acc: 0.5544
# Epoch 7, Train Loss: 11.5323, Train Acc: 0.4973, Val Acc: 0.5638
# Epoch 8, Train Loss: 12.6895, Train Acc: 0.5087, Val Acc: 0.5000
# Epoch 9, Train Loss: 13.0568, Train Acc: 0.5059, Val Acc: 0.5000
# Epoch 10, Train Loss: 13.0220, Train Acc: 0.4962, Val Acc: 0.5000
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adagrad
# Epoch 1, Train Loss: 1.3905, Train Acc: 0.5198, Val Acc: 0.5141
# Epoch 2, Train Loss: 0.7620, Train Acc: 0.5469, Val Acc: 0.5413
# Epoch 3, Train Loss: 0.7049, Train Acc: 0.5679, Val Acc: 0.5103
# Epoch 4, Train Loss: 0.6894, Train Acc: 0.5856, Val Acc: 0.5328
# Epoch 5, Train Loss: 0.6850, Train Acc: 0.5880, Val Acc: 0.5366
# Early stopping
# Best Validation Accuracy: 0.7870544090056285
# Best Hyperparameters: {'lr': 0.01, 'batch_size': 16, 'optimizer': 'Adagrad'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_OOV_freeze['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_OOV_freeze = MaxPoolingRNNModel(embedding_matrix_spelling_bpe, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_OOV_freeze['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
elif best_hyperparams_OOV_freeze['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
elif best_hyperparams_OOV_freeze['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
elif best_hyperparams_OOV_freeze['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_OOV_freeze.parameters(), lr=best_hyperparams_OOV_freeze['lr'])
best_model_OOV_freeze, train_losses, train_accuracies, val_accuracies = train_model(best_model_OOV_freeze, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.6990, Train Acc: 0.5433, Val Acc: 0.5600
# Epoch 2, Train Loss: 0.6595, Train Acc: 0.6048, Val Acc: 0.5657
# Epoch 3, Train Loss: 0.5893, Train Acc: 0.6824, Val Acc: 0.7064
# Epoch 4, Train Loss: 0.5378, Train Acc: 0.7319, Val Acc: 0.6379
# Epoch 5, Train Loss: 0.5111, Train Acc: 0.7464, Val Acc: 0.7402
# Epoch 6, Train Loss: 0.4935, Train Acc: 0.7565, Val Acc: 0.7617
# Epoch 7, Train Loss: 0.4774, Train Acc: 0.7672, Val Acc: 0.6998
# Epoch 8, Train Loss: 0.4697, Train Acc: 0.7742, Val Acc: 0.6886
# Epoch 9, Train Loss: 0.4590, Train Acc: 0.7795, Val Acc: 0.7655
# Epoch 10, Train Loss: 0.4534, Train Acc: 0.7848, Val Acc: 0.7608
# Epoch 11, Train Loss: 0.4457, Train Acc: 0.7893, Val Acc: 0.7214
# Epoch 12, Train Loss: 0.4375, Train Acc: 0.7926, Val Acc: 0.6698
# Early stopping

# %%
epochs_fw = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_fw, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_OOV_freeze, test_loader)
test_accuracies['RNN (Handle OOV)'] = test_acc
print(f'Test Accuracy (Handle OOV): {test_acc:.4f}')
# Out:
# Test Accuracy (Handle OOV): 0.6538

# %% [markdown]
# ### 2) Update Word Embeddings

# %%
# Call grid search
best_hyperparams_OOV_update = run_grid_search(MaxPoolingRNNModelUpdate, embedding_matrix_spelling_bpe, hidden_dim, output_dim, train_sequences, train_labels,
                                   validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6938, Train Acc: 0.5202, Val Acc: 0.5338
# Epoch 2, Train Loss: 0.6900, Train Acc: 0.5352, Val Acc: 0.5497
# Epoch 3, Train Loss: 0.6876, Train Acc: 0.5454, Val Acc: 0.5572
# Epoch 4, Train Loss: 0.6864, Train Acc: 0.5508, Val Acc: 0.5460
# Epoch 5, Train Loss: 0.6858, Train Acc: 0.5465, Val Acc: 0.5572
# Epoch 6, Train Loss: 0.6846, Train Acc: 0.5533, Val Acc: 0.5572
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6684, Train Acc: 0.5871, Val Acc: 0.6811
# Epoch 2, Train Loss: 0.4841, Train Acc: 0.7652, Val Acc: 0.7645
# Epoch 3, Train Loss: 0.3054, Train Acc: 0.8743, Val Acc: 0.7814
# Epoch 4, Train Loss: 0.1857, Train Acc: 0.9273, Val Acc: 0.7617
# Epoch 5, Train Loss: 0.1175, Train Acc: 0.9563, Val Acc: 0.7251
# Epoch 6, Train Loss: 0.0738, Train Acc: 0.9748, Val Acc: 0.7458
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss: 0.7024, Train Acc: 0.5434, Val Acc: 0.5347
# Epoch 2, Train Loss: 0.5875, Train Acc: 0.6800, Val Acc: 0.7158
# Epoch 3, Train Loss: 0.4204, Train Acc: 0.7974, Val Acc: 0.7711
# Epoch 4, Train Loss: 0.3191, Train Acc: 0.8611, Val Acc: 0.7861
# Epoch 5, Train Loss: 0.2417, Train Acc: 0.9039, Val Acc: 0.7645
# Epoch 6, Train Loss: 0.1864, Train Acc: 0.9234, Val Acc: 0.7795
# Epoch 7, Train Loss: 0.1409, Train Acc: 0.9467, Val Acc: 0.7017
# Epoch 7, Train Loss: 0.4052, Train Acc: 0.7970, Val Acc: 0.6379
# Epoch 8, Train Loss: 0.3530, Train Acc: 0.8400, Val Acc: 0.6801
# Epoch 9, Train Loss: 0.3091, Train Acc: 0.8665, Val Acc: 0.6989
# Epoch 10, Train Loss: 0.2762, Train Acc: 0.8836, Val Acc: 0.6839
# Epoch 11, Train Loss: 0.2504, Train Acc: 0.8925, Val Acc: 0.6886
# Epoch 12, Train Loss: 0.2120, Train Acc: 0.9113, Val Acc: 0.7176
# Epoch 13, Train Loss: 0.1785, Train Acc: 0.9305, Val Acc: 0.7139
# Epoch 14, Train Loss: 0.1489, Train Acc: 0.9458, Val Acc: 0.7176
# Epoch 15, Train Loss: 0.1318, Train Acc: 0.9529, Val Acc: 0.7167
# Early stopping
# Best Validation Accuracy: 0.7861163227016885
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 16, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_OOV_update['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_OOV_update = MaxPoolingRNNModelUpdate(embedding_matrix_spelling_bpe, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_OOV_update['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
elif best_hyperparams_OOV_update['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
elif best_hyperparams_OOV_update['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
elif best_hyperparams_OOV_update['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_OOV_update.parameters(), lr=best_hyperparams_OOV_update['lr'])
best_model_OOV_update, train_losses, train_accuracies, val_accuracies = train_model(best_model_OOV_update, train_loader, validation_loader,
                                                                                    best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.7048, Train Acc: 0.5472, Val Acc: 0.5235
# Epoch 2, Train Loss: 0.6337, Train Acc: 0.6308, Val Acc: 0.5797
# Epoch 3, Train Loss: 0.4694, Train Acc: 0.7766, Val Acc: 0.7383
# Epoch 4, Train Loss: 0.3504, Train Acc: 0.8449, Val Acc: 0.6942
# Epoch 5, Train Loss: 0.2772, Train Acc: 0.8849, Val Acc: 0.7739
# Epoch 6, Train Loss: 0.2170, Train Acc: 0.9101, Val Acc: 0.7570
# Epoch 7, Train Loss: 0.1658, Train Acc: 0.9369, Val Acc: 0.6689
# Epoch 8, Train Loss: 0.1262, Train Acc: 0.9539, Val Acc: 0.7636
# Early stopping

# %%
epochs_w = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_w, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_OOV_update, test_loader)
test_accuracies['RNN (Handle OOV with Word Embeddings Update)'] = test_acc
print(f'Test Accuracy (Handle OOV with Word Embeddings Update): {test_acc:.4f}')
# Out:
# Test Accuracy (Handle OOV with Word Embeddings Update): 0.7992

# %% [markdown]
# ### (c) Report the accuracy scores of biLSTM and biGRU on the test set (Part 3.3).

# %%
# Define BiLSTM and BiGRU models
class BiLSTMModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(BiLSTMModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, bidirectional=True).to(device)
        self.fc = nn.Linear(hidden_dim * 2, output_dim).to(device)  # Multiplied by 2 for bidirection
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        lstm_output, _ = self.lstm(embedded)  # Shape: [batch_size, seq_len, hidden_dim * 2]
        # Apply max pooling over the output of the LSTM
        max_pooled, _ = torch.max(lstm_output, dim=1)  # Shape: [batch_size, hidden_dim * 2]
        output = self.fc(max_pooled)
        return output

class BiGRUModel(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim, output_dim):
        super(BiGRUModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True, bidirectional=True).to(device)
        self.fc = nn.Linear(hidden_dim * 2, output_dim).to(device)  # Multiplied by 2 for bidirection
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        gru_output, _ = self.gru(embedded)  # Shape: [batch_size, seq_len, hidden_dim * 2]
        # Apply max pooling over the output of the GRU
        max_pooled, _ = torch.max(gru_output, dim=1)  # Shape: [batch_size, hidden_dim * 2]
        output = self.fc(max_pooled)
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %% [markdown]
# ### 1) biLSTM

# %%
# Call grid search
best_hyperparams_biLSTM = run_grid_search(BiLSTMModel, embedding_matrix_spelling_bpe, hidden_dim, output_dim, train_sequences, train_labels,
                                          validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.
# Early stopping
# Best Validation Accuracy: 0.797373358348968
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_biLSTM['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_biLSTM = BiLSTMModel(embedding_matrix_spelling_bpe, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_biLSTM['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
elif best_hyperparams_biLSTM['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
elif best_hyperparams_biLSTM['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
elif best_hyperparams_biLSTM['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_biLSTM.parameters(), lr=best_hyperparams_biLSTM['lr'])
best_model_biLSTM, train_losses, train_accuracies, val_accuracies = train_model(best_model_biLSTM, train_loader, validation_loader,
                                                                                best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5836, Train Acc: 0.6842, Val Acc: 0.7739
# Epoch 2, Train Loss: 0.3377, Train Acc: 0.8526, Val Acc: 0.7720
# Epoch 3, Train Loss: 0.2169, Train Acc: 0.9141, Val Acc: 0.7617
# Epoch 4, Train Loss: 0.1254, Train Acc: 0.9525, Val Acc: 0.7758
# Epoch 5, Train Loss: 0.0739, Train Acc: 0.9720, Val Acc: 0.7627
# Epoch 6, Train Loss: 0.0389, Train Acc: 0.9858, Val Acc: 0.7702
# Epoch 7, Train Loss: 0.0211, Train Acc: 0.9936, Val Acc: 0.7720
# Early stopping

# %%
epochs_bi = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_bi, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_biLSTM, test_loader)
test_accuracies['biLSTM'] = test_acc
print(f'Test Accuracy (biLSTM): {test_acc:.4f}')
# Out:
# Test Accuracy (biLSTM): 0.7833

# %% [markdown]
# ### 2) biGRU

# %%
# Call grid search
best_hyperparams_biGRU = run_grid_search(BiGRUModel, embedding_matrix_spelling_bpe, hidden_dim, output_dim, train_sequences, train_labels,
                                         validation_sequences, validation_labels, criterion, epochs, patience)
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.
# Epoch 10, Train Loss: 0.0015, Train Acc: 1.0000, Val Acc: 0.7326
# Early stopping
# Best Validation Accuracy: 0.797373358348968
# Best Hyperparameters: {'lr': 0.001, 'batch_size': 32, 'optimizer': 'RMSprop'}

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_biGRU['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_biGRU = BiGRUModel(embedding_matrix_spelling_bpe, hidden_dim, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_biGRU['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
elif best_hyperparams_biGRU['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
elif best_hyperparams_biGRU['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
elif best_hyperparams_biGRU['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_biGRU.parameters(), lr=best_hyperparams_biGRU['lr'])
best_model_biGRU, train_losses, train_accuracies, val_accuracies = train_model(best_model_biGRU, train_loader, validation_loader,
                                                                               best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.5852, Train Acc: 0.6893, Val Acc: 0.7861
# Epoch 2, Train Loss: 0.3368, Train Acc: 0.8532, Val Acc: 0.7645
# Epoch 3, Train Loss: 0.2179, Train Acc: 0.9122, Val Acc: 0.7964
# Epoch 4, Train Loss: 0.1282, Train Acc: 0.9496, Val Acc: 0.7711
# Epoch 5, Train Loss: 0.0676, Train Acc: 0.9761, Val Acc: 0.7674
# Epoch 6, Train Loss: 0.0401, Train Acc: 0.9845, Val Acc: 0.7814
# Early stopping

# %%
epochs_big = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_big, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_biGRU, test_loader)
test_accuracies['biGRU'] = test_acc
print(f'Test Accuracy (biGRU): {test_acc:.4f}')
# Out:
# Test Accuracy (biGRU): 0.8039

# %% [markdown]
# ### (d) Report the accuracy scores of CNN on the test set (Part 3.4).

# %%
# Define CNN Model
class CNNModel(nn.Module):
    def __init__(self, embedding_matrix, output_dim):
        super(CNNModel, self).__init__()
        vocab_size, embedding_dim = embedding_matrix.shape
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float32), freeze=False).to(device)
        self.conv1 = nn.Conv2d(1, 100, (3, embedding_dim)).to(device)  # 1 input channel, 100 output channels
        self.fc = nn.Linear(100, output_dim).to(device)
        self.dropout = nn.Dropout(0.3).to(device)

    def forward(self, x):
        embedded = self.embedding(x).unsqueeze(1)  # Add channel dimension
        conv_out = self.conv1(embedded).squeeze(3)  # Shape: (batch_size, 100, sequence_length - filter_size + 1)
        conv_out = torch.relu(conv_out)  # Apply ReLU
        pooled = nn.functional.max_pool1d(conv_out, conv_out.size(2)).squeeze(2)  # Max pooling
        output = self.fc(self.dropout(pooled))
        return output

# %%
# Model parameters
hidden_dim = 256
output_dim = 2  # Binary classification: positive/negative

# Define loss function, and other constants
criterion = nn.CrossEntropyLoss()
epochs = 20
patience = 3  # Early stopping patience

# %%
best_val_acc = 0
best_hyperparams_CNN = {}

# Prepare datasets
train_data = TensorDataset(train_sequences.to(device), train_labels.to(device))
validation_data = TensorDataset(validation_sequences.to(device), validation_labels.to(device))

# Grid search
for lr in learning_rates:
    for batch_size in batch_sizes:
        for opt in optimizers:
            print(f"Training with lr={lr}, batch_size={batch_size}, optimizer={opt}")

            # Set up DataLoader with the current batch size
            train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
            validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)

            # Initialize a new model for each set of hyperparameters
            model = CNNModel(embedding_matrix=embedding_matrix_spelling_bpe, output_dim=output_dim)  # Reinitialize model
            model = model.to(device)

            # Choose optimizer
            if opt == 'SGD':
                optimizer = optim.SGD(model.parameters(), lr=lr)
            elif opt == 'Adam':
                optimizer = optim.Adam(model.parameters(), lr=lr)
            elif opt == 'RMSprop':
                optimizer = optim.RMSprop(model.parameters(), lr=lr)
            elif opt == 'Adagrad':
                optimizer = optim.Adagrad(model.parameters(), lr=lr)
            # Train and evaluate the model
            val_acc, _, _, _ = train_and_evaluate_model(model, train_loader, validation_loader, optimizer, criterion, epochs, patience)


            # Track the best configuration based on validation accuracy
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_hyperparams = {'lr': lr, 'batch_size': batch_size, 'optimizer': opt}

print(f"Best Validation Accuracy: {best_val_acc}")
print(f"Best Hyperparameters: {best_hyperparams}")
# Out:
# Training with lr=0.001, batch_size=16, optimizer=SGD
# Epoch 1, Train Loss: 0.6983, Train Acc: 0.5120, Val Acc: 0.5375
# Epoch 2, Train Loss: 0.6883, Train Acc: 0.5472, Val Acc: 0.5413
# Epoch 3, Train Loss: 0.6892, Train Acc: 0.5449, Val Acc: 0.5629
# Epoch 4, Train Loss: 0.6858, Train Acc: 0.5505, Val Acc: 0.5657
# Epoch 5, Train Loss: 0.6849, Train Acc: 0.5546, Val Acc: 0.5591
# Epoch 6, Train Loss: 0.6818, Train Acc: 0.5664, Val Acc: 0.5535
# Epoch 7, Train Loss: 0.6776, Train Acc: 0.5741, Val Acc: 0.5563
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=Adam
# Epoch 1, Train Loss: 0.6774, Train Acc: 0.5943, Val Acc: 0.7008
# Epoch 2, Train Loss: 0.4505, Train Acc: 0.7899, Val Acc: 0.7383
# Epoch 3, Train Loss: 0.2578, Train Acc: 0.8948, Val Acc: 0.7411
# Epoch 4, Train Loss: 0.1313, Train Acc: 0.9533, Val Acc: 0.7598
# Epoch 5, Train Loss: 0.0676, Train Acc: 0.9777, Val Acc: 0.7533
# Epoch 6, Train Loss: 0.0292, Train Acc: 0.9903, Val Acc: 0.7495
# Epoch 7, Train Loss: 0.0186, Train Acc: 0.9939, Val Acc: 0.7364
# Early stopping
# Training with lr=0.001, batch_size=16, optimizer=RMSprop
# Epoch 1, Train Loss:
# Early stopping
# Training with lr=0.1, batch_size=64, optimizer=Adagrad
# Epoch 1, Train Loss: 2.0688, Train Acc: 0.6069, Val Acc: 0.6116
# Epoch 2, Train Loss: 0.3574, Train Acc: 0.8495, Val Acc: 0.7233
# Epoch 3, Train Loss: 0.1290, Train Acc: 0.9552, Val Acc: 0.7298
# Epoch 4, Train Loss: 0.0432, Train Acc: 0.9877, Val Acc: 0.7420
# Epoch 5, Train Loss: 0.0229, Train Acc: 0.9936, Val Acc: 0.7383
# Epoch 6, Train Loss: 0.0114, Train Acc: 0.9972, Val Acc: 0.7261
# Epoch 7, Train Loss: 0.0101, Train Acc: 0.9973, Val Acc: 0.7280
# Early stopping
# Best Validation Accuracy: 0.7804878048780488
# Best Hyperparameters: {'lr': 0.005, 'batch_size': 16, 'optimizer': 'Adagrad'}

# %%
best_hyperparams_CNN = best_hyperparams

# %%
# Create DataLoader for mini-batch strategy
batch_size = best_hyperparams_CNN['batch_size']
train_data = TensorDataset(train_sequences, train_labels)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)

validation_data = TensorDataset(validation_sequences, validation_labels)
validation_loader = DataLoader(validation_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(test_sequences, test_labels)
test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size)

# %%
# Retrain using best hyperparameters
best_model_CNN = CNNModel(embedding_matrix_spelling_bpe, output_dim).to(device)

# Dynamically select the optimizer based on the best hyperparameters
if best_hyperparams_CNN['optimizer'] == 'SGD':
    best_optimizer = optim.SGD(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
elif best_hyperparams_CNN['optimizer'] == 'Adam':
    best_optimizer = optim.Adam(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
elif best_hyperparams_CNN['optimizer'] == 'RMSprop':
    best_optimizer = optim.RMSprop(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
elif best_hyperparams_CNN['optimizer']=='Adagrad':
    best_optimizer = optim.Adagrad(best_model_CNN.parameters(), lr=best_hyperparams_CNN['lr'])
best_model_CNN, train_losses, train_accuracies, val_accuracies = train_model(best_model_CNN, train_loader, validation_loader,
                                                                             best_optimizer, criterion, epochs, patience)
# Out:
# Epoch 1, Train Loss: 0.7041, Train Acc: 0.5667, Val Acc: 0.6454
# Epoch 2, Train Loss: 0.6067, Train Acc: 0.6878, Val Acc: 0.6848
# Epoch 3, Train Loss: 0.5100, Train Acc: 0.7778, Val Acc: 0.7608
# Epoch 4, Train Loss: 0.4134, Train Acc: 0.8306, Val Acc: 0.7627
# Epoch 5, Train Loss: 0.3499, Train Acc: 0.8611, Val Acc: 0.7730
# Epoch 6, Train Loss: 0.3004, Train Acc: 0.8907, Val Acc: 0.7627
# Epoch 7, Train Loss: 0.2570, Train Acc: 0.9068, Val Acc: 0.7805
# Epoch 8, Train Loss: 0.2267, Train Acc: 0.9234, Val Acc: 0.7739
# Epoch 9, Train Loss: 0.1956, Train Acc: 0.9361, Val Acc: 0.7777
# Epoch 10, Train Loss: 0.1716, Train Acc: 0.9456, Val Acc: 0.7824
# Epoch 11, Train Loss: 0.1525, Train Acc: 0.9555, Val Acc: 0.7767
# Epoch 12, Train Loss: 0.1351, Train Acc: 0.9628, Val Acc: 0.7805
# Epoch 13, Train Loss: 0.1208, Train Acc: 0.9674, Val Acc: 0.7814
# Early stopping

# %%
epochs_cnn = len(train_accuracies)  # Number of epochs actually trained
plot_metrics(epochs_cnn, train_losses, train_accuracies, val_accuracies)

# %%
# Evaluate on the test set
test_acc = evaluate_model(best_model_CNN, test_loader)
test_accuracies['CNN'] = test_acc
print(f'Test Accuracy (CNN): {test_acc:.4f}')
# Out:
# Test Accuracy (CNN): 0.7917

# %% [markdown]
# ### (e) Describe your final improvement strategy in Part 3.5. Report the accuracy on the test set using your improved model.

# %% [markdown]
# ### Ensemble Methods

# %% [markdown]
# This setup aggregates the model predictions by averaging the class probabilities across each model, then assigns the final prediction based on the highest average probability. This approach should increase overall stability and potentially improve the test accuracy of your sentiment classification task by leveraging the diverse perspectives of different models.

# %%
def ensemble_predict(models, data_loader):
    all_probs = []

    # Collect prediction probabilities from each model
    for model in models:
        model.eval()  # Set to evaluation mode
        model_probs = []
        with torch.no_grad():
            for inputs, _ in data_loader:
                inputs = inputs.to(device)
                outputs = model(inputs)
                model_probs.append(torch.softmax(outputs, dim=1).cpu().numpy())
        all_probs.append(np.vstack(model_probs))

    # Average the probabilities across models
    avg_probs = np.mean(all_probs, axis=0)
    final_preds = np.argmax(avg_probs, axis=1)

    return final_preds

# %%
def compute_ensemble_accuracy(models, test_loader, test_labels):
    # Get ensemble predictions
    ensemble_preds = ensemble_predict(models, test_loader)

    # Calculate accuracy
    accuracy = np.mean(ensemble_preds == test_labels.cpu().numpy())
    print(f'Test Accuracy (Ensemble): {accuracy:.4f}')

    return accuracy

# %%
trained_models = [best_model_biLSTM, best_model_biGRU, best_model_RNN_max, best_model_OOV_update]

# Compute ensemble accuracy on the test set
test_acc = compute_ensemble_accuracy(trained_models, test_loader, test_labels)
test_accuracies['Ensemble'] = test_acc
# Out:
# Test Accuracy (Ensemble): 0.8227

# %% [markdown]
# From the test accuracies, we see that when employing **ensemble method with soft voting (probability averaging)** gives us a higher test accuracy compared to the test accuracies of each individual model.

# %% [markdown]
# ###  (f) Compare the results across different solutions above and describe your observations with possible discussions.

# %%
test_accuracies
# Out:
# {'RNN Last Hidden State': 0.4981238273921201,
#  'RNN Max Pooling': 0.7870544090056285,
#  'RNN Average Pooling': 0.6969981238273921,
#  'RNN (Update Word Embeddings)': 0.8095684803001876,
#  'RNN (Handle OOV)': 0.6538461538461539,
#  'RNN (Handle OOV with Word Embeddings Update)': 0.799249530956848,
#  'biLSTM': 0.7833020637898687,
#  'biGRU': 0.8039399624765479,
#  'CNN': 0.7917448405253283,
#  'Ensemble': 0.8227016885553471}
